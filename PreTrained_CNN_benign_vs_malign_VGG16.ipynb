# %% [markdown]
# <a href="https://colab.research.google.com/github/aleschiavo94/Convolutional-Neural-Network-for-Medical-Imaging-Analysis---Abnormality-detection-in-mammography/blob/main/PreTrained_CNN_benign_vs_malign_VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Project Setup

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import itertools
import numpy as np
import pandas as pd 
import ast #Abstract Syntax Trees
import os 
import gc # Garbage Collector

from tensorflow.keras import backend as K # Useful to free GPU and memory
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras import layers, optimizers, models, regularizers, metrics
from keras.models import load_model
#ROC-AUC 
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from keras.wrappers.scikit_learn import KerasClassifier

#print confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import itertools
import matplotlib.pyplot as plt

BATCH_SIZE = 20
EPOCHS = 100
IMAGE_HEIGHT = 150
IMAGE_WIDTH = 150

base_path = "/content/gdrive/My Drive/Colab_Notebooks/CIDL/DL Project"
PLOTS_PATH =  os.path.join(base_path, 'plots/Benign-Malign')
train_img_path = os.path.join(base_path, 'numpy data/train_tensor.npy')
train_label_path = os.path.join(base_path, 'numpy data/train_labels.npy')
test_img_path = os.path.join(base_path, 'numpy data/public_test_tensor.npy')
test_label_path = os.path.join(base_path, 'numpy data/public_test_labels.npy')

MODEL_PATH = os.path.join(base_path, "models/Benign-Malign")

# to produce final model report histogram 
AUC_values_1x = []
AUC_values_3x = []
AUC_values_5x = []
TPR_values = []
FPR_values = []
ACC_values_1x = []
ACC_values_3x = []
ACC_values_5x = []

# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
      gc.collect()

print("Done")
# Out:
# Done

# %% [markdown]
# ##1.1 Utility Functions

# %%
# ----------------------- Utility Functions -----------------------
def load_training():
  train_images = np.load(train_img_path)
  train_labels = np.load(train_label_path)
  test_images = np.load(test_img_path)
  test_labels = np.load(test_label_path)

  return train_images, train_labels, test_images, test_labels

# Remove baseline samples
def remove_baseline(tensor): 
  max_ind = int(len(tensor)/2)
  indexes = [2*i + 1 for i in range(0, max_ind)]

  return tensor[indexes]

# Interchange the dataset index
def shuffle_dataset(x, y):
  indices = tf.range(start=0, limit=tf.shape(x)[0], dtype=tf.int32)
  shuffled_indices = tf.random.shuffle(indices)

  x = tf.gather(x, shuffled_indices)
  y = tf.gather(y, shuffled_indices)

  x = x.numpy()
  y = y.numpy()

  return x, y

# split dataset into training and validation set 70-30
def split_train_val(dataset, labels):
  train_data_split = dataset[:int(0.7*len(dataset))]
  valid_data_split = dataset[int(0.7*len(dataset)):]
  train_labels_split = labels[:int(0.7*len(labels))]
  valid_labels_split = labels[int(0.7*len(labels)):]

  print(train_data_split.shape)
  print(valid_data_split.shape)
  print(train_labels_split.shape)
  print(valid_labels_split.shape)      

  return train_data_split, valid_data_split, train_labels_split, valid_labels_split

# Unify benign and malign cases 
def labels_mapping(labels):
  labels_local = np.zeros(shape=labels.shape, dtype="float32")
  idx = 0
  for label in labels:
    # benign
    if label == 1 or label == 3:
      labels_local[idx] = 0
    # malign
    else:
      labels_local[idx] = 1
    idx += 1

  return labels_local

print("Done")

def get_model_predictions(model, dataset, labels, sample_count): 
  predictions = np.zeros((sample_count,))   

  BATCH_SIZE = 1
  i = 0
  for batch, labels_batch in test_datagen.flow(dataset, labels, batch_size=BATCH_SIZE, shuffle=False):
    predictions[i * BATCH_SIZE : (i + 1) * BATCH_SIZE] = model.predict(batch)
    i += 1

    if i * BATCH_SIZE  >= sample_count:
      break

    #np.where(predictions < 0.5, 0, 1)
    #predictions = np.where(predictions < 0.5, 0, 1)

  return predictions


def get_model_pred_prob(model, dataset, labels, sample_count): 
  predictions = np.zeros((sample_count,))   

  BATCH_SIZE = 1
  i = 0
  for batch, labels_batch in test_datagen.flow(dataset, labels, batch_size=BATCH_SIZE, shuffle=False):
    predictions[i * BATCH_SIZE : (i + 1) * BATCH_SIZE] = model.predict_classes(batch)
    i += 1

    if i * BATCH_SIZE  >= sample_count:
      break

  return predictions

# Function to calculate True Positive Rate and False Positive Rate
def calc_TP_FP_rate(y_true, y_pred):    
    # Instantiate counters
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    # Determine whether each prediction is TP, FP, TN, or FN
    for i in range(len(y_true)): 
        if y_true[i]==y_pred[i]==1.:
           TP += 1
        if y_pred[i]==1. and y_true[i]!=y_pred[i]:
           FP += 1
        if y_true[i]==y_pred[i]==0.:
           TN += 1
        if y_pred[i]==0. and y_true[i]!=y_pred[i]:
           FN += 1
    
    print("TP: ", TP)
    print("FP: ", FP)
    print("TN: ", TN)
    print("FN: ", FN)
    
    #Precision = TP/(TP+FP)
      #Precision answers the following: How many of those who we labeled as diabetic are actually diabetic?
    precision = TP / (TP + FP)

    #Recall/Sensitivity/TPR = TP/(TP+FN)
        #Recall answers the following question: Of all the people who are diabetic, how many of those we correctly predict?
    tpr = TP / (TP + FN)

    #Specificity = TN/(TN+FP)
        #Specifity answers the following question: Of all the people who are healthy, how many of those did we correctly predict?
    specificity = TN / (TN + FP)

    #FPR  = 1 - Specificity =  FP/FP+TN
    fpr = FP / (FP + TN)

    return tpr, fpr, precision, specificity
# Out:
# Done

# %% [markdown]
# ##1.2 Visualization Functions

# %%
# Visualization Data Histogram
def plot_acc(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  return plt

def plot_loss(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt


def plot_confusion_matrix(model,
                          classes,
                          dataset, 
                          labels,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    Y_pred = model.predict(test_datagen.flow(dataset,
                                            labels,
                                            batch_size=21,
                                            shuffle=False),
                          steps=len(dataset) // BATCH_SIZE)

    np.where(Y_pred < 0.5, 0, 1)
    y_pred = np.where(Y_pred < 0.5, 0, 1)

    print('Confusion Matrix')
    cm = confusion_matrix(labels, y_pred)

    #print(cm)
    #print('Classification Report')
    print(classification_report(labels, y_pred))


    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    return plt

# Visualization Detail Metric
def plot_metrics(history):
  metrics = ['loss', 'auc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.plot(history.epoch, history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)

    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()
    if metrics[-1] != metric:
      plt.figure()

  return plt, cm

def plot_AUC(model, dataset, labels):
  y_pred_keras = get_model_predictions(model, dataset, labels, len(dataset))
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(labels, y_pred_keras)
  #thresholds_keras = np.linspace(0,1,num=100)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='CNN (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  #plt.show()

  return auc_keras, plt
print("Done")
# Out:
# Done

# %% [markdown]
# #2 Data Preparation

# %%
# Get images and labels (test, train)
train_images, train_labels, test_images, test_labels = load_training()

# Get abnormalities only 
train_images = remove_baseline(train_images)
train_labels = remove_baseline(train_labels)
test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)

# Suffle index (Previous dataset is ordered)
train_images, train_labels = shuffle_dataset(train_images, train_labels)

print("Train shape: ", train_images.shape)
print("Test shape: ", test_images.shape)

train_images = train_images.reshape(train_images.shape + (1,)) #(2676, 150, 150, 1)
test_images = test_images.reshape(test_images.shape + (1,)) #(2676, 150, 150, 1)
# Out:
# Train shape:  (2676, 150, 150)
# Test shape:  (336, 150, 150)

# %% [markdown]
# ##2.1 Data Visualization

# %%
from PIL import Image
from matplotlib.pyplot import figure, imshow, axis

def display_samples(abnormality_type):
  idx = 0
  counter = 0

  fig = figure(figsize=(20,4))
  while counter < 5:
    #benign masses 
    if test_labels[idx] == abnormality_type:
      img = test_images[idx]
      pil_img = tf.keras.preprocessing.image.array_to_img(img)
      a=fig.add_subplot(1, 5, counter+1)
      imshow(pil_img,cmap='Greys_r')
      axis('off')

      counter += 1
    idx += 1

# %%
#benign masses 
print("Benign Masses[first row] VS Malign Masses[second row]")
display_samples(1)

#benign calcifications
display_samples(2)
# Out:
# Benign Masses[first row] VS Malign Masses[second row]

# %%
print("Benign Calcifications[first row] VS Malign Calcifications[second row]")
display_samples(3)

display_samples(4)
# Out:
# Benign Calcifications[first row] VS Malign Calcifications[second row]

# %% [markdown]
# ##2.2 Data Preprocessing

# %%
#1: Mass, benign
#2: Mass, malignant
#3: Calcification, benign
#4: Calcification, malignant

#count #of masses and #of calcifications
unique, counts = np.unique(train_labels, return_counts=True)
#print(unique, counts)

print("Benign Masses samples: \t", counts[0])
print("Malign Masses samples: \t", counts[1])
print("Benign Calc samples: \t", counts[2])
print("Malign Calc samples: \t", counts[3])
# Out:
# Benign Masses samples: 	 620
# Malign Masses samples: 	 598
# Benign Calc samples: 	 948
# Malign Calc samples: 	 510

# %%
train_labels = labels_mapping(train_labels)
test_labels = labels_mapping(test_labels)

#check if training dataset is balanced  
unique, counts = np.unique(train_labels, return_counts=True)
print("Benign samples: ", counts[0])
print("Malign samples: ", counts[1])
print()

#train_images = train_images.reshape(train_images.shape + (1,)) #(2676, 150, 150, 1)
#test_images = test_images.reshape(test_images.shape + (1,)) #(2676, 150, 150, 1)
print(train_images.shape)
print(test_images.shape)
# Out:
# Benign samples:  1568
# Malign samples:  1108
#
# (2676, 150, 150, 1)
# (336, 150, 150, 1)

# %%
# split dataset into training and validation set 70-30
train_images_split, valid_images_split, train_labels_split, valid_labels_split = split_train_val(train_images, train_labels)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)

# %% [markdown]
# ##2.3 Global Contrast Normalization

# %%
#Global Contrast Normalization 
import numpy
import scipy
import scipy.misc
from PIL import Image

def global_contrast_normalization(X):
    X_average = numpy.mean(X)
    #print('Mean: ', X_average)
    X = X - X_average
    return X

#nomalize image
norm_image = global_contrast_normalization(train_images[200])

original_image = tf.keras.preprocessing.image.array_to_img(train_images[200])
norm_image = tf.keras.preprocessing.image.array_to_img(norm_image)

#display images 
fig = figure(figsize=(10,5))
a=fig.add_subplot(1, 2, 1)
imshow(original_image,cmap='Greys_r')
a=fig.add_subplot(1, 2, 2)
imshow(norm_image,cmap='Greys_r')

# %%
import numpy
import scipy
import scipy.misc
from PIL import Image


def global_contrast_normalization(X, s, lmda, epsilon):

    # replacement for the loop
    X_average = numpy.mean(X)
    #print('Mean: ', X_average)
    X = X - X_average

    # `su` is here the mean, instead of the sum
    contrast = numpy.sqrt(lmda + numpy.mean(X**2))

    X = s * X / max(contrast, epsilon)
    return X


#nomalize image
norm_image = global_contrast_normalization(train_images[200], 1, 10, 0.000000001)

original_image = tf.keras.preprocessing.image.array_to_img(train_images[200])
norm_image = tf.keras.preprocessing.image.array_to_img(norm_image)

#display images 
fig = figure(figsize=(10,5))
a=fig.add_subplot(1, 2, 1)
imshow(original_image,cmap='Greys_r')
a=fig.add_subplot(1, 2, 2)
imshow(norm_image,cmap='Greys_r')

# %% [markdown]
# ##2.4 Data Augmentation

# %%
# Train data augmentation 
train_datagen = ImageDataGenerator(
    rescale=1./65535,
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=20,
    zoom_range=(0.5,1.5),
    horizontal_flip=True,
    fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale=1./65535)
test_datagen = ImageDataGenerator(rescale=1./65535) 

print("Done")
# Out:
# Done

# %% [markdown]
# ##2.5 All-in-one Data Preparation Function

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#all-in-one data loading & preprocessing function 
def init_data(base_NN, GCN=True, augmentation=True):
  # Get images and labels (test, train)
  train_images, train_labels, test_images, test_labels = load_training()

  # Get abnormalities only 
  train_images = remove_baseline(train_images)
  train_labels = remove_baseline(train_labels)
  test_images = remove_baseline(test_images)
  test_labels = remove_baseline(test_labels)

  # Suffle index (Previous dataset is ordered)
  train_images, train_labels = shuffle_dataset(train_images, train_labels)

  #print("Train shape: ", train_images.shape)
  #print("Test shape: ", test_images.shape)

  #1: Mass, benign
  #2: Mass, malignant
  #3: Calcification, benign
  #4: Calcification, malignant

  #count #of masses and #of calcifications
  #unique, counts = np.unique(train_labels, return_counts=True)
  #print(unique, counts)

  #print("Benign Masses samples: \t", counts[0])
  #print("Malign Masses samples: \t", counts[1])
  #print("Benign Calc samples: \t", counts[2])
  #print("Malign Calc samples: \t", counts[3])

  #labels remapping
  train_labels = labels_mapping(train_labels)
  test_labels = labels_mapping(test_labels)

  #tensors reshaping for models training 
  train_images = train_images.reshape(train_images.shape + (1,)) #(2676, 150, 150, 1)
  test_images = test_images.reshape(test_images.shape + (1,)) #(2676, 150, 150, 1)
  #print(train_images.shape)
  #print(test_images.shape)

  # split dataset into training and validation set 70-30
  train_images_split, valid_images_split, train_labels_split, valid_labels_split = split_train_val(train_images, train_labels)  

  # All images will be rescaled by 1./65535
  if  base_NN == "VGG16":
    from tensorflow.keras.applications.vgg16 import preprocess_input
  if base_NN == "ResNet50":
    from tensorflow.keras.applications.resnet import preprocess_input
  #if Inception no preprocess function 
  if base_NN == "InceptionV3":
    train_datagen = ImageDataGenerator(rescale=1./65535)
    valid_datagen = ImageDataGenerator(rescale=1./65535)
    test_datagen = ImageDataGenerator(rescale=1./65535) 

  if "InceptionV3" not in base_NN:
    train_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    valid_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    test_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input) 

  if GCN:
    train_images_split_gcn = np.zeros(train_images_split.shape)  
    train_labels_split_gcn = np.zeros(train_labels_split.shape)
    valid_images_split_gcn = np.zeros(valid_images_split.shape)
    valid_labels_split_gcn = np.zeros(valid_labels_split.shape)
    train_datagen = ImageDataGenerator()
    valid_datagen = ImageDataGenerator()
    #global contrast normalization 
    counter = 0
    for image, label in train_datagen.flow(train_images_split, train_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image, 1, 10, 0.000000001)
      train_images_split_gcn[counter] = norm_image
      train_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(train_images_split):
        break
    
    counter = 0
    for image, label in valid_datagen.flow(valid_images_split, valid_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image, 1, 10, 0.000000001)
      valid_images_split_gcn[counter] = norm_image
      valid_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(valid_images_split):
        break
    if base_NN == "InceptionV3":  
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn))
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn))     
    else:
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn), preprocessing_function=preprocess_input)
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn), preprocessing_function=preprocess_input)      

  if GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  if not GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  print("Done")
  if GCN:
    #reshape to expand grayscale to rgb
    train_images_split_gcn = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split_gcn = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split_gcn, valid_images_split_gcn, train_labels_split_gcn, valid_labels_split_gcn, train_datagen, valid_datagen, test_datagen
  else:
    #reshape to expand grayscale to rgb
    train_images_split = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen

# %% [markdown]
# # 3.VGG16: Flatten() + 1x Dense(256)

# %%
INPUT_SHAPE = (150, 150, 3)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20

# %%
METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# %% [markdown]
# ##3.1.1 0-Fine-Tuning Strategy With Data Augmentation

# %%
INPUT_SHAPE = (150, 150, 1)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20

# %%
METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_0FT_DA_1x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 21s 137ms/step - loss: 0.8759 - acc: 0.5468 - val_loss: 0.6307 - val_acc: 0.5825
# Epoch 2/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6664 - acc: 0.5921 - val_loss: 0.6798 - val_acc: 0.5863
# Epoch 3/100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.6584 - acc: 0.6140 - val_loss: 0.5870 - val_acc: 0.6850
# Epoch 4/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6300 - acc: 0.6001 - val_loss: 0.5870 - val_acc: 0.6500
# Epoch 5/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6288 - acc: 0.6205 - val_loss: 0.6294 - val_acc: 0.6150
# Epoch 6/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6378 - acc: 0.6147 - val_loss: 0.5727 - val_acc: 0.7063
# Epoch 7/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6304 - acc: 0.6267 - val_loss: 0.6197 - val_acc: 0.6237
# Epoch 8/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6192 - acc: 0.6354 - val_loss: 0.5735 - val_acc: 0.6762
# Epoch 9/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6260 - acc: 0.6177 - val_loss: 0.5710 - val_acc: 0.7000
# Epoch 10/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6194 - acc: 0.6345 - val_loss: 0.5689 - val_acc: 0.6963
# Epoch 11/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6294 - acc: 0.6239 - val_loss: 0.5676 - val_acc: 0.6925
# Epoch 12/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6227 - acc: 0.6345 - val_loss: 0.5727 - val_acc: 0.6837
# Epoch 13/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.5943 - acc: 0.6583 - val_loss: 0.5776 - val_acc: 0.6812
# Epoch 14/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6423 - acc: 0.6193 - val_loss: 0.5834 - val_acc: 0.6625
# Epoch 15/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6386 - acc: 0.6284 - val_loss: 0.5716 - val_acc: 0.6900
# Epoch 16/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6003 - acc: 0.6428 - val_loss: 0.5817 - val_acc: 0.6625
# Epoch 17/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.
100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6051 - acc: 0.6572 - val_loss: 0.6226 - val_acc: 0.6263
# Epoch 51/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.5978 - acc: 0.6459 - val_loss: 0.6215 - val_acc: 0.6325
# Epoch 52/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6072 - acc: 0.6364 - val_loss: 0.5567 - val_acc: 0.7025
# Epoch 53/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5991 - acc: 0.6642 - val_loss: 0.5705 - val_acc: 0.6837
# Epoch 54/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.5984 - acc: 0.6741 - val_loss: 0.5801 - val_acc: 0.6737
# Epoch 55/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6168 - acc: 0.6451 - val_loss: 0.5574 - val_acc: 0.7038
# Epoch 56/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6193 - acc: 0.6320 - val_loss: 0.5659 - val_acc: 0.6925
# Epoch 57/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6052 - acc: 0.6562 - val_loss: 0.5589 - val_acc: 0.6900
# Epoch 58/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5989 - acc: 0.6568 - val_loss: 0.5640 - val_acc: 0.6888
# Epoch 59/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6003 - acc: 0.6598 - val_loss: 0.5933 - val_acc: 0.6275
# Epoch 60/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.5970 - acc: 0.6557 - val_loss: 0.5574 - val_acc: 0.6950
# Epoch 61/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6124 - acc: 0.6500 - val_loss: 0.5576 - val_acc: 0.6950
# Epoch 62/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5988 - acc: 0.6687 - val_loss: 0.5858 - val_acc: 0.6400
# Epoch 63/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6004 - acc: 0.6515 - val_loss: 0.5597 - val_acc: 0.7013
# Epoch 64/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5914 - acc: 0.6739 - val_loss: 0.5917 - val_acc: 0.6388

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_1x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 59ms/step - loss: 0.6100 - acc: 0.6438
#
# ---------------------------------
# Accuracy: 64.38 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.68      0.71       219
#          1.0       0.48      0.55      0.51       117
#
#     accuracy                           0.64       336
#    macro avg       0.61      0.62      0.61       336
# weighted avg       0.65      0.64      0.64       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_1x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  64
# FP:  69
# TN:  150
# FN:  53
#
# TPR(Recall): 		 0.547
# FPR: 			 0.3151
#
# Precision: 		 0.4812
# TNR(Specificity): 	 0.6849

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ##3.2.1 1-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_1FT_DA_1x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last convolutional block 
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block5_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 138ms/step - loss: 0.8901 - acc: 0.5769 - val_loss: 0.6093 - val_acc: 0.6413
# Epoch 2/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6541 - acc: 0.5965 - val_loss: 0.5970 - val_acc: 0.6475
# Epoch 3/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6446 - acc: 0.6209 - val_loss: 0.6084 - val_acc: 0.6288
# Epoch 4/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6399 - acc: 0.6033 - val_loss: 0.6166 - val_acc: 0.6288
# Epoch 5/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6170 - acc: 0.6399 - val_loss: 0.5918 - val_acc: 0.6550
# Epoch 6/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6263 - acc: 0.6419 - val_loss: 0.5991 - val_acc: 0.6338
# Epoch 7/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6261 - acc: 0.6345 - val_loss: 0.5975 - val_acc: 0.6400
# Epoch 8/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6114 - acc: 0.6498 - val_loss: 0.5938 - val_acc: 0.6488
# Epoch 9/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6320 - acc: 0.6288 - val_loss: 0.5955 - val_acc: 0.6438
# Epoch 10/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6133 - acc: 0.6557 - val_loss: 0.5885 - val_acc: 0.6637
# Epoch 11/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6382 - acc: 0.6195 - val_loss: 0.6028 - val_acc: 0.6325
# Epoch 12/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6082 - acc: 0.6485 - val_loss: 0.6670 - val_acc: 0.6150
# Epoch 13/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6338 - acc: 0.6221 - val_loss: 0.6648 - val_acc: 0.6175
# Epoch 14/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.
100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.5368 - acc: 0.6899 - val_loss: 0.5693 - val_acc: 0.7038

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_1x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 61ms/step - loss: 0.6081 - acc: 0.6219
#
# ---------------------------------
# Accuracy: 62.19 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.63      0.68       219
#          1.0       0.46      0.58      0.51       117
#
#     accuracy                           0.61       336
#    macro avg       0.60      0.61      0.60       336
# weighted avg       0.64      0.61      0.62       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_1x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  68
# FP:  81
# TN:  138
# FN:  49
#
# TPR(Recall): 		 0.5812
# FPR: 			 0.3699
#
# Precision: 		 0.4564
# TNR(Specificity): 	 0.6301

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.3.1 2-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_2FT_1x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last 2 convolutional blocks
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block4_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.8021 - acc: 0.5726 - val_loss: 0.7245 - val_acc: 0.5888
# Epoch 2/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6350 - acc: 0.6374 - val_loss: 0.6550 - val_acc: 0.6125
# Epoch 3/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6629 - acc: 0.6144 - val_loss: 0.6239 - val_acc: 0.6137
# Epoch 4/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6245 - acc: 0.6225 - val_loss: 0.6125 - val_acc: 0.6400
# Epoch 5/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6173 - acc: 0.6415 - val_loss: 0.6997 - val_acc: 0.6150
# Epoch 6/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6377 - acc: 0.6321 - val_loss: 0.6489 - val_acc: 0.6162
# Epoch 7/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6350 - acc: 0.6262 - val_loss: 0.6006 - val_acc: 0.6562
# Epoch 8/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6328 - acc: 0.6066 - val_loss: 0.6426 - val_acc: 0.6250
# Epoch 9/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6250 - acc: 0.6337 - val_loss: 0.6045 - val_acc: 0.6513
# Epoch 10/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6068 - acc: 0.6527 - val_loss: 0.5924 - val_acc: 0.6587
# Epoch 11/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6207 - acc: 0.6413 - val_loss: 0.5936 - val_acc: 0.6513
# Epoch 12/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6335 - acc: 0.6400 - val_loss: 0.6146 - val_acc: 0.6413
# Epoch 13/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6186 - acc: 0.6604 - val_loss: 0.6235 - val_acc: 0.6438
# Epoch 14/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6146 - acc: 0.6447 - val_loss: 0.6421 - val_acc: 0.6313
# Epoch 15/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6104 - acc: 0.6560 - val_loss: 0.5911 - val_acc: 0.6538
# Epoch 16/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6257 - acc: 0.6367 - val_loss: 0.5967 - val_acc: 0.6538
# Epoch 17/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6218 - acc: 0.6259 - val_loss: 0.5999 - val_acc: 0.6475
# Epoch 18/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6349 - acc: 0.6172 - val_loss: 0.5963 - val_acc: 0.6575
# Epoch 19/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6105 - acc: 0.6448 - val_loss: 0.6365 - val_acc: 0.6288
# Epoch 20/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6302 - acc: 0.6198 - val_loss: 0.5987 - val_acc: 0.6488
# Epoch 21/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.5980 - acc: 0.6637 - val_loss: 0.5935 - val_acc: 0.6562
# Epoch 22/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6219 - acc: 0.6443 - val_loss: 0.7410 - val_acc: 0.6025
# Epoch 23/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6341 - acc: 0.6300 - val_loss: 0.6059 - val_acc: 0.6400
# Epoch 24/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6171 - acc: 0.6451 - val_loss: 0.5886 - val_acc: 0.6675
# Epoch 25/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.5916 - acc: 0.6794 - val_loss: 0.6232 - val_acc: 0.6400
# Epoch 26/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.5853 - acc: 0.6736 - val_loss: 0.6230 - val_acc: 0.6375
# Epoch 27/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6155 - acc: 0.6396 - val_loss: 0.5891 - val_acc: 0.6612
# Epoch 28/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.
100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5593 - acc: 0.6911 - val_loss: 0.5332 - val_acc: 0.7350
# Epoch 57/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5274 - acc: 0.7155 - val_loss: 0.5258 - val_acc: 0.7262
# Epoch 58/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5213 - acc: 0.7193 - val_loss: 0.6061 - val_acc: 0.7212
# Epoch 59/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5137 - acc: 0.7281 - val_loss: 0.5416 - val_acc: 0.7088
# Epoch 60/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5283 - acc: 0.7067 - val_loss: 0.5301 - val_acc: 0.7375
# Epoch 61/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5162 - acc: 0.7256 - val_loss: 0.5068 - val_acc: 0.7287
# Epoch 62/100
# 93/93 [==============================] - 14s 155ms/step - loss: 0.4948 - acc: 0.7476 - val_loss: 0.5491 - val_acc: 0.7163
# Epoch 63/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5104 - acc: 0.7251 - val_loss: 0.5277 - val_acc: 0.7337
# Epoch 64/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5037 - acc: 0.7305 - val_loss: 0.5327 - val_acc: 0.7312
# Epoch 65/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5110 - acc: 0.7258 - val_loss: 0.5487 - val_acc: 0.7312
# Epoch 66/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5129 - acc: 0.7204 - val_loss: 0.6082 - val_acc: 0.7225
# Epoch 67/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5193 - acc: 0.7202 - val_loss: 0.6918 - val_acc: 0.7262
# Epoch 68/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5051 - acc: 0.7230 - val_loss: 0.5810 - val_acc: 0.7225
# Epoch 69/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5188 - acc: 0.7194 - val_loss: 0.6050 - val_acc: 0.7275
# Epoch 70/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.4930 - acc: 0.7398 - val_loss: 0.5541 - val_acc: 0.7387
# Epoch 71/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5099 - acc: 0.7336 - val_loss: 0.5825 - val_acc: 0.7275
# Epoch 72/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5093 - acc: 0.7338 - val_loss: 0.5225 - val_acc: 0.7450
# Epoch 73/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.4942 - acc: 0.7340 - val_loss: 0.5385 - val_acc: 0.7150
# Epoch 74/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5109 - acc: 0.7533 - val_loss: 0.5186 - val_acc: 0.7375
# Epoch 75/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5049 - acc: 0.7282 - val_loss: 0.5563 - val_acc: 0.7500
# Epoch 76/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.4956 - acc: 0.7446 - val_loss: 0.5993 - val_acc: 0.7400
# Epoch 77/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5080 - acc: 0.7127 - val_loss: 0.5451 - val_acc: 0.7550
# Epoch 78/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5130 - acc: 0.7344 - val_loss: 0.6665 - val_acc: 0.7237
# Epoch 79/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.5197 - acc: 0.7319 - val_loss: 0.5680 - val_acc: 0.7063
# Epoch 80/100
# 93/93 [==============================] - 14s 152ms/step - loss: 0.5123 - acc: 0.7265 - val_loss: 0.5676 - val_acc: 0.7312
# Epoch 81/100
# 93/93 [==============================] - 14s 153ms/step - loss: 0.4889 - acc: 0.7350 - val_loss: 0.5834 - val_acc: 0.7287

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_1x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 59ms/step - loss: 0.5820 - acc: 0.7125
#
# ---------------------------------
# Accuracy: 71.25 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.75      0.77       219
#          1.0       0.58      0.64      0.61       117
#
#     accuracy                           0.71       336
#    macro avg       0.69      0.70      0.69       336
# weighted avg       0.72      0.71      0.72       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_1x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  75
# FP:  54
# TN:  165
# FN:  42
#
# TPR(Recall): 		 0.641
# FPR: 			 0.2466
#
# Precision: 		 0.5814
# TNR(Specificity): 	 0.7534

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.4.2 3-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_3FT_DA_1x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last 3 convolutional blocks
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block3_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 137ms/step - loss: 0.8357 - acc: 0.6305 - val_loss: 0.7203 - val_acc: 0.5763
# Epoch 2/100
# 93/93 [==============================] - 13s 136ms/step - loss: 0.
100
# 93/93 [==============================] - 15s 164ms/step - loss: 0.4815 - acc: 0.7437 - val_loss: 0.5555 - val_acc: 0.7250
# Epoch 58/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.5125 - acc: 0.7323 - val_loss: 0.5553 - val_acc: 0.7300
# Epoch 59/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.5054 - acc: 0.7317 - val_loss: 0.5651 - val_acc: 0.7487
# Epoch 60/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.4946 - acc: 0.7375 - val_loss: 0.5368 - val_acc: 0.7550
# Epoch 61/100
# 93/93 [==============================] - 16s 167ms/step - loss: 0.5299 - acc: 0.7284 - val_loss: 0.5286 - val_acc: 0.7638
# Epoch 62/100
# 93/93 [==============================] - 16s 167ms/step - loss: 0.4957 - acc: 0.7474 - val_loss: 0.6443 - val_acc: 0.7337
# Epoch 63/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.5109 - acc: 0.7235 - val_loss: 0.5516 - val_acc: 0.7487
# Epoch 64/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.4749 - acc: 0.7576 - val_loss: 0.5651 - val_acc: 0.7362
# Epoch 65/100
# 93/93 [==============================] - 15s 164ms/step - loss: 0.4879 - acc: 0.7476 - val_loss: 0.5828 - val_acc: 0.7262
# Epoch 66/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.4874 - acc: 0.7446 - val_loss: 0.6156 - val_acc: 0.7362
# Epoch 67/100
# 93/93 [==============================] - 15s 164ms/step - loss: 0.4882 - acc: 0.7436 - val_loss: 0.6215 - val_acc: 0.7275
# Epoch 68/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.4700 - acc: 0.7556 - val_loss: 0.5879 - val_acc: 0.7375
# Epoch 69/100
# 93/93 [==============================] - 15s 163ms/step - loss: 0.4819 - acc: 0.7400 - val_loss: 0.5502 - val_acc: 0.7475

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_1x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 60ms/step - loss: 0.5871 - acc: 0.7031
#
# ---------------------------------
# Accuracy: 70.31 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.75      0.76       219
#          1.0       0.56      0.60      0.58       117
#
#     accuracy                           0.70       336
#    macro avg       0.67      0.67      0.67       336
# weighted avg       0.70      0.70      0.70       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_1x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  70
# FP:  55
# TN:  164
# FN:  47
#
# TPR(Recall): 		 0.5983
# FPR: 			 0.2511
#
# Precision: 		 0.56
# TNR(Specificity): 	 0.7489

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.5.1 All-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_ALLFT_DA_1x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=30,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze all convolutional blocks
for layer in model.layers:
    layer.trainable = True 


model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 93/93 [==============================] - 13s 136ms/step - loss: 0.9883 - acc: 0.5905 - val_loss: 0.6334 - val_acc: 0.6125
# Epoch 2/30
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6491 - acc: 0.5941 - val_loss: 0.6626 - val_acc: 0.5525
# Epoch 3/30
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6563 - acc: 0.5685 - val_loss: 0.6122 - val_acc: 0.6600
# Epoch 4/30
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6344 - acc: 0.6260 - val_loss: 0.6677 - val_acc: 0.6075
# Epoch 5/30
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6419 - acc: 0.6134 - val_loss: 0.6729 - val_acc: 0.5913
# Epoch 6/30
# 93/93 [==============================] - 13s 134ms/step - loss: 0.6286 - acc: 0.6420 - val_loss: 0.6072 - val_acc: 0.6525
# Epoch 7/30
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6253 - acc: 0.6265 - val_loss: 0.6934 - val_acc: 0.6037
# Epoch 8/30
# 93/93 [==============================] - 13s 137ms/step - loss: 0.6463 - acc: 0.6139 - val_loss: 0.6058 - val_acc: 0.6587
# Epoch 9/30
# 93/93 [==============================] - 13s 136ms/step - loss: 0.6048 - acc: 0.6459 - val_loss: 0.6051 - val_acc: 0.6475
# Epoch 10/30
# 93/93 [==============================] - 13s 138ms/step - loss: 0.6297 - acc: 0.6192 - val_loss: 0.6284 - val_acc: 0.6288
# Epoch 11/30
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5943 - acc: 0.6703 - val_loss: 0.6508 - val_acc: 0.6263
# Epoch 12/30
# 93/93 [==============================] - 13s 135ms/step - loss: 0.6351 - acc: 0.6219 - val_loss: 0.6037 - val_acc: 0.6525
# Epoch 13/30
# 93/93 [==============================] - 13s 136ms/step - loss: 0.
100
# 93/93 [==============================] - 18s 198ms/step - loss: 0.4911 - acc: 0.7325 - val_loss: 0.5452 - val_acc: 0.7450
# Epoch 44/100
# 93/93 [==============================] - 19s 199ms/step - loss: 0.4954 - acc: 0.7452 - val_loss: 0.5519 - val_acc: 0.7337
# Epoch 45/100
# 93/93 [==============================] - 19s 198ms/step - loss: 0.5325 - acc: 0.7060 - val_loss: 0.5582 - val_acc: 0.7412
# Epoch 46/100
# 93/93 [==============================] - 19s 199ms/step - loss: 0.5070 - acc: 0.7264 - val_loss: 0.5620 - val_acc: 0.7300
# Epoch 47/100
# 93/93 [==============================] - 18s 197ms/step - loss: 0.4927 - acc: 0.7414 - val_loss: 0.5465 - val_acc: 0.7325
# Epoch 48/100
# 93/93 [==============================] - 18s 198ms/step - loss: 0.4982 - acc: 0.7364 - val_loss: 0.6068 - val_acc: 0.6850
# Epoch 49/100
# 93/93 [==============================] - 18s 197ms/step - loss: 0.5277 - acc: 0.7170 - val_loss: 0.5270 - val_acc: 0.7450
# Epoch 50/100
# 93/93 [==============================] - 18s 197ms/step - loss: 0.4996 - acc: 0.7258 - val_loss: 0.5315 - val_acc: 0.7375
# Epoch 51/100
# 93/93 [==============================] - 18s 197ms/step - loss: 0.4911 - acc: 0.7669 - val_loss: 0.5806 - val_acc: 0.7250
# Epoch 52/100
# 93/93 [==============================] - 18s 197ms/step - loss: 0.5123 - acc: 0.7234 - val_loss: 0.5352 - val_acc: 0.7550
# Epoch 53/100
# 93/93 [==============================] - 18s 198ms/step - loss: 0.4824 - acc: 0.7523 - val_loss: 0.5262 - val_acc: 0.7450
# Epoch 54/100
# 93/93 [==============================] - 19s 199ms/step - loss: 0.4749 - acc: 0.7466 - val_loss: 0.5499 - val_acc: 0.7387
# Epoch 55/100
# 93/93 [==============================] - 18s 198ms/step - loss: 0.4766 - acc: 0.7602 - val_loss: 0.5483 - val_acc: 0.7487

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_1x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 60ms/step - loss: 0.5721 - acc: 0.6562
#
# ---------------------------------
# Accuracy: 65.62 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.63      0.70       219
#          1.0       0.49      0.67      0.57       117
#
#     accuracy                           0.65       336
#    macro avg       0.64      0.65      0.63       336
# weighted avg       0.68      0.65      0.65       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_1x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  78
# FP:  80
# TN:  139
# FN:  39
#
# TPR(Recall): 		 0.6667
# FPR: 			 0.3653
#
# Precision: 		 0.4937
# TNR(Specificity): 	 0.6347

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# # 4.VGG16: Flatten() + 3x [Dropout(0.5), Dense(256)]

# %%
INPUT_SHAPE = (150, 150, 3)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20

# %%
METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# %% [markdown]
# ##3.1.1 0-Fine-Tuning Strategy With Data Augmentation

# %%
INPUT_SHAPE = (150, 150, 1)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20

# %%
METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_0FT_DA_3x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 93/93 [==============================] - 19s 129ms/step - loss: 0.8173 - acc: 0.5435 - val_loss: 0.6750 - val_acc: 0.5763
# Epoch 2/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.7043 - acc: 0.5608 - val_loss: 0.6764 - val_acc: 0.5763
# Epoch 3/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6764 - acc: 0.6024 - val_loss: 0.6777 - val_acc: 0.5763
# Epoch 4/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6869 - acc: 0.5951 - val_loss: 0.6630 - val_acc: 0.6700
# Epoch 5/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.6785 - acc: 0.5730 - val_loss: 0.6453 - val_acc: 0.5763
# Epoch 6/100
# 93/93 [==============================] - 11s 124ms/step - loss: 0.6735 - acc: 0.5819 - val_loss: 0.6443 - val_acc: 0.5763
# Epoch 7/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.6560 - acc: 0.6024 - val_loss: 0.6370 - val_acc: 0.5763
# Epoch 8/100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.6642 - acc: 0.5785 - val_loss: 0.6319 - val_acc: 0.5813
# Epoch 9/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6656 - acc: 0.5908 - val_loss: 0.6428 - val_acc: 0.5763
# Epoch 10/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6571 - acc: 0.5944 - val_loss: 0.6485 - val_acc: 0.5763
# Epoch 11/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6655 - acc: 0.5930 - val_loss: 0.6352 - val_acc: 0.5763
# Epoch 12/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6692 - acc: 0.5911 - val_loss: 0.6348 - val_acc: 0.5763
# Epoch 13/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6620 - acc: 0.5970 - val_loss: 0.6410 - val_acc: 0.5763
# Epoch 14/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6523 - acc: 0.5894 - val_loss: 0.6459 - val_acc: 0.5763
# Epoch 15/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6540 - acc: 0.5869 - val_loss: 0.6259 - val_acc: 0.5763
# Epoch 16/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6538 - acc: 0.5830 - val_loss: 0.6337 - val_acc: 0.5763
# Epoch 17/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.6666 - acc: 0.5838 - val_loss: 0.6390 - val_acc: 0.5763
# Epoch 18/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6518 - acc: 0.5944 - val_loss: 0.6285 - val_acc: 0.5763
# Epoch 19/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6579 - acc: 0.5858 - val_loss: 0.6286 - val_acc: 0.5763
# Epoch 20/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6606 - acc: 0.5787 - val_loss: 0.6344 - val_acc: 0.5763
# Epoch 21/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6635 - acc: 0.6078 - val_loss: 0.6428 - val_acc: 0.5763
# Epoch 22/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6429 - acc: 0.5830 - val_loss: 0.6253 - val_acc: 0.5763
# Epoch 23/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.6654 - acc: 0.5782 - val_loss: 0.6234 - val_acc: 0.5763
# Epoch 24/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6504 - acc: 0.5896 - val_loss: 0.6259 - val_acc: 0.5763
# Epoch 25/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6478 - acc: 0.6048 - val_loss: 0.6247 - val_acc: 0.5763
# Epoch 26/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6522 - acc: 0.6006 - val_loss: 0.6237 - val_acc: 0.5763
# Epoch 27/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6484 - acc: 0.5884 - val_loss: 0.6291 - val_acc: 0.5763
# Epoch 28/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.
%
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.84      0.77       219
#          1.0       0.53      0.33      0.41       117
#
#     accuracy                           0.66       336
#    macro avg       0.61      0.59      0.59       336
# weighted avg       0.64      0.66      0.64       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_3x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  39
# FP:  35
# TN:  184
# FN:  78
#
# TPR(Recall): 		 0.3333
# FPR: 			 0.1598
#
# Precision: 		 0.527
# TNR(Specificity): 	 0.8402

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ##3.2.1 1-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_1FT_DA_3x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last convolutional block 
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block5_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,943,937
# Trainable params: 2,229,249
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 12s 123ms/step - loss: 0.8076 - acc: 0.5730 - val_loss: 0.6748 - val_acc: 0.5813
# Epoch 2/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.7019 - acc: 0.5420 - val_loss: 0.6739 - val_acc: 0.5813
# Epoch 3/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6812 - acc: 0.5656 - val_loss: 0.6734 - val_acc: 0.5813
# Epoch 4/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6802 - acc: 0.5706 - val_loss: 0.6618 - val_acc: 0.5813
# Epoch 5/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6758 - acc: 0.5890 - val_loss: 0.6418 - val_acc: 0.5813
# Epoch 6/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6617 - acc: 0.5985 - val_loss: 0.6443 - val_acc: 0.5813
# Epoch 7/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6651 - acc: 0.5920 - val_loss: 0.6641 - val_acc: 0.5813
# Epoch 8/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6729 - acc: 0.5809 - val_loss: 0.6506 - val_acc: 0.5813
# Epoch 9/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6737 - acc: 0.5775 - val_loss: 0.6492 - val_acc: 0.5813
# Epoch 10/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6697 - acc: 0.5729 - val_loss: 0.6597 - val_acc: 0.5813
# Epoch 11/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6664 - acc: 0.5896 - val_loss: 0.6571 - val_acc: 0.5813
# Epoch 12/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6639 - acc: 0.5996 - val_loss: 0.6463 - val_acc: 0.5813
# Epoch 13/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6704 - acc: 0.5889 - val_loss: 0.6333 - val_acc: 0.5800
# Epoch 14/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6609 - acc: 0.5801 - val_loss: 0.6312 - val_acc: 0.5800
# Epoch 15/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6932 - acc: 0.5910 - val_loss: 0.6368 - val_acc: 0.5838
# Epoch 16/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6739 - acc: 0.5710 - val_loss: 0.6337 - val_acc: 0.5850
# Epoch 17/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6636 - acc: 0.5906 - val_loss: 0.6394 - val_acc: 0.5813
# Epoch 18/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6602 - acc: 0.5916 - val_loss: 0.6399 - val_acc: 0.5813
# Epoch 19/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6613 - acc: 0.5926 - val_loss: 0.6301 - val_acc: 0.5813
# Epoch 20/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6856 - acc: 0.5758 - val_loss: 0.6431 - val_acc: 0.5813
# Epoch 21/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6644 - acc: 0.5840 - val_loss: 0.6267 - val_acc: 0.5813
# Epoch 22/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6594 - acc: 0.5882 - val_loss: 0.6370 - val_acc: 0.5800
# Epoch 23/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6435 - acc: 0.6007 - val_loss: 0.6372 - val_acc: 0.5800
# Epoch 24/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6610 - acc: 0.5694 - val_loss: 0.6396 - val_acc: 0.5925
# Epoch 25/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6584 - acc: 0.5888 - val_loss: 0.6201 - val_acc: 0.5913
# Epoch 26/100
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6602 - acc: 0.5734 - val_loss: 0.6172 - val_acc: 0.5800
# Epoch 27/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6578 - acc: 0.5989 - val_loss: 0.6280 - val_acc: 0.5925
# Epoch 28/100
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6544 - acc: 0.5885 - val_loss: 0.6174 - val_acc: 0.5813
# Epoch 29/100
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6464 - acc: 0.5874 - val_loss: 0.6366 - val_acc: 0.5813
# Epoch 30/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.
100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5950 - acc: 0.6358 - val_loss: 0.5628 - val_acc: 0.6712
# Epoch 87/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.5846 - acc: 0.6415 - val_loss: 0.5664 - val_acc: 0.6800
# Epoch 88/100
# 93/93 [==============================] - 12s 126ms/step - loss: 0.5770 - acc: 0.6417 - val_loss: 0.5659 - val_acc: 0.6800
# Epoch 89/100
# 93/93 [==============================] - 12s 124ms/step - loss: 0.5967 - acc: 0.6325 - val_loss: 0.5939 - val_acc: 0.6612
# Epoch 90/100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5658 - acc: 0.6702 - val_loss: 0.5674 - val_acc: 0.6850

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_3x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5947 - acc: 0.6344
#
# ---------------------------------
# Accuracy: 63.44 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.68      0.70       219
#          1.0       0.46      0.51      0.49       117
#
#     accuracy                           0.62       336
#    macro avg       0.59      0.60      0.59       336
# weighted avg       0.63      0.62      0.63       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_3x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  60
# FP:  70
# TN:  149
# FN:  57
#
# TPR(Recall): 		 0.5128
# FPR: 			 0.3196
#
# Precision: 		 0.4615
# TNR(Specificity): 	 0.6804

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.3.1 2-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_2FT_3x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last 2 convolutional blocks
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block4_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 16,943,937
# Trainable params: 2,229,249
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 12s 119ms/step - loss: 0.8002 - acc: 0.5472 - val_loss: 0.6649 - val_acc: 0.6075
# Epoch 2/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6991 - acc: 0.5571 - val_loss: 0.6805 - val_acc: 0.6200
# Epoch 3/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6799 - acc: 0.5551 - val_loss: 0.6529 - val_acc: 0.6075
# Epoch 4/100
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6823 - acc: 0.5641 - val_loss: 0.6603 - val_acc: 0.6075
# Epoch 5/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6753 - acc: 0.5962 - val_loss: 0.6609 - val_acc: 0.6075
# Epoch 6/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6632 - acc: 0.5872 - val_loss: 0.6612 - val_acc: 0.6075
# Epoch 7/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6686 - acc: 0.5685 - val_loss: 0.6532 - val_acc: 0.6075
# Epoch 8/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6711 - acc: 0.5739 - val_loss: 0.6549 - val_acc: 0.6062
# Epoch 9/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6716 - acc: 0.5742 - val_loss: 0.6337 - val_acc: 0.6075
# Epoch 10/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6769 - acc: 0.5762 - val_loss: 0.6583 - val_acc: 0.5725
# Epoch 11/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6679 - acc: 0.5592 - val_loss: 0.6316 - val_acc: 0.6150
# Epoch 12/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6631 - acc: 0.5780 - val_loss: 0.6383 - val_acc: 0.6062
# Epoch 13/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6798 - acc: 0.5943 - val_loss: 0.6287 - val_acc: 0.6388
# Epoch 14/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6625 - acc: 0.5808 - val_loss: 0.6365 - val_acc: 0.6125
# Epoch 15/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6493 - acc: 0.5966 - val_loss: 0.6359 - val_acc: 0.6212
# Epoch 16/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6600 - acc: 0.5858 - val_loss: 0.6394 - val_acc: 0.6112
# Epoch 17/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6500 - acc: 0.5855 - val_loss: 0.6301 - val_acc: 0.6250
# Epoch 18/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6646 - acc: 0.5858 - val_loss: 0.6268 - val_acc: 0.6388
# Epoch 19/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6571 - acc: 0.5988 - val_loss: 0.6243 - val_acc: 0.6413
# Epoch 20/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6599 - acc: 0.5862 - val_loss: 0.6380 - val_acc: 0.6275
# Epoch 21/100
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6497 - acc: 0.6108 - val_loss: 0.6321 - val_acc: 0.6075
# Epoch 22/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6566 - acc: 0.5955 - val_loss: 0.6263 - val_acc: 0.6263
# Epoch 23/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6474 - acc: 0.5990 - val_loss: 0.6309 - val_acc: 0.6162
# Epoch 24/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.
100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5582 - acc: 0.6675 - val_loss: 0.5473 - val_acc: 0.7275
# Epoch 79/100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5984 - acc: 0.6263 - val_loss: 0.5441 - val_acc: 0.7163
# Epoch 80/100
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5612 - acc: 0.6605 - val_loss: 0.5446 - val_acc: 0.7387

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_3x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5877 - acc: 0.6781
#
# ---------------------------------
# Accuracy: 67.81 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75       219
#          1.0       0.52      0.46      0.49       117
#
#     accuracy                           0.66       336
#    macro avg       0.62      0.62      0.62       336
# weighted avg       0.66      0.66      0.66       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_3x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  54
# FP:  50
# TN:  169
# FN:  63
#
# TPR(Recall): 		 0.4615
# FPR: 			 0.2283
#
# Precision: 		 0.5192
# TNR(Specificity): 	 0.7717

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.4.2 3-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_3FT_DA')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last 3 convolutional blocks
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block3_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               2097408
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 16,943,937
# Trainable params: 2,229,249
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 12s 120ms/step - loss: 0.8105 - acc: 0.5852 - val_loss: 0.6773 - val_acc: 0.5562
# Epoch 2/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6933 - acc: 0.5865 - val_loss: 0.6779 - val_acc: 0.5562
# Epoch 3/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6937 - acc: 0.5711 - val_loss: 0.6729 - val_acc: 0.5562
# Epoch 4/100
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6785 - acc: 0.5549 - val_loss: 0.6671 - val_acc: 0.5562
# Epoch 5/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6775 - acc: 0.5806 - val_loss: 0.6673 - val_acc: 0.5562
# Epoch 6/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6820 - acc: 0.5813 - val_loss: 0.6663 - val_acc: 0.5562
# Epoch 7/100
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6533 - acc: 0.5944 - val_loss: 0.6563 - val_acc: 0.5562
# Epoch 8/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6605 - acc: 0.5834 - val_loss: 0.6623 - val_acc: 0.5562
# Epoch 9/100
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6709 - acc: 0.5990 - val_loss: 0.6588 - val_acc: 0.5562
# Epoch 10/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6579 - acc: 0.6026 - val_loss: 0.6510 - val_acc: 0.5562
# Epoch 11/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6571 - acc: 0.5918 - val_loss: 0.6567 - val_acc: 0.5562
# Epoch 12/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6615 - acc: 0.5854 - val_loss: 0.6657 - val_acc: 0.5562
# Epoch 13/100
# 93/93 [==============================] - 11s 115ms/step - loss: 0.6630 - acc: 0.5974 - val_loss: 0.6744 - val_acc: 0.5562
# Epoch 14/100
# 93/93 [==============================] - 11s 115ms/step - loss: 0.6711 - acc: 0.6109 - val_loss: 0.6543 - val_acc: 0.5562
# Epoch 15/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6584 - acc: 0.5997 - val_loss: 0.6470 - val_acc: 0.5562
# Epoch 16/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6695 - acc: 0.5915 - val_loss: 0.6483 - val_acc: 0.5562
# Epoch 17/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6500 - acc: 0.6075 - val_loss: 0.6556 - val_acc: 0.5562
# Epoch 18/100
# 93/93 [==============================] - 11s 115ms/step - loss: 0.6558 - acc: 0.6070 - val_loss: 0.6424 - val_acc: 0.5562
# Epoch 19/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6658 - acc: 0.5792 - val_loss: 0.6455 - val_acc: 0.5562
# Epoch 20/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6527 - acc: 0.6003 - val_loss: 0.6568 - val_acc: 0.5562
# Epoch 21/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6512 - acc: 0.6183 - val_loss: 0.6527 - val_acc: 0.5562
# Epoch 22/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6419 - acc: 0.6086 - val_loss: 0.6534 - val_acc: 0.5562
# Epoch 23/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.
100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.5915 - acc: 0.6921 - val_loss: 0.5755 - val_acc: 0.7063
# Epoch 90/100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.5705 - acc: 0.6812 - val_loss: 0.5635 - val_acc: 0.7163
# Epoch 91/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5562 - acc: 0.6907 - val_loss: 0.5694 - val_acc: 0.7225
# Epoch 92/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.5609 - acc: 0.7008 - val_loss: 0.5669 - val_acc: 0.7362
# Epoch 93/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5611 - acc: 0.6847 - val_loss: 0.5630 - val_acc: 0.7212
# Epoch 94/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5675 - acc: 0.7023 - val_loss: 0.5717 - val_acc: 0.7225
# Epoch 95/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.5438 - acc: 0.7213 - val_loss: 0.5804 - val_acc: 0.7163
# Epoch 96/100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.5629 - acc: 0.7036 - val_loss: 0.5653 - val_acc: 0.7312
# Epoch 97/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5485 - acc: 0.7020 - val_loss: 0.5610 - val_acc: 0.7375
# Epoch 98/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5666 - acc: 0.6909 - val_loss: 0.5783 - val_acc: 0.7113
# Epoch 99/100
# 93/93 [==============================] - 13s 135ms/step - loss: 0.5634 - acc: 0.7014 - val_loss: 0.5638 - val_acc: 0.7237
# Epoch 100/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5480 - acc: 0.7119 - val_loss: 0.5804 - val_acc: 0.7038

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_3x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5809 - acc: 0.6562
#
# ---------------------------------
# Accuracy: 65.62 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.64      0.69       219
#          1.0       0.48      0.62      0.54       117
#
#     accuracy                           0.63       336
#    macro avg       0.62      0.63      0.62       336
# weighted avg       0.66      0.63      0.64       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_3x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  73
# FP:  79
# TN:  140
# FN:  44
#
# TPR(Recall): 		 0.6239
# FPR: 			 0.3607
#
# Precision: 		 0.4803
# TNR(Specificity): 	 0.6393

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 4.5.1 All-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_ALLFT_DA_3x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
#model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze all convolutional blocks
for layer in model.layers:
    layer.trainable = True 


model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8192)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               2097408
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 16,943,937
# Trainable params: 2,229,249
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 12s 119ms/step - loss: 0.7911 - acc: 0.5733 - val_loss: 0.6787 - val_acc: 0.5938
# Epoch 2/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.7086 - acc: 0.5651 - val_loss: 0.6608 - val_acc: 0.5938
# Epoch 3/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6807 - acc: 0.5645 - val_loss: 0.6634 - val_acc: 0.6012
# Epoch 4/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6730 - acc: 0.5526 - val_loss: 0.6540 - val_acc: 0.5925
# Epoch 5/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6687 - acc: 0.5885 - val_loss: 0.6486 - val_acc: 0.6075
# Epoch 6/100
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6681 - acc: 0.5866 - val_loss: 0.6552 - val_acc: 0.5987
# Epoch 7/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6671 - acc: 0.6064 - val_loss: 0.6353 - val_acc: 0.6263
# Epoch 8/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6647 - acc: 0.6189 - val_loss: 0.6302 - val_acc: 0.6250
# Epoch 9/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6635 - acc: 0.5762 - val_loss: 0.6477 - val_acc: 0.5863
# Epoch 10/100
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6620 - acc: 0.6043 - val_loss: 0.6343 - val_acc: 0.6062
# Epoch 11/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6507 - acc: 0.5738 - val_loss: 0.6248 - val_acc: 0.6300
# Epoch 12/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6535 - acc: 0.5789 - val_loss: 0.6253 - val_acc: 0.6375
# Epoch 13/100
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6574 - acc: 0.5909 - val_loss: 0.6327 - val_acc: 0.6200
# Epoch 14/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6555 - acc: 0.6118 - val_loss: 0.6276 - val_acc: 0.6225
# Epoch 15/100
# 93/93 [==============================] - 11s 116ms/step - loss: 0.
100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4608 - acc: 0.7605 - val_loss: 0.6358 - val_acc: 0.7387
# Epoch 86/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4716 - acc: 0.7594 - val_loss: 0.6853 - val_acc: 0.7262
# Epoch 87/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4620 - acc: 0.7659 - val_loss: 0.5801 - val_acc: 0.7375
# Epoch 88/100
# 93/93 [==============================] - 13s 142ms/step - loss: 0.4874 - acc: 0.7467 - val_loss: 0.5956 - val_acc: 0.7150
# Epoch 89/100
# 93/93 [==============================] - 13s 140ms/step - loss: 0.4705 - acc: 0.7690 - val_loss: 0.5741 - val_acc: 0.6812
# Epoch 90/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4872 - acc: 0.7455 - val_loss: 0.6195 - val_acc: 0.7287
# Epoch 91/100
# 93/93 [==============================] - 13s 140ms/step - loss: 0.4537 - acc: 0.7759 - val_loss: 0.5656 - val_acc: 0.7100
# Epoch 92/100
# 93/93 [==============================] - 13s 142ms/step - loss: 0.4473 - acc: 0.7906 - val_loss: 0.5883 - val_acc: 0.7063
# Epoch 93/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4457 - acc: 0.7854 - val_loss: 0.6030 - val_acc: 0.7287
# Epoch 94/100
# 93/93 [==============================] - 13s 143ms/step - loss: 0.4722 - acc: 0.7704 - val_loss: 0.5596 - val_acc: 0.7325
# Epoch 95/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4641 - acc: 0.7647 - val_loss: 0.5411 - val_acc: 0.7163
# Epoch 96/100
# 93/93 [==============================] - 13s 143ms/step - loss: 0.4542 - acc: 0.7649 - val_loss: 0.5946 - val_acc: 0.7150
# Epoch 97/100
# 93/93 [==============================] - 13s 145ms/step - loss: 0.4565 - acc: 0.7548 - val_loss: 0.6200 - val_acc: 0.7025
# Epoch 98/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4751 - acc: 0.7570 - val_loss: 0.6287 - val_acc: 0.7375
# Epoch 99/100
# 93/93 [==============================] - 13s 141ms/step - loss: 0.4726 - acc: 0.7609 - val_loss: 0.5751 - val_acc: 0.7375
# Epoch 100/100
# 93/93 [==============================] - 13s 142ms/step - loss: 0.4286 - acc: 0.7914 - val_loss: 0.6271 - val_acc: 0.6888

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_3x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5670 - acc: 0.7063
#
# ---------------------------------
# Accuracy: 70.63 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.70      0.75       219
#          1.0       0.55      0.68      0.61       117
#
#     accuracy                           0.69       336
#    macro avg       0.68      0.69      0.68       336
# weighted avg       0.72      0.69      0.70       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_3x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  80
# FP:  66
# TN:  153
# FN:  37
#
# TPR(Recall): 		 0.6838
# FPR: 			 0.3014
#
# Precision: 		 0.5479
# TNR(Specificity): 	 0.6986

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# # 5.VGG16: Flatten() + 5x [Dropout(0.5), Dense(256)]

# %% [markdown]
# ##3.1.1 0-Fine-Tuning Strategy With Data Augmentation

# %%
INPUT_SHAPE = (150, 150, 1)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20
EPOCHS = 200

# %%
METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_0FT_DA_5x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 17,075,521
# Trainable params: 2,360,833
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 134ms/step - loss: 0.7900 - acc: 0.5907 - val_loss: 0.6847 - val_acc: 0.5625
# Epoch 2/100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.7038 - acc: 0.5630 - val_loss: 0.6891 - val_acc: 0.5600
# Epoch 3/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6833 - acc: 0.5850 - val_loss: 0.6834 - val_acc: 0.5612
# Epoch 4/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.
100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6535 - acc: 0.6063 - val_loss: 0.6460 - val_acc: 0.5600
# Epoch 72/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6315 - acc: 0.6052 - val_loss: 0.6382 - val_acc: 0.6500
# Epoch 73/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6394 - acc: 0.5863 - val_loss: 0.6419 - val_acc: 0.6062
# Epoch 74/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6339 - acc: 0.6226 - val_loss: 0.6414 - val_acc: 0.5925
# Epoch 75/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6298 - acc: 0.6185 - val_loss: 0.6341 - val_acc: 0.6338
# Epoch 76/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6464 - acc: 0.5893 - val_loss: 0.6367 - val_acc: 0.6313
# Epoch 77/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6444 - acc: 0.6090 - val_loss: 0.6382 - val_acc: 0.6125
# Epoch 78/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6307 - acc: 0.6147 - val_loss: 0.6392 - val_acc: 0.6325
# Epoch 79/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6343 - acc: 0.6039 - val_loss: 0.6326 - val_acc: 0.6350
# Epoch 80/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6453 - acc: 0.6107 - val_loss: 0.6389 - val_acc: 0.6112
# Epoch 81/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6336 - acc: 0.6165 - val_loss: 0.6329 - val_acc: 0.6300
# Epoch 82/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6340 - acc: 0.6126 - val_loss: 0.6380 - val_acc: 0.6500
# Epoch 83/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6423 - acc: 0.5758 - val_loss: 0.6528 - val_acc: 0.5612
# Epoch 84/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6593 - acc: 0.5934 - val_loss: 0.6438 - val_acc: 0.5600
# Epoch 85/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6392 - acc: 0.5949 - val_loss: 0.6376 - val_acc: 0.5612
# Epoch 86/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6372 - acc: 0.6043 - val_loss: 0.6360 - val_acc: 0.5612
# Epoch 87/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6464 - acc: 0.5994 - val_loss: 0.6405 - val_acc: 0.5612
# Epoch 88/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6382 - acc: 0.6145 - val_loss: 0.6379 - val_acc: 0.5625
# Epoch 89/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6335 - acc: 0.5940 - val_loss: 0.6366 - val_acc: 0.5625
# Epoch 90/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6249 - acc: 0.6227 - val_loss: 0.6413 - val_acc: 0.5625
# Epoch 91/100
# 93/93 [==============================] - 12s 134ms/step - loss: 0.6382 - acc: 0.5838 - val_loss: 0.6433 - val_acc: 0.5625
# Epoch 92/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6336 - acc: 0.5830 - val_loss: 0.6347 - val_acc: 0.5625
# Epoch 93/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6364 - acc: 0.6099 - val_loss: 0.6385 - val_acc: 0.5612
# Epoch 94/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6294 - acc: 0.5913 - val_loss: 0.6403 - val_acc: 0.5625
# Epoch 95/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6293 - acc: 0.5912 - val_loss: 0.6692 - val_acc: 0.5600
# Epoch 96/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6496 - acc: 0.5923 - val_loss: 0.6588 - val_acc: 0.5625
# Epoch 97/100
# 93/93 [==============================] - 12s 133ms/step - loss: 0.6453 - acc: 0.5833 - val_loss: 0.6474 - val_acc: 0.5612
# Epoch 98/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6521 - acc: 0.6097 - val_loss: 0.6396 - val_acc: 0.5600
# Epoch 99/100
# 93/93 [==============================] - 12s 132ms/step - loss: 0.6408 - acc: 0.6051 - val_loss: 0.6437 - val_acc: 0.5612

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_5x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 56ms/step - loss: 0.6234 - acc: 0.6406
#
# ---------------------------------
# Accuracy: 64.06 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.76      0.73       219
#          1.0       0.46      0.38      0.42       117
#
#     accuracy                           0.63       336
#    macro avg       0.58      0.57      0.57       336
# weighted avg       0.62      0.63      0.62       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_5x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# TP:  45
# FP:  52
# TN:  167
# FN:  72
#
# TPR(Recall): 		 0.3846
# FPR: 			 0.2374
#
# Precision: 		 0.4639
# TNR(Specificity): 	 0.7626

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
#
200
# 93/93 [==============================] - 13s 143ms/step - loss: 0.6308 - acc: 0.5911 - val_loss: 0.5828 - val_acc: 0.6950
# Epoch 50/200
# 93/93 [==============================] - 13s 144ms/step - loss: 0.6071 - acc: 0.6044 - val_loss: 0.5987 - val_acc: 0.6538
# Epoch 51/200
# 93/93 [==============================] - 13s 144ms/step - loss: 0.6019 - acc: 0.6504 - val_loss: 0.5805 - val_acc: 0.6662
# Epoch 52/200
# 93/93 [==============================] - 13s 143ms/step - loss: 0.6156 - acc: 0.6041 - val_loss: 0.6021 - val_acc: 0.7013
# Epoch 53/200
# 93/93 [==============================] - 13s 143ms/step - loss: 0.5939 - acc: 0.6247 - val_loss: 0.5951 - val_acc: 0.7038
# Epoch 54/200
# 93/93 [==============================] - 13s 143ms/step - loss: 0.6073 - acc: 0.6055 - val_loss: 0.6026 - val_acc: 0.6687
# Epoch 55/200
# 93/93 [==============================] - 13s 144ms/step - loss: 0.5997 - acc: 0.6287 - val_loss: 0.5860 - val_acc: 0.7075
# Epoch 56/200
# 93/93 [==============================] - 13s 144ms/step - loss: 0.6002 - acc: 0.6293 - val_loss: 0.5854 - val_acc: 0.6950

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_5x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 48ms/step - loss: 0.5990 - acc: 0.6719
#
# ---------------------------------
# Accuracy: 67.19 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.79      0.75       219
#          1.0       0.51      0.41      0.45       117
#
#     accuracy                           0.66       336
#    macro avg       0.61      0.60      0.60       336
# weighted avg       0.64      0.66      0.65       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_5x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 3.4.2 3-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_3FT_DA_5x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze last 3 convolutional blocks
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "block3_conv1":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8192)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               2097408
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 17,075,521
# Trainable params: 2,360,833
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 132ms/step - loss: 0.8146 - acc: 0.5761 - val_loss: 0.6859 - val_acc: 0.6200
# Epoch 2/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6913 - acc: 0.5355 - val_loss: 0.6880 - val_acc: 0.6187
# Epoch 3/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6965 - acc: 0.5415 - val_loss: 0.6793 - val_acc: 0.6200
# Epoch 4/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6818 - acc: 0.5862 - val_loss: 0.6631 - val_acc: 0.6175
# Epoch 5/100
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6783 - acc: 0.5669 - val_loss: 0.6639 - val_acc: 0.6187
# Epoch 6/100
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6665 - acc: 0.5886 - val_loss: 0.6655 - val_acc: 0.6200
# Epoch 7/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6686 - acc: 0.6000 - val_loss: 0.6498 - val_acc: 0.6187
# Epoch 8/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6724 - acc: 0.5836 - val_loss: 0.6614 - val_acc: 0.6187
# Epoch 9/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6714 - acc: 0.5701 - val_loss: 0.6381 - val_acc: 0.6200
# Epoch 10/100
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6623 - acc: 0.5810 - val_loss: 0.6425 - val_acc: 0.6175
# Epoch 11/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6700 - acc: 0.5660 - val_loss: 0.6560 - val_acc: 0.6212
# Epoch 12/100
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6748 - acc: 0.5760 - val_loss: 0.6466 - val_acc: 0.6187
# Epoch 13/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6699 - acc: 0.5662 - val_loss: 0.6527 - val_acc: 0.6175
# Epoch 14/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6733 - acc: 0.5632 - val_loss: 0.6572 - val_acc: 0.6200
# Epoch 15/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6754 - acc: 0.5588 - val_loss: 0.6477 - val_acc: 0.6187
# Epoch 16/100
# 93/93 [==============================] - 12s 127ms/step - loss: 0.6589 - acc: 0.5798 - val_loss: 0.6482 - val_acc: 0.6187
# Epoch 17/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.
# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_5x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 48ms/step - loss: 0.5957 - acc: 0.6531
#
# ---------------------------------
# Accuracy: 65.31 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.79       219
#          1.0       0.00      0.00      0.00       117
#
#     accuracy                           0.65       336
#    macro avg       0.33      0.50      0.39       336
# weighted avg       0.42      0.65      0.51       336
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_5x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# ## 5.5.1 All-Fine-Tuning Strategy With Data Augmentation

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="VGG16", GCN=False, augmentation=True)

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
checkpoint_filepath =  os.path.join(base_path, 'models/PreTrained-Benign-Malign/best_VGG16_ALLFT_DA_5x')
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
#model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=100,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)

#unfreeze all convolutional blocks
for layer in model.layers:
    layer.trainable = True 


model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-5), # lr = 0.00001
            metrics=METRICS)   

#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights(checkpoint_filepath)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 8192)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               2097408
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 17,075,521
# Trainable params: 2,360,833
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/100
# 93/93 [==============================] - 13s 133ms/step - loss: 0.7986 - acc: 0.5740 - val_loss: 0.6981 - val_acc: 0.4275
# Epoch 2/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.7184 - acc: 0.5415 - val_loss: 0.6903 - val_acc: 0.5713
# Epoch 3/100
# 93/93 [==============================] - 12s 131ms/step - loss: 0.6849 - acc: 0.5842 - val_loss: 0.6817 - val_acc: 0.5713
# Epoch 4/100
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6819 - acc: 0.5652 - val_loss: 0.6776 - val_acc: 0.5725
# Epoch 5/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6803 - acc: 0.5679 - val_loss: 0.6684 - val_acc: 0.5738
# Epoch 6/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6709 - acc: 0.5952 - val_loss: 0.6692 - val_acc: 0.5713
# Epoch 7/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6806 - acc: 0.5904 - val_loss: 0.6692 - val_acc: 0.5738
# Epoch 8/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6642 - acc: 0.5952 - val_loss: 0.6690 - val_acc: 0.5713
# Epoch 9/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6737 - acc: 0.5778 - val_loss: 0.6539 - val_acc: 0.5725
# Epoch 10/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6629 - acc: 0.5942 - val_loss: 0.6691 - val_acc: 0.5725
# Epoch 11/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.6678 - acc: 0.5868 - val_loss: 0.6555 - val_acc: 0.5725
# Epoch 12/100
# 93/93 [==============================] - 12s 128ms/step - loss: 0.6643 - acc: 0.5853 - val_loss: 0.6437 - val_acc: 0.5738
# Epoch 13/100
# 93/93 [==============================] - 12s 129ms/step - loss: 0.
200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5990 - acc: 0.5992 - val_loss: 0.6320 - val_acc: 0.5725
# Epoch 29/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.6049 - acc: 0.6107 - val_loss: 0.6144 - val_acc: 0.5725
# Epoch 30/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.6058 - acc: 0.5921 - val_loss: 0.6270 - val_acc: 0.5738
# Epoch 31/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.5928 - acc: 0.5995 - val_loss: 0.6303 - val_acc: 0.5738
# Epoch 32/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.6098 - acc: 0.5974 - val_loss: 0.6143 - val_acc: 0.5738
# Epoch 33/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.6065 - acc: 0.6056 - val_loss: 0.6189 - val_acc: 0.5725
# Epoch 34/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.5985 - acc: 0.6091 - val_loss: 0.6343 - val_acc: 0.5738
# Epoch 35/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.6041 - acc: 0.5642 - val_loss: 0.6198 - val_acc: 0.5738
# Epoch 36/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5876 - acc: 0.5851 - val_loss: 0.6301 - val_acc: 0.5725
# Epoch 37/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.6090 - acc: 0.5928 - val_loss: 0.6274 - val_acc: 0.5725
# Epoch 38/200
# 93/93 [==============================] - 16s 173ms/step - loss: 0.5972 - acc: 0.6002 - val_loss: 0.6641 - val_acc: 0.5738
# Epoch 39/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5954 - acc: 0.5991 - val_loss: 0.6295 - val_acc: 0.5725
# Epoch 40/200
# 93/93 [==============================] - 16s 174ms/step - loss: 0.5984 - acc: 0.5938 - val_loss: 0.6217 - val_acc: 0.5725
# Epoch 41/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5937 - acc: 0.5955 - val_loss: 0.6142 - val_acc: 0.5713
# Epoch 42/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.6165 - acc: 0.6307 - val_loss: 0.6281 - val_acc: 0.5738
# Epoch 43/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5880 - acc: 0.5967 - val_loss: 0.6145 - val_acc: 0.5738
# Epoch 44/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.6008 - acc: 0.6132 - val_loss: 0.6250 - val_acc: 0.5713
# Epoch 45/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5950 - acc: 0.5881 - val_loss: 0.6279 - val_acc: 0.5713
# Epoch 46/200
# 93/93 [==============================] - 16s 172ms/step - loss: 0.5944 - acc: 0.6258 - val_loss: 0.6200 - val_acc: 0.6562

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

# %%
plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")
ACC_values_5x.append(test_accuracy)
# Out:
# 16/16 [==============================] - 1s 49ms/step - loss: 0.6082 - acc: 0.6531
#
# ---------------------------------
# Accuracy: 65.31 %
# ---------------------------------

# %%
#print confusion matrix
classes = ["Benign", "Malign"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.79       219
#          1.0       0.00      0.00      0.00       117
#
#     accuracy                           0.65       336
#    macro avg       0.33      0.50      0.39       336
# weighted avg       0.42      0.65      0.51       336
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values_5x.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
predictions = get_model_pred_prob(model, test_images, test_labels, len(test_images))
tpr, fpr, precision, specificity = calc_TP_FP_rate(test_labels, predictions)

print()
print("TPR(Recall): \t\t", round(tpr, 4))
print("FPR: \t\t\t", round(fpr, 4))
print()
print("Precision: \t\t", round(precision, 4))
print("TNR(Specificity): \t", round(specificity, 4))

TPR_values.append(tpr)
FPR_values.append(fpr)

# %%
#free RAM 
del model
del conv_base
del train_images_split 
del valid_images_split 
del train_labels_split 
del valid_labels_split

# %% [markdown]
# # Model Results Report

# %% [markdown]
# ACCURACY

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = ['1x', '3x', '5x']
zero_ft = [64.38, 67.19, 64.06]
one_ft = [62.19, 63.44, 65.31]
two_ft = [71.25, 67.81, 67.19]
three_ft = [70.31, 65.62, 65.31]
all_ft = [65.62, 70.63, 65.31]

x = 3*np.arange(len(labels))  # the label locations
width = 0.42  # the width of the bars

fig, ax = plt.subplots()

rects1 = ax.bar(x - 2*1.2*width, zero_ft, width, label='0FT')
rects2 = ax.bar(x - 1.2*width, one_ft, width, label='1FT')
rects3 = ax.bar(x, two_ft, width, label='2FT')
rects4 = ax.bar(x + 1.2*width, three_ft, width, label='3FT')
rects5 = ax.bar(x + 2*1.2*width, all_ft, width, label='AllFT')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy %')
ax.set_title('VGG16 performances')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim([50,80])
ax.set_yticks(np.arange(50,82,2))

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=False, shadow=False, ncol=5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_axisbelow(True)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

#autolabel(rects1)
#autolabel(rects2)
#autolabel(rects3)
#autolabel(rects4)
#autolabel(rects5)

fig.tight_layout()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# AUC

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

labels = ['1x', '3x', '5x']
zero_ft = [0.680, 0.651, 0.643]
one_ft = [0.703, 0.681, 0.636]
two_ft = [0.754, 0.693, 0.653]
three_ft = [0.744, 0.687, 0.652]
all_ft = [0.740, 0.775, 0.638]

x = 3*np.arange(len(labels))  # the label locations
width = 0.42  # the width of the bars

fig, ax = plt.subplots()

rects1 = ax.bar(x - 2*1.2*width, zero_ft, width, label='0FT')
rects2 = ax.bar(x - 1.2*width, one_ft, width, label='1FT')
rects3 = ax.bar(x, two_ft, width, label='2FT')
rects4 = ax.bar(x + 1.2*width, three_ft, width, label='3FT')
rects5 = ax.bar(x + 2*1.2*width, all_ft, width, label='AllFT')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('AUC')
ax.set_title('VGG16 performances')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim([0.5,0.8])
ax.set_yticks(np.arange(0.5,0.8,0.02))

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          fancybox=False, shadow=False, ncol=5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_axisbelow(True)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

#autolabel(rects1)
#autolabel(rects2)
#autolabel(rects3)
#autolabel(rects4)
#autolabel(rects5)

fig.tight_layout()
plt.grid(axis='y')
plt.show()
