# %% [markdown]
# <a href="https://colab.research.google.com/github/aleschiavo94/Convolutional-Neural-Network-for-Medical-Imaging-Analysis---Abnormality-detection-in-mammography/blob/main/PreTrained_CNN_masses_vs_calc_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #0.1 Load Functions

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns # Grouped bar plot
import itertools
import numpy as np
import pandas as pd 
import ast #Abstract Syntax Trees
import os 
import gc # Garbage Collector

from tensorflow.keras import backend as K # Useful to free GPU and memory
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras import layers, optimizers, models, regularizers, metrics
from keras.models import load_model
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from keras.models import Model




import scipy
import scipy.misc
from PIL import Image
BATCH_SIZE = 20
EPOCHS = 50

base_path = "/content/gdrive/My Drive/Colab Notebooks/CIDL/DL Project"
train_img_path = os.path.join(base_path, "numpy data/train_tensor.npy")
train_label_path = os.path.join(base_path, "numpy data/train_labels.npy")
test_img_path = os.path.join(base_path, "numpy data/public_test_tensor.npy")
test_label_path = os.path.join(base_path, "numpy data/public_test_labels.npy")

MODEL_PATH = os.path.join(base_path, "models/PreTrained-Masses-Calcifications/ResNet")
PLOTS_PATH = os.path.join(base_path, "plots/Masses-Calcifications")


# to produce final model report histogram 
AUC_values = []
TPR_values = []
FPR_values = []
PRECISION_values = []
SPECIFICITY_values = []

# Load Arrays from Numpy Files
def load_training():
  train_images = np.load(train_img_path)
  train_labels = np.load(train_label_path)
  test_images = np.load(test_img_path)
  test_labels = np.load(test_label_path)

  return train_images, train_labels, test_images, test_labels

def get_model_predictions(model, dataset, labels, sample_count): 
  predictions = np.zeros((sample_count,))   

  BATCH_SIZE = 1
  i = 0
  for batch, labels_batch in test_datagen.flow(dataset, labels, batch_size=BATCH_SIZE, shuffle=False):
    predictions[i * BATCH_SIZE : (i + 1) * BATCH_SIZE] = model.predict(batch)
    i += 1

    if i * BATCH_SIZE  >= sample_count:
      break

    #np.where(predictions < 0.5, 0, 1)
    #predictions = np.where(predictions < 0.5, 0, 1)

  return predictions


# Remove baseline samples
def remove_baseline(tensor): 
  max_ind = int(len(tensor)/2)
  indexes = [2*i + 1 for i in range(0, max_ind)]

  return tensor[indexes]

# Interchange the dataset index
def shuffle_dataset(x, y):
  indices = tf.range(start=0, limit=tf.shape(x)[0], dtype=tf.int32)
  shuffled_indices = tf.random.shuffle(indices)

  x = tf.gather(x, shuffled_indices)
  y = tf.gather(y, shuffled_indices)

  x = x.numpy()
  y = y.numpy()

  return x, y

# split dataset into training and validation set 70-30
def split_train_val(dataset, labels):
  train_data_split = dataset[:int(0.7*len(dataset))]
  valid_data_split = dataset[int(0.7*len(dataset)):]
  train_labels_split = labels[:int(0.7*len(labels))]
  valid_labels_split = labels[int(0.7*len(labels)):]

  print(train_data_split.shape)
  print(valid_data_split.shape)
  print(train_labels_split.shape)
  print(valid_labels_split.shape)      

  return train_data_split, valid_data_split, train_labels_split, valid_labels_split

# Unify masses and calcifications 
def labels_mapping(labels):
  labels_local = np.zeros(shape=labels.shape, dtype="float32")
  idx = 0
  for label in labels:
    # Masses
    if label == 1 or label == 2:
      labels_local[idx] = 0
    # Calcifications
    else:
      labels_local[idx] = 1
    idx += 1

  return labels_local




def cross_validate(k, batch_size, num_epochs, dataset, targets, verbosity, model_path):
  #10-Fold-Cross-Validation
  num_val_samples = len(dataset) // k 
  validation_accuracies = []
  validation_losses = []
  validation_precisions = []
  validation_recalls = []
  validation_aucs = []
  model = models.load_model(os.path.join(MODEL_PATH, model_path))
  for i in range(k):
    # rigen augmented data 
    
    print("processing fold #", i)
    validation_data = dataset[i * num_val_samples : (i + 1) * num_val_samples]
    validation_labels = targets[i * num_val_samples : (i + 1) * num_val_samples]

    partial_train_data = np.concatenate(
        [dataset[:i * num_val_samples],
        dataset[(i + 1) * num_val_samples:]], 
        axis=0)

    partial_train_targets = np.concatenate(
        [targets[:i * num_val_samples],
        targets[(i + 1) * num_val_samples:]], 
        axis=0)

    
    
    history = model.fit(train_datagen.flow(partial_train_data, 
                                          partial_train_targets,
                                          batch_size=batch_size,
                                          shuffle=False),
                        epochs=num_epochs,
                        steps_per_epoch=len(partial_train_data) // batch_size,
                        verbose=verbosity,
                        callbacks=[GarbageCollectorCallback()])
    
    val_loss, val_acc, val_prec, val_rec, val_auc= model.evaluate(valid_datagen.flow(validation_data,
                                                          validation_labels,
                                                          batch_size=batch_size,
                                                          shuffle=False),
                                       steps=len(validation_data) // batch_size,
                                       callbacks=[GarbageCollectorCallback()])
    
    validation_accuracies.append(val_acc)
    validation_losses.append(val_loss)
    validation_precisions.append(val_prec)
    validation_recalls.append(val_rec)
    validation_aucs.append(val_auc)

    ## ADDED TO TRY AND REDUCE RAM USAGE DURING CROSS VALIDATE
    del partial_train_targets
    del partial_train_data
    del validation_data
    del validation_labels
    del history
    
  return validation_accuracies, validation_losses, validation_precisions, validation_recalls, validation_aucs


def global_contrast_normalization(X):
    X_average = np.mean(X)
    #print('Mean: ', X_average)
    X = X - X_average
    return X

# Visualization Confusion Matrix
def plot_confusion_matrix(model,
                          classes,
                          dataset, 
                          labels,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    Y_pred = model.predict(test_datagen.flow(dataset,
                                            labels,
                                            batch_size=21,
                                            shuffle=False),
                          steps=len(dataset) // BATCH_SIZE)

    np.where(Y_pred < 0.5, 0, 1)
    y_pred = np.where(Y_pred < 0.5, 0, 1)

    print('Confusion Matrix')
    cm = confusion_matrix(labels, y_pred)

    #print(cm)
    #print('Classification Report')
    print(classification_report(labels, y_pred))


    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    return plt


def plot_loss(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt

# Visualization Data Histogram
def plot_acc(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  return plt

# Visualization Data Histogram
def plot(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt

# Visualization Detail Metric
def plot_metrics(history):
  metrics = ['loss', 'auc', 'precision', 'recall']
  plt.figure(figsize=(12,10))

  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)

    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

  return plt


def plot_AUC(model, dataset, labels):
  y_pred_keras = get_model_predictions(model, dataset, labels, len(dataset))
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(labels, y_pred_keras)
  #thresholds_keras = np.linspace(0,1,num=100)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='CNN (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  #plt.show()

  return auc_keras, plt

def plot_AUC2(model, dataset, labels):
  y_pred_keras = get_model_predictions(model, dataset, labels, len(dataset))
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(labels, y_pred_keras)
  #thresholds_keras = np.linspace(0,1,num=100)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='CNN (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.show()


# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
      gc.collect()



print("Done")
# Out:
# Done

# %% [markdown]
# ## Init Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#all-in-one data loading & preprocessing function 
def init_data(base_NN, GCN=True, augmentation=True):
  # Get images and labels (test, train)
  train_images, train_labels, test_images, test_labels = load_training()

  # Get abnormalities only 
  train_images = remove_baseline(train_images)
  train_labels = remove_baseline(train_labels)
  test_images = remove_baseline(test_images)
  test_labels = remove_baseline(test_labels)

  # Suffle index (Previous dataset is ordered)
  train_images, train_labels = shuffle_dataset(train_images, train_labels)

  #print("Train shape: ", train_images.shape)
  #print("Test shape: ", test_images.shape)

  #1: Mass, benign
  #2: Mass, malignant
  #3: Calcification, benign
  #4: Calcification, malignant

  #count #of masses and #of calcifications
  #unique, counts = np.unique(train_labels, return_counts=True)
  #print(unique, counts)

  #print("Benign Masses samples: \t", counts[0])
  #print("Malign Masses samples: \t", counts[1])
  #print("Benign Calc samples: \t", counts[2])
  #print("Malign Calc samples: \t", counts[3])

  #labels remapping
  train_labels = labels_mapping(train_labels)
  test_labels = labels_mapping(test_labels)

  #tensors reshaping for models training 
  train_images = train_images.reshape(train_images.shape + (1,)) #(2676, 150, 150, 1)
  test_images = test_images.reshape(test_images.shape + (1,)) #(2676, 150, 150, 1)
  #print(train_images.shape)
  #print(test_images.shape)

  # split dataset into training and validation set 70-30
  train_images_split, valid_images_split, train_labels_split, valid_labels_split = split_train_val(train_images, train_labels)  

  # All images will be rescaled by 1./65535
  if  base_NN == "VGG16":
    from tensorflow.keras.applications.vgg16 import preprocess_input
  if base_NN == "ResNet50":
    from tensorflow.keras.applications.resnet import preprocess_input
  #if Inception no preprocess function 
  if base_NN == "InceptionV3":
    train_datagen = ImageDataGenerator(rescale=1./65535)
    valid_datagen = ImageDataGenerator(rescale=1./65535)
    test_datagen = ImageDataGenerator(rescale=1./65535) 

  if "InceptionV3" not in base_NN:
    train_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    valid_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    test_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input) 

  if GCN:
    train_images_split_gcn = np.zeros(train_images_split.shape)  
    train_labels_split_gcn = np.zeros(train_labels_split.shape)
    valid_images_split_gcn = np.zeros(valid_images_split.shape)
    valid_labels_split_gcn = np.zeros(valid_labels_split.shape)
    train_datagen = ImageDataGenerator()
    valid_datagen = ImageDataGenerator()
    #global contrast normalization 
    counter = 0
    for image, label in train_datagen.flow(train_images_split, train_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image)
      train_images_split_gcn[counter] = norm_image
      train_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(train_images_split):
        break
    
    counter = 0
    for image, label in valid_datagen.flow(valid_images_split, valid_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image)
      valid_images_split_gcn[counter] = norm_image
      valid_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(valid_images_split):
        break
    if base_NN == "InceptionV3":  
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn))
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn))     
    else:
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn), preprocessing_function=preprocess_input)
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn), preprocessing_function=preprocess_input)      

  if GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  if not GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  print("Done")
  if GCN:
    #reshape to expand grayscale to rgb
    train_images_split_gcn = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split_gcn = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split_gcn, valid_images_split_gcn, train_labels_split_gcn, valid_labels_split_gcn, train_datagen, valid_datagen, test_datagen
  else:
    #reshape to expand grayscale to rgb
    train_images_split = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen

# %% [markdown]
# # 0.2 Set Metrics and Global Variables

# %%
INPUT_SHAPE = (150, 150, 3)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20


METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
      gc.collect()

print("Done")
# Out:
# Done

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, Dense 256

# %% [markdown]
# ## Flatten, Non Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 77, 77, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 38, 38, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 38, 38, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 38, 38, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 38, 38, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 38, 38, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 38, 38, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 38, 38, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 38, 38, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 38, 38, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 38, 38, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 38, 38, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 19, 19, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 19, 19, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 19, 19, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 19, 19, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 19, 19, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 19, 19, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 19, 19, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 19, 19, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 19, 19, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 19, 19, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 19, 19, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 19, 19, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 19, 19, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 19, 19, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 19, 19, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 19, 19, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 19, 19, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 19, 19, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 19, 19, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 19, 19, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 10, 10, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 10, 10, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 10, 10, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 10, 10, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 10, 10, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 10, 10, 512)  0           max_pooling2d_1[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 10, 10, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 10, 10, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 10, 10, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 10, 10, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 10, 10, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 10, 10, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 10, 10, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 10, 10, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 10, 10, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 10, 10, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 10, 10, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 10, 10, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 10, 10, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 10, 10, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 10, 10, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 10, 10, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 10, 10, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 10, 10, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 5, 5, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 5, 5, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 5, 5, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 5, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 5, 5, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 5, 5, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 5, 5, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 5, 5, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 5, 5, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 5, 5, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 5, 5, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 5, 5, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 5, 5, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 5, 5, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 5, 5, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 5, 5, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 5, 5, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 5, 5, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 5, 5, 2048)   0           post_bn[0][0]
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 13,107,713
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 22s 130ms/step - loss: 0.6695 - acc: 0.7103 - val_loss: 0.3884 - val_acc: 0.8350
#
# Epoch 00001: val_loss improved from inf to 0.38837, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4191 - acc: 0.8086 - val_loss: 0.3544 - val_acc: 0.8550
#
# Epoch 00002: val_loss improved from 0.38837 to 0.35442, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4094 - acc: 0.8147 - val_loss: 0.3685 - val_acc: 0.8400
#
# Epoch 00003: val_loss did not improve from 0.35442
# Epoch 4/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3916 - acc: 0.8208 - val_loss: 0.3407 - val_acc: 0.8450
#
# Epoch 00004: val_loss improved from 0.35442 to 0.34074, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3863 - acc: 0.8262 - val_loss: 0.3371 - val_acc: 0.8537
#
# Epoch 00005: val_loss improved from 0.34074 to 0.33707, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3914 - acc: 0.8261 - val_loss: 0.3067 - val_acc: 0.8687
#
# Epoch 00006: val_loss improved from 0.33707 to 0.30674, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3671 - acc: 0.8272 - val_loss: 0.3083 - val_acc: 0.8650
#
# Epoch 00007: val_loss did not improve from 0.30674
# Epoch 8/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3465 - acc: 0.8375 - val_loss: 0.3256 - val_acc: 0.8662
#
# Epoch 00008: val_loss did not improve from 0.30674
# Epoch 9/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3301 - acc: 0.8495 - val_loss: 0.3120 - val_acc: 0.8662
#
# Epoch 00009: val_loss did not improve from 0.30674
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3786 - acc: 0.8301 - val_loss: 0.3014 - val_acc: 0.8725
#
# Epoch 00010: val_loss improved from 0.30674 to 0.30135, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3473 - acc: 0.8522 - val_loss: 0.3135 - val_acc: 0.8612
#
# Epoch 00011: val_loss did not improve from 0.30135
# Epoch 12/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3558 - acc: 0.8490 - val_loss: 0.3345 - val_acc: 0.8662
#
# Epoch 00012: val_loss did not improve from 0.30135
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3721 - acc: 0.8278 - val_loss: 0.3600 - val_acc: 0.8475
#
# Epoch 00013: val_loss did not improve from 0.30135
# Epoch 14/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3559 - acc: 0.8485 - val_loss: 0.3169 - val_acc: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.30135
# Epoch 15/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3505 - acc: 0.8550 - val_loss: 0.3192 - val_acc: 0.8637
#
# Epoch 00015: val_loss did not improve from 0.30135
# Epoch 16/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3360 - acc: 0.8387 - val_loss: 0.2888 - val_acc: 0.8850
#
# Epoch 00016: val_loss improved from 0.30135 to 0.28884, saving model to checkpoint.h5
# Epoch 17/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3503 - acc: 0.8448 - val_loss: 0.3196 - val_acc: 0.8712
#
# Epoch 00017: val_loss did not improve from 0.28884
# Epoch 18/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3486 - acc: 0.8416 - val_loss: 0.3013 - val_acc: 0.8700
#
# Epoch 00018: val_loss did not improve from 0.28884
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3104 - acc: 0.8706 - val_loss: 0.2864 - val_acc: 0.8850
#
# Epoch 00019: val_loss improved from 0.28884 to 0.28642, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3371 - acc: 0.8464 - val_loss: 0.2851 - val_acc: 0.8850
#
# Epoch 00020: val_loss improved from 0.28642 to 0.28507, saving model to checkpoint.h5
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3322 - acc: 0.8535 - val_loss: 0.2742 - val_acc: 0.8888
#
# Epoch 00021: val_loss improved from 0.28507 to 0.27420, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3058 - acc: 0.8633 - val_loss: 0.2842 - val_acc: 0.8763
#
# Epoch 00022: val_loss did not improve from 0.27420
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3350 - acc: 0.8544 - val_loss: 0.2828 - val_acc: 0.8875
#
# Epoch 00023: val_loss did not improve from 0.27420
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2896 - acc: 0.8856 - val_loss: 0.2866 - val_acc: 0.8788
#
# Epoch 00024: val_loss did not improve from 0.27420
# Epoch 25/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3104 - acc: 0.8586 - val_loss: 0.2978 - val_acc: 0.8800
#
# Epoch 00025: val_loss did not improve from 0.27420
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3043 - acc: 0.8651 - val_loss: 0.2936 - val_acc: 0.8875
#
# Epoch 00026: val_loss did not improve from 0.27420
# Epoch 27/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3273 - acc: 0.8528 - val_loss: 0.2982 - val_acc: 0.8725
#
# Epoch 00027: val_loss did not improve from 0.27420
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3369 - acc: 0.8602 - val_loss: 0.3244 - val_acc: 0.8637
#
# Epoch 00028: val_loss did not improve from 0.27420
# Epoch 29/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3247 - acc: 0.8549 - val_loss: 0.2971 - val_acc: 0.8813
#
# Epoch 00029: val_loss did not improve from 0.27420
# Epoch 30/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2957 - acc: 0.8733 - val_loss: 0.2955 - val_acc: 0.8737
#
# Epoch 00030: val_loss did not improve from 0.27420
# Epoch 31/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2828 - acc: 0.8780 - val_loss: 0.2945 - val_acc: 0.8775
#
# Epoch 00031: val_loss did not improve from 0.27420
# Epoch 32/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3215 - acc: 0.8596 - val_loss: 0.3072 - val_acc: 0.8737
#
# Epoch 00032: val_loss did not improve from 0.27420
# Epoch 33/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3129 - acc: 0.8588 - val_loss: 0.2950 - val_acc: 0.8800
#
# Epoch 00033: val_loss did not improve from 0.27420
# Epoch 34/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3186 - acc: 0.8627 - val_loss: 0.2822 - val_acc: 0.8888
#
# Epoch 00034: val_loss did not improve from 0.27420
# Epoch 35/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2819 - acc: 0.8753 - val_loss: 0.2982 - val_acc: 0.8788
#
# Epoch 00035: val_loss did not improve from 0.27420
# Epoch 36/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3311 - acc: 0.8595 - val_loss: 0.3002 - val_acc: 0.8750
#
# Epoch 00036: val_loss did not improve from 0.27420
# Epoch 37/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3049 - acc: 0.8732 - val_loss: 0.2883 - val_acc: 0.8813
#
# Epoch 00037: val_loss did not improve from 0.27420
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3091 - acc: 0.8696 - val_loss: 0.2868 - val_acc: 0.8737
#
# Epoch 00038: val_loss did not improve from 0.27420
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2974 - acc: 0.8748 - val_loss: 0.2681 - val_acc: 0.8875
#
# Epoch 00039: val_loss improved from 0.27420 to 0.26807, saving model to checkpoint.h5
# Epoch 40/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2794 - acc: 0.8824 - val_loss: 0.3128 - val_acc: 0.8650
#
# Epoch 00040: val_loss did not improve from 0.26807
# Epoch 41/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3002 - acc: 0.8768 - val_loss: 0.2769 - val_acc: 0.8737
#
# Epoch 00041: val_loss did not improve from 0.26807
# Epoch 42/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2871 - acc: 0.8761 - val_loss: 0.2696 - val_acc: 0.8900
#
# Epoch 00042: val_loss did not improve from 0.26807
# Epoch 43/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3025 - acc: 0.8632 - val_loss: 0.2712 - val_acc: 0.8838
#
# Epoch 00043: val_loss did not improve from 0.26807
# Epoch 44/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3296 - acc: 0.8628 - val_loss: 0.3058 - val_acc: 0.8750
#
# Epoch 00044: val_loss did not improve from 0.26807
# Epoch 45/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3048 - acc: 0.8683 - val_loss: 0.2828 - val_acc: 0.8950
#
# Epoch 00045: val_loss did not improve from 0.26807
# Epoch 46/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2842 - acc: 0.8685 - val_loss: 0.2793 - val_acc: 0.8888
#
# Epoch 00046: val_loss did not improve from 0.26807
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2598 - acc: 0.8903 - val_loss: 0.2765 - val_acc: 0.8975
#
# Epoch 00047: val_loss did not improve from 0.26807
# Epoch 48/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3112 - acc: 0.8663 - val_loss: 0.2739 - val_acc: 0.8913
#
# Epoch 00048: val_loss did not improve from 0.26807
# Epoch 49/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2814 - acc: 0.8782 - val_loss: 0.2841 - val_acc: 0.8788
#
# Epoch 00049: val_loss did not improve from 0.26807
# Epoch 50/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2787 - acc: 0.8874 - val_loss: 0.2819 - val_acc: 0.8913
#
# Epoch 00050: val_loss did not improve from 0.26807

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3157 - acc: 0.8844
#
# ---------------------------------
# Accuracy: 88.44 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89       179
#          1.0       0.86      0.89      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 77, 77, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 38, 38, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 38, 38, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 38, 38, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 38, 38, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 38, 38, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 38, 38, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 38, 38, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 38, 38, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 38, 38, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 38, 38, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 38, 38, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 19, 19, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 19, 19, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 19, 19, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 19, 19, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 19, 19, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 19, 19, 256)  0           max_pooling2d_6[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 19, 19, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 19, 19, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 19, 19, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 19, 19, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 19, 19, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 19, 19, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 19, 19, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 19, 19, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 19, 19, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 19, 19, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 19, 19, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 19, 19, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 19, 19, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 19, 19, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 10, 10, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 10, 10, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 10, 10, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 10, 10, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 10, 10, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 10, 10, 512)  0           max_pooling2d_7[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 10, 10, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 10, 10, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 10, 10, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 10, 10, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 10, 10, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 10, 10, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 10, 10, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 10, 10, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 10, 10, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 10, 10, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 10, 10, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 10, 10, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 10, 10, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 10, 10, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 10, 10, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 10, 10, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 10, 10, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 10, 10, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 5, 5, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 5, 5, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 5, 5, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 5, 5, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 5, 5, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 5, 5, 1024)   0           max_pooling2d_8[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 5, 5, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 5, 5, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 5, 5, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 5, 5, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 5, 5, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 5, 5, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 5, 5, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 5, 5, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 5, 5, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 5, 5, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 5, 5, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 5, 5, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 5, 5, 2048)   0           post_bn[0][0]
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 13,107,713
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 131ms/step - loss: 5.1333 - acc: 0.5486 - val_loss: 1.3054 - val_acc: 0.5350
#
# Epoch 00001: val_loss improved from inf to 1.30538, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 121ms/step - loss: 4.4602 - acc: 0.5222 - val_loss: 0.8994 - val_acc: 0.5375
#
# Epoch 00002: val_loss improved from 1.30538 to 0.89936, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 1.1643 - acc: 0.5519 - val_loss: 0.8867 - val_acc: 0.5387
#
# Epoch 00003: val_loss improved from 0.89936 to 0.88671, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.9079 - acc: 0.5419 - val_loss: 0.6893 - val_acc: 0.5400
#
# Epoch 00004: val_loss improved from 0.88671 to 0.68931, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6835 - acc: 0.5528 - val_loss: 0.6893 - val_acc: 0.5387
#
# Epoch 00005: val_loss did not improve from 0.68931
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6841 - acc: 0.5688 - val_loss: 0.6891 - val_acc: 0.5375
#
# Epoch 00006: val_loss improved from 0.68931 to 0.68914, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6860 - acc: 0.5404 - val_loss: 0.6903 - val_acc: 0.5362
#
# Epoch 00007: val_loss did not improve from 0.68914
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6848 - acc: 0.5542 - val_loss: 0.6914 - val_acc: 0.5350
#
# Epoch 00008: val_loss did not improve from 0.68914
# Epoch 9/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6858 - acc: 0.5368 - val_loss: 0.6924 - val_acc: 0.5362
#
# Epoch 00009: val_loss did not improve from 0.68914
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6851 - acc: 0.5547 - val_loss: 0.6909 - val_acc: 0.5350
#
# Epoch 00010: val_loss did not improve from 0.68914
# Epoch 11/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6854 - acc: 0.5429 - val_loss: 0.6922 - val_acc: 0.5375
#
# Epoch 00011: val_loss did not improve from 0.68914
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6887 - acc: 0.5504 - val_loss: 0.6917 - val_acc: 0.5337
#
# Epoch 00012: val_loss did not improve from 0.68914
# Epoch 13/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6797 - acc: 0.5613 - val_loss: 0.6925 - val_acc: 0.5375
#
# Epoch 00013: val_loss did not improve from 0.68914
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.7017 - acc: 0.5581 - val_loss: 0.6919 - val_acc: 0.5362
#
# Epoch 00014: val_loss did not improve from 0.68914
# Epoch 15/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6839 - acc: 0.5576 - val_loss: 0.6933 - val_acc: 0.5362
#
# Epoch 00015: val_loss did not improve from 0.68914
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6b8892dfd0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b8890fcc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b888f4c18>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b8849fe80>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6b88449208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b88997d68>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b8846b6a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b8842b9e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b889bb438>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b8838cb70>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b881807b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88180828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b883a4080>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b903fc390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88934cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b903fcfd0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b884124a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b883ced30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b883a3d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b8838cf60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b880fd5c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b88086a20>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b880fd780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88090ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b88096668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b88096f28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b8809e128>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b880a6780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b880aa710>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b880aa898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b880b7160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b880b7c50>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b880b7e10>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b88048390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88048dd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b8804f898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b880483c8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6b880b36a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88060470>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b88060588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b88058908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b880647b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88070780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b88058a20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b8807b4a8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b8807bd68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b88075f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b5e0f84a8>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 36,627,073
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 19s 156ms/step - loss: 0.6026 - acc: 0.6275 - val_loss: 0.6948 - val_acc: 0.5412
#
# Epoch 00001: val_loss did not improve from 0.68914
# Epoch 2/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.4818 - acc: 0.7833 - val_loss: 0.5524 - val_acc: 0.7775
#
# Epoch 00002: val_loss improved from 0.68914 to 0.55241, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.4374 - acc: 0.8036 - val_loss: 0.5819 - val_acc: 0.6712
#
# Epoch 00003: val_loss did not improve from 0.55241
# Epoch 4/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.4138 - acc: 0.8202 - val_loss: 0.4430 - val_acc: 0.8175
#
# Epoch 00004: val_loss improved from 0.55241 to 0.44295, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.4207 - acc: 0.7973 - val_loss: 0.4285 - val_acc: 0.7962
#
# Epoch 00005: val_loss improved from 0.44295 to 0.42848, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3353 - acc: 0.8582 - val_loss: 0.7962 - val_acc: 0.5850
#
# Epoch 00006: val_loss did not improve from 0.42848
# Epoch 7/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3834 - acc: 0.8222 - val_loss: 0.4096 - val_acc: 0.8025
#
# Epoch 00007: val_loss improved from 0.42848 to 0.40964, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3769 - acc: 0.8290 - val_loss: 0.5639 - val_acc: 0.6400
#
# Epoch 00008: val_loss did not improve from 0.40964
# Epoch 9/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3737 - acc: 0.8317 - val_loss: 0.5452 - val_acc: 0.7625
#
# Epoch 00009: val_loss did not improve from 0.40964
# Epoch 10/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3498 - acc: 0.8436 - val_loss: 0.3474 - val_acc: 0.8825
#
# Epoch 00010: val_loss improved from 0.40964 to 0.34741, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3216 - acc: 0.8541 - val_loss: 0.5691 - val_acc: 0.6750
#
# Epoch 00011: val_loss did not improve from 0.34741
# Epoch 12/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3549 - acc: 0.8339 - val_loss: 0.5784 - val_acc: 0.7038
#
# Epoch 00012: val_loss did not improve from 0.34741
# Epoch 13/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3859 - acc: 0.8413 - val_loss: 0.4840 - val_acc: 0.7650
#
# Epoch 00013: val_loss did not improve from 0.34741
# Epoch 14/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3968 - acc: 0.8409 - val_loss: 1.1881 - val_acc: 0.7050
#
# Epoch 00014: val_loss did not improve from 0.34741
# Epoch 15/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3835 - acc: 0.8551 - val_loss: 0.3406 - val_acc: 0.8662
#
# Epoch 00015: val_loss improved from 0.34741 to 0.34056, saving model to checkpoint.h5
# Epoch 16/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.4016 - acc: 0.8463 - val_loss: 0.6436 - val_acc: 0.6862
#
# Epoch 00016: val_loss did not improve from 0.34056
# Epoch 17/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3608 - acc: 0.8338 - val_loss: 0.9339 - val_acc: 0.6625
#
# Epoch 00017: val_loss did not improve from 0.34056
# Epoch 18/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.4375 - acc: 0.8217 - val_loss: 0.5172 - val_acc: 0.7088
#
# Epoch 00018: val_loss did not improve from 0.34056
# Epoch 19/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.3377 - acc: 0.8655 - val_loss: 0.5599 - val_acc: 0.7725
#
# Epoch 00019: val_loss did not improve from 0.34056
# Epoch 20/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3633 - acc: 0.8672 - val_loss: 1.1979 - val_acc: 0.5638
#
# Epoch 00020: val_loss did not improve from 0.34056
# Epoch 21/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3437 - acc: 0.8527 - val_loss: 0.5220 - val_acc: 0.7812
#
# Epoch 00021: val_loss did not improve from 0.34056
# Epoch 22/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3575 - acc: 0.8633 - val_loss: 0.4048 - val_acc: 0.8275
#
# Epoch 00022: val_loss did not improve from 0.34056
# Epoch 23/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.3488 - acc: 0.8559 - val_loss: 0.2919 - val_acc: 0.8750
#
# Epoch 00023: val_loss improved from 0.34056 to 0.29192, saving model to checkpoint.h5
# Epoch 24/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3517 - acc: 0.8648 - val_loss: 0.4645 - val_acc: 0.8200
#
# Epoch 00024: val_loss did not improve from 0.29192
# Epoch 25/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3890 - acc: 0.8442 - val_loss: 0.3680 - val_acc: 0.8450
#
# Epoch 00025: val_loss did not improve from 0.29192
# Epoch 26/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3483 - acc: 0.8710 - val_loss: 0.3611 - val_acc: 0.8800
#
# Epoch 00026: val_loss did not improve from 0.29192
# Epoch 27/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.3325 - acc: 0.8765 - val_loss: 0.4297 - val_acc: 0.8575
#
# Epoch 00027: val_loss did not improve from 0.29192
# Epoch 28/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.3484 - acc: 0.8660 - val_loss: 0.4258 - val_acc: 0.8875
#
# Epoch 00028: val_loss did not improve from 0.29192
# Epoch 29/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2722 - acc: 0.8762 - val_loss: 0.2756 - val_acc: 0.8863
#
# Epoch 00029: val_loss improved from 0.29192 to 0.27557, saving model to checkpoint.h5
# Epoch 30/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2993 - acc: 0.8772 - val_loss: 0.3020 - val_acc: 0.8850
#
# Epoch 00030: val_loss did not improve from 0.27557
# Epoch 31/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.3580 - acc: 0.8505 - val_loss: 0.3905 - val_acc: 0.8475
#
# Epoch 00031: val_loss did not improve from 0.27557
# Epoch 32/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2920 - acc: 0.8834 - val_loss: 0.3196 - val_acc: 0.8700
#
# Epoch 00032: val_loss did not improve from 0.27557
# Epoch 33/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3032 - acc: 0.8745 - val_loss: 0.2800 - val_acc: 0.8950
#
# Epoch 00033: val_loss did not improve from 0.27557
# Epoch 34/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2896 - acc: 0.8776 - val_loss: 0.2985 - val_acc: 0.8788
#
# Epoch 00034: val_loss did not improve from 0.27557
# Epoch 35/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2935 - acc: 0.8896 - val_loss: 0.2485 - val_acc: 0.8963
#
# Epoch 00035: val_loss improved from 0.27557 to 0.24847, saving model to checkpoint.h5
# Epoch 36/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2788 - acc: 0.8859 - val_loss: 0.2599 - val_acc: 0.9025
#
# Epoch 00036: val_loss did not improve from 0.24847
# Epoch 37/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2922 - acc: 0.8792 - val_loss: 0.2931 - val_acc: 0.8888
#
# Epoch 00037: val_loss did not improve from 0.24847
# Epoch 38/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2677 - acc: 0.8808 - val_loss: 0.2640 - val_acc: 0.8938
#
# Epoch 00038: val_loss did not improve from 0.24847
# Epoch 39/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3017 - acc: 0.8857 - val_loss: 0.2895 - val_acc: 0.8763
#
# Epoch 00039: val_loss did not improve from 0.24847
# Epoch 40/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2696 - acc: 0.9058 - val_loss: 0.2365 - val_acc: 0.9137
#
# Epoch 00040: val_loss improved from 0.24847 to 0.23646, saving model to checkpoint.h5
# Epoch 41/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2737 - acc: 0.8947 - val_loss: 0.2484 - val_acc: 0.9150
#
# Epoch 00041: val_loss did not improve from 0.23646
# Epoch 42/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2457 - acc: 0.8970 - val_loss: 0.3006 - val_acc: 0.8938
#
# Epoch 00042: val_loss did not improve from 0.23646
# Epoch 43/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2987 - acc: 0.8981 - val_loss: 0.2421 - val_acc: 0.8963
#
# Epoch 00043: val_loss did not improve from 0.23646
# Epoch 44/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2814 - acc: 0.9058 - val_loss: 0.2323 - val_acc: 0.9125
#
# Epoch 00044: val_loss improved from 0.23646 to 0.23234, saving model to checkpoint.h5
# Epoch 45/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2324 - acc: 0.9112 - val_loss: 0.3229 - val_acc: 0.8625
#
# Epoch 00045: val_loss did not improve from 0.23234
# Epoch 46/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2506 - acc: 0.9007 - val_loss: 0.3372 - val_acc: 0.8550
#
# Epoch 00046: val_loss did not improve from 0.23234
# Epoch 47/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2790 - acc: 0.8876 - val_loss: 0.3162 - val_acc: 0.8600
#
# Epoch 00047: val_loss did not improve from 0.23234
# Epoch 48/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2628 - acc: 0.9012 - val_loss: 0.7425 - val_acc: 0.6612
#
# Epoch 00048: val_loss did not improve from 0.23234
# Epoch 49/50
# 93/93 [==============================] - 14s 155ms/step - loss: 0.2667 - acc: 0.8902 - val_loss: 0.2813 - val_acc: 0.9013
#
# Epoch 00049: val_loss did not improve from 0.23234
# Epoch 50/50
# 93/93 [==============================] - 14s 155ms/step - loss: 0.2621 - acc: 0.8954 - val_loss: 0.5383 - val_acc: 0.7225
#
# Epoch 00050: val_loss did not improve from 0.23234
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2588 - acc: 0.8938
#
# ---------------------------------
# Accuracy: 89.38 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90       179
#          1.0       0.89      0.89      0.89       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256_all_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 524,801
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 131ms/step - loss: 0.5556 - acc: 0.7772 - val_loss: 0.4117 - val_acc: 0.8163
#
# Epoch 00001: val_loss improved from inf to 0.41172, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4395 - acc: 0.8012 - val_loss: 0.3562 - val_acc: 0.8388
#
# Epoch 00002: val_loss improved from 0.41172 to 0.35623, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4454 - acc: 0.7907 - val_loss: 0.3717 - val_acc: 0.8300
#
# Epoch 00003: val_loss did not improve from 0.35623
# Epoch 4/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4252 - acc: 0.8179 - val_loss: 0.3820 - val_acc: 0.8288
#
# Epoch 00004: val_loss did not improve from 0.35623
# Epoch 5/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4080 - acc: 0.8085 - val_loss: 0.3549 - val_acc: 0.8350
#
# Epoch 00005: val_loss improved from 0.35623 to 0.35494, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4306 - acc: 0.8018 - val_loss: 0.3301 - val_acc: 0.8462
#
# Epoch 00006: val_loss improved from 0.35494 to 0.33014, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3754 - acc: 0.8273 - val_loss: 0.3584 - val_acc: 0.8438
#
# Epoch 00007: val_loss did not improve from 0.33014
# Epoch 8/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3853 - acc: 0.8317 - val_loss: 0.3252 - val_acc: 0.8487
#
# Epoch 00008: val_loss improved from 0.33014 to 0.32520, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4017 - acc: 0.8232 - val_loss: 0.3199 - val_acc: 0.8600
#
# Epoch 00009: val_loss improved from 0.32520 to 0.31990, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3715 - acc: 0.8348 - val_loss: 0.3110 - val_acc: 0.8600
#
# Epoch 00010: val_loss improved from 0.31990 to 0.31098, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3671 - acc: 0.8353 - val_loss: 0.3097 - val_acc: 0.8625
#
# Epoch 00011: val_loss improved from 0.31098 to 0.30967, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3875 - acc: 0.8415 - val_loss: 0.3211 - val_acc: 0.8500
#
# Epoch 00012: val_loss did not improve from 0.30967
# Epoch 13/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3550 - acc: 0.8433 - val_loss: 0.3206 - val_acc: 0.8600
#
# Epoch 00013: val_loss did not improve from 0.30967
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4106 - acc: 0.8033 - val_loss: 0.3165 - val_acc: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.30967
# Epoch 15/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3658 - acc: 0.8363 - val_loss: 0.3203 - val_acc: 0.8525
#
# Epoch 00015: val_loss did not improve from 0.30967
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6b71e930f0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b462775f8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6bc0223390>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b46184c50>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6b70464438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6bc0023c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b46182908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6bc0026ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6bc013ca58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b70154f28>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b461824e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b70262ac8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960f65908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b4628b198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6bc009eac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b461b25c0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6bc0023470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960fbc898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b4605c8d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b460b8198>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960fb5f60>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6960f840f0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b70464550>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b4607ae48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b700d3400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6960ff57b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b460b8828>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b460ec8d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b4632bbe0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b460b82e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6960f84780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960f5a828>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6960f5ae80>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6960f888d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b461c63c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b700da668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b700dad30>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6960ff5f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b700c0fd0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b4632b588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960f92fd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6960f5a6a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6960ff4710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960ff49e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b462f9f98>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b460b4080>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6960ee1a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6960ee1080>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 24,044,161
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 19s 159ms/step - loss: 0.5450 - acc: 0.8127 - val_loss: 0.4906 - val_acc: 0.8112
#
# Epoch 00001: val_loss did not improve from 0.30967
# Epoch 2/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.3604 - acc: 0.8491 - val_loss: 0.5670 - val_acc: 0.8425
#
# Epoch 00002: val_loss did not improve from 0.30967
# Epoch 3/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.3462 - acc: 0.8568 - val_loss: 0.3877 - val_acc: 0.8487
#
# Epoch 00003: val_loss did not improve from 0.30967
# Epoch 4/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.3078 - acc: 0.8705 - val_loss: 0.3456 - val_acc: 0.8750
#
# Epoch 00004: val_loss did not improve from 0.30967
# Epoch 5/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.3046 - acc: 0.8701 - val_loss: 0.3446 - val_acc: 0.8550
#
# Epoch 00005: val_loss did not improve from 0.30967
# Epoch 6/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2864 - acc: 0.8786 - val_loss: 0.2882 - val_acc: 0.8888
#
# Epoch 00006: val_loss improved from 0.30967 to 0.28820, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2623 - acc: 0.8902 - val_loss: 0.3400 - val_acc: 0.8625
#
# Epoch 00007: val_loss did not improve from 0.28820
# Epoch 8/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2787 - acc: 0.8911 - val_loss: 0.2651 - val_acc: 0.8888
#
# Epoch 00008: val_loss improved from 0.28820 to 0.26507, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2365 - acc: 0.9004 - val_loss: 0.3938 - val_acc: 0.8263
#
# Epoch 00009: val_loss did not improve from 0.26507
# Epoch 10/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.2450 - acc: 0.8957 - val_loss: 0.4050 - val_acc: 0.8062
#
# Epoch 00010: val_loss did not improve from 0.26507
# Epoch 11/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2441 - acc: 0.8983 - val_loss: 0.4136 - val_acc: 0.8350
#
# Epoch 00011: val_loss did not improve from 0.26507
# Epoch 12/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2393 - acc: 0.9110 - val_loss: 0.3742 - val_acc: 0.8600
#
# Epoch 00012: val_loss did not improve from 0.26507
# Epoch 13/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2430 - acc: 0.9019 - val_loss: 0.9584 - val_acc: 0.7013
#
# Epoch 00013: val_loss did not improve from 0.26507
# Epoch 14/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2453 - acc: 0.9038 - val_loss: 0.3726 - val_acc: 0.8363
#
# Epoch 00014: val_loss did not improve from 0.26507
# Epoch 15/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2254 - acc: 0.9085 - val_loss: 0.3630 - val_acc: 0.8400
#
# Epoch 00015: val_loss did not improve from 0.26507
# Epoch 16/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2059 - acc: 0.9166 - val_loss: 0.2232 - val_acc: 0.8950
#
# Epoch 00016: val_loss improved from 0.26507 to 0.22322, saving model to checkpoint.h5
# Epoch 17/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2491 - acc: 0.9081 - val_loss: 0.2976 - val_acc: 0.8750
#
# Epoch 00017: val_loss did not improve from 0.22322
# Epoch 18/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.1895 - acc: 0.9292 - val_loss: 0.4722 - val_acc: 0.8388
#
# Epoch 00018: val_loss did not improve from 0.22322
# Epoch 19/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2026 - acc: 0.9277 - val_loss: 0.2124 - val_acc: 0.9312
#
# Epoch 00019: val_loss improved from 0.22322 to 0.21237, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2252 - acc: 0.9125 - val_loss: 0.2302 - val_acc: 0.9225
#
# Epoch 00020: val_loss did not improve from 0.21237
# Epoch 21/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2218 - acc: 0.9075 - val_loss: 0.2232 - val_acc: 0.9125
#
# Epoch 00021: val_loss did not improve from 0.21237
# Epoch 22/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2000 - acc: 0.9174 - val_loss: 0.3787 - val_acc: 0.8250
#
# Epoch 00022: val_loss did not improve from 0.21237
# Epoch 23/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1810 - acc: 0.9337 - val_loss: 0.3362 - val_acc: 0.8650
#
# Epoch 00023: val_loss did not improve from 0.21237
# Epoch 24/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2011 - acc: 0.9212 - val_loss: 0.5354 - val_acc: 0.8000
#
# Epoch 00024: val_loss did not improve from 0.21237
# Epoch 25/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.1984 - acc: 0.9250 - val_loss: 0.5688 - val_acc: 0.8250
#
# Epoch 00025: val_loss did not improve from 0.21237
# Epoch 26/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.1946 - acc: 0.9246 - val_loss: 0.3118 - val_acc: 0.8388
#
# Epoch 00026: val_loss did not improve from 0.21237
# Epoch 27/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1835 - acc: 0.9231 - val_loss: 0.4174 - val_acc: 0.8238
#
# Epoch 00027: val_loss did not improve from 0.21237
# Epoch 28/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2037 - acc: 0.9081 - val_loss: 0.2608 - val_acc: 0.8925
#
# Epoch 00028: val_loss did not improve from 0.21237
# Epoch 29/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1933 - acc: 0.9227 - val_loss: 0.2606 - val_acc: 0.8950
#
# Epoch 00029: val_loss did not improve from 0.21237
# Epoch 30/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1609 - acc: 0.9387 - val_loss: 0.3117 - val_acc: 0.8737
#
# Epoch 00030: val_loss did not improve from 0.21237
# Epoch 31/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1556 - acc: 0.9376 - val_loss: 0.2620 - val_acc: 0.9100
#
# Epoch 00031: val_loss did not improve from 0.21237
# Epoch 32/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1619 - acc: 0.9403 - val_loss: 0.2100 - val_acc: 0.9100
#
# Epoch 00032: val_loss improved from 0.21237 to 0.21002, saving model to checkpoint.h5
# Epoch 33/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1747 - acc: 0.9372 - val_loss: 0.5586 - val_acc: 0.7987
#
# Epoch 00033: val_loss did not improve from 0.21002
# Epoch 34/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1900 - acc: 0.9257 - val_loss: 0.3997 - val_acc: 0.8313
#
# Epoch 00034: val_loss did not improve from 0.21002
# Epoch 35/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1972 - acc: 0.9142 - val_loss: 0.3212 - val_acc: 0.8763
#
# Epoch 00035: val_loss did not improve from 0.21002
# Epoch 36/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.1600 - acc: 0.9363 - val_loss: 0.3974 - val_acc: 0.8550
#
# Epoch 00036: val_loss did not improve from 0.21002
# Epoch 37/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1983 - acc: 0.9234 - val_loss: 0.2858 - val_acc: 0.8863
#
# Epoch 00037: val_loss did not improve from 0.21002
# Epoch 38/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1364 - acc: 0.9421 - val_loss: 0.3051 - val_acc: 0.8900
#
# Epoch 00038: val_loss did not improve from 0.21002
# Epoch 39/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.1593 - acc: 0.9407 - val_loss: 0.3706 - val_acc: 0.8225
#
# Epoch 00039: val_loss did not improve from 0.21002
# Epoch 40/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1845 - acc: 0.9323 - val_loss: 0.5397 - val_acc: 0.8050
#
# Epoch 00040: val_loss did not improve from 0.21002
# Epoch 41/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1652 - acc: 0.9429 - val_loss: 0.4760 - val_acc: 0.8338
#
# Epoch 00041: val_loss did not improve from 0.21002
# Epoch 42/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1417 - acc: 0.9487 - val_loss: 0.3206 - val_acc: 0.8988
#
# Epoch 00042: val_loss did not improve from 0.21002
# Epoch 43/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1727 - acc: 0.9277 - val_loss: 0.3372 - val_acc: 0.8963
#
# Epoch 00043: val_loss did not improve from 0.21002
# Epoch 44/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1608 - acc: 0.9332 - val_loss: 0.3087 - val_acc: 0.8938
#
# Epoch 00044: val_loss did not improve from 0.21002
# Epoch 45/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1838 - acc: 0.9375 - val_loss: 0.3502 - val_acc: 0.8775
#
# Epoch 00045: val_loss did not improve from 0.21002
# Epoch 46/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1563 - acc: 0.9377 - val_loss: 0.3193 - val_acc: 0.8863
#
# Epoch 00046: val_loss did not improve from 0.21002
# Epoch 47/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1912 - acc: 0.9318 - val_loss: 0.2628 - val_acc: 0.9025
#
# Epoch 00047: val_loss did not improve from 0.21002
# Epoch 48/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1697 - acc: 0.9236 - val_loss: 0.2725 - val_acc: 0.8900
#
# Epoch 00048: val_loss did not improve from 0.21002
# Epoch 49/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.1693 - acc: 0.9362 - val_loss: 0.2853 - val_acc: 0.9025
#
# Epoch 00049: val_loss did not improve from 0.21002
# Epoch 50/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.1556 - acc: 0.9412 - val_loss: 0.4074 - val_acc: 0.8363
#
# Epoch 00050: val_loss did not improve from 0.21002
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2890 - acc: 0.8719
#
# ---------------------------------
# Accuracy: 87.19 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88       179
#          1.0       0.87      0.85      0.86       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
# Out:
# rm: cannot remove 'checkpoint_2.h5': No such file or directory

# %% [markdown]
# ## Flatten, Last  Block Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last 2 convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block3_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 13,107,713
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 22s 131ms/step - loss: 2.1201 - acc: 0.6580 - val_loss: 0.4386 - val_acc: 0.8087
#
# Epoch 00001: val_loss improved from inf to 0.43857, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4303 - acc: 0.8032 - val_loss: 0.4927 - val_acc: 0.7825
#
# Epoch 00002: val_loss did not improve from 0.43857
# Epoch 3/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4082 - acc: 0.8058 - val_loss: 0.3927 - val_acc: 0.8313
#
# Epoch 00003: val_loss improved from 0.43857 to 0.39268, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4418 - acc: 0.8096 - val_loss: 0.3587 - val_acc: 0.8438
#
# Epoch 00004: val_loss improved from 0.39268 to 0.35874, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4017 - acc: 0.8371 - val_loss: 0.3709 - val_acc: 0.8450
#
# Epoch 00005: val_loss did not improve from 0.35874
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3960 - acc: 0.8248 - val_loss: 0.3560 - val_acc: 0.8575
#
# Epoch 00006: val_loss improved from 0.35874 to 0.35597, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3704 - acc: 0.8313 - val_loss: 0.3465 - val_acc: 0.8612
#
# Epoch 00007: val_loss improved from 0.35597 to 0.34650, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3935 - acc: 0.8279 - val_loss: 0.3408 - val_acc: 0.8550
#
# Epoch 00008: val_loss improved from 0.34650 to 0.34079, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3634 - acc: 0.8462 - val_loss: 0.3206 - val_acc: 0.8637
#
# Epoch 00009: val_loss improved from 0.34079 to 0.32059, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3505 - acc: 0.8570 - val_loss: 0.3076 - val_acc: 0.8712
#
# Epoch 00010: val_loss improved from 0.32059 to 0.30761, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3591 - acc: 0.8393 - val_loss: 0.3376 - val_acc: 0.8550
#
# Epoch 00011: val_loss did not improve from 0.30761
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3502 - acc: 0.8689 - val_loss: 0.3134 - val_acc: 0.8737
#
# Epoch 00012: val_loss did not improve from 0.30761
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3424 - acc: 0.8505 - val_loss: 0.3241 - val_acc: 0.8662
#
# Epoch 00013: val_loss did not improve from 0.30761
# Epoch 14/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3686 - acc: 0.8417 - val_loss: 0.3166 - val_acc: 0.8662
#
# Epoch 00014: val_loss did not improve from 0.30761
# Epoch 15/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3612 - acc: 0.8423 - val_loss: 0.3033 - val_acc: 0.8737
#
# Epoch 00015: val_loss improved from 0.30761 to 0.30335, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f4ddafb3a20>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4ddafb3fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4ddaedf400>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4ddaedfef0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4d90131fd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d90143ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d90143710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d9014ce48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900dddd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900e2da0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d900e5eb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900e5518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900ef2e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900f7160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d9014c278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900ef908>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d90101828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d901057b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d901059e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d9010d550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d90114358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d90114588>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d9009aeb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900a6940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900ab400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900abe80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900b18d0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d900b7518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900bf4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900bf828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900c6d68>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900cd9e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900cd748>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d900d2f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d9005bb70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d9005ba20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d90062b38>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4d900c6438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d9006b208>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d9006be10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d90068a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d900756a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d90081240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d90068978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d9008a048>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d9008a3c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d90081e48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d900681d0>, <tensorflow.python.kera ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 17,576,449
# Non-trainable params: 19,096,064
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 130ms/step - loss: 1.0239 - acc: 0.8301 - val_loss: 0.3292 - val_acc: 0.8587
#
# Epoch 00001: val_loss did not improve from 0.30335
# Epoch 2/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3719 - acc: 0.8358 - val_loss: 0.3746 - val_acc: 0.8550
#
# Epoch 00002: val_loss did not improve from 0.30335
# Epoch 3/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3706 - acc: 0.8452 - val_loss: 0.3863 - val_acc: 0.8400
#
# Epoch 00003: val_loss did not improve from 0.30335
# Epoch 4/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4315 - acc: 0.7989 - val_loss: 0.3696 - val_acc: 0.8637
#
# Epoch 00004: val_loss did not improve from 0.30335
# Epoch 5/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3448 - acc: 0.8467 - val_loss: 0.4108 - val_acc: 0.8438
#
# Epoch 00005: val_loss did not improve from 0.30335
# Epoch 6/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3429 - acc: 0.8453 - val_loss: 0.3522 - val_acc: 0.8537
#
# Epoch 00006: val_loss did not improve from 0.30335
# Epoch 7/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3409 - acc: 0.8410 - val_loss: 0.3922 - val_acc: 0.8525
#
# Epoch 00007: val_loss did not improve from 0.30335
# Epoch 8/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3265 - acc: 0.8625 - val_loss: 0.3211 - val_acc: 0.8800
#
# Epoch 00008: val_loss did not improve from 0.30335
# Epoch 9/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3252 - acc: 0.8569 - val_loss: 0.3708 - val_acc: 0.8550
#
# Epoch 00009: val_loss did not improve from 0.30335
# Epoch 10/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3593 - acc: 0.8426 - val_loss: 0.3207 - val_acc: 0.8737
#
# Epoch 00010: val_loss did not improve from 0.30335
# Epoch 11/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3200 - acc: 0.8709 - val_loss: 0.3335 - val_acc: 0.8750
#
# Epoch 00011: val_loss did not improve from 0.30335
# Epoch 12/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3105 - acc: 0.8766 - val_loss: 0.3366 - val_acc: 0.8662
#
# Epoch 00012: val_loss did not improve from 0.30335
# Epoch 13/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3060 - acc: 0.8657 - val_loss: 0.3751 - val_acc: 0.8550
#
# Epoch 00013: val_loss did not improve from 0.30335
# Epoch 14/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2797 - acc: 0.8806 - val_loss: 0.3680 - val_acc: 0.8800
#
# Epoch 00014: val_loss did not improve from 0.30335
# Epoch 15/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3252 - acc: 0.8582 - val_loss: 0.3625 - val_acc: 0.8675
#
# Epoch 00015: val_loss did not improve from 0.30335
# Epoch 16/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3343 - acc: 0.8538 - val_loss: 0.3609 - val_acc: 0.8612
#
# Epoch 00016: val_loss did not improve from 0.30335
# Epoch 17/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2857 - acc: 0.8767 - val_loss: 0.3190 - val_acc: 0.8763
#
# Epoch 00017: val_loss did not improve from 0.30335
# Epoch 18/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2908 - acc: 0.8842 - val_loss: 0.3418 - val_acc: 0.8625
#
# Epoch 00018: val_loss did not improve from 0.30335
# Epoch 19/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2821 - acc: 0.8772 - val_loss: 0.3837 - val_acc: 0.8562
#
# Epoch 00019: val_loss did not improve from 0.30335
# Epoch 20/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3105 - acc: 0.8682 - val_loss: 0.3400 - val_acc: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.30335
# Epoch 21/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2767 - acc: 0.8769 - val_loss: 0.3721 - val_acc: 0.8637
#
# Epoch 00021: val_loss did not improve from 0.30335
# Epoch 22/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2794 - acc: 0.8784 - val_loss: 0.3249 - val_acc: 0.8863
#
# Epoch 00022: val_loss did not improve from 0.30335
# Epoch 23/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2761 - acc: 0.8748 - val_loss: 0.3288 - val_acc: 0.8850
#
# Epoch 00023: val_loss did not improve from 0.30335
# Epoch 24/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2785 - acc: 0.8745 - val_loss: 0.3616 - val_acc: 0.8963
#
# Epoch 00024: val_loss did not improve from 0.30335
# Epoch 25/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2735 - acc: 0.8933 - val_loss: 0.2851 - val_acc: 0.8913
#
# Epoch 00025: val_loss improved from 0.30335 to 0.28507, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2591 - acc: 0.9034 - val_loss: 0.2953 - val_acc: 0.8850
#
# Epoch 00026: val_loss did not improve from 0.28507
# Epoch 27/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2655 - acc: 0.8804 - val_loss: 0.4029 - val_acc: 0.8500
#
# Epoch 00027: val_loss did not improve from 0.28507
# Epoch 28/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2613 - acc: 0.8962 - val_loss: 0.3273 - val_acc: 0.8750
#
# Epoch 00028: val_loss did not improve from 0.28507
# Epoch 29/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2821 - acc: 0.8826 - val_loss: 0.3348 - val_acc: 0.8687
#
# Epoch 00029: val_loss did not improve from 0.28507
# Epoch 30/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2837 - acc: 0.8812 - val_loss: 0.3269 - val_acc: 0.8925
#
# Epoch 00030: val_loss did not improve from 0.28507
# Epoch 31/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2707 - acc: 0.8837 - val_loss: 0.3306 - val_acc: 0.8825
#
# Epoch 00031: val_loss did not improve from 0.28507
# Epoch 32/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2708 - acc: 0.8835 - val_loss: 0.3362 - val_acc: 0.8988
#
# Epoch 00032: val_loss did not improve from 0.28507
# Epoch 33/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2665 - acc: 0.8928 - val_loss: 0.3785 - val_acc: 0.8550
#
# Epoch 00033: val_loss did not improve from 0.28507
# Epoch 34/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3085 - acc: 0.8689 - val_loss: 0.3696 - val_acc: 0.8775
#
# Epoch 00034: val_loss did not improve from 0.28507
# Epoch 35/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2705 - acc: 0.8894 - val_loss: 0.3220 - val_acc: 0.8963
#
# Epoch 00035: val_loss did not improve from 0.28507
# Epoch 36/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2484 - acc: 0.8955 - val_loss: 0.3604 - val_acc: 0.8775
#
# Epoch 00036: val_loss did not improve from 0.28507
# Epoch 37/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2638 - acc: 0.8941 - val_loss: 0.3653 - val_acc: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.28507
# Epoch 38/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2535 - acc: 0.8896 - val_loss: 0.4307 - val_acc: 0.8550
#
# Epoch 00038: val_loss did not improve from 0.28507
# Epoch 39/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2477 - acc: 0.9008 - val_loss: 0.3060 - val_acc: 0.8913
#
# Epoch 00039: val_loss did not improve from 0.28507
# Epoch 40/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2838 - acc: 0.8874 - val_loss: 0.3778 - val_acc: 0.8612
#
# Epoch 00040: val_loss did not improve from 0.28507
# Epoch 41/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2473 - acc: 0.9020 - val_loss: 0.3928 - val_acc: 0.8712
#
# Epoch 00041: val_loss did not improve from 0.28507
# Epoch 42/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2568 - acc: 0.8897 - val_loss: 0.3446 - val_acc: 0.8838
#
# Epoch 00042: val_loss did not improve from 0.28507
# Epoch 43/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2749 - acc: 0.8922 - val_loss: 0.3610 - val_acc: 0.8700
#
# Epoch 00043: val_loss did not improve from 0.28507
# Epoch 44/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2365 - acc: 0.9047 - val_loss: 0.3530 - val_acc: 0.8788
#
# Epoch 00044: val_loss did not improve from 0.28507
# Epoch 45/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2540 - acc: 0.9050 - val_loss: 0.3344 - val_acc: 0.8863
#
# Epoch 00045: val_loss did not improve from 0.28507
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3167 - acc: 0.9000
#
# ---------------------------------
# Accuracy: 90.00 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.85      0.90       179
#          1.0       0.85      0.95      0.90       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'resNet_dense_256x1_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last 2 convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 13,107,713
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 133ms/step - loss: 1.7999 - acc: 0.7806 - val_loss: 0.5066 - val_acc: 0.7425
#
# Epoch 00001: val_loss improved from inf to 0.50664, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4324 - acc: 0.8171 - val_loss: 0.3558 - val_acc: 0.8425
#
# Epoch 00002: val_loss improved from 0.50664 to 0.35578, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4501 - acc: 0.7926 - val_loss: 0.3296 - val_acc: 0.8512
#
# Epoch 00003: val_loss improved from 0.35578 to 0.32958, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3969 - acc: 0.8222 - val_loss: 0.3498 - val_acc: 0.8450
#
# Epoch 00004: val_loss did not improve from 0.32958
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3964 - acc: 0.8268 - val_loss: 0.4214 - val_acc: 0.8300
#
# Epoch 00005: val_loss did not improve from 0.32958
# Epoch 6/15
# 93/93 [==============================] - 11s 124ms/step - loss: 0.3973 - acc: 0.8434 - val_loss: 0.3522 - val_acc: 0.8425
#
# Epoch 00006: val_loss did not improve from 0.32958
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3752 - acc: 0.8412 - val_loss: 0.3249 - val_acc: 0.8462
#
# Epoch 00007: val_loss improved from 0.32958 to 0.32492, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3552 - acc: 0.8477 - val_loss: 0.3270 - val_acc: 0.8587
#
# Epoch 00008: val_loss did not improve from 0.32492
# Epoch 9/15
# 93/93 [==============================] - 11s 124ms/step - loss: 0.3481 - acc: 0.8580 - val_loss: 0.3338 - val_acc: 0.8487
#
# Epoch 00009: val_loss did not improve from 0.32492
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3853 - acc: 0.8340 - val_loss: 0.3238 - val_acc: 0.8512
#
# Epoch 00010: val_loss improved from 0.32492 to 0.32376, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3418 - acc: 0.8574 - val_loss: 0.3308 - val_acc: 0.8450
#
# Epoch 00011: val_loss did not improve from 0.32376
# Epoch 12/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3253 - acc: 0.8678 - val_loss: 0.3057 - val_acc: 0.8687
#
# Epoch 00012: val_loss improved from 0.32376 to 0.30568, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3357 - acc: 0.8548 - val_loss: 0.3197 - val_acc: 0.8612
#
# Epoch 00013: val_loss did not improve from 0.30568
# Epoch 14/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3456 - acc: 0.8419 - val_loss: 0.3198 - val_acc: 0.8537
#
# Epoch 00014: val_loss did not improve from 0.30568
# Epoch 15/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2970 - acc: 0.8772 - val_loss: 0.3213 - val_acc: 0.8637
#
# Epoch 00015: val_loss did not improve from 0.30568
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f5799e58208>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f5799e58a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c3eb1940>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f5799e6cb38>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f57c3e73c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5799e546d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2c28588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2bc25c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5799e54f98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2bd3048>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c2bd3d68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2bd3390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2bda3c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2be4b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2bc2ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2c285f8>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c2becc88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2bf2c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2bf22e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2bfacf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b7f7b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2b87780>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c2bfa438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b92da0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b98860>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2b98a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b9ed30>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c2ba5978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2baa908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2baaa90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2bbb208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2bbbe48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2bbb828>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c2b4b588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b4bfd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b51a90>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2b4b0b8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f57c2bb3898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b61668>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c2b61940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b57908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2b68b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b72a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b61780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2b51b38>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c2ba54e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2b43e10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b61ef0>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 22,041,089
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 132ms/step - loss: 0.9641 - acc: 0.8247 - val_loss: 0.3675 - val_acc: 0.8350
#
# Epoch 00001: val_loss did not improve from 0.30568
# Epoch 2/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3830 - acc: 0.8259 - val_loss: 0.3053 - val_acc: 0.8687
#
# Epoch 00002: val_loss improved from 0.30568 to 0.30534, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3532 - acc: 0.8466 - val_loss: 0.3684 - val_acc: 0.8537
#
# Epoch 00003: val_loss did not improve from 0.30534
# Epoch 4/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3630 - acc: 0.8335 - val_loss: 0.4058 - val_acc: 0.8425
#
# Epoch 00004: val_loss did not improve from 0.30534
# Epoch 5/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3392 - acc: 0.8490 - val_loss: 0.3073 - val_acc: 0.8637
#
# Epoch 00005: val_loss did not improve from 0.30534
# Epoch 6/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3299 - acc: 0.8480 - val_loss: 0.3076 - val_acc: 0.8650
#
# Epoch 00006: val_loss did not improve from 0.30534
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3111 - acc: 0.8690 - val_loss: 0.2973 - val_acc: 0.8737
#
# Epoch 00007: val_loss improved from 0.30534 to 0.29729, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3415 - acc: 0.8691 - val_loss: 0.3037 - val_acc: 0.8725
#
# Epoch 00008: val_loss did not improve from 0.29729
# Epoch 9/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2919 - acc: 0.8833 - val_loss: 0.3117 - val_acc: 0.8750
#
# Epoch 00009: val_loss did not improve from 0.29729
# Epoch 10/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3104 - acc: 0.8630 - val_loss: 0.3574 - val_acc: 0.8675
#
# Epoch 00010: val_loss did not improve from 0.29729
# Epoch 11/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3266 - acc: 0.8582 - val_loss: 0.3311 - val_acc: 0.8637
#
# Epoch 00011: val_loss did not improve from 0.29729
# Epoch 12/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2936 - acc: 0.8828 - val_loss: 0.2897 - val_acc: 0.8763
#
# Epoch 00012: val_loss improved from 0.29729 to 0.28974, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3000 - acc: 0.8791 - val_loss: 0.2911 - val_acc: 0.8850
#
# Epoch 00013: val_loss did not improve from 0.28974
# Epoch 14/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2795 - acc: 0.8789 - val_loss: 0.2696 - val_acc: 0.8925
#
# Epoch 00014: val_loss improved from 0.28974 to 0.26963, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3068 - acc: 0.8768 - val_loss: 0.3010 - val_acc: 0.8675
#
# Epoch 00015: val_loss did not improve from 0.26963
# Epoch 16/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2904 - acc: 0.8819 - val_loss: 0.3312 - val_acc: 0.8625
#
# Epoch 00016: val_loss did not improve from 0.26963
# Epoch 17/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2904 - acc: 0.8719 - val_loss: 0.3222 - val_acc: 0.8637
#
# Epoch 00017: val_loss did not improve from 0.26963
# Epoch 18/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2843 - acc: 0.8809 - val_loss: 0.2908 - val_acc: 0.8850
#
# Epoch 00018: val_loss did not improve from 0.26963
# Epoch 19/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2678 - acc: 0.8976 - val_loss: 0.2820 - val_acc: 0.8825
#
# Epoch 00019: val_loss did not improve from 0.26963
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2806 - acc: 0.8850 - val_loss: 0.2929 - val_acc: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.26963
# Epoch 21/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2798 - acc: 0.8938 - val_loss: 0.2925 - val_acc: 0.8838
#
# Epoch 00021: val_loss did not improve from 0.26963
# Epoch 22/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2975 - acc: 0.8757 - val_loss: 0.3120 - val_acc: 0.8675
#
# Epoch 00022: val_loss did not improve from 0.26963
# Epoch 23/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2979 - acc: 0.8790 - val_loss: 0.2746 - val_acc: 0.8975
#
# Epoch 00023: val_loss did not improve from 0.26963
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2940 - acc: 0.8793 - val_loss: 0.2577 - val_acc: 0.9013
#
# Epoch 00024: val_loss improved from 0.26963 to 0.25773, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2471 - acc: 0.9084 - val_loss: 0.2680 - val_acc: 0.8950
#
# Epoch 00025: val_loss did not improve from 0.25773
# Epoch 26/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2737 - acc: 0.8917 - val_loss: 0.2422 - val_acc: 0.9013
#
# Epoch 00026: val_loss improved from 0.25773 to 0.24220, saving model to checkpoint.h5
# Epoch 27/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2681 - acc: 0.8913 - val_loss: 0.2502 - val_acc: 0.8888
#
# Epoch 00027: val_loss did not improve from 0.24220
# Epoch 28/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2688 - acc: 0.8888 - val_loss: 0.2470 - val_acc: 0.8963
#
# Epoch 00028: val_loss did not improve from 0.24220
# Epoch 29/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2605 - acc: 0.8912 - val_loss: 0.2618 - val_acc: 0.8900
#
# Epoch 00029: val_loss did not improve from 0.24220
# Epoch 30/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2540 - acc: 0.8887 - val_loss: 0.2655 - val_acc: 0.8838
#
# Epoch 00030: val_loss did not improve from 0.24220
# Epoch 31/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2696 - acc: 0.8910 - val_loss: 0.2771 - val_acc: 0.8850
#
# Epoch 00031: val_loss did not improve from 0.24220
# Epoch 32/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2663 - acc: 0.8942 - val_loss: 0.2947 - val_acc: 0.8788
#
# Epoch 00032: val_loss did not improve from 0.24220
# Epoch 33/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2703 - acc: 0.9009 - val_loss: 0.2579 - val_acc: 0.8950
#
# Epoch 00033: val_loss did not improve from 0.24220
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2245 - acc: 0.9069 - val_loss: 0.2781 - val_acc: 0.8938
#
# Epoch 00034: val_loss did not improve from 0.24220
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2484 - acc: 0.9014 - val_loss: 0.3185 - val_acc: 0.8675
#
# Epoch 00035: val_loss did not improve from 0.24220
# Epoch 36/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2311 - acc: 0.9142 - val_loss: 0.2688 - val_acc: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.24220
# Epoch 37/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2409 - acc: 0.9024 - val_loss: 0.2684 - val_acc: 0.8975
#
# Epoch 00037: val_loss did not improve from 0.24220
# Epoch 38/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2273 - acc: 0.9114 - val_loss: 0.3143 - val_acc: 0.8825
#
# Epoch 00038: val_loss did not improve from 0.24220
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2436 - acc: 0.9022 - val_loss: 0.2782 - val_acc: 0.8888
#
# Epoch 00039: val_loss did not improve from 0.24220
# Epoch 40/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2373 - acc: 0.9087 - val_loss: 0.2671 - val_acc: 0.8975
#
# Epoch 00040: val_loss did not improve from 0.24220
# Epoch 41/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2449 - acc: 0.8910 - val_loss: 0.2730 - val_acc: 0.8938
#
# Epoch 00041: val_loss did not improve from 0.24220
# Epoch 42/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2629 - acc: 0.8901 - val_loss: 0.2858 - val_acc: 0.8938
#
# Epoch 00042: val_loss did not improve from 0.24220
# Epoch 43/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2279 - acc: 0.9127 - val_loss: 0.2917 - val_acc: 0.8988
#
# Epoch 00043: val_loss did not improve from 0.24220
# Epoch 44/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2309 - acc: 0.9118 - val_loss: 0.3117 - val_acc: 0.8938
#
# Epoch 00044: val_loss did not improve from 0.24220
# Epoch 45/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2473 - acc: 0.9122 - val_loss: 0.2758 - val_acc: 0.8913
#
# Epoch 00045: val_loss did not improve from 0.24220
# Epoch 46/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2340 - acc: 0.9164 - val_loss: 0.3025 - val_acc: 0.8763
#
# Epoch 00046: val_loss did not improve from 0.24220
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2587 - acc: 0.8938
#
# ---------------------------------
# Accuracy: 89.38 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.87      0.90       179
#          1.0       0.86      0.92      0.89       157
#
#     accuracy                           0.89       336
#    macro avg       0.89      0.89      0.89       336
# weighted avg       0.89      0.89      0.89       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'resNet_dense_256x1_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 524,801
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 138ms/step - loss: 0.5461 - acc: 0.7871 - val_loss: 0.4276 - val_acc: 0.8050
#
# Epoch 00001: val_loss improved from inf to 0.42763, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4542 - acc: 0.7938 - val_loss: 0.3792 - val_acc: 0.8238
#
# Epoch 00002: val_loss improved from 0.42763 to 0.37921, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3976 - acc: 0.8189 - val_loss: 0.3651 - val_acc: 0.8325
#
# Epoch 00003: val_loss improved from 0.37921 to 0.36513, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3981 - acc: 0.8282 - val_loss: 0.3588 - val_acc: 0.8462
#
# Epoch 00004: val_loss improved from 0.36513 to 0.35881, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3874 - acc: 0.8377 - val_loss: 0.3833 - val_acc: 0.8300
#
# Epoch 00005: val_loss did not improve from 0.35881
# Epoch 6/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4013 - acc: 0.8228 - val_loss: 0.3467 - val_acc: 0.8413
#
# Epoch 00006: val_loss improved from 0.35881 to 0.34669, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3675 - acc: 0.8452 - val_loss: 0.3436 - val_acc: 0.8475
#
# Epoch 00007: val_loss improved from 0.34669 to 0.34359, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3688 - acc: 0.8165 - val_loss: 0.3461 - val_acc: 0.8612
#
# Epoch 00008: val_loss did not improve from 0.34359
# Epoch 9/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3529 - acc: 0.8473 - val_loss: 0.3401 - val_acc: 0.8450
#
# Epoch 00009: val_loss improved from 0.34359 to 0.34008, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3730 - acc: 0.8306 - val_loss: 0.3343 - val_acc: 0.8512
#
# Epoch 00010: val_loss improved from 0.34008 to 0.33426, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3553 - acc: 0.8339 - val_loss: 0.3229 - val_acc: 0.8512
#
# Epoch 00011: val_loss improved from 0.33426 to 0.32290, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3823 - acc: 0.8274 - val_loss: 0.3266 - val_acc: 0.8600
#
# Epoch 00012: val_loss did not improve from 0.32290
# Epoch 13/15
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3907 - acc: 0.8213 - val_loss: 0.3291 - val_acc: 0.8512
#
# Epoch 00013: val_loss did not improve from 0.32290
# Epoch 14/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3914 - acc: 0.8250 - val_loss: 0.3364 - val_acc: 0.8575
#
# Epoch 00014: val_loss did not improve from 0.32290
# Epoch 15/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3567 - acc: 0.8255 - val_loss: 0.3236 - val_acc: 0.8612
#
# Epoch 00015: val_loss did not improve from 0.32290
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f55ae504320>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ae578470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2a6e240>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ae578390>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55ae02bda0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b300b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba3d7ef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57ba379a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2b30208>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae110198>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ae18ff28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae001860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae41b208>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae53ed68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2997748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c3e32a90>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c2a76b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55adf43080>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae452cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae2f90b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae0ca0f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae0caac8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c3e32cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae0c7da0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae1ffac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae1ffd68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae02b438>, <tensorflow.python.keras.layers.merge.Add object at 0x7f55ae27fbe0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae1ffe10>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae0f69e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55adfce7f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae2b4dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae0f3fd0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ae2b4940>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55adf572b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae164710>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae007c18>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55ae0a2a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae0f66a0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f55ae0a2278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae0075f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae06c2e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae007668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae06ca20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55adfcd710>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55adf8f390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae0f64e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55adfcdc18>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 9,458,177
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 135ms/step - loss: 0.5130 - acc: 0.8196 - val_loss: 0.3447 - val_acc: 0.8550
#
# Epoch 00001: val_loss did not improve from 0.32290
# Epoch 2/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3993 - acc: 0.8301 - val_loss: 0.7454 - val_acc: 0.7425
#
# Epoch 00002: val_loss did not improve from 0.32290
# Epoch 3/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3950 - acc: 0.8321 - val_loss: 0.3907 - val_acc: 0.8413
#
# Epoch 00003: val_loss did not improve from 0.32290
# Epoch 4/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3448 - acc: 0.8448 - val_loss: 0.3289 - val_acc: 0.8550
#
# Epoch 00004: val_loss did not improve from 0.32290
# Epoch 5/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3539 - acc: 0.8566 - val_loss: 0.2949 - val_acc: 0.8850
#
# Epoch 00005: val_loss improved from 0.32290 to 0.29488, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3575 - acc: 0.8598 - val_loss: 0.2973 - val_acc: 0.8737
#
# Epoch 00006: val_loss did not improve from 0.29488
# Epoch 7/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3367 - acc: 0.8651 - val_loss: 0.2768 - val_acc: 0.8938
#
# Epoch 00007: val_loss improved from 0.29488 to 0.27680, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3289 - acc: 0.8585 - val_loss: 0.2732 - val_acc: 0.8975
#
# Epoch 00008: val_loss improved from 0.27680 to 0.27324, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3113 - acc: 0.8560 - val_loss: 0.2712 - val_acc: 0.8788
#
# Epoch 00009: val_loss improved from 0.27324 to 0.27119, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2989 - acc: 0.8803 - val_loss: 0.3006 - val_acc: 0.8838
#
# Epoch 00010: val_loss did not improve from 0.27119
# Epoch 11/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2976 - acc: 0.8673 - val_loss: 0.3066 - val_acc: 0.8775
#
# Epoch 00011: val_loss did not improve from 0.27119
# Epoch 12/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2974 - acc: 0.8684 - val_loss: 0.2760 - val_acc: 0.8888
#
# Epoch 00012: val_loss did not improve from 0.27119
# Epoch 13/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3220 - acc: 0.8571 - val_loss: 0.2724 - val_acc: 0.9062
#
# Epoch 00013: val_loss did not improve from 0.27119
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3100 - acc: 0.8586 - val_loss: 0.2739 - val_acc: 0.8863
#
# Epoch 00014: val_loss did not improve from 0.27119
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2850 - acc: 0.8894 - val_loss: 0.2615 - val_acc: 0.8888
#
# Epoch 00015: val_loss improved from 0.27119 to 0.26148, saving model to checkpoint.h5
# Epoch 16/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2923 - acc: 0.8751 - val_loss: 0.2748 - val_acc: 0.8988
#
# Epoch 00016: val_loss did not improve from 0.26148
# Epoch 17/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2779 - acc: 0.8866 - val_loss: 0.3027 - val_acc: 0.8737
#
# Epoch 00017: val_loss did not improve from 0.26148
# Epoch 18/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2816 - acc: 0.8837 - val_loss: 0.2558 - val_acc: 0.8925
#
# Epoch 00018: val_loss improved from 0.26148 to 0.25578, saving model to checkpoint.h5
# Epoch 19/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2726 - acc: 0.8793 - val_loss: 0.2690 - val_acc: 0.9013
#
# Epoch 00019: val_loss did not improve from 0.25578
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2533 - acc: 0.8954 - val_loss: 0.2696 - val_acc: 0.8938
#
# Epoch 00020: val_loss did not improve from 0.25578
# Epoch 21/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2687 - acc: 0.8830 - val_loss: 0.2827 - val_acc: 0.8925
#
# Epoch 00021: val_loss did not improve from 0.25578
# Epoch 22/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2754 - acc: 0.8903 - val_loss: 0.2745 - val_acc: 0.8925
#
# Epoch 00022: val_loss did not improve from 0.25578
# Epoch 23/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2657 - acc: 0.8751 - val_loss: 0.2705 - val_acc: 0.8975
#
# Epoch 00023: val_loss did not improve from 0.25578
# Epoch 24/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2805 - acc: 0.8701 - val_loss: 0.3060 - val_acc: 0.8888
#
# Epoch 00024: val_loss did not improve from 0.25578
# Epoch 25/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2333 - acc: 0.9176 - val_loss: 0.2770 - val_acc: 0.8975
#
# Epoch 00025: val_loss did not improve from 0.25578
# Epoch 26/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2537 - acc: 0.8937 - val_loss: 0.2853 - val_acc: 0.8788
#
# Epoch 00026: val_loss did not improve from 0.25578
# Epoch 27/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2781 - acc: 0.8929 - val_loss: 0.2782 - val_acc: 0.8938
#
# Epoch 00027: val_loss did not improve from 0.25578
# Epoch 28/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2286 - acc: 0.9086 - val_loss: 0.2603 - val_acc: 0.8925
#
# Epoch 00028: val_loss did not improve from 0.25578
# Epoch 29/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2567 - acc: 0.8993 - val_loss: 0.2642 - val_acc: 0.8950
#
# Epoch 00029: val_loss did not improve from 0.25578
# Epoch 30/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2685 - acc: 0.8848 - val_loss: 0.2504 - val_acc: 0.8850
#
# Epoch 00030: val_loss improved from 0.25578 to 0.25038, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2479 - acc: 0.8900 - val_loss: 0.2752 - val_acc: 0.8788
#
# Epoch 00031: val_loss did not improve from 0.25038
# Epoch 32/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2426 - acc: 0.8943 - val_loss: 0.2619 - val_acc: 0.8925
#
# Epoch 00032: val_loss did not improve from 0.25038
# Epoch 33/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2628 - acc: 0.8840 - val_loss: 0.2536 - val_acc: 0.8963
#
# Epoch 00033: val_loss did not improve from 0.25038
# Epoch 34/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2491 - acc: 0.8917 - val_loss: 0.2701 - val_acc: 0.8963
#
# Epoch 00034: val_loss did not improve from 0.25038
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2674 - acc: 0.8936 - val_loss: 0.2738 - val_acc: 0.8925
#
# Epoch 00035: val_loss did not improve from 0.25038
# Epoch 36/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2486 - acc: 0.8953 - val_loss: 0.2832 - val_acc: 0.8838
#
# Epoch 00036: val_loss did not improve from 0.25038
# Epoch 37/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2473 - acc: 0.9013 - val_loss: 0.2708 - val_acc: 0.8913
#
# Epoch 00037: val_loss did not improve from 0.25038
# Epoch 38/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2529 - acc: 0.8997 - val_loss: 0.2848 - val_acc: 0.8900
#
# Epoch 00038: val_loss did not improve from 0.25038
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2245 - acc: 0.9080 - val_loss: 0.2737 - val_acc: 0.8950
#
# Epoch 00039: val_loss did not improve from 0.25038
# Epoch 40/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2654 - acc: 0.9010 - val_loss: 0.2577 - val_acc: 0.8950
#
# Epoch 00040: val_loss did not improve from 0.25038
# Epoch 41/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2405 - acc: 0.9035 - val_loss: 0.2684 - val_acc: 0.8938
#
# Epoch 00041: val_loss did not improve from 0.25038
# Epoch 42/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2372 - acc: 0.9043 - val_loss: 0.2517 - val_acc: 0.8925
#
# Epoch 00042: val_loss did not improve from 0.25038
# Epoch 43/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2027 - acc: 0.9186 - val_loss: 0.2551 - val_acc: 0.8925
#
# Epoch 00043: val_loss did not improve from 0.25038
# Epoch 44/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2169 - acc: 0.9073 - val_loss: 0.3021 - val_acc: 0.8750
#
# Epoch 00044: val_loss did not improve from 0.25038
# Epoch 45/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2325 - acc: 0.9085 - val_loss: 0.2844 - val_acc: 0.8888
#
# Epoch 00045: val_loss did not improve from 0.25038
# Epoch 46/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2508 - acc: 0.8944 - val_loss: 0.2852 - val_acc: 0.8925
#
# Epoch 00046: val_loss did not improve from 0.25038
# Epoch 47/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2464 - acc: 0.9070 - val_loss: 0.2930 - val_acc: 0.8850
#
# Epoch 00047: val_loss did not improve from 0.25038
# Epoch 48/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2173 - acc: 0.9104 - val_loss: 0.2860 - val_acc: 0.8925
#
# Epoch 00048: val_loss did not improve from 0.25038
# Epoch 49/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2405 - acc: 0.8998 - val_loss: 0.2787 - val_acc: 0.8900
#
# Epoch 00049: val_loss did not improve from 0.25038
# Epoch 50/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2302 - acc: 0.9035 - val_loss: 0.3176 - val_acc: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.25038
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3127 - acc: 0.8625
#
# ---------------------------------
# Accuracy: 86.25 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.82      0.86       179
#          1.0       0.81      0.92      0.86       157
#
#     accuracy                           0.86       336
#    macro avg       0.87      0.87      0.86       336
# weighted avg       0.87      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'vgg__globalAvgPool_dense_256x1_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 13,107,713
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 132ms/step - loss: 1.4296 - acc: 0.7483 - val_loss: 0.4120 - val_acc: 0.8275
#
# Epoch 00001: val_loss improved from inf to 0.41197, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4858 - acc: 0.7794 - val_loss: 0.3326 - val_acc: 0.8525
#
# Epoch 00002: val_loss improved from 0.41197 to 0.33255, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4227 - acc: 0.8140 - val_loss: 0.3550 - val_acc: 0.8450
#
# Epoch 00003: val_loss did not improve from 0.33255
# Epoch 4/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4068 - acc: 0.8161 - val_loss: 0.3415 - val_acc: 0.8462
#
# Epoch 00004: val_loss did not improve from 0.33255
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3770 - acc: 0.8348 - val_loss: 0.3271 - val_acc: 0.8587
#
# Epoch 00005: val_loss improved from 0.33255 to 0.32713, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3936 - acc: 0.8256 - val_loss: 0.3266 - val_acc: 0.8637
#
# Epoch 00006: val_loss improved from 0.32713 to 0.32664, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3842 - acc: 0.8261 - val_loss: 0.3560 - val_acc: 0.8425
#
# Epoch 00007: val_loss did not improve from 0.32664
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3875 - acc: 0.8245 - val_loss: 0.3238 - val_acc: 0.8650
#
# Epoch 00008: val_loss improved from 0.32664 to 0.32381, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3884 - acc: 0.8278 - val_loss: 0.3180 - val_acc: 0.8637
#
# Epoch 00009: val_loss improved from 0.32381 to 0.31805, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3465 - acc: 0.8501 - val_loss: 0.3188 - val_acc: 0.8675
#
# Epoch 00010: val_loss did not improve from 0.31805
# Epoch 11/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3356 - acc: 0.8600 - val_loss: 0.3088 - val_acc: 0.8687
#
# Epoch 00011: val_loss improved from 0.31805 to 0.30882, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3935 - acc: 0.8154 - val_loss: 0.3122 - val_acc: 0.8612
#
# Epoch 00012: val_loss did not improve from 0.30882
# Epoch 13/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3338 - acc: 0.8593 - val_loss: 0.2990 - val_acc: 0.8725
#
# Epoch 00013: val_loss improved from 0.30882 to 0.29898, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3556 - acc: 0.8478 - val_loss: 0.3128 - val_acc: 0.8625
#
# Epoch 00014: val_loss did not improve from 0.29898
# Epoch 15/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3481 - acc: 0.8448 - val_loss: 0.3038 - val_acc: 0.8725
#
# Epoch 00015: val_loss did not improve from 0.29898
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f55ad4ac2b0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ad854a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ad71add8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c2698978>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f57c3e32c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ad780908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c26f5160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ad723d68>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ad7f3320>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba3ef080>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ad728780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57ba132470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba183518>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55af67f438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2698748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58103ca400>, <tensorflow.python.keras.layers.merge.Add object at 0x7f55ad71ada0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c267d6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c26f5a90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55af6ab940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55af67f1d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba148cc0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55ad79ce10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c26e35f8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57985bc780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57985bcf28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57ba1c8320>, <tensorflow.python.keras.layers.merge.Add object at 0x7f58104549e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba406048>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba406a90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c23e9eb8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba4065f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f5798483550>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57ba089be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5810394cf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5798483358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c3d68278>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55af619710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57ba148fd0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c23e9978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57985f87f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57985f8208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c26958d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c237a8d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c237a080>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57ba4064a8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55af674128>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c237aa58>, <tensorflow.python.kera ...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,672,513
# Trainable params: 28,078,593
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 132ms/step - loss: 1.1771 - acc: 0.8206 - val_loss: 0.4545 - val_acc: 0.8363
#
# Epoch 00001: val_loss did not improve from 0.29898
# Epoch 2/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3864 - acc: 0.8348 - val_loss: 0.3618 - val_acc: 0.8350
#
# Epoch 00002: val_loss did not improve from 0.29898
# Epoch 3/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3733 - acc: 0.8392 - val_loss: 0.3256 - val_acc: 0.8675
#
# Epoch 00003: val_loss did not improve from 0.29898
# Epoch 4/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3585 - acc: 0.8570 - val_loss: 0.2747 - val_acc: 0.8875
#
# Epoch 00004: val_loss improved from 0.29898 to 0.27472, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3121 - acc: 0.8654 - val_loss: 0.2935 - val_acc: 0.8775
#
# Epoch 00005: val_loss did not improve from 0.27472
# Epoch 6/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3320 - acc: 0.8558 - val_loss: 0.2620 - val_acc: 0.8875
#
# Epoch 00006: val_loss improved from 0.27472 to 0.26204, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2938 - acc: 0.8657 - val_loss: 0.2282 - val_acc: 0.9062
#
# Epoch 00007: val_loss improved from 0.26204 to 0.22824, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3152 - acc: 0.8557 - val_loss: 0.2578 - val_acc: 0.8975
#
# Epoch 00008: val_loss did not improve from 0.22824
# Epoch 9/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3147 - acc: 0.8519 - val_loss: 0.2519 - val_acc: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.22824
# Epoch 10/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2899 - acc: 0.8786 - val_loss: 0.3572 - val_acc: 0.8475
#
# Epoch 00010: val_loss did not improve from 0.22824
# Epoch 11/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2598 - acc: 0.8971 - val_loss: 0.2460 - val_acc: 0.8938
#
# Epoch 00011: val_loss did not improve from 0.22824
# Epoch 12/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2645 - acc: 0.8866 - val_loss: 0.2630 - val_acc: 0.8913
#
# Epoch 00012: val_loss did not improve from 0.22824
# Epoch 13/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2560 - acc: 0.8968 - val_loss: 0.2826 - val_acc: 0.8863
#
# Epoch 00013: val_loss did not improve from 0.22824
# Epoch 14/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2648 - acc: 0.8861 - val_loss: 0.2477 - val_acc: 0.9013
#
# Epoch 00014: val_loss did not improve from 0.22824
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2844 - acc: 0.8863 - val_loss: 0.3025 - val_acc: 0.8775
#
# Epoch 00015: val_loss did not improve from 0.22824
# Epoch 16/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2533 - acc: 0.8915 - val_loss: 0.2750 - val_acc: 0.8950
#
# Epoch 00016: val_loss did not improve from 0.22824
# Epoch 17/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2376 - acc: 0.9030 - val_loss: 0.2822 - val_acc: 0.8813
#
# Epoch 00017: val_loss did not improve from 0.22824
# Epoch 18/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2590 - acc: 0.8888 - val_loss: 0.2461 - val_acc: 0.9075
#
# Epoch 00018: val_loss did not improve from 0.22824
# Epoch 19/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2383 - acc: 0.9121 - val_loss: 0.2282 - val_acc: 0.9100
#
# Epoch 00019: val_loss improved from 0.22824 to 0.22819, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2460 - acc: 0.8847 - val_loss: 0.2474 - val_acc: 0.9100
#
# Epoch 00020: val_loss did not improve from 0.22819
# Epoch 21/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2429 - acc: 0.8957 - val_loss: 0.3323 - val_acc: 0.8712
#
# Epoch 00021: val_loss did not improve from 0.22819
# Epoch 22/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2653 - acc: 0.8860 - val_loss: 0.2971 - val_acc: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.22819
# Epoch 23/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2537 - acc: 0.9034 - val_loss: 0.2768 - val_acc: 0.9125
#
# Epoch 00023: val_loss did not improve from 0.22819
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2499 - acc: 0.9034 - val_loss: 0.2821 - val_acc: 0.8950
#
# Epoch 00024: val_loss did not improve from 0.22819
# Epoch 25/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2287 - acc: 0.9080 - val_loss: 0.2428 - val_acc: 0.9075
#
# Epoch 00025: val_loss did not improve from 0.22819
# Epoch 26/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2430 - acc: 0.8896 - val_loss: 0.2438 - val_acc: 0.9150
#
# Epoch 00026: val_loss did not improve from 0.22819
# Epoch 27/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2485 - acc: 0.8965 - val_loss: 0.3046 - val_acc: 0.9025
#
# Epoch 00027: val_loss did not improve from 0.22819
# Epoch 28/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2320 - acc: 0.9091 - val_loss: 0.2516 - val_acc: 0.9137
#
# Epoch 00028: val_loss did not improve from 0.22819
# Epoch 29/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2305 - acc: 0.9030 - val_loss: 0.2556 - val_acc: 0.8975
#
# Epoch 00029: val_loss did not improve from 0.22819
# Epoch 30/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2499 - acc: 0.8953 - val_loss: 0.2651 - val_acc: 0.8950
#
# Epoch 00030: val_loss did not improve from 0.22819
# Epoch 31/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2190 - acc: 0.9144 - val_loss: 0.2718 - val_acc: 0.9013
#
# Epoch 00031: val_loss did not improve from 0.22819
# Epoch 32/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2069 - acc: 0.9173 - val_loss: 0.2677 - val_acc: 0.9025
#
# Epoch 00032: val_loss did not improve from 0.22819
# Epoch 33/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2330 - acc: 0.9079 - val_loss: 0.2837 - val_acc: 0.8925
#
# Epoch 00033: val_loss did not improve from 0.22819
# Epoch 34/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2064 - acc: 0.9038 - val_loss: 0.2831 - val_acc: 0.8850
#
# Epoch 00034: val_loss did not improve from 0.22819
# Epoch 35/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2058 - acc: 0.9184 - val_loss: 0.2771 - val_acc: 0.9013
#
# Epoch 00035: val_loss did not improve from 0.22819
# Epoch 36/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2422 - acc: 0.9013 - val_loss: 0.2614 - val_acc: 0.9013
#
# Epoch 00036: val_loss did not improve from 0.22819
# Epoch 37/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2216 - acc: 0.9173 - val_loss: 0.2516 - val_acc: 0.9025
#
# Epoch 00037: val_loss did not improve from 0.22819
# Epoch 38/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2011 - acc: 0.9282 - val_loss: 0.2860 - val_acc: 0.9100
#
# Epoch 00038: val_loss did not improve from 0.22819
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.1966 - acc: 0.9211 - val_loss: 0.3466 - val_acc: 0.8737
#
# Epoch 00039: val_loss did not improve from 0.22819
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2753 - acc: 0.8750
#
# ---------------------------------
# Accuracy: 87.50 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.83      0.88       179
#          1.0       0.83      0.94      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_Flatten_dense_256x1_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 524,801
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 139ms/step - loss: 0.6196 - acc: 0.7570 - val_loss: 0.3468 - val_acc: 0.8512
#
# Epoch 00001: val_loss improved from inf to 0.34678, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4741 - acc: 0.7770 - val_loss: 0.3397 - val_acc: 0.8487
#
# Epoch 00002: val_loss improved from 0.34678 to 0.33974, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4327 - acc: 0.7963 - val_loss: 0.3267 - val_acc: 0.8637
#
# Epoch 00003: val_loss improved from 0.33974 to 0.32673, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4262 - acc: 0.7985 - val_loss: 0.3295 - val_acc: 0.8575
#
# Epoch 00004: val_loss did not improve from 0.32673
# Epoch 5/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4150 - acc: 0.8140 - val_loss: 0.3305 - val_acc: 0.8525
#
# Epoch 00005: val_loss did not improve from 0.32673
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4389 - acc: 0.7959 - val_loss: 0.3186 - val_acc: 0.8587
#
# Epoch 00006: val_loss improved from 0.32673 to 0.31861, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3980 - acc: 0.8260 - val_loss: 0.3163 - val_acc: 0.8612
#
# Epoch 00007: val_loss improved from 0.31861 to 0.31630, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4083 - acc: 0.8216 - val_loss: 0.3074 - val_acc: 0.8712
#
# Epoch 00008: val_loss improved from 0.31630 to 0.30738, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3827 - acc: 0.8285 - val_loss: 0.3008 - val_acc: 0.8712
#
# Epoch 00009: val_loss improved from 0.30738 to 0.30083, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3680 - acc: 0.8278 - val_loss: 0.3098 - val_acc: 0.8575
#
# Epoch 00010: val_loss did not improve from 0.30083
# Epoch 11/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3728 - acc: 0.8271 - val_loss: 0.3232 - val_acc: 0.8612
#
# Epoch 00011: val_loss did not improve from 0.30083
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3746 - acc: 0.8404 - val_loss: 0.3180 - val_acc: 0.8637
#
# Epoch 00012: val_loss did not improve from 0.30083
# Epoch 13/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3800 - acc: 0.8344 - val_loss: 0.3003 - val_acc: 0.8637
#
# Epoch 00013: val_loss improved from 0.30083 to 0.30026, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3672 - acc: 0.8321 - val_loss: 0.3268 - val_acc: 0.8612
#
# Epoch 00014: val_loss did not improve from 0.30026
# Epoch 15/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3710 - acc: 0.8322 - val_loss: 0.3412 - val_acc: 0.8388
#
# Epoch 00015: val_loss did not improve from 0.30026
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f55ad4d9b38>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c25cfa58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2553518>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c25cfac8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55af5fa4e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2173c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ad794588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c2565fd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c281c390>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c23dc6a0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f55af5efe48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c23f70b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f581040fc18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba252e10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c215f9e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c281c940>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c2553588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba0372b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ae28e128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58104ad630>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba16ca90>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c286eda0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c22d1b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57985c5978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57ba236198>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c28346d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ad4d0f60>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c23d1a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2be6a90>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ad2bc4e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57ba236f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2ae8e48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57c2ae8630>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57ba170320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55af5fabe0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c2ae8748>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ad6bb6d8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f57c3e49be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c23d1128>, <tensorflow.python.keras.layers.merge.Add object at 0x7f57c3e6fd30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f57c3e496a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f57ba0486d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f57c3e49a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ae281fd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55af5df978>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f57c28342b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55ae2b3438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ad2bcb70>, <tensorflow.python.kera ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,089,601
# Trainable params: 15,495,681
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 133ms/step - loss: 0.5081 - acc: 0.8073 - val_loss: 0.5076 - val_acc: 0.8413
#
# Epoch 00001: val_loss did not improve from 0.30026
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3825 - acc: 0.8284 - val_loss: 0.2847 - val_acc: 0.8712
#
# Epoch 00002: val_loss improved from 0.30026 to 0.28467, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3401 - acc: 0.8573 - val_loss: 0.2498 - val_acc: 0.8863
#
# Epoch 00003: val_loss improved from 0.28467 to 0.24980, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3120 - acc: 0.8743 - val_loss: 0.3050 - val_acc: 0.8938
#
# Epoch 00004: val_loss did not improve from 0.24980
# Epoch 5/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3376 - acc: 0.8599 - val_loss: 0.2567 - val_acc: 0.8900
#
# Epoch 00005: val_loss did not improve from 0.24980
# Epoch 6/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2956 - acc: 0.8711 - val_loss: 0.2283 - val_acc: 0.9062
#
# Epoch 00006: val_loss improved from 0.24980 to 0.22826, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2785 - acc: 0.8904 - val_loss: 0.2491 - val_acc: 0.9025
#
# Epoch 00007: val_loss did not improve from 0.22826
# Epoch 8/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2583 - acc: 0.8911 - val_loss: 0.2768 - val_acc: 0.8963
#
# Epoch 00008: val_loss did not improve from 0.22826
# Epoch 9/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2820 - acc: 0.8900 - val_loss: 0.2315 - val_acc: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.22826
# Epoch 10/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2887 - acc: 0.8758 - val_loss: 0.2309 - val_acc: 0.8975
#
# Epoch 00010: val_loss did not improve from 0.22826
# Epoch 11/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2764 - acc: 0.8874 - val_loss: 0.2217 - val_acc: 0.9112
#
# Epoch 00011: val_loss improved from 0.22826 to 0.22169, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2953 - acc: 0.8662 - val_loss: 0.2506 - val_acc: 0.8975
#
# Epoch 00012: val_loss did not improve from 0.22169
# Epoch 13/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2716 - acc: 0.8843 - val_loss: 0.2404 - val_acc: 0.8900
#
# Epoch 00013: val_loss did not improve from 0.22169
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2766 - acc: 0.8834 - val_loss: 0.2735 - val_acc: 0.8963
#
# Epoch 00014: val_loss did not improve from 0.22169
# Epoch 15/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2543 - acc: 0.8896 - val_loss: 0.2403 - val_acc: 0.9025
#
# Epoch 00015: val_loss did not improve from 0.22169
# Epoch 16/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2544 - acc: 0.9033 - val_loss: 0.2567 - val_acc: 0.8850
#
# Epoch 00016: val_loss did not improve from 0.22169
# Epoch 17/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2600 - acc: 0.8931 - val_loss: 0.2324 - val_acc: 0.9075
#
# Epoch 00017: val_loss did not improve from 0.22169
# Epoch 18/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2554 - acc: 0.9099 - val_loss: 0.2536 - val_acc: 0.8938
#
# Epoch 00018: val_loss did not improve from 0.22169
# Epoch 19/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2630 - acc: 0.9009 - val_loss: 0.2553 - val_acc: 0.8863
#
# Epoch 00019: val_loss did not improve from 0.22169
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2584 - acc: 0.8955 - val_loss: 0.2469 - val_acc: 0.9000
#
# Epoch 00020: val_loss did not improve from 0.22169
# Epoch 21/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2386 - acc: 0.8962 - val_loss: 0.2163 - val_acc: 0.9025
#
# Epoch 00021: val_loss improved from 0.22169 to 0.21631, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2655 - acc: 0.8938 - val_loss: 0.2260 - val_acc: 0.9075
#
# Epoch 00022: val_loss did not improve from 0.21631
# Epoch 23/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2340 - acc: 0.9042 - val_loss: 0.2642 - val_acc: 0.8963
#
# Epoch 00023: val_loss did not improve from 0.21631
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2556 - acc: 0.9035 - val_loss: 0.2162 - val_acc: 0.9125
#
# Epoch 00024: val_loss improved from 0.21631 to 0.21616, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2395 - acc: 0.8970 - val_loss: 0.2828 - val_acc: 0.8863
#
# Epoch 00025: val_loss did not improve from 0.21616
# Epoch 26/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2378 - acc: 0.8933 - val_loss: 0.2229 - val_acc: 0.9062
#
# Epoch 00026: val_loss did not improve from 0.21616
# Epoch 27/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2343 - acc: 0.8953 - val_loss: 0.2344 - val_acc: 0.9000
#
# Epoch 00027: val_loss did not improve from 0.21616
# Epoch 28/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2681 - acc: 0.8927 - val_loss: 0.2371 - val_acc: 0.9100
#
# Epoch 00028: val_loss did not improve from 0.21616
# Epoch 29/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2650 - acc: 0.9014 - val_loss: 0.2440 - val_acc: 0.9087
#
# Epoch 00029: val_loss did not improve from 0.21616
# Epoch 30/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2153 - acc: 0.9152 - val_loss: 0.2376 - val_acc: 0.9013
#
# Epoch 00030: val_loss did not improve from 0.21616
# Epoch 31/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2168 - acc: 0.9109 - val_loss: 0.2210 - val_acc: 0.9062
#
# Epoch 00031: val_loss did not improve from 0.21616
# Epoch 32/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2127 - acc: 0.9163 - val_loss: 0.2501 - val_acc: 0.9038
#
# Epoch 00032: val_loss did not improve from 0.21616
# Epoch 33/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.1964 - acc: 0.9209 - val_loss: 0.2104 - val_acc: 0.9050
#
# Epoch 00033: val_loss improved from 0.21616 to 0.21042, saving model to checkpoint.h5
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.1960 - acc: 0.9109 - val_loss: 0.2043 - val_acc: 0.9150
#
# Epoch 00034: val_loss improved from 0.21042 to 0.20435, saving model to checkpoint.h5
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2216 - acc: 0.9085 - val_loss: 0.2406 - val_acc: 0.9225
#
# Epoch 00035: val_loss did not improve from 0.20435
# Epoch 36/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2044 - acc: 0.9169 - val_loss: 0.3116 - val_acc: 0.8888
#
# Epoch 00036: val_loss did not improve from 0.20435
# Epoch 37/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2099 - acc: 0.9110 - val_loss: 0.2082 - val_acc: 0.9275
#
# Epoch 00037: val_loss did not improve from 0.20435
# Epoch 38/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2177 - acc: 0.9059 - val_loss: 0.2101 - val_acc: 0.9100
#
# Epoch 00038: val_loss did not improve from 0.20435
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2325 - acc: 0.9175 - val_loss: 0.2092 - val_acc: 0.9125
#
# Epoch 00039: val_loss did not improve from 0.20435
# Epoch 40/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.1840 - acc: 0.9263 - val_loss: 0.2548 - val_acc: 0.8975
#
# Epoch 00040: val_loss did not improve from 0.20435
# Epoch 41/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2176 - acc: 0.9167 - val_loss: 0.2406 - val_acc: 0.9062
#
# Epoch 00041: val_loss did not improve from 0.20435
# Epoch 42/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2303 - acc: 0.9020 - val_loss: 0.2596 - val_acc: 0.8900
#
# Epoch 00042: val_loss did not improve from 0.20435
# Epoch 43/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2037 - acc: 0.9150 - val_loss: 0.3037 - val_acc: 0.8963
#
# Epoch 00043: val_loss did not improve from 0.20435
# Epoch 44/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.1858 - acc: 0.9328 - val_loss: 0.2791 - val_acc: 0.8850
#
# Epoch 00044: val_loss did not improve from 0.20435
# Epoch 45/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2167 - acc: 0.9085 - val_loss: 0.2559 - val_acc: 0.9087
#
# Epoch 00045: val_loss did not improve from 0.20435
# Epoch 46/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2163 - acc: 0.9075 - val_loss: 0.2408 - val_acc: 0.9100
#
# Epoch 00046: val_loss did not improve from 0.20435
# Epoch 47/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2010 - acc: 0.9185 - val_loss: 0.2430 - val_acc: 0.9000
#
# Epoch 00047: val_loss did not improve from 0.20435
# Epoch 48/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2017 - acc: 0.9226 - val_loss: 0.2481 - val_acc: 0.8988
#
# Epoch 00048: val_loss did not improve from 0.20435
# Epoch 49/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2026 - acc: 0.9106 - val_loss: 0.2341 - val_acc: 0.8975
#
# Epoch 00049: val_loss did not improve from 0.20435
# Epoch 50/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.1976 - acc: 0.9062 - val_loss: 0.2063 - val_acc: 0.9100
#
# Epoch 00050: val_loss did not improve from 0.20435
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3102 - acc: 0.8906
#
# ---------------------------------
# Accuracy: 89.06 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.88      0.90       179
#          1.0       0.87      0.92      0.89       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet__globalAvgPool_dense_256x1_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, 3x [ DropOut(0.5 + Dense (256)]

# %% [markdown]
# ##Flatten, Non Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 156, 156, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 75, 75, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 77, 77, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 38, 38, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 38, 38, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 38, 38, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 38, 38, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 38, 38, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 38, 38, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 38, 38, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 38, 38, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 38, 38, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 38, 38, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 38, 38, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 38, 38, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 38, 38, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 38, 38, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 38, 38, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 38, 38, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 38, 38, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 40, 40, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 19, 19, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 19, 19, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 19, 19, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 19, 19, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 19, 19, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 19, 19, 256)  0           max_pooling2d_9[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 19, 19, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 19, 19, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 19, 19, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 19, 19, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 19, 19, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 19, 19, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 19, 19, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 19, 19, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 19, 19, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 19, 19, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 19, 19, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 19, 19, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 19, 19, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 19, 19, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 19, 19, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 19, 19, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 19, 19, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 19, 19, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 19, 19, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 19, 19, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 21, 21, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 10, 10, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 10, 10, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 10, 10, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 10, 10, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 10, 10, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 10, 10, 512)  0           max_pooling2d_10[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 10, 10, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 10, 10, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 10, 10, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 10, 10, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 10, 10, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 10, 10, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 10, 10, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 10, 10, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 10, 10, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 10, 10, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 10, 10, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 10, 10, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 10, 10, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 10, 10, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 10, 10, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 10, 10, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 10, 10, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 10, 10, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 10, 10, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 10, 10, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 10, 10, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 10, 10, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 10, 10, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 10, 10, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 12, 12, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 5, 5, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 5, 5, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 5, 5, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 5, 5, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 5, 5, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 5, 5, 1024)   0           max_pooling2d_11[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 5, 5, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 5, 5, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 5, 5, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 5, 5, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 5, 5, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 5, 5, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 5, 5, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 5, 5, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 5, 5, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 5, 5, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 5, 5, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 5, 5, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 5, 5, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 7, 7, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 5, 5, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 5, 5, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 5, 5, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 5, 5, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 5, 5, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 5, 5, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 5, 5, 2048)   0           post_bn[0][0]
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 13,239,297
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 133ms/step - loss: 0.8340 - acc: 0.6677 - val_loss: 0.4662 - val_acc: 0.7675
#
# Epoch 00001: val_loss improved from inf to 0.46616, saving model to checkpoint_2.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6208 - acc: 0.6907 - val_loss: 0.4528 - val_acc: 0.7850
#
# Epoch 00002: val_loss improved from 0.46616 to 0.45278, saving model to checkpoint_2.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5827 - acc: 0.7040 - val_loss: 0.3948 - val_acc: 0.8200
#
# Epoch 00003: val_loss improved from 0.45278 to 0.39475, saving model to checkpoint_2.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5328 - acc: 0.7255 - val_loss: 0.3838 - val_acc: 0.8350
#
# Epoch 00004: val_loss improved from 0.39475 to 0.38375, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5426 - acc: 0.7416 - val_loss: 0.4035 - val_acc: 0.8150
#
# Epoch 00005: val_loss did not improve from 0.38375
# Epoch 6/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5153 - acc: 0.7507 - val_loss: 0.3565 - val_acc: 0.8462
#
# Epoch 00006: val_loss improved from 0.38375 to 0.35654, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5238 - acc: 0.7413 - val_loss: 0.3506 - val_acc: 0.8425
#
# Epoch 00007: val_loss improved from 0.35654 to 0.35063, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5391 - acc: 0.7440 - val_loss: 0.3512 - val_acc: 0.8413
#
# Epoch 00008: val_loss did not improve from 0.35063
# Epoch 9/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5016 - acc: 0.7529 - val_loss: 0.3435 - val_acc: 0.8500
#
# Epoch 00009: val_loss improved from 0.35063 to 0.34347, saving model to checkpoint_2.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4875 - acc: 0.7688 - val_loss: 0.3393 - val_acc: 0.8575
#
# Epoch 00010: val_loss improved from 0.34347 to 0.33929, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4770 - acc: 0.7565 - val_loss: 0.3374 - val_acc: 0.8562
#
# Epoch 00011: val_loss improved from 0.33929 to 0.33738, saving model to checkpoint_2.h5
# Epoch 12/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4400 - acc: 0.7998 - val_loss: 0.3432 - val_acc: 0.8525
#
# Epoch 00012: val_loss did not improve from 0.33738
# Epoch 13/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4797 - acc: 0.7780 - val_loss: 0.3374 - val_acc: 0.8675
#
# Epoch 00013: val_loss did not improve from 0.33738
# Epoch 14/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4981 - acc: 0.7779 - val_loss: 0.3458 - val_acc: 0.8550
#
# Epoch 00014: val_loss did not improve from 0.33738
# Epoch 15/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4751 - acc: 0.7852 - val_loss: 0.3224 - val_acc: 0.8600
#
# Epoch 00015: val_loss improved from 0.33738 to 0.32242, saving model to checkpoint_2.h5
# Epoch 16/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4351 - acc: 0.7855 - val_loss: 0.3462 - val_acc: 0.8537
#
# Epoch 00016: val_loss did not improve from 0.32242
# Epoch 17/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4506 - acc: 0.7843 - val_loss: 0.3422 - val_acc: 0.8475
#
# Epoch 00017: val_loss did not improve from 0.32242
# Epoch 18/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4376 - acc: 0.8047 - val_loss: 0.3264 - val_acc: 0.8612
#
# Epoch 00018: val_loss did not improve from 0.32242
# Epoch 19/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4608 - acc: 0.7783 - val_loss: 0.3253 - val_acc: 0.8662
#
# Epoch 00019: val_loss did not improve from 0.32242
# Epoch 20/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4484 - acc: 0.7967 - val_loss: 0.3294 - val_acc: 0.8575
#
# Epoch 00020: val_loss did not improve from 0.32242
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4279 - acc: 0.8081 - val_loss: 0.3221 - val_acc: 0.8637
#
# Epoch 00021: val_loss improved from 0.32242 to 0.32213, saving model to checkpoint_2.h5
# Epoch 22/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4524 - acc: 0.7882 - val_loss: 0.3263 - val_acc: 0.8637
#
# Epoch 00022: val_loss did not improve from 0.32213
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4476 - acc: 0.8098 - val_loss: 0.3167 - val_acc: 0.8600
#
# Epoch 00023: val_loss improved from 0.32213 to 0.31667, saving model to checkpoint_2.h5
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4361 - acc: 0.7966 - val_loss: 0.3120 - val_acc: 0.8600
#
# Epoch 00024: val_loss improved from 0.31667 to 0.31198, saving model to checkpoint_2.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4533 - acc: 0.7871 - val_loss: 0.3113 - val_acc: 0.8662
#
# Epoch 00025: val_loss improved from 0.31198 to 0.31129, saving model to checkpoint_2.h5
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4365 - acc: 0.7960 - val_loss: 0.3136 - val_acc: 0.8625
#
# Epoch 00026: val_loss did not improve from 0.31129
# Epoch 27/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4527 - acc: 0.7865 - val_loss: 0.3141 - val_acc: 0.8637
#
# Epoch 00027: val_loss did not improve from 0.31129
# Epoch 28/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4234 - acc: 0.7954 - val_loss: 0.3095 - val_acc: 0.8687
#
# Epoch 00028: val_loss improved from 0.31129 to 0.30950, saving model to checkpoint_2.h5
# Epoch 29/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4476 - acc: 0.8059 - val_loss: 0.3178 - val_acc: 0.8637
#
# Epoch 00029: val_loss did not improve from 0.30950
# Epoch 30/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4237 - acc: 0.8142 - val_loss: 0.3172 - val_acc: 0.8637
#
# Epoch 00030: val_loss did not improve from 0.30950
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4326 - acc: 0.8145 - val_loss: 0.3087 - val_acc: 0.8675
#
# Epoch 00031: val_loss improved from 0.30950 to 0.30874, saving model to checkpoint_2.h5
# Epoch 32/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3837 - acc: 0.8344 - val_loss: 0.3230 - val_acc: 0.8562
#
# Epoch 00032: val_loss did not improve from 0.30874
# Epoch 33/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4109 - acc: 0.8042 - val_loss: 0.3097 - val_acc: 0.8550
#
# Epoch 00033: val_loss did not improve from 0.30874
# Epoch 34/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4324 - acc: 0.8053 - val_loss: 0.3088 - val_acc: 0.8687
#
# Epoch 00034: val_loss did not improve from 0.30874
# Epoch 35/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4047 - acc: 0.8207 - val_loss: 0.3158 - val_acc: 0.8675
#
# Epoch 00035: val_loss did not improve from 0.30874
# Epoch 36/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4217 - acc: 0.8192 - val_loss: 0.3020 - val_acc: 0.8763
#
# Epoch 00036: val_loss improved from 0.30874 to 0.30197, saving model to checkpoint_2.h5
# Epoch 37/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3840 - acc: 0.8300 - val_loss: 0.2975 - val_acc: 0.8788
#
# Epoch 00037: val_loss improved from 0.30197 to 0.29754, saving model to checkpoint_2.h5
# Epoch 38/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4658 - acc: 0.7894 - val_loss: 0.3032 - val_acc: 0.8750
#
# Epoch 00038: val_loss did not improve from 0.29754
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4371 - acc: 0.8086 - val_loss: 0.3026 - val_acc: 0.8712
#
# Epoch 00039: val_loss did not improve from 0.29754
# Epoch 40/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4308 - acc: 0.8085 - val_loss: 0.2929 - val_acc: 0.8737
#
# Epoch 00040: val_loss improved from 0.29754 to 0.29294, saving model to checkpoint_2.h5
# Epoch 41/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4162 - acc: 0.7974 - val_loss: 0.3104 - val_acc: 0.8687
#
# Epoch 00041: val_loss did not improve from 0.29294
# Epoch 42/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3894 - acc: 0.8207 - val_loss: 0.3022 - val_acc: 0.8687
#
# Epoch 00042: val_loss did not improve from 0.29294
# Epoch 43/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4123 - acc: 0.8134 - val_loss: 0.3042 - val_acc: 0.8650
#
# Epoch 00043: val_loss did not improve from 0.29294
# Epoch 44/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3990 - acc: 0.8311 - val_loss: 0.2900 - val_acc: 0.8800
#
# Epoch 00044: val_loss improved from 0.29294 to 0.29003, saving model to checkpoint_2.h5
# Epoch 45/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4040 - acc: 0.8260 - val_loss: 0.3109 - val_acc: 0.8700
#
# Epoch 00045: val_loss did not improve from 0.29003
# Epoch 46/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4211 - acc: 0.8031 - val_loss: 0.2913 - val_acc: 0.8750
#
# Epoch 00046: val_loss did not improve from 0.29003
# Epoch 47/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4104 - acc: 0.8234 - val_loss: 0.3109 - val_acc: 0.8675
#
# Epoch 00047: val_loss did not improve from 0.29003
# Epoch 48/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3843 - acc: 0.8354 - val_loss: 0.2962 - val_acc: 0.8737
#
# Epoch 00048: val_loss did not improve from 0.29003
# Epoch 49/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3871 - acc: 0.8298 - val_loss: 0.3000 - val_acc: 0.8775
#
# Epoch 00049: val_loss did not improve from 0.29003
# Epoch 50/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4037 - acc: 0.8178 - val_loss: 0.2980 - val_acc: 0.8788
#
# Epoch 00050: val_loss did not improve from 0.29003

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3540 - acc: 0.8500
#
# ---------------------------------
# Accuracy: 85.00 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.85      0.86       179
#          1.0       0.83      0.86      0.85       157
#
#     accuracy                           0.85       336
#    macro avg       0.85      0.85      0.85       336
# weighted avg       0.85      0.85      0.85       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 13,239,297
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 130ms/step - loss: 1.4474 - acc: 0.6590 - val_loss: 0.4819 - val_acc: 0.7837
#
# Epoch 00001: val_loss improved from inf to 0.48190, saving model to checkpoint_2.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6200 - acc: 0.6870 - val_loss: 0.4742 - val_acc: 0.7725
#
# Epoch 00002: val_loss improved from 0.48190 to 0.47424, saving model to checkpoint_2.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5988 - acc: 0.7064 - val_loss: 0.4527 - val_acc: 0.8163
#
# Epoch 00003: val_loss improved from 0.47424 to 0.45269, saving model to checkpoint_2.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5723 - acc: 0.7499 - val_loss: 0.4425 - val_acc: 0.8087
#
# Epoch 00004: val_loss improved from 0.45269 to 0.44247, saving model to checkpoint_2.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5310 - acc: 0.7379 - val_loss: 0.4284 - val_acc: 0.8313
#
# Epoch 00005: val_loss improved from 0.44247 to 0.42836, saving model to checkpoint_2.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5435 - acc: 0.7439 - val_loss: 0.4787 - val_acc: 0.8025
#
# Epoch 00006: val_loss did not improve from 0.42836
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5256 - acc: 0.7466 - val_loss: 0.4892 - val_acc: 0.8125
#
# Epoch 00007: val_loss did not improve from 0.42836
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5274 - acc: 0.7513 - val_loss: 0.4518 - val_acc: 0.8238
#
# Epoch 00008: val_loss did not improve from 0.42836
# Epoch 9/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5249 - acc: 0.7538 - val_loss: 0.4190 - val_acc: 0.8363
#
# Epoch 00009: val_loss improved from 0.42836 to 0.41899, saving model to checkpoint_2.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5273 - acc: 0.7462 - val_loss: 0.3877 - val_acc: 0.8400
#
# Epoch 00010: val_loss improved from 0.41899 to 0.38769, saving model to checkpoint_2.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4600 - acc: 0.7716 - val_loss: 0.4460 - val_acc: 0.8325
#
# Epoch 00011: val_loss did not improve from 0.38769
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4907 - acc: 0.7671 - val_loss: 0.4092 - val_acc: 0.8338
#
# Epoch 00012: val_loss did not improve from 0.38769
# Epoch 13/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4666 - acc: 0.7960 - val_loss: 0.3992 - val_acc: 0.8288
#
# Epoch 00013: val_loss did not improve from 0.38769
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4640 - acc: 0.7820 - val_loss: 0.3833 - val_acc: 0.8450
#
# Epoch 00014: val_loss improved from 0.38769 to 0.38334, saving model to checkpoint_2.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4847 - acc: 0.7761 - val_loss: 0.4138 - val_acc: 0.8562
#
# Epoch 00015: val_loss did not improve from 0.38334
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6960f38f98>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b68033630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f695f0dc080>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b68033940>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f695f0dc470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f695f030eb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6bc0004a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f695f10ac88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f695eaf9d30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6960f5ba58>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f695e4a3ac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b6838c400>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b6838cb00>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b70c46278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f695eec1400>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6bc01c19b0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f695f0d2278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b46284630>, <tensorflow.python.keras.layers.core.Activation object at 0x7f695f189630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b70c3ada0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b47593ac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b7054b5f8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6bc013c940>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b70c5a0b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b700e0390>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b701ea6d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f695f189080>, <tensorflow.python.keras.layers.merge.Add object at 0x7f695eaf2550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b6836e6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b6836e2e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b70c0bb00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b6836eb38>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b70c6e080>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f695e454278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b701eadd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b70c6e0b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b70c5cd30>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6960424550>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6960f9c898>, <tensorflow.python.keras.layers.merge.Add object at 0x7f6b6836e7f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f695f0e6710>, <tensorflow.python.keras.layers.core.Activation object at 0x7f695f0e6908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f695f1c0518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f695f0e6048>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6b7014aa90>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f6b6836eac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6b70c5ccf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6b70c73630>, <tensorflow.python.kera ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 36,758,657
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 20s 161ms/step - loss: 1.4780 - acc: 0.7812 - val_loss: 0.6210 - val_acc: 0.7412
#
# Epoch 00001: val_loss did not improve from 0.38334
# Epoch 2/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.4375 - acc: 0.8028 - val_loss: 0.4755 - val_acc: 0.7900
#
# Epoch 00002: val_loss did not improve from 0.38334
# Epoch 3/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3884 - acc: 0.8312 - val_loss: 0.3768 - val_acc: 0.8375
#
# Epoch 00003: val_loss improved from 0.38334 to 0.37676, saving model to checkpoint_2.h5
# Epoch 4/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3493 - acc: 0.8513 - val_loss: 0.3208 - val_acc: 0.8700
#
# Epoch 00004: val_loss improved from 0.37676 to 0.32075, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3157 - acc: 0.8868 - val_loss: 0.2964 - val_acc: 0.8800
#
# Epoch 00005: val_loss improved from 0.32075 to 0.29641, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3369 - acc: 0.8680 - val_loss: 0.2617 - val_acc: 0.8863
#
# Epoch 00006: val_loss improved from 0.29641 to 0.26169, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3130 - acc: 0.8762 - val_loss: 0.3335 - val_acc: 0.8562
#
# Epoch 00007: val_loss did not improve from 0.26169
# Epoch 8/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3139 - acc: 0.8693 - val_loss: 0.3085 - val_acc: 0.8838
#
# Epoch 00008: val_loss did not improve from 0.26169
# Epoch 9/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2890 - acc: 0.8739 - val_loss: 0.3193 - val_acc: 0.8813
#
# Epoch 00009: val_loss did not improve from 0.26169
# Epoch 10/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2707 - acc: 0.9003 - val_loss: 0.3803 - val_acc: 0.8300
#
# Epoch 00010: val_loss did not improve from 0.26169
# Epoch 11/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2719 - acc: 0.8970 - val_loss: 0.2705 - val_acc: 0.8800
#
# Epoch 00011: val_loss did not improve from 0.26169
# Epoch 12/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2820 - acc: 0.9003 - val_loss: 0.3774 - val_acc: 0.8512
#
# Epoch 00012: val_loss did not improve from 0.26169
# Epoch 13/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2584 - acc: 0.8945 - val_loss: 0.3809 - val_acc: 0.8612
#
# Epoch 00013: val_loss did not improve from 0.26169
# Epoch 14/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.3024 - acc: 0.8932 - val_loss: 0.3214 - val_acc: 0.8737
#
# Epoch 00014: val_loss did not improve from 0.26169
# Epoch 15/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2780 - acc: 0.9024 - val_loss: 0.3280 - val_acc: 0.8800
#
# Epoch 00015: val_loss did not improve from 0.26169
# Epoch 16/50
# 93/93 [==============================] - 14s 155ms/step - loss: 0.2794 - acc: 0.8946 - val_loss: 0.3318 - val_acc: 0.8600
#
# Epoch 00016: val_loss did not improve from 0.26169
# Epoch 17/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.3050 - acc: 0.8859 - val_loss: 0.3205 - val_acc: 0.8600
#
# Epoch 00017: val_loss did not improve from 0.26169
# Epoch 18/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2476 - acc: 0.9119 - val_loss: 0.3739 - val_acc: 0.8150
#
# Epoch 00018: val_loss did not improve from 0.26169
# Epoch 19/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2758 - acc: 0.8943 - val_loss: 0.2710 - val_acc: 0.8950
#
# Epoch 00019: val_loss did not improve from 0.26169
# Epoch 20/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.2325 - acc: 0.9133 - val_loss: 0.2687 - val_acc: 0.9038
#
# Epoch 00020: val_loss did not improve from 0.26169
# Epoch 21/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2479 - acc: 0.9133 - val_loss: 0.3110 - val_acc: 0.8800
#
# Epoch 00021: val_loss did not improve from 0.26169
# Epoch 22/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2203 - acc: 0.9135 - val_loss: 0.4260 - val_acc: 0.7638
#
# Epoch 00022: val_loss did not improve from 0.26169
# Epoch 23/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2599 - acc: 0.9150 - val_loss: 0.2750 - val_acc: 0.9038
#
# Epoch 00023: val_loss did not improve from 0.26169
# Epoch 24/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2783 - acc: 0.9015 - val_loss: 0.3375 - val_acc: 0.8800
#
# Epoch 00024: val_loss did not improve from 0.26169
# Epoch 25/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2546 - acc: 0.9032 - val_loss: 0.2733 - val_acc: 0.8913
#
# Epoch 00025: val_loss did not improve from 0.26169
# Epoch 26/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2390 - acc: 0.8991 - val_loss: 0.3120 - val_acc: 0.8562
#
# Epoch 00026: val_loss did not improve from 0.26169
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2499 - acc: 0.8969
#
# ---------------------------------
# Accuracy: 89.69 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.89      0.90       179
#          1.0       0.88      0.91      0.89       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 656,385
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 22s 134ms/step - loss: 0.7443 - acc: 0.5782 - val_loss: 0.4983 - val_acc: 0.7550
#
# Epoch 00001: val_loss improved from inf to 0.49826, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5845 - acc: 0.6859 - val_loss: 0.4641 - val_acc: 0.7775
#
# Epoch 00002: val_loss improved from 0.49826 to 0.46406, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.5358 - acc: 0.7262 - val_loss: 0.4543 - val_acc: 0.7950
#
# Epoch 00003: val_loss improved from 0.46406 to 0.45431, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5366 - acc: 0.7352 - val_loss: 0.4746 - val_acc: 0.7675
#
# Epoch 00004: val_loss did not improve from 0.45431
# Epoch 5/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.5173 - acc: 0.7487 - val_loss: 0.4446 - val_acc: 0.8138
#
# Epoch 00005: val_loss improved from 0.45431 to 0.44463, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.5326 - acc: 0.7567 - val_loss: 0.4190 - val_acc: 0.8200
#
# Epoch 00006: val_loss improved from 0.44463 to 0.41902, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.5002 - acc: 0.7599 - val_loss: 0.4267 - val_acc: 0.8225
#
# Epoch 00007: val_loss did not improve from 0.41902
# Epoch 8/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5177 - acc: 0.7571 - val_loss: 0.4313 - val_acc: 0.8037
#
# Epoch 00008: val_loss did not improve from 0.41902
# Epoch 9/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4902 - acc: 0.7673 - val_loss: 0.3928 - val_acc: 0.8350
#
# Epoch 00009: val_loss improved from 0.41902 to 0.39283, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.5128 - acc: 0.7645 - val_loss: 0.4136 - val_acc: 0.8238
#
# Epoch 00010: val_loss did not improve from 0.39283
# Epoch 11/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4969 - acc: 0.7723 - val_loss: 0.3935 - val_acc: 0.8388
#
# Epoch 00011: val_loss did not improve from 0.39283
# Epoch 12/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4860 - acc: 0.7721 - val_loss: 0.4021 - val_acc: 0.8325
#
# Epoch 00012: val_loss did not improve from 0.39283
# Epoch 13/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.4837 - acc: 0.7738 - val_loss: 0.4073 - val_acc: 0.8238
#
# Epoch 00013: val_loss did not improve from 0.39283
# Epoch 14/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4973 - acc: 0.7671 - val_loss: 0.4072 - val_acc: 0.8325
#
# Epoch 00014: val_loss did not improve from 0.39283
# Epoch 15/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4628 - acc: 0.7806 - val_loss: 0.4204 - val_acc: 0.8250
#
# Epoch 00015: val_loss did not improve from 0.39283
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7faef9c7fb70>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faef9c7ff60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0182320>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faea0182f98>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7faea019ceb8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea01ac4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea01ac5c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea01b5c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea0143cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea0147c88>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faea0154d68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0154400>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea01438d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea0158f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faefacb97f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0160f60>, <tensorflow.python.keras.layers.merge.Add object at 0x7faea0158c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea0169630>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea01544a8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea01602b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea01a9630>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea017da90>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faea016e400>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0105c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea010c6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea010c780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0114ba8>, <tensorflow.python.keras.layers.merge.Add object at 0x7faea01157f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea0120780>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea0120978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea0131080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea0131cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea01314e0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faea013c400>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea013ce48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea00c3908>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea013c518>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7faea0128710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea00d24e0>, <tensorflow.python.keras.layers.merge.Add object at 0x7faea00d27f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea00c9978>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea00d8978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea00e37b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea00c9f28>, <tensorflow.python.keras.layers.core.Activation object at 0x7faea00f0518>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7faea00f0cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea00e36a0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea00c9f98>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 24,175,745
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 21s 170ms/step - loss: 0.7302 - acc: 0.7898 - val_loss: 0.4661 - val_acc: 0.7812
#
# Epoch 00001: val_loss did not improve from 0.39283
# Epoch 2/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.3716 - acc: 0.8505 - val_loss: 0.5981 - val_acc: 0.7962
#
# Epoch 00002: val_loss did not improve from 0.39283
# Epoch 3/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.3363 - acc: 0.8557 - val_loss: 0.7023 - val_acc: 0.7638
#
# Epoch 00003: val_loss did not improve from 0.39283
# Epoch 4/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.3318 - acc: 0.8748 - val_loss: 0.3121 - val_acc: 0.8687
#
# Epoch 00004: val_loss improved from 0.39283 to 0.31212, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2979 - acc: 0.8918 - val_loss: 0.2954 - val_acc: 0.8737
#
# Epoch 00005: val_loss improved from 0.31212 to 0.29544, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.3078 - acc: 0.8748 - val_loss: 0.2981 - val_acc: 0.8587
#
# Epoch 00006: val_loss did not improve from 0.29544
# Epoch 7/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.3020 - acc: 0.8588 - val_loss: 0.2550 - val_acc: 0.8838
#
# Epoch 00007: val_loss improved from 0.29544 to 0.25502, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 15s 155ms/step - loss: 0.2875 - acc: 0.8854 - val_loss: 0.2725 - val_acc: 0.8988
#
# Epoch 00008: val_loss did not improve from 0.25502
# Epoch 9/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2761 - acc: 0.8931 - val_loss: 0.3286 - val_acc: 0.8462
#
# Epoch 00009: val_loss did not improve from 0.25502
# Epoch 10/50
# 93/93 [==============================] - 14s 155ms/step - loss: 0.2848 - acc: 0.8866 - val_loss: 0.2387 - val_acc: 0.9162
#
# Epoch 00010: val_loss improved from 0.25502 to 0.23870, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.2695 - acc: 0.9026 - val_loss: 0.3858 - val_acc: 0.8587
#
# Epoch 00011: val_loss did not improve from 0.23870
# Epoch 12/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.2685 - acc: 0.9013 - val_loss: 0.3323 - val_acc: 0.8550
#
# Epoch 00012: val_loss did not improve from 0.23870
# Epoch 13/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2597 - acc: 0.8985 - val_loss: 0.2886 - val_acc: 0.8700
#
# Epoch 00013: val_loss did not improve from 0.23870
# Epoch 14/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2129 - acc: 0.9213 - val_loss: 0.5571 - val_acc: 0.7675
#
# Epoch 00014: val_loss did not improve from 0.23870
# Epoch 15/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2258 - acc: 0.9132 - val_loss: 0.2632 - val_acc: 0.9150
#
# Epoch 00015: val_loss did not improve from 0.23870
# Epoch 16/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2164 - acc: 0.9159 - val_loss: 0.2658 - val_acc: 0.9125
#
# Epoch 00016: val_loss did not improve from 0.23870
# Epoch 17/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2330 - acc: 0.9088 - val_loss: 0.5826 - val_acc: 0.5888
#
# Epoch 00017: val_loss did not improve from 0.23870
# Epoch 18/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.2392 - acc: 0.9036 - val_loss: 0.4183 - val_acc: 0.8012
#
# Epoch 00018: val_loss did not improve from 0.23870
# Epoch 19/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.2116 - acc: 0.9164 - val_loss: 0.4213 - val_acc: 0.8500
#
# Epoch 00019: val_loss did not improve from 0.23870
# Epoch 20/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2431 - acc: 0.8933 - val_loss: 0.2830 - val_acc: 0.9225
#
# Epoch 00020: val_loss did not improve from 0.23870
# Epoch 21/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2650 - acc: 0.8934 - val_loss: 0.2637 - val_acc: 0.9025
#
# Epoch 00021: val_loss did not improve from 0.23870
# Epoch 22/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1998 - acc: 0.9176 - val_loss: 0.2504 - val_acc: 0.9075
#
# Epoch 00022: val_loss did not improve from 0.23870
# Epoch 23/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.1968 - acc: 0.9143 - val_loss: 0.3063 - val_acc: 0.8925
#
# Epoch 00023: val_loss did not improve from 0.23870
# Epoch 24/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2314 - acc: 0.9090 - val_loss: 0.3302 - val_acc: 0.8788
#
# Epoch 00024: val_loss did not improve from 0.23870
# Epoch 25/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2033 - acc: 0.9270 - val_loss: 0.2271 - val_acc: 0.9250
#
# Epoch 00025: val_loss improved from 0.23870 to 0.22708, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1778 - acc: 0.9281 - val_loss: 0.4497 - val_acc: 0.7763
#
# Epoch 00026: val_loss did not improve from 0.22708
# Epoch 27/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2068 - acc: 0.9277 - val_loss: 0.3547 - val_acc: 0.8138
#
# Epoch 00027: val_loss did not improve from 0.22708
# Epoch 28/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2045 - acc: 0.9221 - val_loss: 0.2882 - val_acc: 0.8725
#
# Epoch 00028: val_loss did not improve from 0.22708
# Epoch 29/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1881 - acc: 0.9282 - val_loss: 0.2647 - val_acc: 0.9175
#
# Epoch 00029: val_loss did not improve from 0.22708
# Epoch 30/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1775 - acc: 0.9338 - val_loss: 0.4178 - val_acc: 0.8012
#
# Epoch 00030: val_loss did not improve from 0.22708
# Epoch 31/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2175 - acc: 0.9192 - val_loss: 0.2703 - val_acc: 0.9175
#
# Epoch 00031: val_loss did not improve from 0.22708
# Epoch 32/50
# 93/93 [==============================] - 15s 156ms/step - loss: 0.1912 - acc: 0.9212 - val_loss: 0.3111 - val_acc: 0.8950
#
# Epoch 00032: val_loss did not improve from 0.22708
# Epoch 33/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1985 - acc: 0.9170 - val_loss: 0.2142 - val_acc: 0.9225
#
# Epoch 00033: val_loss improved from 0.22708 to 0.21416, saving model to checkpoint.h5
# Epoch 34/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2040 - acc: 0.9238 - val_loss: 0.3101 - val_acc: 0.9013
#
# Epoch 00034: val_loss did not improve from 0.21416
# Epoch 35/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1844 - acc: 0.9338 - val_loss: 0.2209 - val_acc: 0.9287
#
# Epoch 00035: val_loss did not improve from 0.21416
# Epoch 36/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1956 - acc: 0.9286 - val_loss: 0.2761 - val_acc: 0.8850
#
# Epoch 00036: val_loss did not improve from 0.21416
# Epoch 37/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1879 - acc: 0.9177 - val_loss: 0.2612 - val_acc: 0.9000
#
# Epoch 00037: val_loss did not improve from 0.21416
# Epoch 38/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1923 - acc: 0.9165 - val_loss: 0.3401 - val_acc: 0.8300
#
# Epoch 00038: val_loss did not improve from 0.21416
# Epoch 39/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2046 - acc: 0.9190 - val_loss: 0.2255 - val_acc: 0.9187
#
# Epoch 00039: val_loss did not improve from 0.21416
# Epoch 40/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1886 - acc: 0.9286 - val_loss: 0.3303 - val_acc: 0.8938
#
# Epoch 00040: val_loss did not improve from 0.21416
# Epoch 41/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1761 - acc: 0.9207 - val_loss: 0.2766 - val_acc: 0.9100
#
# Epoch 00041: val_loss did not improve from 0.21416
# Epoch 42/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.2103 - acc: 0.9207 - val_loss: 0.4699 - val_acc: 0.7812
#
# Epoch 00042: val_loss did not improve from 0.21416
# Epoch 43/50
# 93/93 [==============================] - 15s 159ms/step - loss: 0.1742 - acc: 0.9235 - val_loss: 0.3166 - val_acc: 0.8888
#
# Epoch 00043: val_loss did not improve from 0.21416
# Epoch 44/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.2110 - acc: 0.9193 - val_loss: 0.2328 - val_acc: 0.9187
#
# Epoch 00044: val_loss did not improve from 0.21416
# Epoch 45/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1863 - acc: 0.9263 - val_loss: 0.2770 - val_acc: 0.8913
#
# Epoch 00045: val_loss did not improve from 0.21416
# Epoch 46/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1744 - acc: 0.9254 - val_loss: 0.4494 - val_acc: 0.8700
#
# Epoch 00046: val_loss did not improve from 0.21416
# Epoch 47/50
# 93/93 [==============================] - 15s 157ms/step - loss: 0.1941 - acc: 0.9192 - val_loss: 0.2653 - val_acc: 0.9150
#
# Epoch 00047: val_loss did not improve from 0.21416
# Epoch 48/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1405 - acc: 0.9528 - val_loss: 0.2676 - val_acc: 0.9050
#
# Epoch 00048: val_loss did not improve from 0.21416
# Epoch 49/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1895 - acc: 0.9199 - val_loss: 0.4101 - val_acc: 0.8263
#
# Epoch 00049: val_loss did not improve from 0.21416
# Epoch 50/50
# 93/93 [==============================] - 15s 158ms/step - loss: 0.1740 - acc: 0.9351 - val_loss: 0.5821 - val_acc: 0.6400
#
# Epoch 00050: val_loss did not improve from 0.21416
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2819 - acc: 0.8875
#
# ---------------------------------
# Accuracy: 88.75 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.93      0.90       179
#          1.0       0.91      0.85      0.88       157
#
#     accuracy                           0.89       336
#    macro avg       0.89      0.89      0.89       336
# weighted avg       0.89      0.89      0.89       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## Flatten, Last  Block Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last 2 convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block3_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 13,239,297
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 130ms/step - loss: 1.3541 - acc: 0.6907 - val_loss: 0.4447 - val_acc: 0.8250
#
# Epoch 00001: val_loss improved from inf to 0.44465, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.7043 - acc: 0.6652 - val_loss: 0.4834 - val_acc: 0.7862
#
# Epoch 00002: val_loss did not improve from 0.44465
# Epoch 3/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5928 - acc: 0.6967 - val_loss: 0.4504 - val_acc: 0.8050
#
# Epoch 00003: val_loss did not improve from 0.44465
# Epoch 4/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5622 - acc: 0.7281 - val_loss: 0.4448 - val_acc: 0.8225
#
# Epoch 00004: val_loss did not improve from 0.44465
# Epoch 5/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5352 - acc: 0.7442 - val_loss: 0.4396 - val_acc: 0.8275
#
# Epoch 00005: val_loss improved from 0.44465 to 0.43957, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5479 - acc: 0.7263 - val_loss: 0.4345 - val_acc: 0.8325
#
# Epoch 00006: val_loss improved from 0.43957 to 0.43448, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5200 - acc: 0.7589 - val_loss: 0.4390 - val_acc: 0.8363
#
# Epoch 00007: val_loss did not improve from 0.43448
# Epoch 8/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5297 - acc: 0.7375 - val_loss: 0.4198 - val_acc: 0.8238
#
# Epoch 00008: val_loss improved from 0.43448 to 0.41981, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5218 - acc: 0.7604 - val_loss: 0.4226 - val_acc: 0.8375
#
# Epoch 00009: val_loss did not improve from 0.41981
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5048 - acc: 0.7614 - val_loss: 0.3991 - val_acc: 0.8512
#
# Epoch 00010: val_loss improved from 0.41981 to 0.39910, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5194 - acc: 0.7621 - val_loss: 0.3967 - val_acc: 0.8675
#
# Epoch 00011: val_loss improved from 0.39910 to 0.39671, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4917 - acc: 0.7660 - val_loss: 0.3854 - val_acc: 0.8525
#
# Epoch 00012: val_loss improved from 0.39671 to 0.38544, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4923 - acc: 0.7708 - val_loss: 0.4296 - val_acc: 0.8487
#
# Epoch 00013: val_loss did not improve from 0.38544
# Epoch 14/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5075 - acc: 0.7568 - val_loss: 0.3490 - val_acc: 0.8687
#
# Epoch 00014: val_loss improved from 0.38544 to 0.34902, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4720 - acc: 0.7815 - val_loss: 0.3747 - val_acc: 0.8612
#
# Epoch 00015: val_loss did not improve from 0.34902
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f4b2378d780>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d380e7780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d401cf710>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d380e7358>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4d0e2bdf98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d400c3be0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b23625518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d400cab70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d401de7f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d0e2b3f60>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d40024128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e33c4e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d38b2ba58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d0e05fbe0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d380e7be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4b2370ee48>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d400c3438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b23696668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b23726908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4b23631908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d380eaeb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b2376a780>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d90049320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4b23696d30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b237b8128>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b236c5518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e249438>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4b236c52b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b237b8cf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d0e10d518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e28a2b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d0e10deb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b236e6780>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4b237260f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e05fef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d0e10db00>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b236290f0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4b237fcac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e10d7b8>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d0e098b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d0e0e1630>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d0e0e11d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4b236297f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d0e0e14e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b23778e48>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d0e10d0f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d0e1ab588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b23731470>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 17,708,033
# Non-trainable params: 19,096,064
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 132ms/step - loss: 1.0022 - acc: 0.7988 - val_loss: 0.3808 - val_acc: 0.8512
#
# Epoch 00001: val_loss did not improve from 0.34902
# Epoch 2/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.4729 - acc: 0.7727 - val_loss: 0.3566 - val_acc: 0.8612
#
# Epoch 00002: val_loss did not improve from 0.34902
# Epoch 3/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.4517 - acc: 0.8032 - val_loss: 0.3395 - val_acc: 0.8737
#
# Epoch 00003: val_loss improved from 0.34902 to 0.33948, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4059 - acc: 0.8127 - val_loss: 0.3362 - val_acc: 0.8888
#
# Epoch 00004: val_loss improved from 0.33948 to 0.33623, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4517 - acc: 0.8204 - val_loss: 0.3422 - val_acc: 0.8863
#
# Epoch 00005: val_loss did not improve from 0.33623
# Epoch 6/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4389 - acc: 0.8242 - val_loss: 0.3367 - val_acc: 0.8850
#
# Epoch 00006: val_loss did not improve from 0.33623
# Epoch 7/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3962 - acc: 0.8308 - val_loss: 0.3263 - val_acc: 0.8875
#
# Epoch 00007: val_loss improved from 0.33623 to 0.32629, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.4298 - acc: 0.8095 - val_loss: 0.3502 - val_acc: 0.8838
#
# Epoch 00008: val_loss did not improve from 0.32629
# Epoch 9/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4198 - acc: 0.8243 - val_loss: 0.3314 - val_acc: 0.8913
#
# Epoch 00009: val_loss did not improve from 0.32629
# Epoch 10/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3841 - acc: 0.8219 - val_loss: 0.3058 - val_acc: 0.9000
#
# Epoch 00010: val_loss improved from 0.32629 to 0.30575, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3809 - acc: 0.8306 - val_loss: 0.3093 - val_acc: 0.8838
#
# Epoch 00011: val_loss did not improve from 0.30575
# Epoch 12/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3783 - acc: 0.8295 - val_loss: 0.3167 - val_acc: 0.8863
#
# Epoch 00012: val_loss did not improve from 0.30575
# Epoch 13/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3730 - acc: 0.8461 - val_loss: 0.3096 - val_acc: 0.8975
#
# Epoch 00013: val_loss did not improve from 0.30575
# Epoch 14/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3587 - acc: 0.8523 - val_loss: 0.3145 - val_acc: 0.8850
#
# Epoch 00014: val_loss did not improve from 0.30575
# Epoch 15/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3652 - acc: 0.8406 - val_loss: 0.3123 - val_acc: 0.8950
#
# Epoch 00015: val_loss did not improve from 0.30575
# Epoch 16/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3597 - acc: 0.8477 - val_loss: 0.3252 - val_acc: 0.8788
#
# Epoch 00016: val_loss did not improve from 0.30575
# Epoch 17/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3439 - acc: 0.8502 - val_loss: 0.3017 - val_acc: 0.8963
#
# Epoch 00017: val_loss improved from 0.30575 to 0.30166, saving model to checkpoint.h5
# Epoch 18/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3416 - acc: 0.8416 - val_loss: 0.2874 - val_acc: 0.8925
#
# Epoch 00018: val_loss improved from 0.30166 to 0.28740, saving model to checkpoint.h5
# Epoch 19/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3315 - acc: 0.8678 - val_loss: 0.2837 - val_acc: 0.9038
#
# Epoch 00019: val_loss improved from 0.28740 to 0.28375, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3102 - acc: 0.8716 - val_loss: 0.2788 - val_acc: 0.9100
#
# Epoch 00020: val_loss improved from 0.28375 to 0.27883, saving model to checkpoint.h5
# Epoch 21/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3256 - acc: 0.8629 - val_loss: 0.2947 - val_acc: 0.8950
#
# Epoch 00021: val_loss did not improve from 0.27883
# Epoch 22/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3423 - acc: 0.8507 - val_loss: 0.2925 - val_acc: 0.8900
#
# Epoch 00022: val_loss did not improve from 0.27883
# Epoch 23/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3364 - acc: 0.8662 - val_loss: 0.2969 - val_acc: 0.8975
#
# Epoch 00023: val_loss did not improve from 0.27883
# Epoch 24/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3226 - acc: 0.8697 - val_loss: 0.2769 - val_acc: 0.8975
#
# Epoch 00024: val_loss improved from 0.27883 to 0.27691, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3304 - acc: 0.8674 - val_loss: 0.2757 - val_acc: 0.9013
#
# Epoch 00025: val_loss improved from 0.27691 to 0.27573, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3295 - acc: 0.8730 - val_loss: 0.3100 - val_acc: 0.8788
#
# Epoch 00026: val_loss did not improve from 0.27573
# Epoch 27/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3364 - acc: 0.8554 - val_loss: 0.3029 - val_acc: 0.8788
#
# Epoch 00027: val_loss did not improve from 0.27573
# Epoch 28/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3051 - acc: 0.8795 - val_loss: 0.2768 - val_acc: 0.8938
#
# Epoch 00028: val_loss did not improve from 0.27573
# Epoch 29/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3414 - acc: 0.8539 - val_loss: 0.2858 - val_acc: 0.8863
#
# Epoch 00029: val_loss did not improve from 0.27573
# Epoch 30/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3786 - acc: 0.8482 - val_loss: 0.2697 - val_acc: 0.8975
#
# Epoch 00030: val_loss improved from 0.27573 to 0.26966, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3254 - acc: 0.8585 - val_loss: 0.2908 - val_acc: 0.8838
#
# Epoch 00031: val_loss did not improve from 0.26966
# Epoch 32/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3206 - acc: 0.8669 - val_loss: 0.2550 - val_acc: 0.8925
#
# Epoch 00032: val_loss improved from 0.26966 to 0.25502, saving model to checkpoint.h5
# Epoch 33/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3241 - acc: 0.8822 - val_loss: 0.2833 - val_acc: 0.8975
#
# Epoch 00033: val_loss did not improve from 0.25502
# Epoch 34/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3033 - acc: 0.8774 - val_loss: 0.2921 - val_acc: 0.8825
#
# Epoch 00034: val_loss did not improve from 0.25502
# Epoch 35/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3423 - acc: 0.8399 - val_loss: 0.2716 - val_acc: 0.8963
#
# Epoch 00035: val_loss did not improve from 0.25502
# Epoch 36/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3291 - acc: 0.8681 - val_loss: 0.2982 - val_acc: 0.8913
#
# Epoch 00036: val_loss did not improve from 0.25502
# Epoch 37/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2986 - acc: 0.8788 - val_loss: 0.2695 - val_acc: 0.9087
#
# Epoch 00037: val_loss did not improve from 0.25502
# Epoch 38/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3177 - acc: 0.8709 - val_loss: 0.2984 - val_acc: 0.9013
#
# Epoch 00038: val_loss did not improve from 0.25502
# Epoch 39/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2995 - acc: 0.8797 - val_loss: 0.2956 - val_acc: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.25502
# Epoch 40/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2893 - acc: 0.8820 - val_loss: 0.2837 - val_acc: 0.9100
#
# Epoch 00040: val_loss did not improve from 0.25502
# Epoch 41/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2978 - acc: 0.8860 - val_loss: 0.2902 - val_acc: 0.8888
#
# Epoch 00041: val_loss did not improve from 0.25502
# Epoch 42/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2949 - acc: 0.8810 - val_loss: 0.2967 - val_acc: 0.9025
#
# Epoch 00042: val_loss did not improve from 0.25502
# Epoch 43/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3075 - acc: 0.8793 - val_loss: 0.3143 - val_acc: 0.8950
#
# Epoch 00043: val_loss did not improve from 0.25502
# Epoch 44/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2856 - acc: 0.8875 - val_loss: 0.3026 - val_acc: 0.9013
#
# Epoch 00044: val_loss did not improve from 0.25502
# Epoch 45/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2798 - acc: 0.8808 - val_loss: 0.3080 - val_acc: 0.8988
#
# Epoch 00045: val_loss did not improve from 0.25502
# Epoch 46/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2886 - acc: 0.8799 - val_loss: 0.2907 - val_acc: 0.8838
#
# Epoch 00046: val_loss did not improve from 0.25502
# Epoch 47/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2740 - acc: 0.8893 - val_loss: 0.2928 - val_acc: 0.9025
#
# Epoch 00047: val_loss did not improve from 0.25502
# Epoch 48/50
# 93/93 [==============================] - 11s 124ms/step - loss: 0.2967 - acc: 0.8758 - val_loss: 0.2851 - val_acc: 0.8963
#
# Epoch 00048: val_loss did not improve from 0.25502
# Epoch 49/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3049 - acc: 0.8730 - val_loss: 0.2818 - val_acc: 0.8963
#
# Epoch 00049: val_loss did not improve from 0.25502
# Epoch 50/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2933 - acc: 0.8732 - val_loss: 0.2726 - val_acc: 0.9025
#
# Epoch 00050: val_loss did not improve from 0.25502
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3290 - acc: 0.8656
#
# ---------------------------------
# Accuracy: 86.56 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.87       179
#          1.0       0.87      0.83      0.85       157
#
#     accuracy                           0.86       336
#    macro avg       0.86      0.86      0.86       336
# weighted avg       0.86      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'resNet_dense_256x3_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 13,239,297
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 136ms/step - loss: 1.5947 - acc: 0.6699 - val_loss: 0.4287 - val_acc: 0.8062
#
# Epoch 00001: val_loss improved from inf to 0.42870, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.6291 - acc: 0.7119 - val_loss: 0.4413 - val_acc: 0.8325
#
# Epoch 00002: val_loss did not improve from 0.42870
# Epoch 3/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.6068 - acc: 0.7233 - val_loss: 0.4071 - val_acc: 0.8238
#
# Epoch 00003: val_loss improved from 0.42870 to 0.40707, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.5836 - acc: 0.7133 - val_loss: 0.3810 - val_acc: 0.8400
#
# Epoch 00004: val_loss improved from 0.40707 to 0.38102, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5740 - acc: 0.7364 - val_loss: 0.4076 - val_acc: 0.8400
#
# Epoch 00005: val_loss did not improve from 0.38102
# Epoch 6/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5694 - acc: 0.7285 - val_loss: 0.4218 - val_acc: 0.8525
#
# Epoch 00006: val_loss did not improve from 0.38102
# Epoch 7/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5540 - acc: 0.7340 - val_loss: 0.3557 - val_acc: 0.8637
#
# Epoch 00007: val_loss improved from 0.38102 to 0.35567, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5319 - acc: 0.7324 - val_loss: 0.3974 - val_acc: 0.8275
#
# Epoch 00008: val_loss did not improve from 0.35567
# Epoch 9/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4843 - acc: 0.7711 - val_loss: 0.3614 - val_acc: 0.8700
#
# Epoch 00009: val_loss did not improve from 0.35567
# Epoch 10/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.5606 - acc: 0.7285 - val_loss: 0.3850 - val_acc: 0.8388
#
# Epoch 00010: val_loss did not improve from 0.35567
# Epoch 11/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.5367 - acc: 0.7403 - val_loss: 0.4013 - val_acc: 0.8400
#
# Epoch 00011: val_loss did not improve from 0.35567
# Epoch 12/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5337 - acc: 0.7477 - val_loss: 0.3598 - val_acc: 0.8600
#
# Epoch 00012: val_loss did not improve from 0.35567
# Epoch 13/15
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4853 - acc: 0.7803 - val_loss: 0.3535 - val_acc: 0.8750
#
# Epoch 00013: val_loss improved from 0.35567 to 0.35347, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4707 - acc: 0.7734 - val_loss: 0.3612 - val_acc: 0.8487
#
# Epoch 00014: val_loss did not improve from 0.35347
# Epoch 15/15
# 93/93 [==============================] - 12s 127ms/step - loss: 0.4829 - acc: 0.7863 - val_loss: 0.3799 - val_acc: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.35347
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fac45ba9358>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac45af7940>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7faea01158d0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac45af7ef0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fac4f2dd9b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fae5e5bb908>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45d71a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fae5e5bfa58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7faea0038a20>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac460050b8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac45c27860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45c3f2b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac46005ac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac46001b38>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fae5e64f8d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45d71cc0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fae5e5bb320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac4605e668>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45c275c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac46005cf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45c295f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45eb2898>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac45dbe470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45ec9748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45ff38d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45bcf320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45d795f8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fac45eed1d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45d02860>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac460279b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45eb2ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac46027780>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45f5b630>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac45c88a90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45af7c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac46027668>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45fba1d0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fac460be2b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac46027d30>, <tensorflow.python.keras.layers.merge.Add object at 0x7fac45bcf160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45b8ba20>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac45fedcc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac45b8bcc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45fedf98>, <tensorflow.python.keras.layers.core.Activation object at 0x7fac460c9e48>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fac46027898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fac4607e0b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fac45fc6b70>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 22,172,673
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 138ms/step - loss: 0.9250 - acc: 0.7905 - val_loss: 0.3590 - val_acc: 0.8525
#
# Epoch 00001: val_loss did not improve from 0.35347
# Epoch 2/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4842 - acc: 0.7770 - val_loss: 0.3000 - val_acc: 0.8800
#
# Epoch 00002: val_loss improved from 0.35347 to 0.29997, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.4097 - acc: 0.8133 - val_loss: 0.3299 - val_acc: 0.8675
#
# Epoch 00003: val_loss did not improve from 0.29997
# Epoch 4/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4336 - acc: 0.8006 - val_loss: 0.2880 - val_acc: 0.8788
#
# Epoch 00004: val_loss improved from 0.29997 to 0.28804, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.4403 - acc: 0.8131 - val_loss: 0.2943 - val_acc: 0.8625
#
# Epoch 00005: val_loss did not improve from 0.28804
# Epoch 6/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4055 - acc: 0.8106 - val_loss: 0.2787 - val_acc: 0.8850
#
# Epoch 00006: val_loss improved from 0.28804 to 0.27874, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3456 - acc: 0.8575 - val_loss: 0.2633 - val_acc: 0.9038
#
# Epoch 00007: val_loss improved from 0.27874 to 0.26328, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3449 - acc: 0.8576 - val_loss: 0.2744 - val_acc: 0.9013
#
# Epoch 00008: val_loss did not improve from 0.26328
# Epoch 9/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3774 - acc: 0.8332 - val_loss: 0.2746 - val_acc: 0.8913
#
# Epoch 00009: val_loss did not improve from 0.26328
# Epoch 10/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3712 - acc: 0.8521 - val_loss: 0.2583 - val_acc: 0.9013
#
# Epoch 00010: val_loss improved from 0.26328 to 0.25831, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3333 - acc: 0.8655 - val_loss: 0.2537 - val_acc: 0.9013
#
# Epoch 00011: val_loss improved from 0.25831 to 0.25368, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3398 - acc: 0.8586 - val_loss: 0.2614 - val_acc: 0.9013
#
# Epoch 00012: val_loss did not improve from 0.25368
# Epoch 13/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3326 - acc: 0.8555 - val_loss: 0.2675 - val_acc: 0.8950
#
# Epoch 00013: val_loss did not improve from 0.25368
# Epoch 14/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3634 - acc: 0.8318 - val_loss: 0.2576 - val_acc: 0.8900
#
# Epoch 00014: val_loss did not improve from 0.25368
# Epoch 15/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3368 - acc: 0.8602 - val_loss: 0.2528 - val_acc: 0.9025
#
# Epoch 00015: val_loss improved from 0.25368 to 0.25278, saving model to checkpoint.h5
# Epoch 16/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3413 - acc: 0.8581 - val_loss: 0.2650 - val_acc: 0.8950
#
# Epoch 00016: val_loss did not improve from 0.25278
# Epoch 17/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3363 - acc: 0.8702 - val_loss: 0.2625 - val_acc: 0.8950
#
# Epoch 00017: val_loss did not improve from 0.25278
# Epoch 18/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3125 - acc: 0.8575 - val_loss: 0.2979 - val_acc: 0.8900
#
# Epoch 00018: val_loss did not improve from 0.25278
# Epoch 19/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3192 - acc: 0.8714 - val_loss: 0.2822 - val_acc: 0.8963
#
# Epoch 00019: val_loss did not improve from 0.25278
# Epoch 20/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3157 - acc: 0.8633 - val_loss: 0.2535 - val_acc: 0.9025
#
# Epoch 00020: val_loss did not improve from 0.25278
# Epoch 21/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3504 - acc: 0.8632 - val_loss: 0.2633 - val_acc: 0.9087
#
# Epoch 00021: val_loss did not improve from 0.25278
# Epoch 22/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3215 - acc: 0.8743 - val_loss: 0.2726 - val_acc: 0.9025
#
# Epoch 00022: val_loss did not improve from 0.25278
# Epoch 23/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2890 - acc: 0.8699 - val_loss: 0.2682 - val_acc: 0.8975
#
# Epoch 00023: val_loss did not improve from 0.25278
# Epoch 24/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3189 - acc: 0.8681 - val_loss: 0.2739 - val_acc: 0.8988
#
# Epoch 00024: val_loss did not improve from 0.25278
# Epoch 25/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3084 - acc: 0.8799 - val_loss: 0.2506 - val_acc: 0.9013
#
# Epoch 00025: val_loss improved from 0.25278 to 0.25057, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3225 - acc: 0.8628 - val_loss: 0.2657 - val_acc: 0.8975
#
# Epoch 00026: val_loss did not improve from 0.25057
# Epoch 27/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2978 - acc: 0.8727 - val_loss: 0.2677 - val_acc: 0.8963
#
# Epoch 00027: val_loss did not improve from 0.25057
# Epoch 28/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3594 - acc: 0.8695 - val_loss: 0.2507 - val_acc: 0.8950
#
# Epoch 00028: val_loss did not improve from 0.25057
# Epoch 29/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2960 - acc: 0.8775 - val_loss: 0.2761 - val_acc: 0.8913
#
# Epoch 00029: val_loss did not improve from 0.25057
# Epoch 30/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3036 - acc: 0.8823 - val_loss: 0.2485 - val_acc: 0.9000
#
# Epoch 00030: val_loss improved from 0.25057 to 0.24850, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3272 - acc: 0.8688 - val_loss: 0.2525 - val_acc: 0.8925
#
# Epoch 00031: val_loss did not improve from 0.24850
# Epoch 32/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2912 - acc: 0.8825 - val_loss: 0.2497 - val_acc: 0.9000
#
# Epoch 00032: val_loss did not improve from 0.24850
# Epoch 33/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2817 - acc: 0.8950 - val_loss: 0.2689 - val_acc: 0.8938
#
# Epoch 00033: val_loss did not improve from 0.24850
# Epoch 34/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3031 - acc: 0.8760 - val_loss: 0.2599 - val_acc: 0.8988
#
# Epoch 00034: val_loss did not improve from 0.24850
# Epoch 35/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2711 - acc: 0.8919 - val_loss: 0.2714 - val_acc: 0.8875
#
# Epoch 00035: val_loss did not improve from 0.24850
# Epoch 36/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2998 - acc: 0.8858 - val_loss: 0.2838 - val_acc: 0.8788
#
# Epoch 00036: val_loss did not improve from 0.24850
# Epoch 37/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2729 - acc: 0.8991 - val_loss: 0.3210 - val_acc: 0.8737
#
# Epoch 00037: val_loss did not improve from 0.24850
# Epoch 38/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2823 - acc: 0.8824 - val_loss: 0.2669 - val_acc: 0.9100
#
# Epoch 00038: val_loss did not improve from 0.24850
# Epoch 39/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2790 - acc: 0.8963 - val_loss: 0.2745 - val_acc: 0.8900
#
# Epoch 00039: val_loss did not improve from 0.24850
# Epoch 40/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2882 - acc: 0.8839 - val_loss: 0.2835 - val_acc: 0.8913
#
# Epoch 00040: val_loss did not improve from 0.24850
# Epoch 41/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2804 - acc: 0.8993 - val_loss: 0.2821 - val_acc: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.24850
# Epoch 42/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2939 - acc: 0.8826 - val_loss: 0.2875 - val_acc: 0.8963
#
# Epoch 00042: val_loss did not improve from 0.24850
# Epoch 43/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2757 - acc: 0.8966 - val_loss: 0.2918 - val_acc: 0.8900
#
# Epoch 00043: val_loss did not improve from 0.24850
# Epoch 44/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2627 - acc: 0.8899 - val_loss: 0.2648 - val_acc: 0.9000
#
# Epoch 00044: val_loss did not improve from 0.24850
# Epoch 45/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2865 - acc: 0.8849 - val_loss: 0.2830 - val_acc: 0.8950
#
# Epoch 00045: val_loss did not improve from 0.24850
# Epoch 46/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2459 - acc: 0.8923 - val_loss: 0.2950 - val_acc: 0.8888
#
# Epoch 00046: val_loss did not improve from 0.24850
# Epoch 47/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2472 - acc: 0.8959 - val_loss: 0.2689 - val_acc: 0.8900
#
# Epoch 00047: val_loss did not improve from 0.24850
# Epoch 48/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2609 - acc: 0.8834 - val_loss: 0.2669 - val_acc: 0.8950
#
# Epoch 00048: val_loss did not improve from 0.24850
# Epoch 49/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2622 - acc: 0.8925 - val_loss: 0.2919 - val_acc: 0.8875
#
# Epoch 00049: val_loss did not improve from 0.24850
# Epoch 50/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.2717 - acc: 0.8850 - val_loss: 0.2907 - val_acc: 0.8913
#
# Epoch 00050: val_loss did not improve from 0.24850
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 38ms/step - loss: 0.2705 - acc: 0.8813
#
# ---------------------------------
# Accuracy: 88.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89       179
#          1.0       0.86      0.89      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256x3_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
# Out:
# rm: cannot remove 'checkpoint.h5': No such file or directory

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 656,385
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 22s 131ms/step - loss: 0.7206 - acc: 0.5632 - val_loss: 0.4818 - val_acc: 0.7937
#
# Epoch 00001: val_loss improved from inf to 0.48184, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6116 - acc: 0.6768 - val_loss: 0.4423 - val_acc: 0.8188
#
# Epoch 00002: val_loss improved from 0.48184 to 0.44226, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5635 - acc: 0.7107 - val_loss: 0.4439 - val_acc: 0.8163
#
# Epoch 00003: val_loss did not improve from 0.44226
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4979 - acc: 0.7483 - val_loss: 0.4402 - val_acc: 0.8238
#
# Epoch 00004: val_loss improved from 0.44226 to 0.44018, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5622 - acc: 0.7241 - val_loss: 0.4193 - val_acc: 0.8288
#
# Epoch 00005: val_loss improved from 0.44018 to 0.41930, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4886 - acc: 0.7575 - val_loss: 0.4229 - val_acc: 0.8225
#
# Epoch 00006: val_loss did not improve from 0.41930
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5095 - acc: 0.7603 - val_loss: 0.4349 - val_acc: 0.8350
#
# Epoch 00007: val_loss did not improve from 0.41930
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5080 - acc: 0.7479 - val_loss: 0.4016 - val_acc: 0.8388
#
# Epoch 00008: val_loss improved from 0.41930 to 0.40162, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5073 - acc: 0.7555 - val_loss: 0.4191 - val_acc: 0.8350
#
# Epoch 00009: val_loss did not improve from 0.40162
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5103 - acc: 0.7591 - val_loss: 0.4126 - val_acc: 0.8300
#
# Epoch 00010: val_loss did not improve from 0.40162
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5152 - acc: 0.7465 - val_loss: 0.4054 - val_acc: 0.8413
#
# Epoch 00011: val_loss did not improve from 0.40162
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5008 - acc: 0.7600 - val_loss: 0.4029 - val_acc: 0.8313
#
# Epoch 00012: val_loss did not improve from 0.40162
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4730 - acc: 0.7616 - val_loss: 0.3971 - val_acc: 0.8375
#
# Epoch 00013: val_loss improved from 0.40162 to 0.39713, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4899 - acc: 0.7678 - val_loss: 0.3860 - val_acc: 0.8375
#
# Epoch 00014: val_loss improved from 0.39713 to 0.38598, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4709 - acc: 0.7892 - val_loss: 0.3923 - val_acc: 0.8388
#
# Epoch 00015: val_loss did not improve from 0.38598
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd68039a128>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd68039a208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd680411710>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6802b42b0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd680314ac8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd680314940>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd712ef2b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6802f0a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6802ec160>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6802fb9e8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6576b5f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576b5748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6802fba20>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576baa20>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6802ecef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576c8080>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd6576c07f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6802ec320>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576c8e10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576d7470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6576ceb70>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576c0ba8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6802f0d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd680314e48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6802f0cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576c88d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576dfe10>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd6576d7eb8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6576c0358>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576e44e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576edc50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6802ec080>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd657672d30>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd657682470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576799e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6576e4b38>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd657682d68>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd657672240>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576903c8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd657686b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd657682780>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd657690fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd657697f60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6576a22b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6576a6cf8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6576acd30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6576357b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd65763b278>, <tensorflow.python.kera ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 9,589,761
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 134ms/step - loss: 0.6833 - acc: 0.7889 - val_loss: 0.3463 - val_acc: 0.8725
#
# Epoch 00001: val_loss improved from 0.38598 to 0.34632, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4156 - acc: 0.8038 - val_loss: 0.3436 - val_acc: 0.8512
#
# Epoch 00002: val_loss improved from 0.34632 to 0.34362, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4103 - acc: 0.8237 - val_loss: 0.3359 - val_acc: 0.8537
#
# Epoch 00003: val_loss improved from 0.34362 to 0.33595, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3993 - acc: 0.8277 - val_loss: 0.3311 - val_acc: 0.8587
#
# Epoch 00004: val_loss improved from 0.33595 to 0.33108, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3997 - acc: 0.8184 - val_loss: 0.2867 - val_acc: 0.8750
#
# Epoch 00005: val_loss improved from 0.33108 to 0.28672, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3117 - acc: 0.8748 - val_loss: 0.2924 - val_acc: 0.8813
#
# Epoch 00006: val_loss did not improve from 0.28672
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3473 - acc: 0.8629 - val_loss: 0.2673 - val_acc: 0.8875
#
# Epoch 00007: val_loss improved from 0.28672 to 0.26726, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3664 - acc: 0.8411 - val_loss: 0.2609 - val_acc: 0.8913
#
# Epoch 00008: val_loss improved from 0.26726 to 0.26094, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3492 - acc: 0.8435 - val_loss: 0.2895 - val_acc: 0.8838
#
# Epoch 00009: val_loss did not improve from 0.26094
# Epoch 10/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3665 - acc: 0.8555 - val_loss: 0.2543 - val_acc: 0.8963
#
# Epoch 00010: val_loss improved from 0.26094 to 0.25434, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3345 - acc: 0.8682 - val_loss: 0.2620 - val_acc: 0.8863
#
# Epoch 00011: val_loss did not improve from 0.25434
# Epoch 12/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3435 - acc: 0.8668 - val_loss: 0.2744 - val_acc: 0.8737
#
# Epoch 00012: val_loss did not improve from 0.25434
# Epoch 13/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3244 - acc: 0.8656 - val_loss: 0.3079 - val_acc: 0.8637
#
# Epoch 00013: val_loss did not improve from 0.25434
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2984 - acc: 0.8721 - val_loss: 0.2709 - val_acc: 0.8913
#
# Epoch 00014: val_loss did not improve from 0.25434
# Epoch 15/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2909 - acc: 0.8871 - val_loss: 0.2879 - val_acc: 0.8763
#
# Epoch 00015: val_loss did not improve from 0.25434
# Epoch 16/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2919 - acc: 0.8759 - val_loss: 0.2671 - val_acc: 0.8850
#
# Epoch 00016: val_loss did not improve from 0.25434
# Epoch 17/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3038 - acc: 0.8644 - val_loss: 0.2892 - val_acc: 0.8938
#
# Epoch 00017: val_loss did not improve from 0.25434
# Epoch 18/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3060 - acc: 0.8752 - val_loss: 0.2777 - val_acc: 0.8875
#
# Epoch 00018: val_loss did not improve from 0.25434
# Epoch 19/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2862 - acc: 0.8742 - val_loss: 0.2929 - val_acc: 0.8775
#
# Epoch 00019: val_loss did not improve from 0.25434
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3271 - acc: 0.8631 - val_loss: 0.2594 - val_acc: 0.8950
#
# Epoch 00020: val_loss did not improve from 0.25434
# Epoch 21/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2485 - acc: 0.8915 - val_loss: 0.2531 - val_acc: 0.8925
#
# Epoch 00021: val_loss improved from 0.25434 to 0.25305, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3153 - acc: 0.8751 - val_loss: 0.2738 - val_acc: 0.8950
#
# Epoch 00022: val_loss did not improve from 0.25305
# Epoch 23/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2921 - acc: 0.8889 - val_loss: 0.3035 - val_acc: 0.8838
#
# Epoch 00023: val_loss did not improve from 0.25305
# Epoch 24/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2794 - acc: 0.8943 - val_loss: 0.3039 - val_acc: 0.8825
#
# Epoch 00024: val_loss did not improve from 0.25305
# Epoch 25/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2896 - acc: 0.8862 - val_loss: 0.2653 - val_acc: 0.8850
#
# Epoch 00025: val_loss did not improve from 0.25305
# Epoch 26/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2739 - acc: 0.8802 - val_loss: 0.2705 - val_acc: 0.8850
#
# Epoch 00026: val_loss did not improve from 0.25305
# Epoch 27/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2745 - acc: 0.8927 - val_loss: 0.2618 - val_acc: 0.8925
#
# Epoch 00027: val_loss did not improve from 0.25305
# Epoch 28/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2291 - acc: 0.9032 - val_loss: 0.2749 - val_acc: 0.8963
#
# Epoch 00028: val_loss did not improve from 0.25305
# Epoch 29/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2564 - acc: 0.8975 - val_loss: 0.2961 - val_acc: 0.8737
#
# Epoch 00029: val_loss did not improve from 0.25305
# Epoch 30/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2845 - acc: 0.8783 - val_loss: 0.2591 - val_acc: 0.8800
#
# Epoch 00030: val_loss did not improve from 0.25305
# Epoch 31/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2843 - acc: 0.8820 - val_loss: 0.2479 - val_acc: 0.9013
#
# Epoch 00031: val_loss improved from 0.25305 to 0.24787, saving model to checkpoint.h5
# Epoch 32/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2612 - acc: 0.8957 - val_loss: 0.2529 - val_acc: 0.8850
#
# Epoch 00032: val_loss did not improve from 0.24787
# Epoch 33/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2797 - acc: 0.8886 - val_loss: 0.2539 - val_acc: 0.8925
#
# Epoch 00033: val_loss did not improve from 0.24787
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2789 - acc: 0.8843 - val_loss: 0.2592 - val_acc: 0.8913
#
# Epoch 00034: val_loss did not improve from 0.24787
# Epoch 35/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2608 - acc: 0.9030 - val_loss: 0.2563 - val_acc: 0.8925
#
# Epoch 00035: val_loss did not improve from 0.24787
# Epoch 36/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2536 - acc: 0.8819 - val_loss: 0.2575 - val_acc: 0.8875
#
# Epoch 00036: val_loss did not improve from 0.24787
# Epoch 37/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2639 - acc: 0.8988 - val_loss: 0.2693 - val_acc: 0.8813
#
# Epoch 00037: val_loss did not improve from 0.24787
# Epoch 38/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2663 - acc: 0.8958 - val_loss: 0.2616 - val_acc: 0.8963
#
# Epoch 00038: val_loss did not improve from 0.24787
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3079 - acc: 0.8722 - val_loss: 0.2805 - val_acc: 0.8863
#
# Epoch 00039: val_loss did not improve from 0.24787
# Epoch 40/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2797 - acc: 0.8840 - val_loss: 0.2719 - val_acc: 0.8888
#
# Epoch 00040: val_loss did not improve from 0.24787
# Epoch 41/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2691 - acc: 0.8888 - val_loss: 0.2461 - val_acc: 0.8963
#
# Epoch 00041: val_loss improved from 0.24787 to 0.24615, saving model to checkpoint.h5
# Epoch 42/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2520 - acc: 0.8981 - val_loss: 0.3045 - val_acc: 0.8712
#
# Epoch 00042: val_loss did not improve from 0.24615
# Epoch 43/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2590 - acc: 0.8981 - val_loss: 0.2615 - val_acc: 0.8938
#
# Epoch 00043: val_loss did not improve from 0.24615
# Epoch 44/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2575 - acc: 0.8985 - val_loss: 0.2863 - val_acc: 0.8775
#
# Epoch 00044: val_loss did not improve from 0.24615
# Epoch 45/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2735 - acc: 0.8974 - val_loss: 0.2677 - val_acc: 0.8963
#
# Epoch 00045: val_loss did not improve from 0.24615
# Epoch 46/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2683 - acc: 0.8877 - val_loss: 0.2804 - val_acc: 0.8838
#
# Epoch 00046: val_loss did not improve from 0.24615
# Epoch 47/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2449 - acc: 0.9026 - val_loss: 0.2567 - val_acc: 0.8950
#
# Epoch 00047: val_loss did not improve from 0.24615
# Epoch 48/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2552 - acc: 0.9062 - val_loss: 0.2659 - val_acc: 0.8925
#
# Epoch 00048: val_loss did not improve from 0.24615
# Epoch 49/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2448 - acc: 0.9032 - val_loss: 0.2623 - val_acc: 0.8975
#
# Epoch 00049: val_loss did not improve from 0.24615
# Epoch 50/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2431 - acc: 0.9037 - val_loss: 0.2757 - val_acc: 0.8900
#
# Epoch 00050: val_loss did not improve from 0.24615
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2821 - acc: 0.8781
#
# ---------------------------------
# Accuracy: 87.81 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.84      0.88       179
#          1.0       0.84      0.92      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.89      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'vgg__globalAvgPool_dense_256x3_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 13,239,297
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 132ms/step - loss: 1.4054 - acc: 0.7099 - val_loss: 0.4694 - val_acc: 0.7775
#
# Epoch 00001: val_loss improved from inf to 0.46942, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6349 - acc: 0.7003 - val_loss: 0.5035 - val_acc: 0.7475
#
# Epoch 00002: val_loss did not improve from 0.46942
# Epoch 3/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6369 - acc: 0.7195 - val_loss: 0.4584 - val_acc: 0.7887
#
# Epoch 00003: val_loss improved from 0.46942 to 0.45836, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5423 - acc: 0.7354 - val_loss: 0.4434 - val_acc: 0.8037
#
# Epoch 00004: val_loss improved from 0.45836 to 0.44335, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5315 - acc: 0.7412 - val_loss: 0.4171 - val_acc: 0.8175
#
# Epoch 00005: val_loss improved from 0.44335 to 0.41712, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5193 - acc: 0.7595 - val_loss: 0.4700 - val_acc: 0.7763
#
# Epoch 00006: val_loss did not improve from 0.41712
# Epoch 7/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5115 - acc: 0.7452 - val_loss: 0.4338 - val_acc: 0.8087
#
# Epoch 00007: val_loss did not improve from 0.41712
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4835 - acc: 0.7682 - val_loss: 0.4107 - val_acc: 0.8163
#
# Epoch 00008: val_loss improved from 0.41712 to 0.41074, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4960 - acc: 0.7599 - val_loss: 0.4032 - val_acc: 0.8288
#
# Epoch 00009: val_loss improved from 0.41074 to 0.40323, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5011 - acc: 0.7832 - val_loss: 0.4325 - val_acc: 0.8300
#
# Epoch 00010: val_loss did not improve from 0.40323
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5065 - acc: 0.7588 - val_loss: 0.3923 - val_acc: 0.8388
#
# Epoch 00011: val_loss improved from 0.40323 to 0.39227, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4936 - acc: 0.7786 - val_loss: 0.3878 - val_acc: 0.8338
#
# Epoch 00012: val_loss improved from 0.39227 to 0.38780, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4834 - acc: 0.7750 - val_loss: 0.4041 - val_acc: 0.8225
#
# Epoch 00013: val_loss did not improve from 0.38780
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4540 - acc: 0.7904 - val_loss: 0.3860 - val_acc: 0.8200
#
# Epoch 00014: val_loss improved from 0.38780 to 0.38604, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4386 - acc: 0.8022 - val_loss: 0.4099 - val_acc: 0.8388
#
# Epoch 00015: val_loss did not improve from 0.38604
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd45ed33a20>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45ed33198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd657489c50>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45ed331d0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd45ed2b470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd65749ec88>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45eab8630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6574a5c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd65750ab70>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45e992e80>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45e9e0470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e992cc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed1ce48>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd657482208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45ed33160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e9075c0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd65749e4e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed2bd30>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45eab8278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45eb95588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed2b438>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45ed9a588>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd657513e48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e9a1320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed9a208>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45ed11eb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e925668>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd45ec6c6a0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed82d30>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45e8c9d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45ed9a438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45ed116a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45ea34550>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45e786978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd657482dd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45e7e54e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45e85b6d8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd45e9f8400>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e9f8ba8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd45eab89e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45e85bcc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45e7eca90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45e85b748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45eb5d3c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd45ec39978>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45e8c9588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45ed1a240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45eb5dd30>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,804,097
# Trainable params: 28,210,177
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 134ms/step - loss: 0.9461 - acc: 0.7923 - val_loss: 0.3659 - val_acc: 0.8425
#
# Epoch 00001: val_loss improved from 0.38604 to 0.36592, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4202 - acc: 0.8100 - val_loss: 0.3206 - val_acc: 0.8587
#
# Epoch 00002: val_loss improved from 0.36592 to 0.32060, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4114 - acc: 0.8178 - val_loss: 0.3287 - val_acc: 0.8662
#
# Epoch 00003: val_loss did not improve from 0.32060
# Epoch 4/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3623 - acc: 0.8357 - val_loss: 0.2997 - val_acc: 0.8675
#
# Epoch 00004: val_loss improved from 0.32060 to 0.29969, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3705 - acc: 0.8490 - val_loss: 0.3065 - val_acc: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.29969
# Epoch 6/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3691 - acc: 0.8421 - val_loss: 0.3057 - val_acc: 0.8763
#
# Epoch 00006: val_loss did not improve from 0.29969
# Epoch 7/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3387 - acc: 0.8589 - val_loss: 0.2983 - val_acc: 0.8725
#
# Epoch 00007: val_loss improved from 0.29969 to 0.29828, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3211 - acc: 0.8694 - val_loss: 0.3095 - val_acc: 0.8788
#
# Epoch 00008: val_loss did not improve from 0.29828
# Epoch 9/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2999 - acc: 0.8762 - val_loss: 0.2921 - val_acc: 0.8838
#
# Epoch 00009: val_loss improved from 0.29828 to 0.29207, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2944 - acc: 0.8910 - val_loss: 0.3097 - val_acc: 0.8687
#
# Epoch 00010: val_loss did not improve from 0.29207
# Epoch 11/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2994 - acc: 0.8789 - val_loss: 0.3035 - val_acc: 0.8662
#
# Epoch 00011: val_loss did not improve from 0.29207
# Epoch 12/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3006 - acc: 0.8827 - val_loss: 0.2710 - val_acc: 0.8900
#
# Epoch 00012: val_loss improved from 0.29207 to 0.27096, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3313 - acc: 0.8606 - val_loss: 0.3119 - val_acc: 0.8512
#
# Epoch 00013: val_loss did not improve from 0.27096
# Epoch 14/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.2953 - acc: 0.8800 - val_loss: 0.3085 - val_acc: 0.8888
#
# Epoch 00014: val_loss did not improve from 0.27096
# Epoch 15/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2875 - acc: 0.8853 - val_loss: 0.3078 - val_acc: 0.8963
#
# Epoch 00015: val_loss did not improve from 0.27096
# Epoch 16/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2515 - acc: 0.8931 - val_loss: 0.2882 - val_acc: 0.8963
#
# Epoch 00016: val_loss did not improve from 0.27096
# Epoch 17/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2918 - acc: 0.8999 - val_loss: 0.2922 - val_acc: 0.8875
#
# Epoch 00017: val_loss did not improve from 0.27096
# Epoch 18/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2695 - acc: 0.8912 - val_loss: 0.2856 - val_acc: 0.8950
#
# Epoch 00018: val_loss did not improve from 0.27096
# Epoch 19/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2769 - acc: 0.8865 - val_loss: 0.2649 - val_acc: 0.9013
#
# Epoch 00019: val_loss improved from 0.27096 to 0.26493, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2587 - acc: 0.9054 - val_loss: 0.2733 - val_acc: 0.8925
#
# Epoch 00020: val_loss did not improve from 0.26493
# Epoch 21/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2971 - acc: 0.8682 - val_loss: 0.2526 - val_acc: 0.8938
#
# Epoch 00021: val_loss improved from 0.26493 to 0.25260, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2444 - acc: 0.9013 - val_loss: 0.2786 - val_acc: 0.8975
#
# Epoch 00022: val_loss did not improve from 0.25260
# Epoch 23/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2449 - acc: 0.8955 - val_loss: 0.2515 - val_acc: 0.9075
#
# Epoch 00023: val_loss improved from 0.25260 to 0.25146, saving model to checkpoint.h5
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2816 - acc: 0.8858 - val_loss: 0.2711 - val_acc: 0.9062
#
# Epoch 00024: val_loss did not improve from 0.25146
# Epoch 25/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2604 - acc: 0.8997 - val_loss: 0.2667 - val_acc: 0.9075
#
# Epoch 00025: val_loss did not improve from 0.25146
# Epoch 26/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2368 - acc: 0.8998 - val_loss: 0.2784 - val_acc: 0.9000
#
# Epoch 00026: val_loss did not improve from 0.25146
# Epoch 27/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2491 - acc: 0.8991 - val_loss: 0.2935 - val_acc: 0.8875
#
# Epoch 00027: val_loss did not improve from 0.25146
# Epoch 28/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2333 - acc: 0.9075 - val_loss: 0.2814 - val_acc: 0.8925
#
# Epoch 00028: val_loss did not improve from 0.25146
# Epoch 29/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2513 - acc: 0.9058 - val_loss: 0.3202 - val_acc: 0.8850
#
# Epoch 00029: val_loss did not improve from 0.25146
# Epoch 30/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2424 - acc: 0.9064 - val_loss: 0.2725 - val_acc: 0.8925
#
# Epoch 00030: val_loss did not improve from 0.25146
# Epoch 31/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2607 - acc: 0.8926 - val_loss: 0.2692 - val_acc: 0.9175
#
# Epoch 00031: val_loss did not improve from 0.25146
# Epoch 32/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2354 - acc: 0.9039 - val_loss: 0.2938 - val_acc: 0.9075
#
# Epoch 00032: val_loss did not improve from 0.25146
# Epoch 33/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2352 - acc: 0.9136 - val_loss: 0.2551 - val_acc: 0.9150
#
# Epoch 00033: val_loss did not improve from 0.25146
# Epoch 34/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2500 - acc: 0.9169 - val_loss: 0.2466 - val_acc: 0.9050
#
# Epoch 00034: val_loss improved from 0.25146 to 0.24663, saving model to checkpoint.h5
# Epoch 35/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2424 - acc: 0.9095 - val_loss: 0.2659 - val_acc: 0.8975
#
# Epoch 00035: val_loss did not improve from 0.24663
# Epoch 36/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2365 - acc: 0.9004 - val_loss: 0.2615 - val_acc: 0.8975
#
# Epoch 00036: val_loss did not improve from 0.24663
# Epoch 37/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2302 - acc: 0.9090 - val_loss: 0.2841 - val_acc: 0.8763
#
# Epoch 00037: val_loss did not improve from 0.24663
# Epoch 38/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2067 - acc: 0.9226 - val_loss: 0.3116 - val_acc: 0.8687
#
# Epoch 00038: val_loss did not improve from 0.24663
# Epoch 39/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2282 - acc: 0.9144 - val_loss: 0.3056 - val_acc: 0.8788
#
# Epoch 00039: val_loss did not improve from 0.24663
# Epoch 40/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2563 - acc: 0.9000 - val_loss: 0.2804 - val_acc: 0.8850
#
# Epoch 00040: val_loss did not improve from 0.24663
# Epoch 41/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2258 - acc: 0.9077 - val_loss: 0.2547 - val_acc: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.24663
# Epoch 42/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.1955 - acc: 0.9338 - val_loss: 0.2900 - val_acc: 0.8975
#
# Epoch 00042: val_loss did not improve from 0.24663
# Epoch 43/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2409 - acc: 0.9011 - val_loss: 0.2702 - val_acc: 0.9038
#
# Epoch 00043: val_loss did not improve from 0.24663
# Epoch 44/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2403 - acc: 0.9226 - val_loss: 0.2966 - val_acc: 0.9075
#
# Epoch 00044: val_loss did not improve from 0.24663
# Epoch 45/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2368 - acc: 0.9112 - val_loss: 0.2484 - val_acc: 0.9150
#
# Epoch 00045: val_loss did not improve from 0.24663
# Epoch 46/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2147 - acc: 0.9227 - val_loss: 0.2911 - val_acc: 0.8938
#
# Epoch 00046: val_loss did not improve from 0.24663
# Epoch 47/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2195 - acc: 0.9133 - val_loss: 0.2976 - val_acc: 0.8913
#
# Epoch 00047: val_loss did not improve from 0.24663
# Epoch 48/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2115 - acc: 0.9213 - val_loss: 0.2800 - val_acc: 0.9000
#
# Epoch 00048: val_loss did not improve from 0.24663
# Epoch 49/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2215 - acc: 0.9066 - val_loss: 0.2805 - val_acc: 0.8988
#
# Epoch 00049: val_loss did not improve from 0.24663
# Epoch 50/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.1912 - acc: 0.9257 - val_loss: 0.2797 - val_acc: 0.9013
#
# Epoch 00050: val_loss did not improve from 0.24663
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2555 - acc: 0.9000
#
# ---------------------------------
# Accuracy: 90.00 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.89      0.91       179
#          1.0       0.88      0.91      0.90       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256x3_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 656,385
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 131ms/step - loss: 0.7446 - acc: 0.6740 - val_loss: 0.4672 - val_acc: 0.7937
#
# Epoch 00001: val_loss improved from inf to 0.46717, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5806 - acc: 0.6978 - val_loss: 0.4338 - val_acc: 0.7937
#
# Epoch 00002: val_loss improved from 0.46717 to 0.43375, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6001 - acc: 0.6935 - val_loss: 0.4537 - val_acc: 0.8313
#
# Epoch 00003: val_loss did not improve from 0.43375
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5464 - acc: 0.6968 - val_loss: 0.4227 - val_acc: 0.8200
#
# Epoch 00004: val_loss improved from 0.43375 to 0.42268, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5072 - acc: 0.7528 - val_loss: 0.4164 - val_acc: 0.8075
#
# Epoch 00005: val_loss improved from 0.42268 to 0.41638, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5247 - acc: 0.7476 - val_loss: 0.4261 - val_acc: 0.8275
#
# Epoch 00006: val_loss did not improve from 0.41638
# Epoch 7/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4846 - acc: 0.7873 - val_loss: 0.3955 - val_acc: 0.8300
#
# Epoch 00007: val_loss improved from 0.41638 to 0.39546, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5274 - acc: 0.7465 - val_loss: 0.4225 - val_acc: 0.8225
#
# Epoch 00008: val_loss did not improve from 0.39546
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5098 - acc: 0.7590 - val_loss: 0.4199 - val_acc: 0.8075
#
# Epoch 00009: val_loss did not improve from 0.39546
# Epoch 10/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5527 - acc: 0.7315 - val_loss: 0.4174 - val_acc: 0.8275
#
# Epoch 00010: val_loss did not improve from 0.39546
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5032 - acc: 0.7719 - val_loss: 0.4204 - val_acc: 0.8288
#
# Epoch 00011: val_loss did not improve from 0.39546
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5086 - acc: 0.7491 - val_loss: 0.4220 - val_acc: 0.8400
#
# Epoch 00012: val_loss did not improve from 0.39546
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4861 - acc: 0.7768 - val_loss: 0.4237 - val_acc: 0.8325
#
# Epoch 00013: val_loss did not improve from 0.39546
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4715 - acc: 0.7726 - val_loss: 0.3861 - val_acc: 0.8388
#
# Epoch 00014: val_loss improved from 0.39546 to 0.38611, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5101 - acc: 0.7397 - val_loss: 0.4157 - val_acc: 0.8413
#
# Epoch 00015: val_loss did not improve from 0.38611
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fd65610cdd8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6572179e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45df6ec18>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6572176d8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd6571d6208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45df52748>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd679ddc2b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45df76ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd45e03d7b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd679d817b8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd679d9feb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd656d404a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd656126550>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6563f6dd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45dfb9128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd678423940>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd45df6ebe0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd657052710>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd679d62ac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd679d41198>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd656e76cf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd656dd1f98>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45eb88320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6783445c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd656dd1198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd67830a2e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd657214cc0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd656ea2cc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd67830a6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6561c0f28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd656dd1550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6561c0048>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd6781a1b00>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd45fee8f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd45fed8780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd6561c0eb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd67817fc18>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fd679e0ecc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd679e16a58>, <tensorflow.python.keras.layers.merge.Add object at 0x7fd6570569b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd656e82710>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd656e82fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd6782e1438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd656e82908>, <tensorflow.python.keras.layers.core.Activation object at 0x7fd657257fd0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fd6561c0208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fd656e91c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fd657257550>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,221,185
# Trainable params: 15,627,265
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 134ms/step - loss: 0.6276 - acc: 0.7946 - val_loss: 0.3265 - val_acc: 0.8625
#
# Epoch 00001: val_loss improved from 0.38611 to 0.32653, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4024 - acc: 0.8413 - val_loss: 0.2637 - val_acc: 0.8900
#
# Epoch 00002: val_loss improved from 0.32653 to 0.26370, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3860 - acc: 0.8313 - val_loss: 0.2887 - val_acc: 0.8925
#
# Epoch 00003: val_loss did not improve from 0.26370
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3624 - acc: 0.8491 - val_loss: 0.2708 - val_acc: 0.8813
#
# Epoch 00004: val_loss did not improve from 0.26370
# Epoch 5/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3430 - acc: 0.8521 - val_loss: 0.2508 - val_acc: 0.9025
#
# Epoch 00005: val_loss improved from 0.26370 to 0.25084, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3075 - acc: 0.8661 - val_loss: 0.2488 - val_acc: 0.8900
#
# Epoch 00006: val_loss improved from 0.25084 to 0.24881, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3272 - acc: 0.8404 - val_loss: 0.2388 - val_acc: 0.9137
#
# Epoch 00007: val_loss improved from 0.24881 to 0.23883, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3417 - acc: 0.8573 - val_loss: 0.2690 - val_acc: 0.8813
#
# Epoch 00008: val_loss did not improve from 0.23883
# Epoch 9/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3141 - acc: 0.8754 - val_loss: 0.2357 - val_acc: 0.9162
#
# Epoch 00009: val_loss improved from 0.23883 to 0.23574, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2954 - acc: 0.8833 - val_loss: 0.2265 - val_acc: 0.9162
#
# Epoch 00010: val_loss improved from 0.23574 to 0.22655, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3050 - acc: 0.8834 - val_loss: 0.2740 - val_acc: 0.8813
#
# Epoch 00011: val_loss did not improve from 0.22655
# Epoch 12/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3219 - acc: 0.8813 - val_loss: 0.2369 - val_acc: 0.9137
#
# Epoch 00012: val_loss did not improve from 0.22655
# Epoch 13/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2833 - acc: 0.8852 - val_loss: 0.2498 - val_acc: 0.9125
#
# Epoch 00013: val_loss did not improve from 0.22655
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2587 - acc: 0.8885 - val_loss: 0.2290 - val_acc: 0.9137
#
# Epoch 00014: val_loss did not improve from 0.22655
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2840 - acc: 0.8903 - val_loss: 0.2566 - val_acc: 0.8913
#
# Epoch 00015: val_loss did not improve from 0.22655
# Epoch 16/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2786 - acc: 0.8914 - val_loss: 0.2160 - val_acc: 0.9250
#
# Epoch 00016: val_loss improved from 0.22655 to 0.21602, saving model to checkpoint.h5
# Epoch 17/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2732 - acc: 0.8930 - val_loss: 0.2302 - val_acc: 0.9137
#
# Epoch 00017: val_loss did not improve from 0.21602
# Epoch 18/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2344 - acc: 0.9090 - val_loss: 0.2148 - val_acc: 0.9125
#
# Epoch 00018: val_loss improved from 0.21602 to 0.21482, saving model to checkpoint.h5
# Epoch 19/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2218 - acc: 0.9165 - val_loss: 0.2311 - val_acc: 0.9075
#
# Epoch 00019: val_loss did not improve from 0.21482
# Epoch 20/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2530 - acc: 0.8995 - val_loss: 0.2194 - val_acc: 0.9112
#
# Epoch 00020: val_loss did not improve from 0.21482
# Epoch 21/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2838 - acc: 0.8843 - val_loss: 0.2594 - val_acc: 0.9013
#
# Epoch 00021: val_loss did not improve from 0.21482
# Epoch 22/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2672 - acc: 0.8880 - val_loss: 0.2254 - val_acc: 0.9175
#
# Epoch 00022: val_loss did not improve from 0.21482
# Epoch 23/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2728 - acc: 0.8881 - val_loss: 0.2441 - val_acc: 0.9125
#
# Epoch 00023: val_loss did not improve from 0.21482
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2756 - acc: 0.8874 - val_loss: 0.2450 - val_acc: 0.8975
#
# Epoch 00024: val_loss did not improve from 0.21482
# Epoch 25/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2491 - acc: 0.9052 - val_loss: 0.2689 - val_acc: 0.8988
#
# Epoch 00025: val_loss did not improve from 0.21482
# Epoch 26/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2668 - acc: 0.9006 - val_loss: 0.2184 - val_acc: 0.9187
#
# Epoch 00026: val_loss did not improve from 0.21482
# Epoch 27/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2560 - acc: 0.9062 - val_loss: 0.2552 - val_acc: 0.9050
#
# Epoch 00027: val_loss did not improve from 0.21482
# Epoch 28/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2425 - acc: 0.9025 - val_loss: 0.2094 - val_acc: 0.9237
#
# Epoch 00028: val_loss improved from 0.21482 to 0.20940, saving model to checkpoint.h5
# Epoch 29/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2279 - acc: 0.9048 - val_loss: 0.2313 - val_acc: 0.9150
#
# Epoch 00029: val_loss did not improve from 0.20940
# Epoch 30/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2367 - acc: 0.9089 - val_loss: 0.2459 - val_acc: 0.9038
#
# Epoch 00030: val_loss did not improve from 0.20940
# Epoch 31/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2527 - acc: 0.8961 - val_loss: 0.2443 - val_acc: 0.9100
#
# Epoch 00031: val_loss did not improve from 0.20940
# Epoch 32/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2411 - acc: 0.9076 - val_loss: 0.2475 - val_acc: 0.9013
#
# Epoch 00032: val_loss did not improve from 0.20940
# Epoch 33/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2420 - acc: 0.9175 - val_loss: 0.2191 - val_acc: 0.9212
#
# Epoch 00033: val_loss did not improve from 0.20940
# Epoch 34/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2273 - acc: 0.9076 - val_loss: 0.2265 - val_acc: 0.9100
#
# Epoch 00034: val_loss did not improve from 0.20940
# Epoch 35/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2199 - acc: 0.9121 - val_loss: 0.3255 - val_acc: 0.8788
#
# Epoch 00035: val_loss did not improve from 0.20940
# Epoch 36/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2454 - acc: 0.9122 - val_loss: 0.2209 - val_acc: 0.9162
#
# Epoch 00036: val_loss did not improve from 0.20940
# Epoch 37/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2270 - acc: 0.9145 - val_loss: 0.2573 - val_acc: 0.9062
#
# Epoch 00037: val_loss did not improve from 0.20940
# Epoch 38/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2370 - acc: 0.8950 - val_loss: 0.2421 - val_acc: 0.8900
#
# Epoch 00038: val_loss did not improve from 0.20940
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2277 - acc: 0.9056 - val_loss: 0.2637 - val_acc: 0.9000
#
# Epoch 00039: val_loss did not improve from 0.20940
# Epoch 40/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2300 - acc: 0.9134 - val_loss: 0.2309 - val_acc: 0.9175
#
# Epoch 00040: val_loss did not improve from 0.20940
# Epoch 41/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2025 - acc: 0.9213 - val_loss: 0.2505 - val_acc: 0.9162
#
# Epoch 00041: val_loss did not improve from 0.20940
# Epoch 42/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2218 - acc: 0.9164 - val_loss: 0.2188 - val_acc: 0.9212
#
# Epoch 00042: val_loss did not improve from 0.20940
# Epoch 43/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.1955 - acc: 0.9259 - val_loss: 0.2046 - val_acc: 0.9275
#
# Epoch 00043: val_loss improved from 0.20940 to 0.20459, saving model to checkpoint.h5
# Epoch 44/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2258 - acc: 0.9079 - val_loss: 0.2364 - val_acc: 0.9087
#
# Epoch 00044: val_loss did not improve from 0.20459
# Epoch 45/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2111 - acc: 0.9127 - val_loss: 0.3004 - val_acc: 0.8913
#
# Epoch 00045: val_loss did not improve from 0.20459
# Epoch 46/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2082 - acc: 0.9127 - val_loss: 0.2293 - val_acc: 0.9200
#
# Epoch 00046: val_loss did not improve from 0.20459
# Epoch 47/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2636 - acc: 0.8856 - val_loss: 0.2429 - val_acc: 0.9175
#
# Epoch 00047: val_loss did not improve from 0.20459
# Epoch 48/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2305 - acc: 0.8993 - val_loss: 0.2638 - val_acc: 0.9025
#
# Epoch 00048: val_loss did not improve from 0.20459
# Epoch 49/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.1981 - acc: 0.9325 - val_loss: 0.2260 - val_acc: 0.9162
#
# Epoch 00049: val_loss did not improve from 0.20459
# Epoch 50/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2239 - acc: 0.9101 - val_loss: 0.2501 - val_acc: 0.9112
#
# Epoch 00050: val_loss did not improve from 0.20459
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2594 - acc: 0.8813
#
# ---------------------------------
# Accuracy: 88.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.87      0.88       179
#          1.0       0.85      0.89      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'vgg__globalAvgPool_dense_256x3_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, 5x [ DropOut(0.5 + Dense (256)]

# %% [markdown]
# ##Flatten, Non Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 13,370,881
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 22s 131ms/step - loss: 0.9044 - acc: 0.4960 - val_loss: 0.6303 - val_acc: 0.6350
#
# Epoch 00001: val_loss improved from inf to 0.63026, saving model to checkpoint_2.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.7579 - acc: 0.5257 - val_loss: 0.5905 - val_acc: 0.7625
#
# Epoch 00002: val_loss improved from 0.63026 to 0.59049, saving model to checkpoint_2.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6820 - acc: 0.6003 - val_loss: 0.5613 - val_acc: 0.7738
#
# Epoch 00003: val_loss improved from 0.59049 to 0.56128, saving model to checkpoint_2.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.6653 - acc: 0.5922 - val_loss: 0.5125 - val_acc: 0.7663
#
# Epoch 00004: val_loss improved from 0.56128 to 0.51255, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6402 - acc: 0.6643 - val_loss: 0.4865 - val_acc: 0.8012
#
# Epoch 00005: val_loss improved from 0.51255 to 0.48645, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6124 - acc: 0.6524 - val_loss: 0.4622 - val_acc: 0.8012
#
# Epoch 00006: val_loss improved from 0.48645 to 0.46217, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5889 - acc: 0.6804 - val_loss: 0.4538 - val_acc: 0.7900
#
# Epoch 00007: val_loss improved from 0.46217 to 0.45383, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5521 - acc: 0.7126 - val_loss: 0.4404 - val_acc: 0.8163
#
# Epoch 00008: val_loss improved from 0.45383 to 0.44039, saving model to checkpoint_2.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5188 - acc: 0.7520 - val_loss: 0.4231 - val_acc: 0.8138
#
# Epoch 00009: val_loss improved from 0.44039 to 0.42309, saving model to checkpoint_2.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5304 - acc: 0.7326 - val_loss: 0.4168 - val_acc: 0.8225
#
# Epoch 00010: val_loss improved from 0.42309 to 0.41684, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5089 - acc: 0.7569 - val_loss: 0.4124 - val_acc: 0.8238
#
# Epoch 00011: val_loss improved from 0.41684 to 0.41238, saving model to checkpoint_2.h5
# Epoch 12/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5330 - acc: 0.7528 - val_loss: 0.4134 - val_acc: 0.8163
#
# Epoch 00012: val_loss did not improve from 0.41238
# Epoch 13/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4803 - acc: 0.7828 - val_loss: 0.4082 - val_acc: 0.8200
#
# Epoch 00013: val_loss improved from 0.41238 to 0.40823, saving model to checkpoint_2.h5
# Epoch 14/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4750 - acc: 0.7848 - val_loss: 0.4005 - val_acc: 0.8213
#
# Epoch 00014: val_loss improved from 0.40823 to 0.40051, saving model to checkpoint_2.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4686 - acc: 0.7845 - val_loss: 0.4055 - val_acc: 0.8238
#
# Epoch 00015: val_loss did not improve from 0.40051
# Epoch 16/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4309 - acc: 0.7953 - val_loss: 0.4042 - val_acc: 0.8275
#
# Epoch 00016: val_loss did not improve from 0.40051
# Epoch 17/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4358 - acc: 0.7971 - val_loss: 0.3874 - val_acc: 0.8338
#
# Epoch 00017: val_loss improved from 0.40051 to 0.38741, saving model to checkpoint_2.h5
# Epoch 18/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4517 - acc: 0.7965 - val_loss: 0.3915 - val_acc: 0.8350
#
# Epoch 00018: val_loss did not improve from 0.38741
# Epoch 19/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4586 - acc: 0.8021 - val_loss: 0.3897 - val_acc: 0.8363
#
# Epoch 00019: val_loss did not improve from 0.38741
# Epoch 20/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4716 - acc: 0.7909 - val_loss: 0.3825 - val_acc: 0.8388
#
# Epoch 00020: val_loss improved from 0.38741 to 0.38254, saving model to checkpoint_2.h5
# Epoch 21/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4366 - acc: 0.8102 - val_loss: 0.3904 - val_acc: 0.8188
#
# Epoch 00021: val_loss did not improve from 0.38254
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4721 - acc: 0.7777 - val_loss: 0.3807 - val_acc: 0.8300
#
# Epoch 00022: val_loss improved from 0.38254 to 0.38072, saving model to checkpoint_2.h5
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4248 - acc: 0.8265 - val_loss: 0.3940 - val_acc: 0.8275
#
# Epoch 00023: val_loss did not improve from 0.38072
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4579 - acc: 0.7900 - val_loss: 0.3751 - val_acc: 0.8438
#
# Epoch 00024: val_loss improved from 0.38072 to 0.37507, saving model to checkpoint_2.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4455 - acc: 0.7927 - val_loss: 0.3904 - val_acc: 0.8338
#
# Epoch 00025: val_loss did not improve from 0.37507
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4406 - acc: 0.8034 - val_loss: 0.3771 - val_acc: 0.8438
#
# Epoch 00026: val_loss did not improve from 0.37507
# Epoch 27/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4198 - acc: 0.8147 - val_loss: 0.3806 - val_acc: 0.8400
#
# Epoch 00027: val_loss did not improve from 0.37507
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4222 - acc: 0.7941 - val_loss: 0.3762 - val_acc: 0.8375
#
# Epoch 00028: val_loss did not improve from 0.37507
# Epoch 29/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4342 - acc: 0.8117 - val_loss: 0.3688 - val_acc: 0.8450
#
# Epoch 00029: val_loss improved from 0.37507 to 0.36885, saving model to checkpoint_2.h5
# Epoch 30/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4473 - acc: 0.8189 - val_loss: 0.3746 - val_acc: 0.8450
#
# Epoch 00030: val_loss did not improve from 0.36885
# Epoch 31/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4201 - acc: 0.8213 - val_loss: 0.3668 - val_acc: 0.8475
#
# Epoch 00031: val_loss improved from 0.36885 to 0.36681, saving model to checkpoint_2.h5
# Epoch 32/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4209 - acc: 0.8042 - val_loss: 0.3695 - val_acc: 0.8375
#
# Epoch 00032: val_loss did not improve from 0.36681
# Epoch 33/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4277 - acc: 0.7943 - val_loss: 0.3636 - val_acc: 0.8475
#
# Epoch 00033: val_loss improved from 0.36681 to 0.36362, saving model to checkpoint_2.h5
# Epoch 34/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4095 - acc: 0.8261 - val_loss: 0.3637 - val_acc: 0.8413
#
# Epoch 00034: val_loss did not improve from 0.36362
# Epoch 35/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4324 - acc: 0.8124 - val_loss: 0.3663 - val_acc: 0.8363
#
# Epoch 00035: val_loss did not improve from 0.36362
# Epoch 36/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3864 - acc: 0.8223 - val_loss: 0.3646 - val_acc: 0.8475
#
# Epoch 00036: val_loss did not improve from 0.36362
# Epoch 37/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4135 - acc: 0.8065 - val_loss: 0.3725 - val_acc: 0.8425
#
# Epoch 00037: val_loss did not improve from 0.36362
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4005 - acc: 0.8210 - val_loss: 0.3684 - val_acc: 0.8363
#
# Epoch 00038: val_loss did not improve from 0.36362
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4011 - acc: 0.8187 - val_loss: 0.3683 - val_acc: 0.8388
#
# Epoch 00039: val_loss did not improve from 0.36362
# Epoch 40/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4430 - acc: 0.8077 - val_loss: 0.3665 - val_acc: 0.8375
#
# Epoch 00040: val_loss did not improve from 0.36362
# Epoch 41/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4128 - acc: 0.7998 - val_loss: 0.3722 - val_acc: 0.8425
#
# Epoch 00041: val_loss did not improve from 0.36362
# Epoch 42/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4032 - acc: 0.8194 - val_loss: 0.3616 - val_acc: 0.8425
#
# Epoch 00042: val_loss improved from 0.36362 to 0.36163, saving model to checkpoint_2.h5
# Epoch 43/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4175 - acc: 0.8252 - val_loss: 0.3564 - val_acc: 0.8487
#
# Epoch 00043: val_loss improved from 0.36163 to 0.35643, saving model to checkpoint_2.h5
# Epoch 44/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4018 - acc: 0.8156 - val_loss: 0.3650 - val_acc: 0.8487
#
# Epoch 00044: val_loss did not improve from 0.35643
# Epoch 45/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4044 - acc: 0.8171 - val_loss: 0.3597 - val_acc: 0.8475
#
# Epoch 00045: val_loss did not improve from 0.35643
# Epoch 46/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4071 - acc: 0.8303 - val_loss: 0.3543 - val_acc: 0.8500
#
# Epoch 00046: val_loss improved from 0.35643 to 0.35433, saving model to checkpoint_2.h5
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4241 - acc: 0.8064 - val_loss: 0.3655 - val_acc: 0.8375
#
# Epoch 00047: val_loss did not improve from 0.35433
# Epoch 48/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4056 - acc: 0.8164 - val_loss: 0.3636 - val_acc: 0.8438
#
# Epoch 00048: val_loss did not improve from 0.35433
# Epoch 49/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4044 - acc: 0.8280 - val_loss: 0.3640 - val_acc: 0.8475
#
# Epoch 00049: val_loss did not improve from 0.35433
# Epoch 50/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4004 - acc: 0.8180 - val_loss: 0.3565 - val_acc: 0.8450
#
# Epoch 00050: val_loss did not improve from 0.35433

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3490 - acc: 0.8594
#
# ---------------------------------
# Accuracy: 85.94 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.84      0.86       179
#          1.0       0.83      0.87      0.85       157
#
#     accuracy                           0.86       336
#    macro avg       0.86      0.86      0.86       336
# weighted avg       0.86      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 13,370,881
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 132ms/step - loss: 1.3977 - acc: 0.6183 - val_loss: 0.5956 - val_acc: 0.7100
#
# Epoch 00001: val_loss improved from inf to 0.59562, saving model to checkpoint_2.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.7288 - acc: 0.5846 - val_loss: 0.5271 - val_acc: 0.7900
#
# Epoch 00002: val_loss improved from 0.59562 to 0.52714, saving model to checkpoint_2.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6427 - acc: 0.6472 - val_loss: 0.4739 - val_acc: 0.8163
#
# Epoch 00003: val_loss improved from 0.52714 to 0.47391, saving model to checkpoint_2.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5942 - acc: 0.6710 - val_loss: 0.4401 - val_acc: 0.7925
#
# Epoch 00004: val_loss improved from 0.47391 to 0.44011, saving model to checkpoint_2.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5924 - acc: 0.6678 - val_loss: 0.4525 - val_acc: 0.7962
#
# Epoch 00005: val_loss did not improve from 0.44011
# Epoch 6/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5693 - acc: 0.7138 - val_loss: 0.4454 - val_acc: 0.8388
#
# Epoch 00006: val_loss did not improve from 0.44011
# Epoch 7/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5443 - acc: 0.7260 - val_loss: 0.4054 - val_acc: 0.8375
#
# Epoch 00007: val_loss improved from 0.44011 to 0.40541, saving model to checkpoint_2.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5374 - acc: 0.7398 - val_loss: 0.3839 - val_acc: 0.8438
#
# Epoch 00008: val_loss improved from 0.40541 to 0.38391, saving model to checkpoint_2.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5390 - acc: 0.7310 - val_loss: 0.3909 - val_acc: 0.8500
#
# Epoch 00009: val_loss did not improve from 0.38391
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5779 - acc: 0.7228 - val_loss: 0.4024 - val_acc: 0.8350
#
# Epoch 00010: val_loss did not improve from 0.38391
# Epoch 11/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5311 - acc: 0.7284 - val_loss: 0.4161 - val_acc: 0.8450
#
# Epoch 00011: val_loss did not improve from 0.38391
# Epoch 12/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4911 - acc: 0.7675 - val_loss: 0.3574 - val_acc: 0.8537
#
# Epoch 00012: val_loss improved from 0.38391 to 0.35737, saving model to checkpoint_2.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5240 - acc: 0.7530 - val_loss: 0.3954 - val_acc: 0.8550
#
# Epoch 00013: val_loss did not improve from 0.35737
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5203 - acc: 0.7667 - val_loss: 0.4035 - val_acc: 0.8475
#
# Epoch 00014: val_loss did not improve from 0.35737
# Epoch 15/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5174 - acc: 0.7521 - val_loss: 0.4099 - val_acc: 0.8363
#
# Epoch 00015: val_loss did not improve from 0.35737
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc09c7ac550>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c1d49e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0f0291438>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc092105630>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc0f00a1c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0f00a4908>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092094e10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0f00a9a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0f01bd588>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0920d86a0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c1edeb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09239c7b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0922ac710>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0920753c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09cc62630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092205c50>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc0f00a4320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09223e518>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0921b4e80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092166cf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c1e07b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0922a1ac8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc092205198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0920c07b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0923a1b38>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c061630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092094358>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc092311be0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09221b5c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092159da0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09213d9e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c0de4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0923bfc50>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c1e0748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092094ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c159a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09217b588>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc09c182160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c182e80>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc0922c1048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09217ba20>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09227ea58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09217bc88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0921edc88>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092365a20>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc092159860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0922b8be0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09232c160>, <tensorflow.python.kera ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 36,890,241
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 20s 165ms/step - loss: 1.4215 - acc: 0.7628 - val_loss: 0.4850 - val_acc: 0.7625
#
# Epoch 00001: val_loss did not improve from 0.35737
# Epoch 2/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.4984 - acc: 0.7599 - val_loss: 0.3603 - val_acc: 0.8225
#
# Epoch 00002: val_loss did not improve from 0.35737
# Epoch 3/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.4710 - acc: 0.7949 - val_loss: 0.3611 - val_acc: 0.8500
#
# Epoch 00003: val_loss did not improve from 0.35737
# Epoch 4/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.4014 - acc: 0.8339 - val_loss: 0.3034 - val_acc: 0.8800
#
# Epoch 00004: val_loss improved from 0.35737 to 0.30342, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3862 - acc: 0.8429 - val_loss: 0.2863 - val_acc: 0.8750
#
# Epoch 00005: val_loss improved from 0.30342 to 0.28628, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.3924 - acc: 0.8353 - val_loss: 0.2634 - val_acc: 0.9075
#
# Epoch 00006: val_loss improved from 0.28628 to 0.26343, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3610 - acc: 0.8530 - val_loss: 0.2328 - val_acc: 0.9150
#
# Epoch 00007: val_loss improved from 0.26343 to 0.23285, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3622 - acc: 0.8759 - val_loss: 0.2449 - val_acc: 0.9262
#
# Epoch 00008: val_loss did not improve from 0.23285
# Epoch 9/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3707 - acc: 0.8630 - val_loss: 0.4013 - val_acc: 0.8687
#
# Epoch 00009: val_loss did not improve from 0.23285
# Epoch 10/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3309 - acc: 0.8686 - val_loss: 0.2228 - val_acc: 0.9287
#
# Epoch 00010: val_loss improved from 0.23285 to 0.22278, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.3001 - acc: 0.8872 - val_loss: 0.2688 - val_acc: 0.9200
#
# Epoch 00011: val_loss did not improve from 0.22278
# Epoch 12/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3195 - acc: 0.8698 - val_loss: 0.4108 - val_acc: 0.7962
#
# Epoch 00012: val_loss did not improve from 0.22278
# Epoch 13/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3268 - acc: 0.8632 - val_loss: 0.2915 - val_acc: 0.9212
#
# Epoch 00013: val_loss did not improve from 0.22278
# Epoch 14/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2899 - acc: 0.8781 - val_loss: 0.2903 - val_acc: 0.9075
#
# Epoch 00014: val_loss did not improve from 0.22278
# Epoch 15/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3168 - acc: 0.8863 - val_loss: 0.2790 - val_acc: 0.9212
#
# Epoch 00015: val_loss did not improve from 0.22278
# Epoch 16/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2905 - acc: 0.8827 - val_loss: 0.3153 - val_acc: 0.9312
#
# Epoch 00016: val_loss did not improve from 0.22278
# Epoch 17/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.3072 - acc: 0.8848 - val_loss: 0.4454 - val_acc: 0.7725
#
# Epoch 00017: val_loss did not improve from 0.22278
# Epoch 18/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2688 - acc: 0.9053 - val_loss: 0.3410 - val_acc: 0.8875
#
# Epoch 00018: val_loss did not improve from 0.22278
# Epoch 19/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2704 - acc: 0.8910 - val_loss: 0.3517 - val_acc: 0.8487
#
# Epoch 00019: val_loss did not improve from 0.22278
# Epoch 20/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2680 - acc: 0.8898 - val_loss: 0.2867 - val_acc: 0.9112
#
# Epoch 00020: val_loss did not improve from 0.22278
# Epoch 21/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2456 - acc: 0.8988 - val_loss: 0.3879 - val_acc: 0.8712
#
# Epoch 00021: val_loss did not improve from 0.22278
# Epoch 22/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2504 - acc: 0.9128 - val_loss: 0.3334 - val_acc: 0.9013
#
# Epoch 00022: val_loss did not improve from 0.22278
# Epoch 23/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2497 - acc: 0.9005 - val_loss: 0.3250 - val_acc: 0.9287
#
# Epoch 00023: val_loss did not improve from 0.22278
# Epoch 24/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2518 - acc: 0.9011 - val_loss: 0.2895 - val_acc: 0.9287
#
# Epoch 00024: val_loss did not improve from 0.22278
# Epoch 25/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2785 - acc: 0.8861 - val_loss: 0.3190 - val_acc: 0.8800
#
# Epoch 00025: val_loss did not improve from 0.22278
# Epoch 26/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2584 - acc: 0.8849 - val_loss: 0.4057 - val_acc: 0.8413
#
# Epoch 00026: val_loss did not improve from 0.22278
# Epoch 27/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2415 - acc: 0.8939 - val_loss: 0.3569 - val_acc: 0.8825
#
# Epoch 00027: val_loss did not improve from 0.22278
# Epoch 28/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2651 - acc: 0.8962 - val_loss: 0.2914 - val_acc: 0.9350
#
# Epoch 00028: val_loss did not improve from 0.22278
# Epoch 29/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2244 - acc: 0.9097 - val_loss: 0.3382 - val_acc: 0.9100
#
# Epoch 00029: val_loss did not improve from 0.22278
# Epoch 30/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2944 - acc: 0.8960 - val_loss: 0.4231 - val_acc: 0.8462
#
# Epoch 00030: val_loss did not improve from 0.22278
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2658 - acc: 0.8844
#
# ---------------------------------
# Accuracy: 88.44 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.85      0.88       179
#          1.0       0.85      0.91      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 787,969
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 132ms/step - loss: 0.7845 - acc: 0.6325 - val_loss: 0.6495 - val_acc: 0.7688
#
# Epoch 00001: val_loss improved from inf to 0.64952, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6903 - acc: 0.5758 - val_loss: 0.5186 - val_acc: 0.8025
#
# Epoch 00002: val_loss improved from 0.64952 to 0.51863, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5769 - acc: 0.6905 - val_loss: 0.4969 - val_acc: 0.8075
#
# Epoch 00003: val_loss improved from 0.51863 to 0.49690, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5722 - acc: 0.7060 - val_loss: 0.4838 - val_acc: 0.8150
#
# Epoch 00004: val_loss improved from 0.49690 to 0.48382, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5338 - acc: 0.7326 - val_loss: 0.4685 - val_acc: 0.8188
#
# Epoch 00005: val_loss improved from 0.48382 to 0.46854, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5393 - acc: 0.7412 - val_loss: 0.4483 - val_acc: 0.8238
#
# Epoch 00006: val_loss improved from 0.46854 to 0.44832, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5239 - acc: 0.7453 - val_loss: 0.4141 - val_acc: 0.8288
#
# Epoch 00007: val_loss improved from 0.44832 to 0.41413, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5556 - acc: 0.7247 - val_loss: 0.4574 - val_acc: 0.8288
#
# Epoch 00008: val_loss did not improve from 0.41413
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5422 - acc: 0.7285 - val_loss: 0.3888 - val_acc: 0.8425
#
# Epoch 00009: val_loss improved from 0.41413 to 0.38881, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5227 - acc: 0.7666 - val_loss: 0.4052 - val_acc: 0.8438
#
# Epoch 00010: val_loss did not improve from 0.38881
# Epoch 11/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5132 - acc: 0.7712 - val_loss: 0.4430 - val_acc: 0.8400
#
# Epoch 00011: val_loss did not improve from 0.38881
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5041 - acc: 0.7592 - val_loss: 0.4580 - val_acc: 0.8350
#
# Epoch 00012: val_loss did not improve from 0.38881
# Epoch 13/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5143 - acc: 0.7653 - val_loss: 0.4632 - val_acc: 0.8300
#
# Epoch 00013: val_loss did not improve from 0.38881
# Epoch 14/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4886 - acc: 0.7883 - val_loss: 0.4356 - val_acc: 0.8413
#
# Epoch 00014: val_loss did not improve from 0.38881
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5165 - acc: 0.7475 - val_loss: 0.4475 - val_acc: 0.8338
#
# Epoch 00015: val_loss did not improve from 0.38881
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc09201b2e8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a4d5470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc07001ecc0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a99ba90>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fbe8a44ac88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc07008bef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a444470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc07008b518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0700d6c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a5bb2b0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a4a2e48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a6769b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a93f8d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a764828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a99b390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8bab7ac8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc07008b860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0931905c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8aa53470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a5bb9e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a6697b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a95da90>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc0700d6908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a4d0e10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a95da20>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a6f7198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a8e27b8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fbe8a8f9c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a61ef28>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a4e40b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a95dbe0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8aa5d358>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a70fd68>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8aa716a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a4a2908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8aa5d320>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a797f60>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fbe8a44acc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8aa5ddd8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fbe8a676cf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a744940>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a744dd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a4ceb70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a744358>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a48c908>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8aa5d4a8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a4cec18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8aa65d30>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 24,307,329
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/50
#  6/93 [>.............................] - ETA: 11s - loss: 1.1088 - acc: 0.8157WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0648s vs `on_train_batch_end` time: 0.0735s). Check your callbacks.
# 93/93 [==============================] - 19s 159ms/step - loss: 0.6798 - acc: 0.7861 - val_loss: 1.1629 - val_acc: 0.7113
#
# Epoch 00001: val_loss did not improve from 0.38881
# Epoch 2/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.4469 - acc: 0.8066 - val_loss: 0.3339 - val_acc: 0.8650
#
# Epoch 00002: val_loss improved from 0.38881 to 0.33393, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3673 - acc: 0.8539 - val_loss: 0.5933 - val_acc: 0.7650
#
# Epoch 00003: val_loss did not improve from 0.33393
# Epoch 4/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3543 - acc: 0.8398 - val_loss: 0.4496 - val_acc: 0.7738
#
# Epoch 00004: val_loss did not improve from 0.33393
# Epoch 5/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.3789 - acc: 0.8562 - val_loss: 0.3717 - val_acc: 0.7987
#
# Epoch 00005: val_loss did not improve from 0.33393
# Epoch 6/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3192 - acc: 0.8620 - val_loss: 0.4188 - val_acc: 0.7550
#
# Epoch 00006: val_loss did not improve from 0.33393
# Epoch 7/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2987 - acc: 0.8861 - val_loss: 0.2515 - val_acc: 0.8938
#
# Epoch 00007: val_loss improved from 0.33393 to 0.25152, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3670 - acc: 0.8515 - val_loss: 0.3103 - val_acc: 0.9137
#
# Epoch 00008: val_loss did not improve from 0.25152
# Epoch 9/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2915 - acc: 0.8979 - val_loss: 0.3556 - val_acc: 0.8988
#
# Epoch 00009: val_loss did not improve from 0.25152
# Epoch 10/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2862 - acc: 0.8938 - val_loss: 0.2886 - val_acc: 0.9150
#
# Epoch 00010: val_loss did not improve from 0.25152
# Epoch 11/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.3051 - acc: 0.8971 - val_loss: 0.2845 - val_acc: 0.9062
#
# Epoch 00011: val_loss did not improve from 0.25152
# Epoch 12/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2744 - acc: 0.8963 - val_loss: 0.3071 - val_acc: 0.9000
#
# Epoch 00012: val_loss did not improve from 0.25152
# Epoch 13/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2760 - acc: 0.8883 - val_loss: 0.3051 - val_acc: 0.9125
#
# Epoch 00013: val_loss did not improve from 0.25152
# Epoch 14/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2680 - acc: 0.9068 - val_loss: 0.2616 - val_acc: 0.9225
#
# Epoch 00014: val_loss did not improve from 0.25152
# Epoch 15/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2844 - acc: 0.9000 - val_loss: 0.4048 - val_acc: 0.8000
#
# Epoch 00015: val_loss did not improve from 0.25152
# Epoch 16/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.3032 - acc: 0.8948 - val_loss: 0.3473 - val_acc: 0.8813
#
# Epoch 00016: val_loss did not improve from 0.25152
# Epoch 17/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2714 - acc: 0.8966 - val_loss: 0.2834 - val_acc: 0.9000
#
# Epoch 00017: val_loss did not improve from 0.25152
# Epoch 18/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2462 - acc: 0.9060 - val_loss: 0.2745 - val_acc: 0.9025
#
# Epoch 00018: val_loss did not improve from 0.25152
# Epoch 19/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2271 - acc: 0.9191 - val_loss: 0.3554 - val_acc: 0.8400
#
# Epoch 00019: val_loss did not improve from 0.25152
# Epoch 20/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2327 - acc: 0.9199 - val_loss: 0.4415 - val_acc: 0.7725
#
# Epoch 00020: val_loss did not improve from 0.25152
# Epoch 21/50
# 93/93 [==============================] - 14s 149ms/step - loss: 0.2990 - acc: 0.8907 - val_loss: 0.4138 - val_acc: 0.7275
#
# Epoch 00021: val_loss did not improve from 0.25152
# Epoch 22/50
# 93/93 [==============================] - 14s 150ms/step - loss: 0.2099 - acc: 0.9184 - val_loss: 0.3052 - val_acc: 0.8575
#
# Epoch 00022: val_loss did not improve from 0.25152
# Epoch 23/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2575 - acc: 0.9174 - val_loss: 0.2804 - val_acc: 0.9262
#
# Epoch 00023: val_loss did not improve from 0.25152
# Epoch 24/50
# 93/93 [==============================] - 14s 153ms/step - loss: 0.2267 - acc: 0.9134 - val_loss: 0.2667 - val_acc: 0.9150
#
# Epoch 00024: val_loss did not improve from 0.25152
# Epoch 25/50
# 93/93 [==============================] - 14s 151ms/step - loss: 0.2184 - acc: 0.9163 - val_loss: 0.3786 - val_acc: 0.8375
#
# Epoch 00025: val_loss did not improve from 0.25152
# Epoch 26/50
# 93/93 [==============================] - 14s 152ms/step - loss: 0.2505 - acc: 0.9127 - val_loss: 0.2741 - val_acc: 0.9187
#
# Epoch 00026: val_loss did not improve from 0.25152
# Epoch 27/50
# 93/93 [==============================] - 14s 154ms/step - loss: 0.2223 - acc: 0.9119 - val_loss: 0.3271 - val_acc: 0.8662
#
# Epoch 00027: val_loss did not improve from 0.25152
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3041 - acc: 0.8500
#
# ---------------------------------
# Accuracy: 85.00 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.78      0.85       179
#          1.0       0.79      0.94      0.86       157
#
#     accuracy                           0.85       336
#    macro avg       0.86      0.86      0.85       336
# weighted avg       0.87      0.85      0.85       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'
# Out:
# rm: cannot remove 'checkpoint_2.h5': No such file or directory

# %% [markdown]
# ## Flatten, Last  Block Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last 2 convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block3_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 13,370,881
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 131ms/step - loss: 1.3925 - acc: 0.6392 - val_loss: 0.6247 - val_acc: 0.6600
#
# Epoch 00001: val_loss improved from inf to 0.62472, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.7294 - acc: 0.5764 - val_loss: 0.5506 - val_acc: 0.7350
#
# Epoch 00002: val_loss improved from 0.62472 to 0.55063, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6728 - acc: 0.6074 - val_loss: 0.5095 - val_acc: 0.7763
#
# Epoch 00003: val_loss improved from 0.55063 to 0.50948, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6127 - acc: 0.6791 - val_loss: 0.4849 - val_acc: 0.8138
#
# Epoch 00004: val_loss improved from 0.50948 to 0.48488, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6010 - acc: 0.6703 - val_loss: 0.4947 - val_acc: 0.8213
#
# Epoch 00005: val_loss did not improve from 0.48488
# Epoch 6/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5538 - acc: 0.7238 - val_loss: 0.4644 - val_acc: 0.8125
#
# Epoch 00006: val_loss improved from 0.48488 to 0.46441, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5642 - acc: 0.7120 - val_loss: 0.4639 - val_acc: 0.8200
#
# Epoch 00007: val_loss improved from 0.46441 to 0.46386, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5272 - acc: 0.7313 - val_loss: 0.4364 - val_acc: 0.8363
#
# Epoch 00008: val_loss improved from 0.46386 to 0.43640, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5578 - acc: 0.7416 - val_loss: 0.3953 - val_acc: 0.8375
#
# Epoch 00009: val_loss improved from 0.43640 to 0.39526, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5133 - acc: 0.7604 - val_loss: 0.4345 - val_acc: 0.8200
#
# Epoch 00010: val_loss did not improve from 0.39526
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4848 - acc: 0.7778 - val_loss: 0.4233 - val_acc: 0.8275
#
# Epoch 00011: val_loss did not improve from 0.39526
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5288 - acc: 0.7280 - val_loss: 0.3974 - val_acc: 0.8313
#
# Epoch 00012: val_loss did not improve from 0.39526
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4886 - acc: 0.7652 - val_loss: 0.4079 - val_acc: 0.8400
#
# Epoch 00013: val_loss did not improve from 0.39526
# Epoch 14/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4751 - acc: 0.7671 - val_loss: 0.4530 - val_acc: 0.8375
#
# Epoch 00014: val_loss did not improve from 0.39526
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4535 - acc: 0.7976 - val_loss: 0.4259 - val_acc: 0.8300
#
# Epoch 00015: val_loss did not improve from 0.39526
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f4d3be1f9e8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4b22de62b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d900ef4a8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d3be14780>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4d3a705dd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b22df50b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4b22d91d68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4b22da3550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4b22e686d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a8e9fd0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4b22db4710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3be1ecc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3be1f550>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a743a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3abaa5c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3a397978>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4b22d916d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a788978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3ab9b2e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d38a45d30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a94d198>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3ab1c828>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d38b26ef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3a8b19b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3abab198>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3aac68d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3ab9bcc0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d3be1ec18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a456240>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a88df28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3abab518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a88d898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a888860>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d3a462cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3acb3a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a88dba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a4b6860>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f4d3aa274e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3a88dc88>, <tensorflow.python.keras.layers.merge.Add object at 0x7f4d3aac6d68>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3a4b6f98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3a888eb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3a4b6c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d0f7c7898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f4d3ab20160>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f4d3a88dac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f4d3a462fd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f4d3ab20278>, <tensorflow.python.kera ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 51200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               13107456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 17,839,617
# Non-trainable params: 19,096,064
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 133ms/step - loss: 0.8683 - acc: 0.7737 - val_loss: 0.4383 - val_acc: 0.8250
#
# Epoch 00001: val_loss did not improve from 0.39526
# Epoch 2/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.5458 - acc: 0.7458 - val_loss: 0.4015 - val_acc: 0.8475
#
# Epoch 00002: val_loss did not improve from 0.39526
# Epoch 3/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4956 - acc: 0.7813 - val_loss: 0.3837 - val_acc: 0.8462
#
# Epoch 00003: val_loss improved from 0.39526 to 0.38373, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 124ms/step - loss: 0.4745 - acc: 0.7886 - val_loss: 0.3768 - val_acc: 0.8450
#
# Epoch 00004: val_loss improved from 0.38373 to 0.37684, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4240 - acc: 0.8088 - val_loss: 0.3947 - val_acc: 0.8462
#
# Epoch 00005: val_loss did not improve from 0.37684
# Epoch 6/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4328 - acc: 0.8063 - val_loss: 0.3420 - val_acc: 0.8675
#
# Epoch 00006: val_loss improved from 0.37684 to 0.34202, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4316 - acc: 0.8222 - val_loss: 0.3575 - val_acc: 0.8712
#
# Epoch 00007: val_loss did not improve from 0.34202
# Epoch 8/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4434 - acc: 0.7966 - val_loss: 0.3732 - val_acc: 0.8763
#
# Epoch 00008: val_loss did not improve from 0.34202
# Epoch 9/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4087 - acc: 0.8203 - val_loss: 0.3636 - val_acc: 0.8662
#
# Epoch 00009: val_loss did not improve from 0.34202
# Epoch 10/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4195 - acc: 0.8240 - val_loss: 0.3472 - val_acc: 0.8763
#
# Epoch 00010: val_loss did not improve from 0.34202
# Epoch 11/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3723 - acc: 0.8476 - val_loss: 0.3371 - val_acc: 0.8763
#
# Epoch 00011: val_loss improved from 0.34202 to 0.33708, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3896 - acc: 0.8436 - val_loss: 0.3630 - val_acc: 0.8712
#
# Epoch 00012: val_loss did not improve from 0.33708
# Epoch 13/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3934 - acc: 0.8288 - val_loss: 0.3754 - val_acc: 0.8712
#
# Epoch 00013: val_loss did not improve from 0.33708
# Epoch 14/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3832 - acc: 0.8495 - val_loss: 0.3538 - val_acc: 0.8813
#
# Epoch 00014: val_loss did not improve from 0.33708
# Epoch 15/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3531 - acc: 0.8507 - val_loss: 0.3621 - val_acc: 0.8775
#
# Epoch 00015: val_loss did not improve from 0.33708
# Epoch 16/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3508 - acc: 0.8608 - val_loss: 0.3759 - val_acc: 0.8825
#
# Epoch 00016: val_loss did not improve from 0.33708
# Epoch 17/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3692 - acc: 0.8400 - val_loss: 0.3627 - val_acc: 0.8712
#
# Epoch 00017: val_loss did not improve from 0.33708
# Epoch 18/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3529 - acc: 0.8612 - val_loss: 0.3913 - val_acc: 0.8838
#
# Epoch 00018: val_loss did not improve from 0.33708
# Epoch 19/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3526 - acc: 0.8490 - val_loss: 0.3793 - val_acc: 0.8725
#
# Epoch 00019: val_loss did not improve from 0.33708
# Epoch 20/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3722 - acc: 0.8471 - val_loss: 0.3526 - val_acc: 0.8825
#
# Epoch 00020: val_loss did not improve from 0.33708
# Epoch 21/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3729 - acc: 0.8531 - val_loss: 0.3542 - val_acc: 0.8675
#
# Epoch 00021: val_loss did not improve from 0.33708
# Epoch 22/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3435 - acc: 0.8573 - val_loss: 0.3482 - val_acc: 0.8687
#
# Epoch 00022: val_loss did not improve from 0.33708
# Epoch 23/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3697 - acc: 0.8473 - val_loss: 0.3439 - val_acc: 0.8700
#
# Epoch 00023: val_loss did not improve from 0.33708
# Epoch 24/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3483 - acc: 0.8523 - val_loss: 0.3244 - val_acc: 0.8825
#
# Epoch 00024: val_loss improved from 0.33708 to 0.32444, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3144 - acc: 0.8640 - val_loss: 0.3155 - val_acc: 0.8850
#
# Epoch 00025: val_loss improved from 0.32444 to 0.31546, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3445 - acc: 0.8383 - val_loss: 0.3450 - val_acc: 0.8612
#
# Epoch 00026: val_loss did not improve from 0.31546
# Epoch 27/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3249 - acc: 0.8659 - val_loss: 0.3442 - val_acc: 0.8725
#
# Epoch 00027: val_loss did not improve from 0.31546
# Epoch 28/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3595 - acc: 0.8523 - val_loss: 0.3209 - val_acc: 0.8838
#
# Epoch 00028: val_loss did not improve from 0.31546
# Epoch 29/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3045 - acc: 0.8744 - val_loss: 0.3692 - val_acc: 0.8537
#
# Epoch 00029: val_loss did not improve from 0.31546
# Epoch 30/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3574 - acc: 0.8503 - val_loss: 0.3425 - val_acc: 0.8788
#
# Epoch 00030: val_loss did not improve from 0.31546
# Epoch 31/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3521 - acc: 0.8676 - val_loss: 0.3460 - val_acc: 0.8750
#
# Epoch 00031: val_loss did not improve from 0.31546
# Epoch 32/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3084 - acc: 0.8753 - val_loss: 0.3370 - val_acc: 0.8763
#
# Epoch 00032: val_loss did not improve from 0.31546
# Epoch 33/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3500 - acc: 0.8605 - val_loss: 0.3510 - val_acc: 0.8763
#
# Epoch 00033: val_loss did not improve from 0.31546
# Epoch 34/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3186 - acc: 0.8843 - val_loss: 0.3614 - val_acc: 0.8788
#
# Epoch 00034: val_loss did not improve from 0.31546
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3166 - acc: 0.8743 - val_loss: 0.3490 - val_acc: 0.8775
#
# Epoch 00035: val_loss did not improve from 0.31546
# Epoch 36/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3146 - acc: 0.8622 - val_loss: 0.3427 - val_acc: 0.8863
#
# Epoch 00036: val_loss did not improve from 0.31546
# Epoch 37/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3060 - acc: 0.8799 - val_loss: 0.3644 - val_acc: 0.8750
#
# Epoch 00037: val_loss did not improve from 0.31546
# Epoch 38/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3392 - acc: 0.8618 - val_loss: 0.3224 - val_acc: 0.8800
#
# Epoch 00038: val_loss did not improve from 0.31546
# Epoch 39/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3328 - acc: 0.8640 - val_loss: 0.3279 - val_acc: 0.8825
#
# Epoch 00039: val_loss did not improve from 0.31546
# Epoch 40/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2927 - acc: 0.8826 - val_loss: 0.3787 - val_acc: 0.8637
#
# Epoch 00040: val_loss did not improve from 0.31546
# Epoch 41/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3218 - acc: 0.8808 - val_loss: 0.3767 - val_acc: 0.8800
#
# Epoch 00041: val_loss did not improve from 0.31546
# Epoch 42/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2874 - acc: 0.8848 - val_loss: 0.3695 - val_acc: 0.8825
#
# Epoch 00042: val_loss did not improve from 0.31546
# Epoch 43/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3020 - acc: 0.8802 - val_loss: 0.3717 - val_acc: 0.8525
#
# Epoch 00043: val_loss did not improve from 0.31546
# Epoch 44/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3135 - acc: 0.8823 - val_loss: 0.3819 - val_acc: 0.8700
#
# Epoch 00044: val_loss did not improve from 0.31546
# Epoch 45/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3044 - acc: 0.8775 - val_loss: 0.3986 - val_acc: 0.8550
#
# Epoch 00045: val_loss did not improve from 0.31546
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3600 - acc: 0.8562
#
# ---------------------------------
# Accuracy: 85.62 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.85      0.86       179
#          1.0       0.83      0.86      0.85       157
#
#     accuracy                           0.85       336
#    macro avg       0.85      0.85      0.85       336
# weighted avg       0.85      0.85      0.85       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'resNet_dense_256x5_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 51200)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 13,370,881
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 131ms/step - loss: 1.5236 - acc: 0.5088 - val_loss: 0.6515 - val_acc: 0.5600
#
# Epoch 00001: val_loss improved from inf to 0.65147, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.7326 - acc: 0.5973 - val_loss: 0.5335 - val_acc: 0.7688
#
# Epoch 00002: val_loss improved from 0.65147 to 0.53345, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6291 - acc: 0.6307 - val_loss: 0.4545 - val_acc: 0.7775
#
# Epoch 00003: val_loss improved from 0.53345 to 0.45446, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5784 - acc: 0.7078 - val_loss: 0.5064 - val_acc: 0.8050
#
# Epoch 00004: val_loss did not improve from 0.45446
# Epoch 5/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6087 - acc: 0.7075 - val_loss: 0.4568 - val_acc: 0.8112
#
# Epoch 00005: val_loss did not improve from 0.45446
# Epoch 6/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5259 - acc: 0.7442 - val_loss: 0.4379 - val_acc: 0.8025
#
# Epoch 00006: val_loss improved from 0.45446 to 0.43791, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5679 - acc: 0.7364 - val_loss: 0.4269 - val_acc: 0.8150
#
# Epoch 00007: val_loss improved from 0.43791 to 0.42692, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5571 - acc: 0.7317 - val_loss: 0.4429 - val_acc: 0.8138
#
# Epoch 00008: val_loss did not improve from 0.42692
# Epoch 9/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4849 - acc: 0.7706 - val_loss: 0.4467 - val_acc: 0.8012
#
# Epoch 00009: val_loss did not improve from 0.42692
# Epoch 10/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5069 - acc: 0.7673 - val_loss: 0.4452 - val_acc: 0.8100
#
# Epoch 00010: val_loss did not improve from 0.42692
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5509 - acc: 0.7401 - val_loss: 0.4159 - val_acc: 0.8150
#
# Epoch 00011: val_loss improved from 0.42692 to 0.41587, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5229 - acc: 0.7484 - val_loss: 0.4204 - val_acc: 0.8100
#
# Epoch 00012: val_loss did not improve from 0.41587
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4784 - acc: 0.7803 - val_loss: 0.4451 - val_acc: 0.8087
#
# Epoch 00013: val_loss did not improve from 0.41587
# Epoch 14/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5811 - acc: 0.7523 - val_loss: 0.4350 - val_acc: 0.8100
#
# Epoch 00014: val_loss did not improve from 0.41587
# Epoch 15/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4837 - acc: 0.7976 - val_loss: 0.4379 - val_acc: 0.8238
#
# Epoch 00015: val_loss did not improve from 0.41587
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fbe8bfd2198>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c4199b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8becdac8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c419e10>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc0a4112828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a2852e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c197e10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2f52e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a364940>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092cf5c18>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a2db240>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0923d25c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8bfaecf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c649080>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092edefd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8bec0898>, <tensorflow.python.keras.layers.merge.Add object at 0x7fbe8a28f390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092e0ccc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c60c908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09dd727b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092e920b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8bfd76d8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a356a90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092e929b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c60c438>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8becd208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092e82438>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc092ec24a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c5c14e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0a415a320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8bb6b160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092e924a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0931e4208>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc0fdc90fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0fd857d68>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092e925c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092d4d6d8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fbe8bfd1da0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0a40f8da0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc0a41276a0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0931e4dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0931ee390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c3d35c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c3d3780>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8bb0e588>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc092fc17f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0fca0b438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092d4d8d0>, <tensorflow.python.kera ...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 51200)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 22,304,257
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 132ms/step - loss: 0.9131 - acc: 0.7842 - val_loss: 0.4666 - val_acc: 0.7638
#
# Epoch 00001: val_loss did not improve from 0.41587
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.5143 - acc: 0.7517 - val_loss: 0.3600 - val_acc: 0.8425
#
# Epoch 00002: val_loss improved from 0.41587 to 0.36001, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.4600 - acc: 0.8100 - val_loss: 0.3780 - val_acc: 0.8200
#
# Epoch 00003: val_loss did not improve from 0.36001
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4130 - acc: 0.8230 - val_loss: 0.3469 - val_acc: 0.8562
#
# Epoch 00004: val_loss improved from 0.36001 to 0.34690, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4309 - acc: 0.8066 - val_loss: 0.3762 - val_acc: 0.8225
#
# Epoch 00005: val_loss did not improve from 0.34690
# Epoch 6/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3586 - acc: 0.8618 - val_loss: 0.3402 - val_acc: 0.8587
#
# Epoch 00006: val_loss improved from 0.34690 to 0.34025, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3958 - acc: 0.8398 - val_loss: 0.3402 - val_acc: 0.8612
#
# Epoch 00007: val_loss improved from 0.34025 to 0.34025, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3777 - acc: 0.8564 - val_loss: 0.3312 - val_acc: 0.8687
#
# Epoch 00008: val_loss improved from 0.34025 to 0.33120, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.4057 - acc: 0.8493 - val_loss: 0.3489 - val_acc: 0.8537
#
# Epoch 00009: val_loss did not improve from 0.33120
# Epoch 10/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3930 - acc: 0.8340 - val_loss: 0.3271 - val_acc: 0.8737
#
# Epoch 00010: val_loss improved from 0.33120 to 0.32710, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3645 - acc: 0.8466 - val_loss: 0.4438 - val_acc: 0.8075
#
# Epoch 00011: val_loss did not improve from 0.32710
# Epoch 12/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3418 - acc: 0.8572 - val_loss: 0.3137 - val_acc: 0.8700
#
# Epoch 00012: val_loss improved from 0.32710 to 0.31368, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3422 - acc: 0.8559 - val_loss: 0.3186 - val_acc: 0.8763
#
# Epoch 00013: val_loss did not improve from 0.31368
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3484 - acc: 0.8635 - val_loss: 0.3423 - val_acc: 0.8750
#
# Epoch 00014: val_loss did not improve from 0.31368
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3309 - acc: 0.8728 - val_loss: 0.3866 - val_acc: 0.8500
#
# Epoch 00015: val_loss did not improve from 0.31368
# Epoch 16/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3254 - acc: 0.8645 - val_loss: 0.3271 - val_acc: 0.8775
#
# Epoch 00016: val_loss did not improve from 0.31368
# Epoch 17/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3383 - acc: 0.8546 - val_loss: 0.3330 - val_acc: 0.8825
#
# Epoch 00017: val_loss did not improve from 0.31368
# Epoch 18/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3118 - acc: 0.8735 - val_loss: 0.3578 - val_acc: 0.8725
#
# Epoch 00018: val_loss did not improve from 0.31368
# Epoch 19/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3367 - acc: 0.8479 - val_loss: 0.3336 - val_acc: 0.8800
#
# Epoch 00019: val_loss did not improve from 0.31368
# Epoch 20/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3242 - acc: 0.8772 - val_loss: 0.3515 - val_acc: 0.8500
#
# Epoch 00020: val_loss did not improve from 0.31368
# Epoch 21/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3275 - acc: 0.8680 - val_loss: 0.3769 - val_acc: 0.8637
#
# Epoch 00021: val_loss did not improve from 0.31368
# Epoch 22/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3538 - acc: 0.8593 - val_loss: 0.4000 - val_acc: 0.8525
#
# Epoch 00022: val_loss did not improve from 0.31368
# Epoch 23/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3011 - acc: 0.8794 - val_loss: 0.3650 - val_acc: 0.8637
#
# Epoch 00023: val_loss did not improve from 0.31368
# Epoch 24/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3390 - acc: 0.8550 - val_loss: 0.3802 - val_acc: 0.8487
#
# Epoch 00024: val_loss did not improve from 0.31368
# Epoch 25/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3046 - acc: 0.8886 - val_loss: 0.3189 - val_acc: 0.8850
#
# Epoch 00025: val_loss did not improve from 0.31368
# Epoch 26/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2677 - acc: 0.8938 - val_loss: 0.4101 - val_acc: 0.8300
#
# Epoch 00026: val_loss did not improve from 0.31368
# Epoch 27/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3139 - acc: 0.8811 - val_loss: 0.3668 - val_acc: 0.8612
#
# Epoch 00027: val_loss did not improve from 0.31368
# Epoch 28/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3129 - acc: 0.8850 - val_loss: 0.3741 - val_acc: 0.8725
#
# Epoch 00028: val_loss did not improve from 0.31368
# Epoch 29/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3192 - acc: 0.8660 - val_loss: 0.3886 - val_acc: 0.8687
#
# Epoch 00029: val_loss did not improve from 0.31368
# Epoch 30/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3084 - acc: 0.8802 - val_loss: 0.3735 - val_acc: 0.8700
#
# Epoch 00030: val_loss did not improve from 0.31368
# Epoch 31/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2936 - acc: 0.8922 - val_loss: 0.3364 - val_acc: 0.8838
#
# Epoch 00031: val_loss did not improve from 0.31368
# Epoch 32/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2577 - acc: 0.8870 - val_loss: 0.3739 - val_acc: 0.8637
#
# Epoch 00032: val_loss did not improve from 0.31368
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3168 - acc: 0.8750
#
# ---------------------------------
# Accuracy: 87.50 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89       179
#          1.0       0.87      0.87      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256x5_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block2_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 787,969
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 132ms/step - loss: 0.7729 - acc: 0.6404 - val_loss: 0.6464 - val_acc: 0.7437
#
# Epoch 00001: val_loss improved from inf to 0.64636, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6626 - acc: 0.6025 - val_loss: 0.5189 - val_acc: 0.7663
#
# Epoch 00002: val_loss improved from 0.64636 to 0.51890, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 12s 124ms/step - loss: 0.5951 - acc: 0.7179 - val_loss: 0.5089 - val_acc: 0.7800
#
# Epoch 00003: val_loss improved from 0.51890 to 0.50886, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5236 - acc: 0.7343 - val_loss: 0.4679 - val_acc: 0.7937
#
# Epoch 00004: val_loss improved from 0.50886 to 0.46789, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5785 - acc: 0.7160 - val_loss: 0.4870 - val_acc: 0.8138
#
# Epoch 00005: val_loss did not improve from 0.46789
# Epoch 6/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5238 - acc: 0.7580 - val_loss: 0.4653 - val_acc: 0.8087
#
# Epoch 00006: val_loss improved from 0.46789 to 0.46533, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5361 - acc: 0.7522 - val_loss: 0.4479 - val_acc: 0.8125
#
# Epoch 00007: val_loss improved from 0.46533 to 0.44789, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5218 - acc: 0.7439 - val_loss: 0.4709 - val_acc: 0.8263
#
# Epoch 00008: val_loss did not improve from 0.44789
# Epoch 9/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5145 - acc: 0.7675 - val_loss: 0.4563 - val_acc: 0.8250
#
# Epoch 00009: val_loss did not improve from 0.44789
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5071 - acc: 0.7677 - val_loss: 0.4526 - val_acc: 0.8238
#
# Epoch 00010: val_loss did not improve from 0.44789
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4749 - acc: 0.7832 - val_loss: 0.4584 - val_acc: 0.8225
#
# Epoch 00011: val_loss did not improve from 0.44789
# Epoch 12/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4843 - acc: 0.7721 - val_loss: 0.4673 - val_acc: 0.8213
#
# Epoch 00012: val_loss did not improve from 0.44789
# Epoch 13/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5014 - acc: 0.7481 - val_loss: 0.4474 - val_acc: 0.8075
#
# Epoch 00013: val_loss improved from 0.44789 to 0.44743, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4649 - acc: 0.7968 - val_loss: 0.4446 - val_acc: 0.8163
#
# Epoch 00014: val_loss improved from 0.44743 to 0.44458, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 12s 123ms/step - loss: 0.4971 - acc: 0.7755 - val_loss: 0.4464 - val_acc: 0.8263
#
# Epoch 00015: val_loss did not improve from 0.44458
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc0f01261d0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a0bda58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09dded278>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a77b7f0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc09301df98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09ddec630>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c06dcc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09301d470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09dd62240>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8bf62320>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc0f01a00f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0921df518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8bfe7908>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8bf62c18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c3d3f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0f019c358>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc09301ccc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc07012a7b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0f019ceb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc092413b38>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc070127978>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c214e80>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8bcb0f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a34f2e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c0d1048>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c0fe978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc0f019c240>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc0932a8e80>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc0f01216a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c709470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc07013f4a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c709400>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0923d9278>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a6bf208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a30f940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7092e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc070151f28>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc09c107978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c214cc0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc09c0fe208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c1313c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc0921cf748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09dd24f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c131cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09dd1bac8>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c709748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09dd1b9b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c6ceda0>, <tensorflow.python.kera ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 9,721,345
# Non-trainable params: 14,631,424
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 133ms/step - loss: 0.6336 - acc: 0.7866 - val_loss: 0.4078 - val_acc: 0.8288
#
# Epoch 00001: val_loss improved from 0.44458 to 0.40783, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4323 - acc: 0.8091 - val_loss: 0.3434 - val_acc: 0.8662
#
# Epoch 00002: val_loss improved from 0.40783 to 0.34342, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3999 - acc: 0.8482 - val_loss: 0.3127 - val_acc: 0.8675
#
# Epoch 00003: val_loss improved from 0.34342 to 0.31268, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3686 - acc: 0.8543 - val_loss: 0.3062 - val_acc: 0.8788
#
# Epoch 00004: val_loss improved from 0.31268 to 0.30621, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3815 - acc: 0.8411 - val_loss: 0.3204 - val_acc: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.30621
# Epoch 6/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3845 - acc: 0.8454 - val_loss: 0.3104 - val_acc: 0.8725
#
# Epoch 00006: val_loss did not improve from 0.30621
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3699 - acc: 0.8416 - val_loss: 0.3101 - val_acc: 0.8725
#
# Epoch 00007: val_loss did not improve from 0.30621
# Epoch 8/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3395 - acc: 0.8515 - val_loss: 0.2840 - val_acc: 0.8788
#
# Epoch 00008: val_loss improved from 0.30621 to 0.28398, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3275 - acc: 0.8677 - val_loss: 0.3351 - val_acc: 0.8625
#
# Epoch 00009: val_loss did not improve from 0.28398
# Epoch 10/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3176 - acc: 0.8671 - val_loss: 0.2866 - val_acc: 0.8863
#
# Epoch 00010: val_loss did not improve from 0.28398
# Epoch 11/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3293 - acc: 0.8702 - val_loss: 0.2725 - val_acc: 0.8800
#
# Epoch 00011: val_loss improved from 0.28398 to 0.27247, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3481 - acc: 0.8507 - val_loss: 0.2942 - val_acc: 0.8763
#
# Epoch 00012: val_loss did not improve from 0.27247
# Epoch 13/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3303 - acc: 0.8683 - val_loss: 0.3017 - val_acc: 0.8788
#
# Epoch 00013: val_loss did not improve from 0.27247
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2944 - acc: 0.8849 - val_loss: 0.3031 - val_acc: 0.8725
#
# Epoch 00014: val_loss did not improve from 0.27247
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3118 - acc: 0.8818 - val_loss: 0.3078 - val_acc: 0.8888
#
# Epoch 00015: val_loss did not improve from 0.27247
# Epoch 16/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3698 - acc: 0.8457 - val_loss: 0.2680 - val_acc: 0.8825
#
# Epoch 00016: val_loss improved from 0.27247 to 0.26802, saving model to checkpoint.h5
# Epoch 17/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3222 - acc: 0.8834 - val_loss: 0.2779 - val_acc: 0.8888
#
# Epoch 00017: val_loss did not improve from 0.26802
# Epoch 18/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2897 - acc: 0.8780 - val_loss: 0.3182 - val_acc: 0.8775
#
# Epoch 00018: val_loss did not improve from 0.26802
# Epoch 19/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3269 - acc: 0.8793 - val_loss: 0.2818 - val_acc: 0.8863
#
# Epoch 00019: val_loss did not improve from 0.26802
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2618 - acc: 0.8973 - val_loss: 0.2894 - val_acc: 0.8825
#
# Epoch 00020: val_loss did not improve from 0.26802
# Epoch 21/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3214 - acc: 0.8609 - val_loss: 0.2580 - val_acc: 0.8875
#
# Epoch 00021: val_loss improved from 0.26802 to 0.25803, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3158 - acc: 0.8722 - val_loss: 0.2936 - val_acc: 0.8900
#
# Epoch 00022: val_loss did not improve from 0.25803
# Epoch 23/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3127 - acc: 0.8650 - val_loss: 0.2757 - val_acc: 0.8963
#
# Epoch 00023: val_loss did not improve from 0.25803
# Epoch 24/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3036 - acc: 0.8814 - val_loss: 0.2671 - val_acc: 0.8963
#
# Epoch 00024: val_loss did not improve from 0.25803
# Epoch 25/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3047 - acc: 0.8805 - val_loss: 0.2809 - val_acc: 0.8913
#
# Epoch 00025: val_loss did not improve from 0.25803
# Epoch 26/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2792 - acc: 0.8913 - val_loss: 0.3105 - val_acc: 0.8825
#
# Epoch 00026: val_loss did not improve from 0.25803
# Epoch 27/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3002 - acc: 0.8819 - val_loss: 0.3042 - val_acc: 0.8838
#
# Epoch 00027: val_loss did not improve from 0.25803
# Epoch 28/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3095 - acc: 0.8842 - val_loss: 0.3192 - val_acc: 0.8900
#
# Epoch 00028: val_loss did not improve from 0.25803
# Epoch 29/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2962 - acc: 0.8707 - val_loss: 0.2844 - val_acc: 0.8775
#
# Epoch 00029: val_loss did not improve from 0.25803
# Epoch 30/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2745 - acc: 0.8901 - val_loss: 0.3152 - val_acc: 0.8913
#
# Epoch 00030: val_loss did not improve from 0.25803
# Epoch 31/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2597 - acc: 0.8972 - val_loss: 0.3193 - val_acc: 0.8813
#
# Epoch 00031: val_loss did not improve from 0.25803
# Epoch 32/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2836 - acc: 0.8887 - val_loss: 0.2786 - val_acc: 0.8963
#
# Epoch 00032: val_loss did not improve from 0.25803
# Epoch 33/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2753 - acc: 0.9039 - val_loss: 0.3121 - val_acc: 0.8925
#
# Epoch 00033: val_loss did not improve from 0.25803
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2488 - acc: 0.8945 - val_loss: 0.3163 - val_acc: 0.8925
#
# Epoch 00034: val_loss did not improve from 0.25803
# Epoch 35/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2641 - acc: 0.8912 - val_loss: 0.3303 - val_acc: 0.8950
#
# Epoch 00035: val_loss did not improve from 0.25803
# Epoch 36/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2665 - acc: 0.8942 - val_loss: 0.2753 - val_acc: 0.8963
#
# Epoch 00036: val_loss did not improve from 0.25803
# Epoch 37/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2870 - acc: 0.8767 - val_loss: 0.3060 - val_acc: 0.8950
#
# Epoch 00037: val_loss did not improve from 0.25803
# Epoch 38/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2938 - acc: 0.8898 - val_loss: 0.2864 - val_acc: 0.8838
#
# Epoch 00038: val_loss did not improve from 0.25803
# Epoch 39/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2761 - acc: 0.8998 - val_loss: 0.3236 - val_acc: 0.8850
#
# Epoch 00039: val_loss did not improve from 0.25803
# Epoch 40/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2648 - acc: 0.8830 - val_loss: 0.3093 - val_acc: 0.8825
#
# Epoch 00040: val_loss did not improve from 0.25803
# Epoch 41/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2425 - acc: 0.9010 - val_loss: 0.3096 - val_acc: 0.8813
#
# Epoch 00041: val_loss did not improve from 0.25803
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2763 - acc: 0.8906
#
# ---------------------------------
# Accuracy: 89.06 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.87      0.89       179
#          1.0       0.86      0.92      0.89       157
#
#     accuracy                           0.89       336
#    macro avg       0.89      0.89      0.89       336
# weighted avg       0.89      0.89      0.89       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet__globalAvgPool_dense_256x5_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 51200)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 13,370,881
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 133ms/step - loss: 1.4824 - acc: 0.6380 - val_loss: 0.6452 - val_acc: 0.7100
#
# Epoch 00001: val_loss improved from inf to 0.64524, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 12s 124ms/step - loss: 0.7859 - acc: 0.5139 - val_loss: 0.5878 - val_acc: 0.7650
#
# Epoch 00002: val_loss improved from 0.64524 to 0.58781, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6787 - acc: 0.5836 - val_loss: 0.5546 - val_acc: 0.8000
#
# Epoch 00003: val_loss improved from 0.58781 to 0.55460, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.6148 - acc: 0.6303 - val_loss: 0.4749 - val_acc: 0.8100
#
# Epoch 00004: val_loss improved from 0.55460 to 0.47492, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5974 - acc: 0.6538 - val_loss: 0.4199 - val_acc: 0.8125
#
# Epoch 00005: val_loss improved from 0.47492 to 0.41993, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5860 - acc: 0.6882 - val_loss: 0.4462 - val_acc: 0.8025
#
# Epoch 00006: val_loss did not improve from 0.41993
# Epoch 7/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5584 - acc: 0.7035 - val_loss: 0.4719 - val_acc: 0.8125
#
# Epoch 00007: val_loss did not improve from 0.41993
# Epoch 8/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5754 - acc: 0.7308 - val_loss: 0.4083 - val_acc: 0.8325
#
# Epoch 00008: val_loss improved from 0.41993 to 0.40832, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5420 - acc: 0.7447 - val_loss: 0.4280 - val_acc: 0.8263
#
# Epoch 00009: val_loss did not improve from 0.40832
# Epoch 10/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5839 - acc: 0.6989 - val_loss: 0.3949 - val_acc: 0.8125
#
# Epoch 00010: val_loss improved from 0.40832 to 0.39489, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5347 - acc: 0.7504 - val_loss: 0.4273 - val_acc: 0.7962
#
# Epoch 00011: val_loss did not improve from 0.39489
# Epoch 12/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5104 - acc: 0.7623 - val_loss: 0.4059 - val_acc: 0.8263
#
# Epoch 00012: val_loss did not improve from 0.39489
# Epoch 13/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4910 - acc: 0.7601 - val_loss: 0.3822 - val_acc: 0.8263
#
# Epoch 00013: val_loss improved from 0.39489 to 0.38223, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4658 - acc: 0.7910 - val_loss: 0.3979 - val_acc: 0.8300
#
# Epoch 00014: val_loss did not improve from 0.38223
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4860 - acc: 0.7692 - val_loss: 0.4279 - val_acc: 0.8325
#
# Epoch 00015: val_loss did not improve from 0.38223
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc092048b38>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09ddf0198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc093133048>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc092f0f898>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc092f0f240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092ef0f98>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc092efc208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2ce748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc092ee2e10>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a2cfbe0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a2e3898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2e32b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a2726a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a2c1898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2ce588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2cf6d8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fbe8a2d1668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a2fa5f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a2fa978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8a2c32e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8a2f3198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8a2f3ef0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fbe8a2e8cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7e0780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7e5240>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c7e53c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7cb3c8>, <tensorflow.python.keras.layers.merge.Add object at 0x7fc09c7c7358>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7db2e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c7c7908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7e9ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7b4828>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c7b44e0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c7e1f28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7de9b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7de2b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c7cf978>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc09c7e9278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7e4fd0>, <tensorflow.python.keras.layers.merge.Add object at 0x7fbe8bcd7c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc09c7e44e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbe8bcf44e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe8bcd1518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8bcf4dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc09c7cf080>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fc09c7c74e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc09c7e1550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe8bcf44a8>, <tensorflow.python.kera ...
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 51200)             0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 51200)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               13107456
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 36,935,681
# Trainable params: 28,341,761
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 136ms/step - loss: 0.8880 - acc: 0.7832 - val_loss: 0.3322 - val_acc: 0.8487
#
# Epoch 00001: val_loss improved from 0.38223 to 0.33219, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.4281 - acc: 0.8290 - val_loss: 0.3116 - val_acc: 0.8712
#
# Epoch 00002: val_loss improved from 0.33219 to 0.31158, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3963 - acc: 0.8372 - val_loss: 0.3105 - val_acc: 0.8662
#
# Epoch 00003: val_loss improved from 0.31158 to 0.31046, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4034 - acc: 0.8171 - val_loss: 0.3198 - val_acc: 0.8712
#
# Epoch 00004: val_loss did not improve from 0.31046
# Epoch 5/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3594 - acc: 0.8565 - val_loss: 0.2975 - val_acc: 0.8813
#
# Epoch 00005: val_loss improved from 0.31046 to 0.29753, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3598 - acc: 0.8517 - val_loss: 0.3063 - val_acc: 0.8838
#
# Epoch 00006: val_loss did not improve from 0.29753
# Epoch 7/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3339 - acc: 0.8685 - val_loss: 0.2999 - val_acc: 0.8925
#
# Epoch 00007: val_loss did not improve from 0.29753
# Epoch 8/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3467 - acc: 0.8513 - val_loss: 0.3067 - val_acc: 0.8925
#
# Epoch 00008: val_loss did not improve from 0.29753
# Epoch 9/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3796 - acc: 0.8693 - val_loss: 0.3058 - val_acc: 0.8850
#
# Epoch 00009: val_loss did not improve from 0.29753
# Epoch 10/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3379 - acc: 0.8587 - val_loss: 0.3154 - val_acc: 0.8813
#
# Epoch 00010: val_loss did not improve from 0.29753
# Epoch 11/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3359 - acc: 0.8731 - val_loss: 0.3126 - val_acc: 0.8850
#
# Epoch 00011: val_loss did not improve from 0.29753
# Epoch 12/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3160 - acc: 0.8610 - val_loss: 0.3327 - val_acc: 0.8913
#
# Epoch 00012: val_loss did not improve from 0.29753
# Epoch 13/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3012 - acc: 0.8947 - val_loss: 0.3387 - val_acc: 0.8800
#
# Epoch 00013: val_loss did not improve from 0.29753
# Epoch 14/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3094 - acc: 0.8835 - val_loss: 0.3485 - val_acc: 0.8850
#
# Epoch 00014: val_loss did not improve from 0.29753
# Epoch 15/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3161 - acc: 0.8818 - val_loss: 0.3116 - val_acc: 0.8775
#
# Epoch 00015: val_loss did not improve from 0.29753
# Epoch 16/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2874 - acc: 0.8908 - val_loss: 0.3778 - val_acc: 0.8712
#
# Epoch 00016: val_loss did not improve from 0.29753
# Epoch 17/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3106 - acc: 0.8704 - val_loss: 0.3273 - val_acc: 0.8913
#
# Epoch 00017: val_loss did not improve from 0.29753
# Epoch 18/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3103 - acc: 0.8786 - val_loss: 0.3374 - val_acc: 0.8788
#
# Epoch 00018: val_loss did not improve from 0.29753
# Epoch 19/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2957 - acc: 0.8859 - val_loss: 0.3390 - val_acc: 0.8838
#
# Epoch 00019: val_loss did not improve from 0.29753
# Epoch 20/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2971 - acc: 0.8837 - val_loss: 0.3665 - val_acc: 0.8775
#
# Epoch 00020: val_loss did not improve from 0.29753
# Epoch 21/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2654 - acc: 0.9068 - val_loss: 0.3871 - val_acc: 0.8675
#
# Epoch 00021: val_loss did not improve from 0.29753
# Epoch 22/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2496 - acc: 0.8974 - val_loss: 0.3422 - val_acc: 0.8838
#
# Epoch 00022: val_loss did not improve from 0.29753
# Epoch 23/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2747 - acc: 0.8938 - val_loss: 0.3588 - val_acc: 0.8900
#
# Epoch 00023: val_loss did not improve from 0.29753
# Epoch 24/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2551 - acc: 0.9005 - val_loss: 0.3423 - val_acc: 0.8875
#
# Epoch 00024: val_loss did not improve from 0.29753
# Epoch 25/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2770 - acc: 0.8938 - val_loss: 0.3934 - val_acc: 0.8963
#
# Epoch 00025: val_loss did not improve from 0.29753
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3226 - acc: 0.8844
#
# ---------------------------------
# Accuracy: 88.44 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89       179
#          1.0       0.89      0.86      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256x5_last_3_blocks_trainable.h5'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-f00ac0520bb8> in <module>()
# ----> 1 models.save_model(model, os.path.join(MODEL_PATH, 'ResNet_flatten_dense_256x5_last_3_blocks_trainable.h5'))
#
# NameError: name 'model' is not defined

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import ResNet50V2
from tensorflow.keras import models
from tensorflow.keras import layers

#load VGG16 as convolutional base
conv_base = ResNet50V2(weights='imagenet',
                     include_top=False,
                     input_shape=(150, 150, 3))

#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="ResNet50", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True
set_trainable = False 
for layer in conv_base.layers:
  if layer.name == "conv5_block1_preact_bn":
    set_trainable = True
  if set_trainable:
    layer.trainable = True 
  else: 
    layer.trainable = False 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 787,969
# Non-trainable params: 23,564,800
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 22s 135ms/step - loss: 0.7907 - acc: 0.5156 - val_loss: 0.5884 - val_acc: 0.6650
#
# Epoch 00001: val_loss improved from inf to 0.58839, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.6676 - acc: 0.5952 - val_loss: 0.4804 - val_acc: 0.8050
#
# Epoch 00002: val_loss improved from 0.58839 to 0.48037, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5792 - acc: 0.6873 - val_loss: 0.4854 - val_acc: 0.8075
#
# Epoch 00003: val_loss did not improve from 0.48037
# Epoch 4/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5617 - acc: 0.7050 - val_loss: 0.4229 - val_acc: 0.8112
#
# Epoch 00004: val_loss improved from 0.48037 to 0.42293, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5693 - acc: 0.7111 - val_loss: 0.4949 - val_acc: 0.8125
#
# Epoch 00005: val_loss did not improve from 0.42293
# Epoch 6/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5390 - acc: 0.7384 - val_loss: 0.4366 - val_acc: 0.8175
#
# Epoch 00006: val_loss did not improve from 0.42293
# Epoch 7/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5353 - acc: 0.7461 - val_loss: 0.4493 - val_acc: 0.8200
#
# Epoch 00007: val_loss did not improve from 0.42293
# Epoch 8/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5012 - acc: 0.7782 - val_loss: 0.4944 - val_acc: 0.8325
#
# Epoch 00008: val_loss did not improve from 0.42293
# Epoch 9/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5133 - acc: 0.7478 - val_loss: 0.4166 - val_acc: 0.8175
#
# Epoch 00009: val_loss improved from 0.42293 to 0.41659, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 123ms/step - loss: 0.5207 - acc: 0.7561 - val_loss: 0.4648 - val_acc: 0.8150
#
# Epoch 00010: val_loss did not improve from 0.41659
# Epoch 11/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5079 - acc: 0.7631 - val_loss: 0.4350 - val_acc: 0.8175
#
# Epoch 00011: val_loss did not improve from 0.41659
# Epoch 12/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5133 - acc: 0.7665 - val_loss: 0.4517 - val_acc: 0.8250
#
# Epoch 00012: val_loss did not improve from 0.41659
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4818 - acc: 0.7820 - val_loss: 0.4454 - val_acc: 0.8250
#
# Epoch 00013: val_loss did not improve from 0.41659
# Epoch 14/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4661 - acc: 0.7971 - val_loss: 0.4191 - val_acc: 0.8263
#
# Epoch 00014: val_loss did not improve from 0.41659
# Epoch 15/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5009 - acc: 0.7660 - val_loss: 0.4262 - val_acc: 0.8288
#
# Epoch 00015: val_loss did not improve from 0.41659
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f22457ffcc0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f22457ffe10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f22457c1470>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f22457c1b38>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f21f030dcf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f0314668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f030d470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f0314898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02a9438>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f02afda0>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f21f02b5eb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f02b5518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02bc358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f02c5160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f02a92e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f02bc908>, <tensorflow.python.keras.layers.merge.Add object at 0x7f21f02d1828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02d37b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f02d3a20>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f02d94a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02e1358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f02e1588>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f21f0269eb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f0270940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f0274400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f0274e80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f027d8d0>, <tensorflow.python.keras.layers.merge.Add object at 0x7f21f0283518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f028b4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f028b828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f0292d68>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02989e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f0298748>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f21f02a3f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f02a8b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02a8a20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f022cb38>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f21f0292438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f023f208>, <tensorflow.python.keras.layers.merge.Add object at 0x7f21f023fe10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f0236a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f02446a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f024e240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f0236978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21f025a048>, <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7f21f025a3c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21f024ee48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21f02361d0>, <tensorflow.python.kera ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 5, 5, 2048)        23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 24,352,769
# Trainable params: 15,758,849
# Non-trainable params: 8,593,920
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 133ms/step - loss: 0.7355 - acc: 0.7802 - val_loss: 0.3469 - val_acc: 0.8575
#
# Epoch 00001: val_loss improved from 0.41659 to 0.34687, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4458 - acc: 0.8131 - val_loss: 0.3702 - val_acc: 0.8338
#
# Epoch 00002: val_loss did not improve from 0.34687
# Epoch 3/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3647 - acc: 0.8601 - val_loss: 0.3608 - val_acc: 0.8487
#
# Epoch 00003: val_loss did not improve from 0.34687
# Epoch 4/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3601 - acc: 0.8456 - val_loss: 0.2970 - val_acc: 0.8950
#
# Epoch 00004: val_loss improved from 0.34687 to 0.29702, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3223 - acc: 0.8692 - val_loss: 0.2837 - val_acc: 0.8813
#
# Epoch 00005: val_loss improved from 0.29702 to 0.28368, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3281 - acc: 0.8773 - val_loss: 0.2736 - val_acc: 0.8825
#
# Epoch 00006: val_loss improved from 0.28368 to 0.27355, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3733 - acc: 0.8504 - val_loss: 0.3088 - val_acc: 0.8813
#
# Epoch 00007: val_loss did not improve from 0.27355
# Epoch 8/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2896 - acc: 0.8863 - val_loss: 0.3080 - val_acc: 0.8750
#
# Epoch 00008: val_loss did not improve from 0.27355
# Epoch 9/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2903 - acc: 0.8870 - val_loss: 0.3073 - val_acc: 0.8850
#
# Epoch 00009: val_loss did not improve from 0.27355
# Epoch 10/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3122 - acc: 0.8836 - val_loss: 0.2892 - val_acc: 0.8863
#
# Epoch 00010: val_loss did not improve from 0.27355
# Epoch 11/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2804 - acc: 0.8861 - val_loss: 0.2914 - val_acc: 0.8850
#
# Epoch 00011: val_loss did not improve from 0.27355
# Epoch 12/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2938 - acc: 0.8837 - val_loss: 0.3046 - val_acc: 0.8788
#
# Epoch 00012: val_loss did not improve from 0.27355
# Epoch 13/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2876 - acc: 0.8775 - val_loss: 0.3089 - val_acc: 0.8800
#
# Epoch 00013: val_loss did not improve from 0.27355
# Epoch 14/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2764 - acc: 0.8897 - val_loss: 0.3308 - val_acc: 0.8525
#
# Epoch 00014: val_loss did not improve from 0.27355
# Epoch 15/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2724 - acc: 0.9015 - val_loss: 0.2936 - val_acc: 0.8938
#
# Epoch 00015: val_loss did not improve from 0.27355
# Epoch 16/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2496 - acc: 0.8901 - val_loss: 0.3201 - val_acc: 0.8587
#
# Epoch 00016: val_loss did not improve from 0.27355
# Epoch 17/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2557 - acc: 0.8868 - val_loss: 0.2726 - val_acc: 0.8975
#
# Epoch 00017: val_loss improved from 0.27355 to 0.27260, saving model to checkpoint.h5
# Epoch 18/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2960 - acc: 0.8740 - val_loss: 0.2852 - val_acc: 0.8888
#
# Epoch 00018: val_loss did not improve from 0.27260
# Epoch 19/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3094 - acc: 0.8775 - val_loss: 0.3593 - val_acc: 0.8487
#
# Epoch 00019: val_loss did not improve from 0.27260
# Epoch 20/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2703 - acc: 0.8845 - val_loss: 0.2886 - val_acc: 0.8900
#
# Epoch 00020: val_loss did not improve from 0.27260
# Epoch 21/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2865 - acc: 0.8888 - val_loss: 0.2866 - val_acc: 0.8950
#
# Epoch 00021: val_loss did not improve from 0.27260
# Epoch 22/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2761 - acc: 0.8858 - val_loss: 0.2809 - val_acc: 0.8913
#
# Epoch 00022: val_loss did not improve from 0.27260
# Epoch 23/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2523 - acc: 0.8946 - val_loss: 0.3272 - val_acc: 0.8775
#
# Epoch 00023: val_loss did not improve from 0.27260
# Epoch 24/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3137 - acc: 0.8776 - val_loss: 0.2859 - val_acc: 0.8975
#
# Epoch 00024: val_loss did not improve from 0.27260
# Epoch 25/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2466 - acc: 0.8959 - val_loss: 0.2947 - val_acc: 0.9025
#
# Epoch 00025: val_loss did not improve from 0.27260
# Epoch 26/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2560 - acc: 0.8991 - val_loss: 0.2931 - val_acc: 0.9050
#
# Epoch 00026: val_loss did not improve from 0.27260
# Epoch 27/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2396 - acc: 0.9182 - val_loss: 0.3034 - val_acc: 0.8825
#
# Epoch 00027: val_loss did not improve from 0.27260
# Epoch 28/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2632 - acc: 0.8951 - val_loss: 0.2717 - val_acc: 0.9075
#
# Epoch 00028: val_loss improved from 0.27260 to 0.27170, saving model to checkpoint.h5
# Epoch 29/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2568 - acc: 0.8987 - val_loss: 0.2945 - val_acc: 0.8925
#
# Epoch 00029: val_loss did not improve from 0.27170
# Epoch 30/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2509 - acc: 0.9071 - val_loss: 0.3039 - val_acc: 0.8750
#
# Epoch 00030: val_loss did not improve from 0.27170
# Epoch 31/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2204 - acc: 0.9196 - val_loss: 0.2876 - val_acc: 0.9038
#
# Epoch 00031: val_loss did not improve from 0.27170
# Epoch 32/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2331 - acc: 0.9219 - val_loss: 0.2841 - val_acc: 0.9112
#
# Epoch 00032: val_loss did not improve from 0.27170
# Epoch 33/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2569 - acc: 0.8981 - val_loss: 0.3150 - val_acc: 0.8850
#
# Epoch 00033: val_loss did not improve from 0.27170
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2499 - acc: 0.8883 - val_loss: 0.3085 - val_acc: 0.8875
#
# Epoch 00034: val_loss did not improve from 0.27170
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2262 - acc: 0.9087 - val_loss: 0.3046 - val_acc: 0.8950
#
# Epoch 00035: val_loss did not improve from 0.27170
# Epoch 36/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2386 - acc: 0.9077 - val_loss: 0.2953 - val_acc: 0.8975
#
# Epoch 00036: val_loss did not improve from 0.27170
# Epoch 37/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.2331 - acc: 0.9103 - val_loss: 0.3152 - val_acc: 0.8963
#
# Epoch 00037: val_loss did not improve from 0.27170
# Epoch 38/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2187 - acc: 0.9178 - val_loss: 0.2776 - val_acc: 0.9038
#
# Epoch 00038: val_loss did not improve from 0.27170
# Epoch 39/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2528 - acc: 0.9026 - val_loss: 0.3154 - val_acc: 0.8888
#
# Epoch 00039: val_loss did not improve from 0.27170
# Epoch 40/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2150 - acc: 0.9123 - val_loss: 0.3228 - val_acc: 0.8963
#
# Epoch 00040: val_loss did not improve from 0.27170
# Epoch 41/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2261 - acc: 0.9110 - val_loss: 0.3097 - val_acc: 0.9000
#
# Epoch 00041: val_loss did not improve from 0.27170
# Epoch 42/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2132 - acc: 0.9168 - val_loss: 0.2646 - val_acc: 0.9025
#
# Epoch 00042: val_loss improved from 0.27170 to 0.26460, saving model to checkpoint.h5
# Epoch 43/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2708 - acc: 0.9083 - val_loss: 0.3054 - val_acc: 0.8888
#
# Epoch 00043: val_loss did not improve from 0.26460
# Epoch 44/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2030 - acc: 0.9128 - val_loss: 0.3357 - val_acc: 0.8700
#
# Epoch 00044: val_loss did not improve from 0.26460
# Epoch 45/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.2333 - acc: 0.9114 - val_loss: 0.3296 - val_acc: 0.8825
#
# Epoch 00045: val_loss did not improve from 0.26460
# Epoch 46/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2097 - acc: 0.9116 - val_loss: 0.2858 - val_acc: 0.8988
#
# Epoch 00046: val_loss did not improve from 0.26460
# Epoch 47/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.1964 - acc: 0.9200 - val_loss: 0.3492 - val_acc: 0.8600
#
# Epoch 00047: val_loss did not improve from 0.26460
# Epoch 48/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.1958 - acc: 0.9327 - val_loss: 0.3070 - val_acc: 0.8975
#
# Epoch 00048: val_loss did not improve from 0.26460
# Epoch 49/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.2215 - acc: 0.9154 - val_loss: 0.3092 - val_acc: 0.9013
#
# Epoch 00049: val_loss did not improve from 0.26460
# Epoch 50/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.1795 - acc: 0.9341 - val_loss: 0.2840 - val_acc: 0.8938
#
# Epoch 00050: val_loss did not improve from 0.26460
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2905 - acc: 0.8750
#
# ---------------------------------
# Accuracy: 87.50 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.81      0.88       179
#          1.0       0.82      0.96      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.89      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'ResNet__globalAvgPool_dense_256x5_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
