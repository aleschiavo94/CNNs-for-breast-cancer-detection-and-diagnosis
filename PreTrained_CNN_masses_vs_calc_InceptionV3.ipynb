# %% [markdown]
# <a href="https://colab.research.google.com/github/aleschiavo94/Convolutional-Neural-Network-for-Medical-Imaging-Analysis---Abnormality-detection-in-mammography/blob/main/PreTrained_CNN_masses_vs_calc_InceptionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #0.1 Load Functions

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns # Grouped bar plot
import itertools
import numpy as np
import pandas as pd 
import ast #Abstract Syntax Trees
import os 
import gc # Garbage Collector

from tensorflow.keras import backend as K # Useful to free GPU and memory
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras import layers, optimizers, models, regularizers, metrics
from keras.models import load_model
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from keras.models import Model




import scipy
import scipy.misc
from PIL import Image
BATCH_SIZE = 20
EPOCHS = 50

base_path = "/content/gdrive/My Drive/Colab Notebooks/CIDL/DL Project"
train_img_path = os.path.join(base_path, "numpy data/train_tensor.npy")
train_label_path = os.path.join(base_path, "numpy data/train_labels.npy")
test_img_path = os.path.join(base_path, "numpy data/public_test_tensor.npy")
test_label_path = os.path.join(base_path, "numpy data/public_test_labels.npy")

MODEL_PATH = os.path.join(base_path, "models/PreTrained-Masses-Calcifications/Inception")
PLOTS_PATH = os.path.join(base_path, "plots/Masses-Calcifications")


# to produce final model report histogram 
AUC_values = []
TPR_values = []
FPR_values = []
PRECISION_values = []
SPECIFICITY_values = []

# Load Arrays from Numpy Files
def load_training():
  train_images = np.load(train_img_path)
  train_labels = np.load(train_label_path)
  test_images = np.load(test_img_path)
  test_labels = np.load(test_label_path)

  return train_images, train_labels, test_images, test_labels

def get_model_predictions(model, dataset, labels, sample_count): 
  predictions = np.zeros((sample_count,))   

  BATCH_SIZE = 1
  i = 0
  for batch, labels_batch in test_datagen.flow(dataset, labels, batch_size=BATCH_SIZE, shuffle=False):
    predictions[i * BATCH_SIZE : (i + 1) * BATCH_SIZE] = model.predict(batch)
    i += 1

    if i * BATCH_SIZE  >= sample_count:
      break

    #np.where(predictions < 0.5, 0, 1)
    #predictions = np.where(predictions < 0.5, 0, 1)

  return predictions


# Remove baseline samples
def remove_baseline(tensor): 
  max_ind = int(len(tensor)/2)
  indexes = [2*i + 1 for i in range(0, max_ind)]

  return tensor[indexes]

# Interchange the dataset index
def shuffle_dataset(x, y):
  indices = tf.range(start=0, limit=tf.shape(x)[0], dtype=tf.int32)
  shuffled_indices = tf.random.shuffle(indices)

  x = tf.gather(x, shuffled_indices)
  y = tf.gather(y, shuffled_indices)

  x = x.numpy()
  y = y.numpy()

  return x, y

# split dataset into training and validation set 70-30
def split_train_val(dataset, labels):
  train_data_split = dataset[:int(0.7*len(dataset))]
  valid_data_split = dataset[int(0.7*len(dataset)):]
  train_labels_split = labels[:int(0.7*len(labels))]
  valid_labels_split = labels[int(0.7*len(labels)):]

  print(train_data_split.shape)
  print(valid_data_split.shape)
  print(train_labels_split.shape)
  print(valid_labels_split.shape)      

  return train_data_split, valid_data_split, train_labels_split, valid_labels_split

# Unify masses and calcifications 
def labels_mapping(labels):
  labels_local = np.zeros(shape=labels.shape, dtype="float32")
  idx = 0
  for label in labels:
    # Masses
    if label == 1 or label == 2:
      labels_local[idx] = 0
    # Calcifications
    else:
      labels_local[idx] = 1
    idx += 1

  return labels_local




def cross_validate(k, batch_size, num_epochs, dataset, targets, verbosity, model_path):
  #10-Fold-Cross-Validation
  num_val_samples = len(dataset) // k 
  validation_accuracies = []
  validation_losses = []
  validation_precisions = []
  validation_recalls = []
  validation_aucs = []
  model = models.load_model(os.path.join(MODEL_PATH, model_path))
  for i in range(k):
    # rigen augmented data 
    
    print("processing fold #", i)
    validation_data = dataset[i * num_val_samples : (i + 1) * num_val_samples]
    validation_labels = targets[i * num_val_samples : (i + 1) * num_val_samples]

    partial_train_data = np.concatenate(
        [dataset[:i * num_val_samples],
        dataset[(i + 1) * num_val_samples:]], 
        axis=0)

    partial_train_targets = np.concatenate(
        [targets[:i * num_val_samples],
        targets[(i + 1) * num_val_samples:]], 
        axis=0)

    
    
    history = model.fit(train_datagen.flow(partial_train_data, 
                                          partial_train_targets,
                                          batch_size=batch_size,
                                          shuffle=False),
                        epochs=num_epochs,
                        steps_per_epoch=len(partial_train_data) // batch_size,
                        verbose=verbosity,
                        callbacks=[GarbageCollectorCallback()])
    
    val_loss, val_acc, val_prec, val_rec, val_auc= model.evaluate(valid_datagen.flow(validation_data,
                                                          validation_labels,
                                                          batch_size=batch_size,
                                                          shuffle=False),
                                       steps=len(validation_data) // batch_size,
                                       callbacks=[GarbageCollectorCallback()])
    
    validation_accuracies.append(val_acc)
    validation_losses.append(val_loss)
    validation_precisions.append(val_prec)
    validation_recalls.append(val_rec)
    validation_aucs.append(val_auc)

    ## ADDED TO TRY AND REDUCE RAM USAGE DURING CROSS VALIDATE
    del partial_train_targets
    del partial_train_data
    del validation_data
    del validation_labels
    del history
    
  return validation_accuracies, validation_losses, validation_precisions, validation_recalls, validation_aucs


def global_contrast_normalization(X):
    X_average = np.mean(X)
    #print('Mean: ', X_average)
    X = X - X_average
    return X

# Visualization Confusion Matrix
def plot_confusion_matrix(model,
                          classes,
                          dataset, 
                          labels,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    Y_pred = model.predict(test_datagen.flow(dataset,
                                            labels,
                                            batch_size=21,
                                            shuffle=False),
                          steps=len(dataset) // BATCH_SIZE)

    np.where(Y_pred < 0.5, 0, 1)
    y_pred = np.where(Y_pred < 0.5, 0, 1)

    print('Confusion Matrix')
    cm = confusion_matrix(labels, y_pred)

    #print(cm)
    #print('Classification Report')
    print(classification_report(labels, y_pred))


    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    return plt


def plot_loss(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt

# Visualization Data Histogram
def plot_acc(history):
  acc = history.history['acc']
  val_acc = history.history['val_acc']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  return plt

# Visualization Data Histogram
def plot(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  return plt

# Visualization Detail Metric
def plot_metrics(history):
  metrics = ['loss', 'auc', 'precision', 'recall']
  plt.figure(figsize=(12,10))

  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)

    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

  return plt


def plot_AUC(model, dataset, labels):
  y_pred_keras = get_model_predictions(model, dataset, labels, len(dataset))
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(labels, y_pred_keras)
  #thresholds_keras = np.linspace(0,1,num=100)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='CNN (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  #plt.show()

  return auc_keras, plt

def plot_AUC2(model, dataset, labels):
  y_pred_keras = get_model_predictions(model, dataset, labels, len(dataset))
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(labels, y_pred_keras)
  #thresholds_keras = np.linspace(0,1,num=100)
  auc_keras = auc(fpr_keras, tpr_keras)

  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_keras, tpr_keras, label='CNN (area = {:.3f})'.format(auc_keras))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.show()


# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
      gc.collect()



print("Done")
# Out:
# Done

# %% [markdown]
# ## Init Data

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#all-in-one data loading & preprocessing function 
def init_data(base_NN, GCN=True, augmentation=True):
  # Get images and labels (test, train)
  train_images, train_labels, test_images, test_labels = load_training()

  # Get abnormalities only 
  train_images = remove_baseline(train_images)
  train_labels = remove_baseline(train_labels)
  test_images = remove_baseline(test_images)
  test_labels = remove_baseline(test_labels)

  # Suffle index (Previous dataset is ordered)
  train_images, train_labels = shuffle_dataset(train_images, train_labels)

  #print("Train shape: ", train_images.shape)
  #print("Test shape: ", test_images.shape)

  #1: Mass, benign
  #2: Mass, malignant
  #3: Calcification, benign
  #4: Calcification, malignant

  #count #of masses and #of calcifications
  #unique, counts = np.unique(train_labels, return_counts=True)
  #print(unique, counts)

  #print("Benign Masses samples: \t", counts[0])
  #print("Malign Masses samples: \t", counts[1])
  #print("Benign Calc samples: \t", counts[2])
  #print("Malign Calc samples: \t", counts[3])

  #labels remapping
  train_labels = labels_mapping(train_labels)
  test_labels = labels_mapping(test_labels)

  #tensors reshaping for models training 
  train_images = train_images.reshape(train_images.shape + (1,)) #(2676, 150, 150, 1)
  test_images = test_images.reshape(test_images.shape + (1,)) #(2676, 150, 150, 1)
  #print(train_images.shape)
  #print(test_images.shape)

  # split dataset into training and validation set 70-30
  train_images_split, valid_images_split, train_labels_split, valid_labels_split = split_train_val(train_images, train_labels)  

  # All images will be rescaled by 1./65535
  if  base_NN == "VGG16":
    from tensorflow.keras.applications.vgg16 import preprocess_input
  if base_NN == "ResNet50":
    from tensorflow.keras.applications.resnet import preprocess_input
  #if Inception no preprocess function 
  if "InceptionV3" in base_NN:
    train_datagen = ImageDataGenerator(rescale=1./65535)
    valid_datagen = ImageDataGenerator(rescale=1./65535)
    test_datagen = ImageDataGenerator(rescale=1./65535) 

  if "InceptionV3" not in base_NN:
    train_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    valid_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input)
    test_datagen = ImageDataGenerator(rescale=1./65535, preprocessing_function=preprocess_input) 

  if GCN:
    train_images_split_gcn = np.zeros(train_images_split.shape)  
    train_labels_split_gcn = np.zeros(train_labels_split.shape)
    valid_images_split_gcn = np.zeros(valid_images_split.shape)
    valid_labels_split_gcn = np.zeros(valid_labels_split.shape)
    train_datagen = ImageDataGenerator()
    valid_datagen = ImageDataGenerator()
    #global contrast normalization 
    counter = 0
    for image, label in train_datagen.flow(train_images_split, train_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image)
      train_images_split_gcn[counter] = norm_image
      train_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(train_images_split):
        break
    
    counter = 0
    for image, label in valid_datagen.flow(valid_images_split, valid_labels_split, batch_size=1, shuffle=False):
      #nomalize image
      norm_image = global_contrast_normalization(image)
      valid_images_split_gcn[counter] = norm_image
      valid_labels_split_gcn[counter] = label
      
      counter += 1
      if counter == len(valid_images_split):
        break
    if base_NN == "InceptionV3":  
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn))
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn))     
    else:
      train_datagen = ImageDataGenerator(rescale=1./np.max(train_images_split_gcn), preprocessing_function=preprocess_input)
      valid_datagen = ImageDataGenerator(rescale=1./np.max(valid_images_split_gcn), preprocessing_function=preprocess_input)      

  if GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./np.max(train_images_split_gcn),
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  if not GCN and augmentation:
    if base_NN == "InceptionV3":
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')
    else:
      train_datagen = ImageDataGenerator(
          rescale=1./65535,
          preprocessing_function=preprocess_input,
          rotation_range=40,
          width_shift_range=0.25,
          height_shift_range=0.25,
          shear_range=20,
          zoom_range=(0.5,1.5),
          horizontal_flip=True,
          fill_mode='nearest')

  print("Done")
  if GCN:
    #reshape to expand grayscale to rgb
    train_images_split_gcn = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split_gcn = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split_gcn, valid_images_split_gcn, train_labels_split_gcn, valid_labels_split_gcn, train_datagen, valid_datagen, test_datagen
  else:
    #reshape to expand grayscale to rgb
    train_images_split = np.repeat(train_images_split, 3, axis = 3)
    valid_images_split = np.repeat(valid_images_split, 3, axis = 3)
    return train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen

# %% [markdown]
# # 0.2 Set Metrics and Global Variables

# %%
INPUT_SHAPE = (150, 150, 3)
IMG_HEIGHT = 150
IMG_WIDTH = 150
BATCH_SIZE = 20


METRICS = [
      metrics.BinaryAccuracy(name='acc'),
      #metrics.Precision(name='precision'),
      #metrics.Recall(name='recall'),
      #metrics.AUC(name='auc'),
      # metrics.TruePositives(name='tp'),
      # metrics.FalsePositives(name='fp'),
      # metrics.TrueNegatives(name='tn'),
      # metrics.FalseNegatives(name='fn'),     
]

es = tf.keras.callbacks.EarlyStopping(
     monitor='val_loss', patience=20, verbose=0,
     mode='auto', restore_best_weights=True
)

# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
      gc.collect()

print("Done")
# Out:
# Done

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, Dense 256

# %% [markdown]
# ## Flatten, Non Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 74, 74, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 72, 72, 32)   9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 72, 72, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 72, 72, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 72, 72, 64)   18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 72, 72, 64)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 72, 72, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 35, 35, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 35, 35, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 35, 35, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 35, 35, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 33, 33, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 33, 33, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 33, 33, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 16, 16, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 16, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 16, 16, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 16, 16, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 16, 16, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 7, 7, 384)    995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 7, 7, 96)     82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 7, 7, 384)    1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 7, 7, 96)     288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 7, 7, 384)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 7, 7, 96)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 288)    0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 7, 7, 768)    0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 7, 7, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 7, 7, 128)    384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 7, 7, 128)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 7, 7, 128)    114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 7, 7, 128)    384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 7, 7, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 7, 7, 128)    98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 7, 7, 128)    114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 7, 7, 128)    384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 7, 7, 128)    384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 7, 7, 128)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 7, 7, 128)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 7, 7, 128)    114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 7, 7, 128)    114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 7, 7, 128)    384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 7, 7, 128)    384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 7, 7, 128)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 7, 7, 128)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 7, 7, 768)    0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 7, 7, 192)    147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 7, 7, 192)    172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 7, 7, 192)    172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 7, 7, 192)    147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 7, 7, 192)    576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 7, 7, 192)    576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 7, 7, 192)    576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 7, 7, 192)    576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 7, 7, 192)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 7, 7, 192)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 7, 7, 192)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 7, 7, 192)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 7, 7, 768)    0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 7, 7, 160)    480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 160)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 160)    179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 7, 7, 160)    480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 160)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 7, 7, 160)    122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 160)    179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 7, 7, 160)    480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 7, 7, 160)    480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 160)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 160)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 7, 7, 160)    179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 160)    179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 7, 7, 160)    480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 7, 7, 160)    480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 160)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 160)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 7, 7, 768)    0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 7, 7, 192)    147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 7, 7, 192)    215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 192)    215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 192)    147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 7, 7, 192)    576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 7, 7, 192)    576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 7, 7, 192)    576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 7, 7, 192)    576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 7, 7, 192)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 192)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 192)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 192)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 7, 7, 768)    0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 7, 7, 160)    480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 7, 7, 160)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 160)    179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 160)    480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 7, 7, 160)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 160)    122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 160)    179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 160)    480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 160)    480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 7, 7, 160)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, 7, 160)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 160)    179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 160)    179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 160)    480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 7, 7, 160)    480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 7, 7, 160)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 160)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 7, 7, 768)    0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 192)    147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 192)    215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 192)    215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 7, 7, 192)    147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 7, 7, 192)    576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 7, 7, 192)    576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 7, 7, 192)    576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 7, 7, 192)    576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 7, 7, 192)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 7, 7, 192)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 192)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 7, 7, 192)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 7, 7, 768)    0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 7, 7, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 7, 7, 192)    576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 7, 7, 192)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 7, 7, 192)    258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 7, 7, 192)    576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 7, 7, 192)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 7, 7, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 7, 7, 192)    258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 7, 7, 192)    576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 7, 7, 192)    576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 7, 7, 192)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 7, 7, 192)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 7, 7, 192)    258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 7, 7, 192)    258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 7, 7, 192)    576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 7, 7, 192)    576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 7, 7, 192)    0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 7, 7, 192)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 7, 7, 768)    0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 7, 7, 192)    147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 7, 7, 192)    258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 7, 7, 192)    258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 7, 7, 192)    147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 7, 7, 192)    576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 7, 7, 192)    576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 7, 7, 192)    576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 7, 7, 192)    576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 7, 7, 192)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 7, 7, 192)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 7, 7, 192)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 7, 7, 192)    0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 7, 7, 768)    0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 7, 7, 192)    576         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 7, 7, 192)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 7, 7, 192)    0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 3, 3, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 3, 3, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 3, 3, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 3, 3, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 3, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 3, 3, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 3, 3, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 3, 3, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 3, 3, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 3, 3, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 3, 3, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 3, 3, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 3, 3, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 3, 3, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 3, 3, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 3, 3, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 3, 3, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 3, 3, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 3, 3, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 3, 3, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 3, 3, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 3, 3, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 3, 3, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 3, 3, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 3, 3, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 3, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 3, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 3, 3, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 3, 3, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3, 3, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 3, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 3, 3, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 3, 3, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 3, 3, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 3, 3, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 3, 3, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 3, 3, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 3, 3, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 3, 3, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 3, 3, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 3, 3, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 3, 3, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 3, 3, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 3, 3, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 3, 3, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 3, 3, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 3, 3, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 3, 3, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 3, 3, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 3, 3, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 3, 3, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 3, 3, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 3, 3, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 3, 3, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 3, 3, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 3, 3, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 3, 3, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 3, 3, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 3, 3, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 3, 3, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 3, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 3, 3, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 3, 3, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 23s 137ms/step - loss: 0.6164 - acc: 0.6835 - val_loss: 0.3900 - val_acc: 0.8525
#
# Epoch 00001: val_loss improved from inf to 0.38999, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4937 - acc: 0.7835 - val_loss: 0.3628 - val_acc: 0.8587
#
# Epoch 00002: val_loss improved from 0.38999 to 0.36281, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4823 - acc: 0.7858 - val_loss: 0.3418 - val_acc: 0.8625
#
# Epoch 00003: val_loss improved from 0.36281 to 0.34182, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4346 - acc: 0.7959 - val_loss: 0.3358 - val_acc: 0.8675
#
# Epoch 00004: val_loss improved from 0.34182 to 0.33578, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4634 - acc: 0.7984 - val_loss: 0.3291 - val_acc: 0.8687
#
# Epoch 00005: val_loss improved from 0.33578 to 0.32910, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4267 - acc: 0.8112 - val_loss: 0.3176 - val_acc: 0.8700
#
# Epoch 00006: val_loss improved from 0.32910 to 0.31759, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3734 - acc: 0.8415 - val_loss: 0.3089 - val_acc: 0.8650
#
# Epoch 00007: val_loss improved from 0.31759 to 0.30894, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4238 - acc: 0.8030 - val_loss: 0.2994 - val_acc: 0.8725
#
# Epoch 00008: val_loss improved from 0.30894 to 0.29937, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4135 - acc: 0.8087 - val_loss: 0.3103 - val_acc: 0.8687
#
# Epoch 00009: val_loss did not improve from 0.29937
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4235 - acc: 0.8171 - val_loss: 0.3089 - val_acc: 0.8687
#
# Epoch 00010: val_loss did not improve from 0.29937
# Epoch 11/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3812 - acc: 0.8195 - val_loss: 0.3003 - val_acc: 0.8737
#
# Epoch 00011: val_loss did not improve from 0.29937
# Epoch 12/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3874 - acc: 0.8427 - val_loss: 0.2953 - val_acc: 0.8725
#
# Epoch 00012: val_loss improved from 0.29937 to 0.29528, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3848 - acc: 0.8322 - val_loss: 0.2909 - val_acc: 0.8800
#
# Epoch 00013: val_loss improved from 0.29528 to 0.29093, saving model to checkpoint.h5
# Epoch 14/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3929 - acc: 0.8275 - val_loss: 0.2809 - val_acc: 0.8888
#
# Epoch 00014: val_loss improved from 0.29093 to 0.28088, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4058 - acc: 0.8300 - val_loss: 0.2863 - val_acc: 0.8788
#
# Epoch 00015: val_loss did not improve from 0.28088
# Epoch 16/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3901 - acc: 0.8135 - val_loss: 0.3327 - val_acc: 0.8550
#
# Epoch 00016: val_loss did not improve from 0.28088
# Epoch 17/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4158 - acc: 0.8132 - val_loss: 0.2903 - val_acc: 0.8763
#
# Epoch 00017: val_loss did not improve from 0.28088
# Epoch 18/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4000 - acc: 0.8274 - val_loss: 0.2857 - val_acc: 0.8913
#
# Epoch 00018: val_loss did not improve from 0.28088
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3716 - acc: 0.8299 - val_loss: 0.2767 - val_acc: 0.8925
#
# Epoch 00019: val_loss improved from 0.28088 to 0.27666, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3814 - acc: 0.8288 - val_loss: 0.2830 - val_acc: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.27666
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3776 - acc: 0.8288 - val_loss: 0.2762 - val_acc: 0.8850
#
# Epoch 00021: val_loss improved from 0.27666 to 0.27617, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3652 - acc: 0.8569 - val_loss: 0.2889 - val_acc: 0.8825
#
# Epoch 00022: val_loss did not improve from 0.27617
# Epoch 23/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3620 - acc: 0.8357 - val_loss: 0.2813 - val_acc: 0.8913
#
# Epoch 00023: val_loss did not improve from 0.27617
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3931 - acc: 0.8240 - val_loss: 0.2756 - val_acc: 0.8950
#
# Epoch 00024: val_loss improved from 0.27617 to 0.27556, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3965 - acc: 0.8234 - val_loss: 0.2848 - val_acc: 0.8763
#
# Epoch 00025: val_loss did not improve from 0.27556
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3696 - acc: 0.8375 - val_loss: 0.2753 - val_acc: 0.8850
#
# Epoch 00026: val_loss improved from 0.27556 to 0.27530, saving model to checkpoint.h5
# Epoch 27/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3757 - acc: 0.8311 - val_loss: 0.2810 - val_acc: 0.8775
#
# Epoch 00027: val_loss did not improve from 0.27530
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3518 - acc: 0.8443 - val_loss: 0.2886 - val_acc: 0.8875
#
# Epoch 00028: val_loss did not improve from 0.27530
# Epoch 29/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3632 - acc: 0.8418 - val_loss: 0.3043 - val_acc: 0.8712
#
# Epoch 00029: val_loss did not improve from 0.27530
# Epoch 30/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3463 - acc: 0.8452 - val_loss: 0.2992 - val_acc: 0.8763
#
# Epoch 00030: val_loss did not improve from 0.27530
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4152 - acc: 0.8066 - val_loss: 0.3112 - val_acc: 0.8650
#
# Epoch 00031: val_loss did not improve from 0.27530
# Epoch 32/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3596 - acc: 0.8442 - val_loss: 0.2827 - val_acc: 0.8763
#
# Epoch 00032: val_loss did not improve from 0.27530
# Epoch 33/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3685 - acc: 0.8310 - val_loss: 0.2918 - val_acc: 0.8725
#
# Epoch 00033: val_loss did not improve from 0.27530
# Epoch 34/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3745 - acc: 0.8280 - val_loss: 0.2800 - val_acc: 0.8813
#
# Epoch 00034: val_loss did not improve from 0.27530
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3587 - acc: 0.8536 - val_loss: 0.2735 - val_acc: 0.8875
#
# Epoch 00035: val_loss improved from 0.27530 to 0.27345, saving model to checkpoint.h5
# Epoch 36/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3873 - acc: 0.8294 - val_loss: 0.2784 - val_acc: 0.8712
#
# Epoch 00036: val_loss did not improve from 0.27345
# Epoch 37/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3637 - acc: 0.8308 - val_loss: 0.2944 - val_acc: 0.8737
#
# Epoch 00037: val_loss did not improve from 0.27345
# Epoch 38/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3822 - acc: 0.8422 - val_loss: 0.2806 - val_acc: 0.8800
#
# Epoch 00038: val_loss did not improve from 0.27345
# Epoch 39/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3326 - acc: 0.8505 - val_loss: 0.2835 - val_acc: 0.8825
#
# Epoch 00039: val_loss did not improve from 0.27345
# Epoch 40/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3733 - acc: 0.8250 - val_loss: 0.2868 - val_acc: 0.8788
#
# Epoch 00040: val_loss did not improve from 0.27345
# Epoch 41/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3509 - acc: 0.8444 - val_loss: 0.2763 - val_acc: 0.8900
#
# Epoch 00041: val_loss did not improve from 0.27345
# Epoch 42/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3733 - acc: 0.8281 - val_loss: 0.2754 - val_acc: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.27345
# Epoch 43/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3840 - acc: 0.8349 - val_loss: 0.2821 - val_acc: 0.8800
#
# Epoch 00043: val_loss did not improve from 0.27345
# Epoch 44/50
# 93/93 [==============================] - 11s 124ms/step - loss: 0.3477 - acc: 0.8519 - val_loss: 0.2922 - val_acc: 0.8737
#
# Epoch 00044: val_loss did not improve from 0.27345
# Epoch 45/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3846 - acc: 0.8390 - val_loss: 0.2868 - val_acc: 0.8850
#
# Epoch 00045: val_loss did not improve from 0.27345
# Epoch 46/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3311 - acc: 0.8516 - val_loss: 0.2840 - val_acc: 0.8850
#
# Epoch 00046: val_loss did not improve from 0.27345
# Epoch 47/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3553 - acc: 0.8462 - val_loss: 0.2843 - val_acc: 0.8900
#
# Epoch 00047: val_loss did not improve from 0.27345
# Epoch 48/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3490 - acc: 0.8470 - val_loss: 0.2828 - val_acc: 0.8900
#
# Epoch 00048: val_loss did not improve from 0.27345
# Epoch 49/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3824 - acc: 0.8198 - val_loss: 0.2939 - val_acc: 0.8712
#
# Epoch 00049: val_loss did not improve from 0.27345
# Epoch 50/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3540 - acc: 0.8522 - val_loss: 0.2781 - val_acc: 0.8813
#
# Epoch 00050: val_loss did not improve from 0.27345

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3616 - acc: 0.8406
#
# ---------------------------------
# Accuracy: 84.06 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.83      0.85       179
#          1.0       0.82      0.87      0.84       157
#
#     accuracy                           0.85       336
#    macro avg       0.85      0.85      0.85       336
# weighted avg       0.85      0.85      0.85       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6f56e0441ad0> in <module>()
#       2 del model
#       3 del conv_base
# ----> 4 del history
#       5 get_ipython().system("rm 'checkpoint.h5'")
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)



#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 130ms/step - loss: 0.9441 - acc: 0.7358 - val_loss: 0.4531 - val_acc: 0.8200
#
# Epoch 00001: val_loss improved from inf to 0.45309, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5248 - acc: 0.7817 - val_loss: 0.3918 - val_acc: 0.8325
#
# Epoch 00002: val_loss improved from 0.45309 to 0.39182, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4531 - acc: 0.8150 - val_loss: 0.3621 - val_acc: 0.8525
#
# Epoch 00003: val_loss improved from 0.39182 to 0.36215, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4070 - acc: 0.8071 - val_loss: 0.4016 - val_acc: 0.8188
#
# Epoch 00004: val_loss did not improve from 0.36215
# Epoch 5/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4047 - acc: 0.8148 - val_loss: 0.3553 - val_acc: 0.8462
#
# Epoch 00005: val_loss improved from 0.36215 to 0.35529, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3884 - acc: 0.8246 - val_loss: 0.3776 - val_acc: 0.8537
#
# Epoch 00006: val_loss did not improve from 0.35529
# Epoch 7/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4011 - acc: 0.7975 - val_loss: 0.3798 - val_acc: 0.8413
#
# Epoch 00007: val_loss did not improve from 0.35529
# Epoch 8/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.3964 - acc: 0.8282 - val_loss: 0.3741 - val_acc: 0.8400
#
# Epoch 00008: val_loss did not improve from 0.35529
# Epoch 9/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3915 - acc: 0.8380 - val_loss: 0.3460 - val_acc: 0.8575
#
# Epoch 00009: val_loss improved from 0.35529 to 0.34604, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3701 - acc: 0.8393 - val_loss: 0.3537 - val_acc: 0.8450
#
# Epoch 00010: val_loss did not improve from 0.34604
# Epoch 11/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3780 - acc: 0.8314 - val_loss: 0.3578 - val_acc: 0.8562
#
# Epoch 00011: val_loss did not improve from 0.34604
# Epoch 12/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3660 - acc: 0.8241 - val_loss: 0.3437 - val_acc: 0.8550
#
# Epoch 00012: val_loss improved from 0.34604 to 0.34366, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3851 - acc: 0.8172 - val_loss: 0.3383 - val_acc: 0.8600
#
# Epoch 00013: val_loss improved from 0.34366 to 0.33834, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3725 - acc: 0.8377 - val_loss: 0.3455 - val_acc: 0.8575
#
# Epoch 00014: val_loss did not improve from 0.33834
# Epoch 15/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3878 - acc: 0.8250 - val_loss: 0.3272 - val_acc: 0.8637
#
# Epoch 00015: val_loss improved from 0.33834 to 0.32719, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f3e72d41b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e6a1ac6d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d45860>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d526a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d45a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d5e208>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d5e668>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d64ac8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d6b780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d6fd30>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3e72d6b4e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d79a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d7d6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d7de10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d04080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d0a7f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d10668>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3e72d04828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d21ef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d5a940>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d284a8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d10898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d2db00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d7d898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d2d5f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d6f240>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d28320>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f3e72cbfdd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d17a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d10e80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72d3b128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72cc3748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d1a6d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d5e2b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72d3be48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72cc3390>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d1a240>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d52160>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72d32b00>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72cbf358>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f3e72ccafd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72cf88d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72c7f160>, <tensorflow.python.keras.layers.core.Activation object at 0x7f3e72c7ff98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72ce5278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e72c86ac8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72ce5e48>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f3e72c8f6d ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 26,487,457
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 20s 150ms/step - loss: 0.5715 - acc: 0.8036 - val_loss: 0.5210 - val_acc: 0.7638
#
# Epoch 00001: val_loss did not improve from 0.32719
# Epoch 2/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.4020 - acc: 0.8154 - val_loss: 0.6165 - val_acc: 0.7738
#
# Epoch 00002: val_loss did not improve from 0.32719
# Epoch 3/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.3581 - acc: 0.8677 - val_loss: 0.3276 - val_acc: 0.8687
#
# Epoch 00003: val_loss did not improve from 0.32719
# Epoch 4/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3498 - acc: 0.8519 - val_loss: 0.3312 - val_acc: 0.8850
#
# Epoch 00004: val_loss did not improve from 0.32719
# Epoch 5/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3215 - acc: 0.8614 - val_loss: 0.3115 - val_acc: 0.8938
#
# Epoch 00005: val_loss improved from 0.32719 to 0.31152, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.3188 - acc: 0.8651 - val_loss: 0.2643 - val_acc: 0.9100
#
# Epoch 00006: val_loss improved from 0.31152 to 0.26430, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2966 - acc: 0.8713 - val_loss: 0.3449 - val_acc: 0.8650
#
# Epoch 00007: val_loss did not improve from 0.26430
# Epoch 8/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2703 - acc: 0.8938 - val_loss: 0.3711 - val_acc: 0.8637
#
# Epoch 00008: val_loss did not improve from 0.26430
# Epoch 9/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2456 - acc: 0.9060 - val_loss: 0.3911 - val_acc: 0.8562
#
# Epoch 00009: val_loss did not improve from 0.26430
# Epoch 10/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2546 - acc: 0.8925 - val_loss: 0.3507 - val_acc: 0.8662
#
# Epoch 00010: val_loss did not improve from 0.26430
# Epoch 11/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2362 - acc: 0.9067 - val_loss: 0.2885 - val_acc: 0.9038
#
# Epoch 00011: val_loss did not improve from 0.26430
# Epoch 12/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2182 - acc: 0.9156 - val_loss: 0.2807 - val_acc: 0.8988
#
# Epoch 00012: val_loss did not improve from 0.26430
# Epoch 13/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2721 - acc: 0.8924 - val_loss: 0.3479 - val_acc: 0.8687
#
# Epoch 00013: val_loss did not improve from 0.26430
# Epoch 14/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2419 - acc: 0.9016 - val_loss: 0.3064 - val_acc: 0.8838
#
# Epoch 00014: val_loss did not improve from 0.26430
# Epoch 15/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2041 - acc: 0.9178 - val_loss: 0.5495 - val_acc: 0.7862
#
# Epoch 00015: val_loss did not improve from 0.26430
# Epoch 16/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2159 - acc: 0.9179 - val_loss: 0.4232 - val_acc: 0.8487
#
# Epoch 00016: val_loss did not improve from 0.26430
# Epoch 17/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2006 - acc: 0.9130 - val_loss: 0.4165 - val_acc: 0.8450
#
# Epoch 00017: val_loss did not improve from 0.26430
# Epoch 18/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2061 - acc: 0.9116 - val_loss: 0.2717 - val_acc: 0.9112
#
# Epoch 00018: val_loss did not improve from 0.26430
# Epoch 19/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1864 - acc: 0.9297 - val_loss: 0.3091 - val_acc: 0.8988
#
# Epoch 00019: val_loss did not improve from 0.26430
# Epoch 20/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2550 - acc: 0.8928 - val_loss: 0.2763 - val_acc: 0.9025
#
# Epoch 00020: val_loss did not improve from 0.26430
# Epoch 21/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2001 - acc: 0.9257 - val_loss: 0.2645 - val_acc: 0.9050
#
# Epoch 00021: val_loss did not improve from 0.26430
# Epoch 22/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.2020 - acc: 0.9220 - val_loss: 0.2514 - val_acc: 0.9100
#
# Epoch 00022: val_loss improved from 0.26430 to 0.25137, saving model to checkpoint.h5
# Epoch 23/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1910 - acc: 0.9296 - val_loss: 0.4363 - val_acc: 0.7962
#
# Epoch 00023: val_loss did not improve from 0.25137
# Epoch 24/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1834 - acc: 0.9236 - val_loss: 0.3220 - val_acc: 0.8813
#
# Epoch 00024: val_loss did not improve from 0.25137
# Epoch 25/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1830 - acc: 0.9355 - val_loss: 0.2841 - val_acc: 0.9137
#
# Epoch 00025: val_loss did not improve from 0.25137
# Epoch 26/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1809 - acc: 0.9274 - val_loss: 0.3231 - val_acc: 0.8825
#
# Epoch 00026: val_loss did not improve from 0.25137
# Epoch 27/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.2096 - acc: 0.9204 - val_loss: 0.3124 - val_acc: 0.8850
#
# Epoch 00027: val_loss did not improve from 0.25137
# Epoch 28/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1526 - acc: 0.9415 - val_loss: 0.2638 - val_acc: 0.8975
#
# Epoch 00028: val_loss did not improve from 0.25137
# Epoch 29/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1713 - acc: 0.9411 - val_loss: 0.5073 - val_acc: 0.8413
#
# Epoch 00029: val_loss did not improve from 0.25137
# Epoch 30/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1770 - acc: 0.9290 - val_loss: 0.2678 - val_acc: 0.9050
#
# Epoch 00030: val_loss did not improve from 0.25137
# Epoch 31/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1680 - acc: 0.9390 - val_loss: 0.4714 - val_acc: 0.8650
#
# Epoch 00031: val_loss did not improve from 0.25137
# Epoch 32/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1844 - acc: 0.9374 - val_loss: 0.3188 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.25137
# Epoch 33/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1715 - acc: 0.9275 - val_loss: 0.4995 - val_acc: 0.8475
#
# Epoch 00033: val_loss did not improve from 0.25137
# Epoch 34/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.1776 - acc: 0.9396 - val_loss: 0.3425 - val_acc: 0.8600
#
# Epoch 00034: val_loss did not improve from 0.25137
# Epoch 35/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1655 - acc: 0.9344 - val_loss: 0.2905 - val_acc: 0.9000
#
# Epoch 00035: val_loss did not improve from 0.25137
# Epoch 36/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1835 - acc: 0.9261 - val_loss: 0.3191 - val_acc: 0.8863
#
# Epoch 00036: val_loss did not improve from 0.25137
# Epoch 37/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1626 - acc: 0.9340 - val_loss: 0.3954 - val_acc: 0.8487
#
# Epoch 00037: val_loss did not improve from 0.25137
# Epoch 38/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1572 - acc: 0.9333 - val_loss: 0.3249 - val_acc: 0.8900
#
# Epoch 00038: val_loss did not improve from 0.25137
# Epoch 39/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1639 - acc: 0.9378 - val_loss: 0.3162 - val_acc: 0.8775
#
# Epoch 00039: val_loss did not improve from 0.25137
# Epoch 40/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1259 - acc: 0.9585 - val_loss: 0.2930 - val_acc: 0.9013
#
# Epoch 00040: val_loss did not improve from 0.25137
# Epoch 41/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.1647 - acc: 0.9417 - val_loss: 0.2658 - val_acc: 0.8875
#
# Epoch 00041: val_loss did not improve from 0.25137
# Epoch 42/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1899 - acc: 0.9212 - val_loss: 0.3247 - val_acc: 0.8763
#
# Epoch 00042: val_loss did not improve from 0.25137
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2728 - acc: 0.8938
#
# ---------------------------------
# Accuracy: 89.38 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90       179
#          1.0       0.88      0.90      0.89       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256_all_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
#conv_base.trainable = True

for layer in model.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 524,801
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 25s 153ms/step - loss: 0.6366 - acc: 0.6818 - val_loss: 0.4548 - val_acc: 0.7900
#
# Epoch 00001: val_loss improved from inf to 0.45484, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 12s 132ms/step - loss: 0.5216 - acc: 0.7463 - val_loss: 0.3915 - val_acc: 0.8587
#
# Epoch 00002: val_loss improved from 0.45484 to 0.39147, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4545 - acc: 0.7956 - val_loss: 0.3842 - val_acc: 0.8450
#
# Epoch 00003: val_loss improved from 0.39147 to 0.38420, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 12s 131ms/step - loss: 0.4472 - acc: 0.7930 - val_loss: 0.3589 - val_acc: 0.8600
#
# Epoch 00004: val_loss improved from 0.38420 to 0.35890, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4276 - acc: 0.8025 - val_loss: 0.3479 - val_acc: 0.8562
#
# Epoch 00005: val_loss improved from 0.35890 to 0.34790, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.4214 - acc: 0.8077 - val_loss: 0.3457 - val_acc: 0.8637
#
# Epoch 00006: val_loss improved from 0.34790 to 0.34570, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4164 - acc: 0.8120 - val_loss: 0.3385 - val_acc: 0.8637
#
# Epoch 00007: val_loss improved from 0.34570 to 0.33848, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4288 - acc: 0.8017 - val_loss: 0.3415 - val_acc: 0.8512
#
# Epoch 00008: val_loss did not improve from 0.33848
# Epoch 9/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4364 - acc: 0.7956 - val_loss: 0.3353 - val_acc: 0.8562
#
# Epoch 00009: val_loss improved from 0.33848 to 0.33534, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3719 - acc: 0.8404 - val_loss: 0.3703 - val_acc: 0.8537
#
# Epoch 00010: val_loss did not improve from 0.33534
# Epoch 11/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4303 - acc: 0.7980 - val_loss: 0.3253 - val_acc: 0.8725
#
# Epoch 00011: val_loss improved from 0.33534 to 0.32533, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4252 - acc: 0.8095 - val_loss: 0.3401 - val_acc: 0.8562
#
# Epoch 00012: val_loss did not improve from 0.32533
# Epoch 13/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3943 - acc: 0.8105 - val_loss: 0.3192 - val_acc: 0.8712
#
# Epoch 00013: val_loss improved from 0.32533 to 0.31920, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3825 - acc: 0.8445 - val_loss: 0.3227 - val_acc: 0.8763
#
# Epoch 00014: val_loss did not improve from 0.31920
# Epoch 15/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4159 - acc: 0.8164 - val_loss: 0.3392 - val_acc: 0.8450
#
# Epoch 00015: val_loss did not improve from 0.31920
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f58bc20aa58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58bc20af28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58701782e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58701784e0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58701ae160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58701aed30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f5870135d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f587013b6d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58701412e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f5870141358>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f587014aba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5870151710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5870157240>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58701573c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f587015e748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5870164358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58701643c8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f5870168ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f587010de80>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f5870124e48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f5870129e48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5870102748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58701020f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700ff358>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700b6400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700ff3c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700bd278>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f58700cdeb8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58700f55c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f587010dc18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58700bdc18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58700cd860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700f8240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58701168d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700b6048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700c7e80>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700f8470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f587011b8d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700c7860>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700d2828>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f58700d9e80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f587011b208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700ff7b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f58700f5128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58700ef320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5870130f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f58700e8c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f587016835 ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 22,293,153
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 23s 164ms/step - loss: 0.5636 - acc: 0.8013 - val_loss: 0.7381 - val_acc: 0.6625
#
# Epoch 00001: val_loss did not improve from 0.31920
# Epoch 2/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.4127 - acc: 0.8160 - val_loss: 0.3967 - val_acc: 0.8138
#
# Epoch 00002: val_loss did not improve from 0.31920
# Epoch 3/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.3414 - acc: 0.8514 - val_loss: 0.3519 - val_acc: 0.8500
#
# Epoch 00003: val_loss did not improve from 0.31920
# Epoch 4/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.2976 - acc: 0.8741 - val_loss: 0.4458 - val_acc: 0.8213
#
# Epoch 00004: val_loss did not improve from 0.31920
# Epoch 5/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.2947 - acc: 0.8780 - val_loss: 0.2984 - val_acc: 0.8788
#
# Epoch 00005: val_loss improved from 0.31920 to 0.29837, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.2978 - acc: 0.8792 - val_loss: 0.2454 - val_acc: 0.9087
#
# Epoch 00006: val_loss improved from 0.29837 to 0.24541, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.2914 - acc: 0.8837 - val_loss: 0.2591 - val_acc: 0.9150
#
# Epoch 00007: val_loss did not improve from 0.24541
# Epoch 8/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.2711 - acc: 0.8856 - val_loss: 0.2513 - val_acc: 0.9212
#
# Epoch 00008: val_loss did not improve from 0.24541
# Epoch 9/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.2581 - acc: 0.8852 - val_loss: 0.3303 - val_acc: 0.8612
#
# Epoch 00009: val_loss did not improve from 0.24541
# Epoch 10/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.2506 - acc: 0.8974 - val_loss: 0.3250 - val_acc: 0.8587
#
# Epoch 00010: val_loss did not improve from 0.24541
# Epoch 11/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.2558 - acc: 0.8897 - val_loss: 0.2178 - val_acc: 0.9300
#
# Epoch 00011: val_loss improved from 0.24541 to 0.21781, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.2300 - acc: 0.9131 - val_loss: 0.2138 - val_acc: 0.9275
#
# Epoch 00012: val_loss improved from 0.21781 to 0.21380, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.2201 - acc: 0.9216 - val_loss: 0.4315 - val_acc: 0.8900
#
# Epoch 00013: val_loss did not improve from 0.21380
# Epoch 14/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.2301 - acc: 0.9021 - val_loss: 0.3098 - val_acc: 0.8863
#
# Epoch 00014: val_loss did not improve from 0.21380
# Epoch 15/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.2214 - acc: 0.9153 - val_loss: 0.2745 - val_acc: 0.9000
#
# Epoch 00015: val_loss did not improve from 0.21380
# Epoch 16/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.2212 - acc: 0.9144 - val_loss: 0.2933 - val_acc: 0.8950
#
# Epoch 00016: val_loss did not improve from 0.21380
# Epoch 17/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.2384 - acc: 0.9087 - val_loss: 0.3156 - val_acc: 0.8800
#
# Epoch 00017: val_loss did not improve from 0.21380
# Epoch 18/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.2256 - acc: 0.9188 - val_loss: 0.3173 - val_acc: 0.8775
#
# Epoch 00018: val_loss did not improve from 0.21380
# Epoch 19/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1934 - acc: 0.9214 - val_loss: 0.2267 - val_acc: 0.9212
#
# Epoch 00019: val_loss did not improve from 0.21380
# Epoch 20/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1886 - acc: 0.9208 - val_loss: 0.2418 - val_acc: 0.9287
#
# Epoch 00020: val_loss did not improve from 0.21380
# Epoch 21/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1918 - acc: 0.9264 - val_loss: 0.2030 - val_acc: 0.9375
#
# Epoch 00021: val_loss improved from 0.21380 to 0.20295, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.2087 - acc: 0.9151 - val_loss: 0.2517 - val_acc: 0.9162
#
# Epoch 00022: val_loss did not improve from 0.20295
# Epoch 23/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1768 - acc: 0.9293 - val_loss: 0.2508 - val_acc: 0.9000
#
# Epoch 00023: val_loss did not improve from 0.20295
# Epoch 24/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1916 - acc: 0.9197 - val_loss: 0.3364 - val_acc: 0.8763
#
# Epoch 00024: val_loss did not improve from 0.20295
# Epoch 25/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.1774 - acc: 0.9309 - val_loss: 0.5409 - val_acc: 0.7925
#
# Epoch 00025: val_loss did not improve from 0.20295
# Epoch 26/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1812 - acc: 0.9258 - val_loss: 0.2759 - val_acc: 0.8975
#
# Epoch 00026: val_loss did not improve from 0.20295
# Epoch 27/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1755 - acc: 0.9307 - val_loss: 0.2075 - val_acc: 0.9350
#
# Epoch 00027: val_loss did not improve from 0.20295
# Epoch 28/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1800 - acc: 0.9321 - val_loss: 0.2960 - val_acc: 0.8850
#
# Epoch 00028: val_loss did not improve from 0.20295
# Epoch 29/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1713 - acc: 0.9381 - val_loss: 0.2929 - val_acc: 0.8875
#
# Epoch 00029: val_loss did not improve from 0.20295
# Epoch 30/50
# 93/93 [==============================] - 14s 147ms/step - loss: 0.1792 - acc: 0.9317 - val_loss: 0.4963 - val_acc: 0.8150
#
# Epoch 00030: val_loss did not improve from 0.20295
# Epoch 31/50
# 93/93 [==============================] - 14s 146ms/step - loss: 0.1663 - acc: 0.9288 - val_loss: 0.2514 - val_acc: 0.9038
#
# Epoch 00031: val_loss did not improve from 0.20295
# Epoch 32/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1653 - acc: 0.9355 - val_loss: 0.2557 - val_acc: 0.9112
#
# Epoch 00032: val_loss did not improve from 0.20295
# Epoch 33/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1883 - acc: 0.9237 - val_loss: 0.3033 - val_acc: 0.9125
#
# Epoch 00033: val_loss did not improve from 0.20295
# Epoch 34/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1671 - acc: 0.9263 - val_loss: 0.3296 - val_acc: 0.8838
#
# Epoch 00034: val_loss did not improve from 0.20295
# Epoch 35/50
# 93/93 [==============================] - 14s 145ms/step - loss: 0.1742 - acc: 0.9346 - val_loss: 0.4521 - val_acc: 0.8075
#
# Epoch 00035: val_loss did not improve from 0.20295
# Epoch 36/50
# 93/93 [==============================] - 13s 143ms/step - loss: 0.1409 - acc: 0.9503 - val_loss: 0.2034 - val_acc: 0.9375
#
# Epoch 00036: val_loss did not improve from 0.20295
# Epoch 37/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.1476 - acc: 0.9363 - val_loss: 0.2239 - val_acc: 0.9225
#
# Epoch 00037: val_loss did not improve from 0.20295
# Epoch 38/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1556 - acc: 0.9461 - val_loss: 0.3828 - val_acc: 0.8712
#
# Epoch 00038: val_loss did not improve from 0.20295
# Epoch 39/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1626 - acc: 0.9407 - val_loss: 0.3493 - val_acc: 0.8750
#
# Epoch 00039: val_loss did not improve from 0.20295
# Epoch 40/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.1692 - acc: 0.9330 - val_loss: 0.2804 - val_acc: 0.9175
#
# Epoch 00040: val_loss did not improve from 0.20295
# Epoch 41/50
# 93/93 [==============================] - 13s 144ms/step - loss: 0.1694 - acc: 0.9299 - val_loss: 0.3080 - val_acc: 0.9013
#
# Epoch 00041: val_loss did not improve from 0.20295
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2658 - acc: 0.9187
#
# ---------------------------------
# Accuracy: 91.87 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.91      0.92       179
#          1.0       0.90      0.94      0.92       157
#
#     accuracy                           0.92       336
#    macro avg       0.92      0.92      0.92       336
# weighted avg       0.92      0.92      0.92       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last Block Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=1,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True

#unfreeze last Inception module
for layer in conv_base.layers[:280]:
    layer.trainable = False
for layer in conv_base.layers[280:]:
    layer.trainable = True


model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# 93/93 [==============================] - 22s 130ms/step - loss: 0.8287 - acc: 0.6579 - val_loss: 0.4692 - val_acc: 0.7912
#
# Epoch 00001: val_loss improved from inf to 0.46916, saving model to checkpoint.h5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 10,792,641
# Non-trainable params: 15,729,248
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 127ms/step - loss: 0.6211 - acc: 0.7784 - val_loss: 0.3803 - val_acc: 0.8300
#
# Epoch 00001: val_loss improved from 0.46916 to 0.38028, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4465 - acc: 0.7942 - val_loss: 0.3611 - val_acc: 0.8500
#
# Epoch 00002: val_loss improved from 0.38028 to 0.36115, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4195 - acc: 0.8202 - val_loss: 0.3428 - val_acc: 0.8650
#
# Epoch 00003: val_loss improved from 0.36115 to 0.34276, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3856 - acc: 0.8241 - val_loss: 0.3334 - val_acc: 0.8562
#
# Epoch 00004: val_loss improved from 0.34276 to 0.33336, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3737 - acc: 0.8281 - val_loss: 0.3886 - val_acc: 0.8438
#
# Epoch 00005: val_loss did not improve from 0.33336
# Epoch 6/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3950 - acc: 0.8229 - val_loss: 0.3262 - val_acc: 0.8675
#
# Epoch 00006: val_loss improved from 0.33336 to 0.32620, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3796 - acc: 0.8404 - val_loss: 0.3456 - val_acc: 0.8612
#
# Epoch 00007: val_loss did not improve from 0.32620
# Epoch 8/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3811 - acc: 0.8352 - val_loss: 0.3024 - val_acc: 0.8813
#
# Epoch 00008: val_loss improved from 0.32620 to 0.30236, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4133 - acc: 0.8296 - val_loss: 0.3267 - val_acc: 0.8825
#
# Epoch 00009: val_loss did not improve from 0.30236
# Epoch 10/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4020 - acc: 0.8111 - val_loss: 0.3117 - val_acc: 0.8700
#
# Epoch 00010: val_loss did not improve from 0.30236
# Epoch 11/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3918 - acc: 0.8230 - val_loss: 0.3082 - val_acc: 0.8737
#
# Epoch 00011: val_loss did not improve from 0.30236
# Epoch 12/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3368 - acc: 0.8537 - val_loss: 0.5716 - val_acc: 0.7462
#
# Epoch 00012: val_loss did not improve from 0.30236
# Epoch 13/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3951 - acc: 0.8268 - val_loss: 0.3667 - val_acc: 0.8363
#
# Epoch 00013: val_loss did not improve from 0.30236
# Epoch 14/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3799 - acc: 0.8161 - val_loss: 0.2948 - val_acc: 0.8875
#
# Epoch 00014: val_loss improved from 0.30236 to 0.29480, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3358 - acc: 0.8493 - val_loss: 0.4667 - val_acc: 0.7925
#
# Epoch 00015: val_loss did not improve from 0.29480
# Epoch 16/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3528 - acc: 0.8352 - val_loss: 0.3052 - val_acc: 0.8813
#
# Epoch 00016: val_loss did not improve from 0.29480
# Epoch 17/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3093 - acc: 0.8682 - val_loss: 0.3197 - val_acc: 0.8662
#
# Epoch 00017: val_loss did not improve from 0.29480
# Epoch 18/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3766 - acc: 0.8191 - val_loss: 0.3308 - val_acc: 0.8600
#
# Epoch 00018: val_loss did not improve from 0.29480
# Epoch 19/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3052 - acc: 0.8649 - val_loss: 0.2834 - val_acc: 0.8737
#
# Epoch 00019: val_loss improved from 0.29480 to 0.28342, saving model to checkpoint.h5
# Epoch 20/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3315 - acc: 0.8488 - val_loss: 0.2995 - val_acc: 0.8788
#
# Epoch 00020: val_loss did not improve from 0.28342
# Epoch 21/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3600 - acc: 0.8431 - val_loss: 0.2859 - val_acc: 0.8775
#
# Epoch 00021: val_loss did not improve from 0.28342
# Epoch 22/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3331 - acc: 0.8541 - val_loss: 0.2954 - val_acc: 0.8863
#
# Epoch 00022: val_loss did not improve from 0.28342
# Epoch 23/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3470 - acc: 0.8507 - val_loss: 0.3021 - val_acc: 0.8775
#
# Epoch 00023: val_loss did not improve from 0.28342
# Epoch 24/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3141 - acc: 0.8574 - val_loss: 0.2913 - val_acc: 0.8763
#
# Epoch 00024: val_loss did not improve from 0.28342
# Epoch 25/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3196 - acc: 0.8521 - val_loss: 0.2897 - val_acc: 0.8825
#
# Epoch 00025: val_loss did not improve from 0.28342
# Epoch 26/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3223 - acc: 0.8542 - val_loss: 0.2826 - val_acc: 0.8850
#
# Epoch 00026: val_loss improved from 0.28342 to 0.28261, saving model to checkpoint.h5
# Epoch 27/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3125 - acc: 0.8561 - val_loss: 0.2873 - val_acc: 0.8875
#
# Epoch 00027: val_loss did not improve from 0.28261
# Epoch 28/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3040 - acc: 0.8684 - val_loss: 0.2903 - val_acc: 0.8750
#
# Epoch 00028: val_loss did not improve from 0.28261
# Epoch 29/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3056 - acc: 0.8720 - val_loss: 0.3436 - val_acc: 0.8475
#
# Epoch 00029: val_loss did not improve from 0.28261
# Epoch 30/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3135 - acc: 0.8615 - val_loss: 0.2837 - val_acc: 0.8875
#
# Epoch 00030: val_loss did not improve from 0.28261
# Epoch 31/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3632 - acc: 0.8478 - val_loss: 0.3097 - val_acc: 0.8675
#
# Epoch 00031: val_loss did not improve from 0.28261
# Epoch 32/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3127 - acc: 0.8798 - val_loss: 0.2965 - val_acc: 0.8687
#
# Epoch 00032: val_loss did not improve from 0.28261
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3488 - acc: 0.8566 - val_loss: 0.2964 - val_acc: 0.8763
#
# Epoch 00033: val_loss did not improve from 0.28261
# Epoch 34/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3333 - acc: 0.8613 - val_loss: 0.2893 - val_acc: 0.8850
#
# Epoch 00034: val_loss did not improve from 0.28261
# Epoch 35/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3121 - acc: 0.8640 - val_loss: 0.3034 - val_acc: 0.8712
#
# Epoch 00035: val_loss did not improve from 0.28261
# Epoch 36/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2872 - acc: 0.8821 - val_loss: 0.2966 - val_acc: 0.8838
#
# Epoch 00036: val_loss did not improve from 0.28261
# Epoch 37/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3057 - acc: 0.8685 - val_loss: 0.2956 - val_acc: 0.8800
#
# Epoch 00037: val_loss did not improve from 0.28261
# Epoch 38/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2972 - acc: 0.8818 - val_loss: 0.2856 - val_acc: 0.8888
#
# Epoch 00038: val_loss did not improve from 0.28261
# Epoch 39/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3194 - acc: 0.8487 - val_loss: 0.4165 - val_acc: 0.8225
#
# Epoch 00039: val_loss did not improve from 0.28261
# Epoch 40/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3010 - acc: 0.8642 - val_loss: 0.2840 - val_acc: 0.8825
#
# Epoch 00040: val_loss did not improve from 0.28261
# Epoch 41/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3148 - acc: 0.8593 - val_loss: 0.2770 - val_acc: 0.8950
#
# Epoch 00041: val_loss improved from 0.28261 to 0.27699, saving model to checkpoint.h5
# Epoch 42/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3271 - acc: 0.8670 - val_loss: 0.2831 - val_acc: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.27699
# Epoch 43/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3013 - acc: 0.8592 - val_loss: 0.2807 - val_acc: 0.8875
#
# Epoch 00043: val_loss did not improve from 0.27699
# Epoch 44/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3257 - acc: 0.8531 - val_loss: 0.2833 - val_acc: 0.8813
#
# Epoch 00044: val_loss did not improve from 0.27699
# Epoch 45/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2957 - acc: 0.8755 - val_loss: 0.2861 - val_acc: 0.8763
#
# Epoch 00045: val_loss did not improve from 0.27699
# Epoch 46/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2889 - acc: 0.8777 - val_loss: 0.3199 - val_acc: 0.8750
#
# Epoch 00046: val_loss did not improve from 0.27699
# Epoch 47/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3106 - acc: 0.8734 - val_loss: 0.3042 - val_acc: 0.8750
#
# Epoch 00047: val_loss did not improve from 0.27699
# Epoch 48/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3143 - acc: 0.8707 - val_loss: 0.2953 - val_acc: 0.8813
#
# Epoch 00048: val_loss did not improve from 0.27699
# Epoch 49/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3042 - acc: 0.8645 - val_loss: 0.2958 - val_acc: 0.8863
#
# Epoch 00049: val_loss did not improve from 0.27699
# Epoch 50/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3241 - acc: 0.8631 - val_loss: 0.2883 - val_acc: 0.8850
#
# Epoch 00050: val_loss did not improve from 0.27699
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.3209 - acc: 0.8656
#
# ---------------------------------
# Accuracy: 86.56 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.87      0.88       179
#          1.0       0.85      0.88      0.87       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_dense_256x1_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True

#unfreeze last 2 Inception modules
for layer in conv_base.layers[:249]:
    layer.trainable = False
for layer in conv_base.layers[249:]:
    layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 131ms/step - loss: 0.9131 - acc: 0.7049 - val_loss: 0.4369 - val_acc: 0.8163
#
# Epoch 00001: val_loss improved from inf to 0.43694, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4876 - acc: 0.7879 - val_loss: 0.4010 - val_acc: 0.8388
#
# Epoch 00002: val_loss improved from 0.43694 to 0.40101, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4770 - acc: 0.7727 - val_loss: 0.3784 - val_acc: 0.8600
#
# Epoch 00003: val_loss improved from 0.40101 to 0.37840, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4282 - acc: 0.8066 - val_loss: 0.3435 - val_acc: 0.8662
#
# Epoch 00004: val_loss improved from 0.37840 to 0.34352, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4264 - acc: 0.8173 - val_loss: 0.3509 - val_acc: 0.8637
#
# Epoch 00005: val_loss did not improve from 0.34352
# Epoch 6/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4154 - acc: 0.8081 - val_loss: 0.3688 - val_acc: 0.8400
#
# Epoch 00006: val_loss did not improve from 0.34352
# Epoch 7/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4177 - acc: 0.8060 - val_loss: 0.3480 - val_acc: 0.8525
#
# Epoch 00007: val_loss did not improve from 0.34352
# Epoch 8/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.3843 - acc: 0.8188 - val_loss: 0.3653 - val_acc: 0.8425
#
# Epoch 00008: val_loss did not improve from 0.34352
# Epoch 9/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4185 - acc: 0.8163 - val_loss: 0.3328 - val_acc: 0.8650
#
# Epoch 00009: val_loss improved from 0.34352 to 0.33280, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4258 - acc: 0.8086 - val_loss: 0.3361 - val_acc: 0.8612
#
# Epoch 00010: val_loss did not improve from 0.33280
# Epoch 11/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4056 - acc: 0.8208 - val_loss: 0.3394 - val_acc: 0.8587
#
# Epoch 00011: val_loss did not improve from 0.33280
# Epoch 12/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4353 - acc: 0.7864 - val_loss: 0.3306 - val_acc: 0.8712
#
# Epoch 00012: val_loss improved from 0.33280 to 0.33058, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3827 - acc: 0.8263 - val_loss: 0.3333 - val_acc: 0.8763
#
# Epoch 00013: val_loss did not improve from 0.33058
# Epoch 14/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3822 - acc: 0.8273 - val_loss: 0.3286 - val_acc: 0.8687
#
# Epoch 00014: val_loss improved from 0.33058 to 0.32861, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3908 - acc: 0.8202 - val_loss: 0.3474 - val_acc: 0.8562
#
# Epoch 00015: val_loss did not improve from 0.32861
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc92736d588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9270bdc88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcbb007ecc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9270a8ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9270bdc50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9275cbfd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9270a8860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcbb011b278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9275addd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc92732b470>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc927238fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9270bdcc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc927246048>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc927208c88>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcbb0135b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc92866e048>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9270834e0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc927359a20>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc927560208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9270e2cf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9273219e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc928657048>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92715af98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9272e9710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9271d2eb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc92722c8d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc927106278>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fc928663ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9275cb630>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc927508898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc927106c18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9275a30f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9270984a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc92715a4e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9271d2748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9271d2da0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc92715a8d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc927321710>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc928663940>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9271c9208>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fcbb0063438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92740ce80>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9270299b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc92701d780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9271c9860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92755bbe0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc92755bf28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc926f43f9 ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 15,833,985
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 130ms/step - loss: 0.5225 - acc: 0.8031 - val_loss: 0.3870 - val_acc: 0.8250
#
# Epoch 00001: val_loss did not improve from 0.32861
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4196 - acc: 0.8183 - val_loss: 0.3633 - val_acc: 0.8338
#
# Epoch 00002: val_loss did not improve from 0.32861
# Epoch 3/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3892 - acc: 0.8284 - val_loss: 0.3459 - val_acc: 0.8487
#
# Epoch 00003: val_loss did not improve from 0.32861
# Epoch 4/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3808 - acc: 0.8186 - val_loss: 0.2819 - val_acc: 0.8775
#
# Epoch 00004: val_loss improved from 0.32861 to 0.28188, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3580 - acc: 0.8447 - val_loss: 0.4443 - val_acc: 0.8037
#
# Epoch 00005: val_loss did not improve from 0.28188
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3661 - acc: 0.8315 - val_loss: 0.3730 - val_acc: 0.8487
#
# Epoch 00006: val_loss did not improve from 0.28188
# Epoch 7/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3867 - acc: 0.8261 - val_loss: 0.2997 - val_acc: 0.8800
#
# Epoch 00007: val_loss did not improve from 0.28188
# Epoch 8/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3270 - acc: 0.8680 - val_loss: 0.3398 - val_acc: 0.8637
#
# Epoch 00008: val_loss did not improve from 0.28188
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3289 - acc: 0.8568 - val_loss: 0.3108 - val_acc: 0.8813
#
# Epoch 00009: val_loss did not improve from 0.28188
# Epoch 10/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3333 - acc: 0.8582 - val_loss: 0.2879 - val_acc: 0.8913
#
# Epoch 00010: val_loss did not improve from 0.28188
# Epoch 11/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3442 - acc: 0.8507 - val_loss: 0.2956 - val_acc: 0.8700
#
# Epoch 00011: val_loss did not improve from 0.28188
# Epoch 12/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3467 - acc: 0.8525 - val_loss: 0.3061 - val_acc: 0.8813
#
# Epoch 00012: val_loss did not improve from 0.28188
# Epoch 13/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3064 - acc: 0.8613 - val_loss: 0.2794 - val_acc: 0.8938
#
# Epoch 00013: val_loss improved from 0.28188 to 0.27942, saving model to checkpoint.h5
# Epoch 14/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3102 - acc: 0.8624 - val_loss: 0.2975 - val_acc: 0.8850
#
# Epoch 00014: val_loss did not improve from 0.27942
# Epoch 15/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3153 - acc: 0.8623 - val_loss: 0.4529 - val_acc: 0.8250
#
# Epoch 00015: val_loss did not improve from 0.27942
# Epoch 16/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3455 - acc: 0.8519 - val_loss: 0.2857 - val_acc: 0.8850
#
# Epoch 00016: val_loss did not improve from 0.27942
# Epoch 17/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3121 - acc: 0.8595 - val_loss: 0.3022 - val_acc: 0.8850
#
# Epoch 00017: val_loss did not improve from 0.27942
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3090 - acc: 0.8711 - val_loss: 0.2686 - val_acc: 0.8875
#
# Epoch 00018: val_loss improved from 0.27942 to 0.26858, saving model to checkpoint.h5
# Epoch 19/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3391 - acc: 0.8488 - val_loss: 0.3085 - val_acc: 0.8775
#
# Epoch 00019: val_loss did not improve from 0.26858
# Epoch 20/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3194 - acc: 0.8658 - val_loss: 0.2629 - val_acc: 0.8938
#
# Epoch 00020: val_loss improved from 0.26858 to 0.26285, saving model to checkpoint.h5
# Epoch 21/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3165 - acc: 0.8567 - val_loss: 0.2770 - val_acc: 0.8800
#
# Epoch 00021: val_loss did not improve from 0.26285
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3179 - acc: 0.8692 - val_loss: 0.2862 - val_acc: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.26285
# Epoch 23/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3243 - acc: 0.8489 - val_loss: 0.3269 - val_acc: 0.8800
#
# Epoch 00023: val_loss did not improve from 0.26285
# Epoch 24/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3227 - acc: 0.8700 - val_loss: 0.2801 - val_acc: 0.8863
#
# Epoch 00024: val_loss did not improve from 0.26285
# Epoch 25/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2913 - acc: 0.8798 - val_loss: 0.3258 - val_acc: 0.8637
#
# Epoch 00025: val_loss did not improve from 0.26285
# Epoch 26/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3304 - acc: 0.8696 - val_loss: 0.6872 - val_acc: 0.7475
#
# Epoch 00026: val_loss did not improve from 0.26285
# Epoch 27/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3075 - acc: 0.8723 - val_loss: 0.2553 - val_acc: 0.8925
#
# Epoch 00027: val_loss improved from 0.26285 to 0.25534, saving model to checkpoint.h5
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3212 - acc: 0.8616 - val_loss: 0.2530 - val_acc: 0.8825
#
# Epoch 00028: val_loss improved from 0.25534 to 0.25297, saving model to checkpoint.h5
# Epoch 29/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3287 - acc: 0.8620 - val_loss: 0.2951 - val_acc: 0.8963
#
# Epoch 00029: val_loss did not improve from 0.25297
# Epoch 30/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3016 - acc: 0.8741 - val_loss: 0.2617 - val_acc: 0.8913
#
# Epoch 00030: val_loss did not improve from 0.25297
# Epoch 31/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3041 - acc: 0.8725 - val_loss: 0.4087 - val_acc: 0.8313
#
# Epoch 00031: val_loss did not improve from 0.25297
# Epoch 32/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2909 - acc: 0.8758 - val_loss: 0.3739 - val_acc: 0.8487
#
# Epoch 00032: val_loss did not improve from 0.25297
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2585 - acc: 0.8955 - val_loss: 0.3742 - val_acc: 0.8112
#
# Epoch 00033: val_loss did not improve from 0.25297
# Epoch 34/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3109 - acc: 0.8594 - val_loss: 0.2868 - val_acc: 0.8813
#
# Epoch 00034: val_loss did not improve from 0.25297
# Epoch 35/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2853 - acc: 0.8776 - val_loss: 0.2738 - val_acc: 0.8938
#
# Epoch 00035: val_loss did not improve from 0.25297
# Epoch 36/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2809 - acc: 0.8865 - val_loss: 0.2565 - val_acc: 0.8938
#
# Epoch 00036: val_loss did not improve from 0.25297
# Epoch 37/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2964 - acc: 0.8627 - val_loss: 0.2724 - val_acc: 0.8963
#
# Epoch 00037: val_loss did not improve from 0.25297
# Epoch 38/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3000 - acc: 0.8703 - val_loss: 0.2710 - val_acc: 0.9038
#
# Epoch 00038: val_loss did not improve from 0.25297
# Epoch 39/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2950 - acc: 0.8658 - val_loss: 0.3681 - val_acc: 0.8650
#
# Epoch 00039: val_loss did not improve from 0.25297
# Epoch 40/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2886 - acc: 0.8730 - val_loss: 0.2856 - val_acc: 0.8925
#
# Epoch 00040: val_loss did not improve from 0.25297
# Epoch 41/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3372 - acc: 0.8571 - val_loss: 0.2909 - val_acc: 0.8963
#
# Epoch 00041: val_loss did not improve from 0.25297
# Epoch 42/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2694 - acc: 0.8898 - val_loss: 0.3355 - val_acc: 0.8650
#
# Epoch 00042: val_loss did not improve from 0.25297
# Epoch 43/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2631 - acc: 0.8951 - val_loss: 0.3279 - val_acc: 0.8725
#
# Epoch 00043: val_loss did not improve from 0.25297
# Epoch 44/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3195 - acc: 0.8765 - val_loss: 0.3665 - val_acc: 0.8525
#
# Epoch 00044: val_loss did not improve from 0.25297
# Epoch 45/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3058 - acc: 0.8571 - val_loss: 0.4954 - val_acc: 0.7837
#
# Epoch 00045: val_loss did not improve from 0.25297
# Epoch 46/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2847 - acc: 0.8666 - val_loss: 0.3016 - val_acc: 0.8763
#
# Epoch 00046: val_loss did not improve from 0.25297
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2482 - acc: 0.8979 - val_loss: 0.2601 - val_acc: 0.9062
#
# Epoch 00047: val_loss did not improve from 0.25297
# Epoch 48/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2684 - acc: 0.8835 - val_loss: 0.4009 - val_acc: 0.8413
#
# Epoch 00048: val_loss did not improve from 0.25297
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.2980 - acc: 0.8719
#
# ---------------------------------
# Accuracy: 87.19 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.87      0.88       179
#          1.0       0.85      0.88      0.87       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_dense_256x1_last_2_blocks_trainable.h5'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7dbf6bafcd34> in <module>()
# ----> 1 models.save_model(model, os.path.join(MODEL_PATH, 'Inception_dense_256x1_last_2_blocks_trainable.h5'))
#
# NameError: name 'model' is not defined

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6f56e0441ad0> in <module>()
#       1 #free RAM
# ----> 2 del model
#       3 del conv_base
#       4 del history
#       5 get_ipython().system("rm 'checkpoint.h5'")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True

#unfreeze last 2 Inception modules
for layer in conv_base.layers[:249]:
    layer.trainable = False
for layer in conv_base.layers[249:]:
    layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 524,801
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 128ms/step - loss: 0.6465 - acc: 0.7356 - val_loss: 0.4608 - val_acc: 0.7987
#
# Epoch 00001: val_loss improved from inf to 0.46084, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4796 - acc: 0.7798 - val_loss: 0.4089 - val_acc: 0.8388
#
# Epoch 00002: val_loss improved from 0.46084 to 0.40890, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4262 - acc: 0.8001 - val_loss: 0.3862 - val_acc: 0.8388
#
# Epoch 00003: val_loss improved from 0.40890 to 0.38619, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4745 - acc: 0.7734 - val_loss: 0.3875 - val_acc: 0.8300
#
# Epoch 00004: val_loss did not improve from 0.38619
# Epoch 5/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4316 - acc: 0.8212 - val_loss: 0.3881 - val_acc: 0.8238
#
# Epoch 00005: val_loss did not improve from 0.38619
# Epoch 6/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4412 - acc: 0.7983 - val_loss: 0.3784 - val_acc: 0.8462
#
# Epoch 00006: val_loss improved from 0.38619 to 0.37842, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4121 - acc: 0.8113 - val_loss: 0.3735 - val_acc: 0.8425
#
# Epoch 00007: val_loss improved from 0.37842 to 0.37353, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4403 - acc: 0.7937 - val_loss: 0.3786 - val_acc: 0.8413
#
# Epoch 00008: val_loss did not improve from 0.37353
# Epoch 9/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4336 - acc: 0.7937 - val_loss: 0.3470 - val_acc: 0.8438
#
# Epoch 00009: val_loss improved from 0.37353 to 0.34698, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4206 - acc: 0.8167 - val_loss: 0.3424 - val_acc: 0.8625
#
# Epoch 00010: val_loss improved from 0.34698 to 0.34240, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4432 - acc: 0.7998 - val_loss: 0.3693 - val_acc: 0.8288
#
# Epoch 00011: val_loss did not improve from 0.34240
# Epoch 12/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4051 - acc: 0.8070 - val_loss: 0.3382 - val_acc: 0.8500
#
# Epoch 00012: val_loss improved from 0.34240 to 0.33822, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4193 - acc: 0.8054 - val_loss: 0.3712 - val_acc: 0.8425
#
# Epoch 00013: val_loss did not improve from 0.33822
# Epoch 14/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4098 - acc: 0.8160 - val_loss: 0.3443 - val_acc: 0.8637
#
# Epoch 00014: val_loss did not improve from 0.33822
# Epoch 15/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3850 - acc: 0.8286 - val_loss: 0.3428 - val_acc: 0.8587
#
# Epoch 00015: val_loss did not improve from 0.33822
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc9288b19b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9288b1080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc92669ada0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f6e7e10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9288b15f8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58bd3390>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f700208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92704b550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f4d8128>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc928857668>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fcb3f583be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9288b1ac8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f6ac198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb582492b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9268164a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58ca9828>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f2c2198>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fcb3f6e7320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb58d0df28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb50237a90>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9288aa080>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92885e7b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb50237208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f6e7400>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb5865dd30>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58658f28>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb50223d68>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fcb3f600278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb58d16cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f2eb940>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f6f70b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb502235c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc928890ef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f2eb668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9288aa278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f5a6208>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f2ebfd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f2779b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58cf4198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb585c8da0>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fc9266d3048>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f4db908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc928897e80>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58643908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb585c8d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb50223cc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb502237b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f5b440 ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 11,639,681
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 134ms/step - loss: 0.5270 - acc: 0.8085 - val_loss: 0.4775 - val_acc: 0.7925
#
# Epoch 00001: val_loss did not improve from 0.33822
# Epoch 2/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4424 - acc: 0.7970 - val_loss: 0.3375 - val_acc: 0.8487
#
# Epoch 00002: val_loss improved from 0.33822 to 0.33753, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3781 - acc: 0.8193 - val_loss: 0.3091 - val_acc: 0.8625
#
# Epoch 00003: val_loss improved from 0.33753 to 0.30912, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3788 - acc: 0.8346 - val_loss: 0.3282 - val_acc: 0.8737
#
# Epoch 00004: val_loss did not improve from 0.30912
# Epoch 5/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3605 - acc: 0.8304 - val_loss: 0.3509 - val_acc: 0.8487
#
# Epoch 00005: val_loss did not improve from 0.30912
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3880 - acc: 0.8400 - val_loss: 0.3729 - val_acc: 0.8325
#
# Epoch 00006: val_loss did not improve from 0.30912
# Epoch 7/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3641 - acc: 0.8462 - val_loss: 0.3794 - val_acc: 0.8350
#
# Epoch 00007: val_loss did not improve from 0.30912
# Epoch 8/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3584 - acc: 0.8349 - val_loss: 0.3320 - val_acc: 0.8537
#
# Epoch 00008: val_loss did not improve from 0.30912
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3723 - acc: 0.8276 - val_loss: 0.4058 - val_acc: 0.8350
#
# Epoch 00009: val_loss did not improve from 0.30912
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3343 - acc: 0.8475 - val_loss: 0.4049 - val_acc: 0.8275
#
# Epoch 00010: val_loss did not improve from 0.30912
# Epoch 11/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3238 - acc: 0.8647 - val_loss: 0.3378 - val_acc: 0.8775
#
# Epoch 00011: val_loss did not improve from 0.30912
# Epoch 12/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3327 - acc: 0.8550 - val_loss: 0.4109 - val_acc: 0.8338
#
# Epoch 00012: val_loss did not improve from 0.30912
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3199 - acc: 0.8657 - val_loss: 0.3097 - val_acc: 0.8625
#
# Epoch 00013: val_loss did not improve from 0.30912
# Epoch 14/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3352 - acc: 0.8620 - val_loss: 0.3199 - val_acc: 0.8788
#
# Epoch 00014: val_loss did not improve from 0.30912
# Epoch 15/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3539 - acc: 0.8367 - val_loss: 0.2805 - val_acc: 0.8850
#
# Epoch 00015: val_loss improved from 0.30912 to 0.28055, saving model to checkpoint.h5
# Epoch 16/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2927 - acc: 0.8751 - val_loss: 0.3723 - val_acc: 0.8313
#
# Epoch 00016: val_loss did not improve from 0.28055
# Epoch 17/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2961 - acc: 0.8719 - val_loss: 0.4105 - val_acc: 0.8425
#
# Epoch 00017: val_loss did not improve from 0.28055
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3404 - acc: 0.8588 - val_loss: 0.3049 - val_acc: 0.8800
#
# Epoch 00018: val_loss did not improve from 0.28055
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3351 - acc: 0.8611 - val_loss: 0.2935 - val_acc: 0.8938
#
# Epoch 00019: val_loss did not improve from 0.28055
# Epoch 20/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3177 - acc: 0.8652 - val_loss: 0.2944 - val_acc: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.28055
# Epoch 21/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3185 - acc: 0.8614 - val_loss: 0.2873 - val_acc: 0.8863
#
# Epoch 00021: val_loss did not improve from 0.28055
# Epoch 22/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2881 - acc: 0.8809 - val_loss: 0.3114 - val_acc: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.28055
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3124 - acc: 0.8649 - val_loss: 0.6036 - val_acc: 0.7750
#
# Epoch 00023: val_loss did not improve from 0.28055
# Epoch 24/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2824 - acc: 0.8691 - val_loss: 0.3925 - val_acc: 0.8100
#
# Epoch 00024: val_loss did not improve from 0.28055
# Epoch 25/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3313 - acc: 0.8590 - val_loss: 0.2704 - val_acc: 0.9000
#
# Epoch 00025: val_loss improved from 0.28055 to 0.27043, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2831 - acc: 0.8892 - val_loss: 0.2905 - val_acc: 0.8925
#
# Epoch 00026: val_loss did not improve from 0.27043
# Epoch 27/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3168 - acc: 0.8536 - val_loss: 0.2724 - val_acc: 0.9013
#
# Epoch 00027: val_loss did not improve from 0.27043
# Epoch 28/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2974 - acc: 0.8810 - val_loss: 0.3314 - val_acc: 0.8625
#
# Epoch 00028: val_loss did not improve from 0.27043
# Epoch 29/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3106 - acc: 0.8652 - val_loss: 0.3016 - val_acc: 0.8775
#
# Epoch 00029: val_loss did not improve from 0.27043
# Epoch 30/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2747 - acc: 0.8843 - val_loss: 0.2587 - val_acc: 0.9025
#
# Epoch 00030: val_loss improved from 0.27043 to 0.25870, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2904 - acc: 0.8815 - val_loss: 0.3434 - val_acc: 0.8475
#
# Epoch 00031: val_loss did not improve from 0.25870
# Epoch 32/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2803 - acc: 0.8915 - val_loss: 0.2845 - val_acc: 0.8850
#
# Epoch 00032: val_loss did not improve from 0.25870
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2959 - acc: 0.8690 - val_loss: 0.2605 - val_acc: 0.8900
#
# Epoch 00033: val_loss did not improve from 0.25870
# Epoch 34/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3104 - acc: 0.8751 - val_loss: 0.2616 - val_acc: 0.8875
#
# Epoch 00034: val_loss did not improve from 0.25870
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2642 - acc: 0.8805 - val_loss: 0.2931 - val_acc: 0.8888
#
# Epoch 00035: val_loss did not improve from 0.25870
# Epoch 36/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2922 - acc: 0.8699 - val_loss: 0.2658 - val_acc: 0.8900
#
# Epoch 00036: val_loss did not improve from 0.25870
# Epoch 37/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3028 - acc: 0.8646 - val_loss: 0.4495 - val_acc: 0.8250
#
# Epoch 00037: val_loss did not improve from 0.25870
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2755 - acc: 0.8835 - val_loss: 0.3001 - val_acc: 0.8675
#
# Epoch 00038: val_loss did not improve from 0.25870
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2901 - acc: 0.8754 - val_loss: 0.2708 - val_acc: 0.8963
#
# Epoch 00039: val_loss did not improve from 0.25870
# Epoch 40/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2747 - acc: 0.8758 - val_loss: 0.2693 - val_acc: 0.8963
#
# Epoch 00040: val_loss did not improve from 0.25870
# Epoch 41/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3097 - acc: 0.8783 - val_loss: 0.2809 - val_acc: 0.8963
#
# Epoch 00041: val_loss did not improve from 0.25870
# Epoch 42/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2918 - acc: 0.8797 - val_loss: 0.5316 - val_acc: 0.7900
#
# Epoch 00042: val_loss did not improve from 0.25870
# Epoch 43/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3022 - acc: 0.8732 - val_loss: 0.5256 - val_acc: 0.8313
#
# Epoch 00043: val_loss did not improve from 0.25870
# Epoch 44/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2734 - acc: 0.8871 - val_loss: 0.3279 - val_acc: 0.8562
#
# Epoch 00044: val_loss did not improve from 0.25870
# Epoch 45/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2840 - acc: 0.8845 - val_loss: 0.4204 - val_acc: 0.8188
#
# Epoch 00045: val_loss did not improve from 0.25870
# Epoch 46/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2726 - acc: 0.8832 - val_loss: 0.2628 - val_acc: 0.8950
#
# Epoch 00046: val_loss did not improve from 0.25870
# Epoch 47/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2848 - acc: 0.8804 - val_loss: 0.2859 - val_acc: 0.8913
#
# Epoch 00047: val_loss did not improve from 0.25870
# Epoch 48/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2648 - acc: 0.8956 - val_loss: 0.3185 - val_acc: 0.8775
#
# Epoch 00048: val_loss did not improve from 0.25870
# Epoch 49/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2783 - acc: 0.8859 - val_loss: 0.2666 - val_acc: 0.8988
#
# Epoch 00049: val_loss did not improve from 0.25870
# Epoch 50/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2596 - acc: 0.9011 - val_loss: 0.4081 - val_acc: 0.8450
#
# Epoch 00050: val_loss did not improve from 0.25870
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.3059 - acc: 0.8781
#
# ---------------------------------
# Accuracy: 87.81 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.87      0.88       179
#          1.0       0.86      0.89      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception__globalAvgPool_dense_256x1_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True

#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 127ms/step - loss: 1.0791 - acc: 0.7257 - val_loss: 0.4092 - val_acc: 0.8175
#
# Epoch 00001: val_loss improved from inf to 0.40920, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4990 - acc: 0.7796 - val_loss: 0.3657 - val_acc: 0.8350
#
# Epoch 00002: val_loss improved from 0.40920 to 0.36565, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4538 - acc: 0.7920 - val_loss: 0.3618 - val_acc: 0.8462
#
# Epoch 00003: val_loss improved from 0.36565 to 0.36178, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4077 - acc: 0.8044 - val_loss: 0.3889 - val_acc: 0.8313
#
# Epoch 00004: val_loss did not improve from 0.36178
# Epoch 5/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4457 - acc: 0.7886 - val_loss: 0.3527 - val_acc: 0.8500
#
# Epoch 00005: val_loss improved from 0.36178 to 0.35268, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4172 - acc: 0.8047 - val_loss: 0.3520 - val_acc: 0.8363
#
# Epoch 00006: val_loss improved from 0.35268 to 0.35201, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3975 - acc: 0.8157 - val_loss: 0.3551 - val_acc: 0.8512
#
# Epoch 00007: val_loss did not improve from 0.35201
# Epoch 8/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4351 - acc: 0.8082 - val_loss: 0.3467 - val_acc: 0.8425
#
# Epoch 00008: val_loss improved from 0.35201 to 0.34669, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3930 - acc: 0.8252 - val_loss: 0.3637 - val_acc: 0.8363
#
# Epoch 00009: val_loss did not improve from 0.34669
# Epoch 10/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3699 - acc: 0.8417 - val_loss: 0.3505 - val_acc: 0.8388
#
# Epoch 00010: val_loss did not improve from 0.34669
# Epoch 11/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3896 - acc: 0.8262 - val_loss: 0.3441 - val_acc: 0.8525
#
# Epoch 00011: val_loss improved from 0.34669 to 0.34415, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3678 - acc: 0.8303 - val_loss: 0.3362 - val_acc: 0.8450
#
# Epoch 00012: val_loss improved from 0.34415 to 0.33619, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3838 - acc: 0.8339 - val_loss: 0.3421 - val_acc: 0.8537
#
# Epoch 00013: val_loss did not improve from 0.33619
# Epoch 14/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.3973 - acc: 0.8197 - val_loss: 0.3196 - val_acc: 0.8562
#
# Epoch 00014: val_loss improved from 0.33619 to 0.31959, saving model to checkpoint.h5
# Epoch 15/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4037 - acc: 0.8178 - val_loss: 0.3505 - val_acc: 0.8475
#
# Epoch 00015: val_loss did not improve from 0.31959
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fcb3f2c2f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930ae04e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc930ae0b00>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb588a66d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930ae0e10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc927427ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58dc9f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc927259160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc930ab9c88>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58dd9ac8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc930ab9ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92744fcf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588b12e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb504d3cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb59f20710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588b1208>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58d76780>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fcb504fc3c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930aeb3c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc930aebfd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc930b19160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb58dd9390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930b19208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588a65c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58dd7ef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb582dc780>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb588a25c0>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fc930b74518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb504d35c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc9287daf98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930b19710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92645ab70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9287daba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588a2a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588a6438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb588a9438>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58d77dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc926441be0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb588b17f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb586d6b38>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fcb3f6449e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3e0d8828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb504ab780>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb504b0cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb586d6908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb586d6470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9273bdba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb50486c5 ...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 17,937,281
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 131ms/step - loss: 0.5072 - acc: 0.8110 - val_loss: 0.6064 - val_acc: 0.7563
#
# Epoch 00001: val_loss did not improve from 0.31959
# Epoch 2/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4369 - acc: 0.7886 - val_loss: 0.4217 - val_acc: 0.8062
#
# Epoch 00002: val_loss did not improve from 0.31959
# Epoch 3/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4104 - acc: 0.8028 - val_loss: 0.3631 - val_acc: 0.8375
#
# Epoch 00003: val_loss did not improve from 0.31959
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3678 - acc: 0.8322 - val_loss: 0.3098 - val_acc: 0.8700
#
# Epoch 00004: val_loss improved from 0.31959 to 0.30980, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3649 - acc: 0.8232 - val_loss: 0.4806 - val_acc: 0.8150
#
# Epoch 00005: val_loss did not improve from 0.30980
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3378 - acc: 0.8584 - val_loss: 0.3444 - val_acc: 0.8475
#
# Epoch 00006: val_loss did not improve from 0.30980
# Epoch 7/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3500 - acc: 0.8472 - val_loss: 0.3545 - val_acc: 0.8700
#
# Epoch 00007: val_loss did not improve from 0.30980
# Epoch 8/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3581 - acc: 0.8568 - val_loss: 0.3314 - val_acc: 0.8562
#
# Epoch 00008: val_loss did not improve from 0.30980
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3556 - acc: 0.8387 - val_loss: 0.2761 - val_acc: 0.8825
#
# Epoch 00009: val_loss improved from 0.30980 to 0.27606, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3220 - acc: 0.8606 - val_loss: 0.3365 - val_acc: 0.8600
#
# Epoch 00010: val_loss did not improve from 0.27606
# Epoch 11/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3198 - acc: 0.8639 - val_loss: 0.3047 - val_acc: 0.8700
#
# Epoch 00011: val_loss did not improve from 0.27606
# Epoch 12/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3162 - acc: 0.8609 - val_loss: 0.3156 - val_acc: 0.8737
#
# Epoch 00012: val_loss did not improve from 0.27606
# Epoch 13/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3338 - acc: 0.8538 - val_loss: 0.3103 - val_acc: 0.8775
#
# Epoch 00013: val_loss did not improve from 0.27606
# Epoch 14/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3447 - acc: 0.8468 - val_loss: 0.3142 - val_acc: 0.8687
#
# Epoch 00014: val_loss did not improve from 0.27606
# Epoch 15/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3033 - acc: 0.8722 - val_loss: 0.2949 - val_acc: 0.8763
#
# Epoch 00015: val_loss did not improve from 0.27606
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2878 - acc: 0.8824 - val_loss: 0.3072 - val_acc: 0.8825
#
# Epoch 00016: val_loss did not improve from 0.27606
# Epoch 17/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3181 - acc: 0.8753 - val_loss: 0.2743 - val_acc: 0.8900
#
# Epoch 00017: val_loss improved from 0.27606 to 0.27430, saving model to checkpoint.h5
# Epoch 18/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2804 - acc: 0.8752 - val_loss: 0.2813 - val_acc: 0.8763
#
# Epoch 00018: val_loss did not improve from 0.27430
# Epoch 19/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3100 - acc: 0.8640 - val_loss: 0.2814 - val_acc: 0.8938
#
# Epoch 00019: val_loss did not improve from 0.27430
# Epoch 20/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3295 - acc: 0.8685 - val_loss: 0.3100 - val_acc: 0.8675
#
# Epoch 00020: val_loss did not improve from 0.27430
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2923 - acc: 0.8784 - val_loss: 0.3022 - val_acc: 0.8800
#
# Epoch 00021: val_loss did not improve from 0.27430
# Epoch 22/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2725 - acc: 0.8772 - val_loss: 0.3681 - val_acc: 0.8438
#
# Epoch 00022: val_loss did not improve from 0.27430
# Epoch 23/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2843 - acc: 0.8824 - val_loss: 0.3065 - val_acc: 0.8662
#
# Epoch 00023: val_loss did not improve from 0.27430
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2869 - acc: 0.8808 - val_loss: 0.2728 - val_acc: 0.8888
#
# Epoch 00024: val_loss improved from 0.27430 to 0.27275, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2391 - acc: 0.9112 - val_loss: 0.2849 - val_acc: 0.8775
#
# Epoch 00025: val_loss did not improve from 0.27275
# Epoch 26/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2324 - acc: 0.9020 - val_loss: 0.3576 - val_acc: 0.8250
#
# Epoch 00026: val_loss did not improve from 0.27275
# Epoch 27/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3092 - acc: 0.8623 - val_loss: 0.2703 - val_acc: 0.8888
#
# Epoch 00027: val_loss improved from 0.27275 to 0.27032, saving model to checkpoint.h5
# Epoch 28/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2722 - acc: 0.8963 - val_loss: 0.2559 - val_acc: 0.8963
#
# Epoch 00028: val_loss improved from 0.27032 to 0.25592, saving model to checkpoint.h5
# Epoch 29/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2517 - acc: 0.8983 - val_loss: 0.3038 - val_acc: 0.8750
#
# Epoch 00029: val_loss did not improve from 0.25592
# Epoch 30/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3056 - acc: 0.8737 - val_loss: 0.2655 - val_acc: 0.8900
#
# Epoch 00030: val_loss did not improve from 0.25592
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2767 - acc: 0.8803 - val_loss: 0.2956 - val_acc: 0.8800
#
# Epoch 00031: val_loss did not improve from 0.25592
# Epoch 32/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2724 - acc: 0.8782 - val_loss: 0.2961 - val_acc: 0.8750
#
# Epoch 00032: val_loss did not improve from 0.25592
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2678 - acc: 0.8928 - val_loss: 0.2633 - val_acc: 0.8913
#
# Epoch 00033: val_loss did not improve from 0.25592
# Epoch 34/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2465 - acc: 0.9095 - val_loss: 0.3010 - val_acc: 0.8625
#
# Epoch 00034: val_loss did not improve from 0.25592
# Epoch 35/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2463 - acc: 0.9062 - val_loss: 0.2710 - val_acc: 0.8938
#
# Epoch 00035: val_loss did not improve from 0.25592
# Epoch 36/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2631 - acc: 0.8941 - val_loss: 0.2502 - val_acc: 0.9062
#
# Epoch 00036: val_loss improved from 0.25592 to 0.25023, saving model to checkpoint.h5
# Epoch 37/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2562 - acc: 0.8988 - val_loss: 0.3571 - val_acc: 0.8400
#
# Epoch 00037: val_loss did not improve from 0.25023
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2587 - acc: 0.8985 - val_loss: 0.2760 - val_acc: 0.8925
#
# Epoch 00038: val_loss did not improve from 0.25023
# Epoch 39/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2724 - acc: 0.8781 - val_loss: 0.2923 - val_acc: 0.8737
#
# Epoch 00039: val_loss did not improve from 0.25023
# Epoch 40/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2479 - acc: 0.8901 - val_loss: 0.2718 - val_acc: 0.8913
#
# Epoch 00040: val_loss did not improve from 0.25023
# Epoch 41/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2672 - acc: 0.8900 - val_loss: 0.2912 - val_acc: 0.8687
#
# Epoch 00041: val_loss did not improve from 0.25023
# Epoch 42/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2430 - acc: 0.8992 - val_loss: 0.2566 - val_acc: 0.9025
#
# Epoch 00042: val_loss did not improve from 0.25023
# Epoch 43/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2503 - acc: 0.8909 - val_loss: 0.2654 - val_acc: 0.9013
#
# Epoch 00043: val_loss did not improve from 0.25023
# Epoch 44/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2875 - acc: 0.8750 - val_loss: 0.2746 - val_acc: 0.8938
#
# Epoch 00044: val_loss did not improve from 0.25023
# Epoch 45/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2397 - acc: 0.9116 - val_loss: 0.2734 - val_acc: 0.8963
#
# Epoch 00045: val_loss did not improve from 0.25023
# Epoch 46/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2330 - acc: 0.9011 - val_loss: 0.2647 - val_acc: 0.8900
#
# Epoch 00046: val_loss did not improve from 0.25023
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2470 - acc: 0.9055 - val_loss: 0.3360 - val_acc: 0.8537
#
# Epoch 00047: val_loss did not improve from 0.25023
# Epoch 48/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2422 - acc: 0.8940 - val_loss: 0.2808 - val_acc: 0.8888
#
# Epoch 00048: val_loss did not improve from 0.25023
# Epoch 49/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2475 - acc: 0.8951 - val_loss: 0.3102 - val_acc: 0.8838
#
# Epoch 00049: val_loss did not improve from 0.25023
# Epoch 50/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2357 - acc: 0.9023 - val_loss: 0.3036 - val_acc: 0.8850
#
# Epoch 00050: val_loss did not improve from 0.25023
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.2771 - acc: 0.8813
#
# ---------------------------------
# Accuracy: 88.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.85      0.88       179
#          1.0       0.85      0.91      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_Flatten_dense_256x1_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 524,801
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 128ms/step - loss: 0.5928 - acc: 0.7715 - val_loss: 0.4228 - val_acc: 0.8112
#
# Epoch 00001: val_loss improved from inf to 0.42284, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5084 - acc: 0.7697 - val_loss: 0.4187 - val_acc: 0.8150
#
# Epoch 00002: val_loss improved from 0.42284 to 0.41867, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4838 - acc: 0.7703 - val_loss: 0.3900 - val_acc: 0.8425
#
# Epoch 00003: val_loss improved from 0.41867 to 0.38998, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4496 - acc: 0.7998 - val_loss: 0.3752 - val_acc: 0.8325
#
# Epoch 00004: val_loss improved from 0.38998 to 0.37515, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4748 - acc: 0.7837 - val_loss: 0.3901 - val_acc: 0.8288
#
# Epoch 00005: val_loss did not improve from 0.37515
# Epoch 6/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4430 - acc: 0.8045 - val_loss: 0.3732 - val_acc: 0.8288
#
# Epoch 00006: val_loss improved from 0.37515 to 0.37317, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4206 - acc: 0.8144 - val_loss: 0.3922 - val_acc: 0.8238
#
# Epoch 00007: val_loss did not improve from 0.37317
# Epoch 8/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4587 - acc: 0.7779 - val_loss: 0.3700 - val_acc: 0.8413
#
# Epoch 00008: val_loss improved from 0.37317 to 0.37000, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4181 - acc: 0.8262 - val_loss: 0.3807 - val_acc: 0.8325
#
# Epoch 00009: val_loss did not improve from 0.37000
# Epoch 10/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4157 - acc: 0.8143 - val_loss: 0.3573 - val_acc: 0.8425
#
# Epoch 00010: val_loss improved from 0.37000 to 0.35731, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4223 - acc: 0.8222 - val_loss: 0.3559 - val_acc: 0.8438
#
# Epoch 00011: val_loss improved from 0.35731 to 0.35587, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3998 - acc: 0.8180 - val_loss: 0.3577 - val_acc: 0.8487
#
# Epoch 00012: val_loss did not improve from 0.35587
# Epoch 13/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4308 - acc: 0.8099 - val_loss: 0.3535 - val_acc: 0.8413
#
# Epoch 00013: val_loss improved from 0.35587 to 0.35347, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4054 - acc: 0.8125 - val_loss: 0.3554 - val_acc: 0.8487
#
# Epoch 00014: val_loss did not improve from 0.35347
# Epoch 15/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4068 - acc: 0.8118 - val_loss: 0.3491 - val_acc: 0.8475
#
# Epoch 00015: val_loss improved from 0.35347 to 0.34906, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fc928650160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc926047550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc927162198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb5079a668>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f324b00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcbb03d0978>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58d1d5c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb58347ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58905518>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb58273668>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc928833198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f324cc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb59e85ef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f5feac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb588a2080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb587a8ef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9271cf2e8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fc9271cfc88>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92687e160>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc930a4ff60>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f6029e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f5d4ef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc927180a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58d2f198>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc928871ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f5e67b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9271dee48>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fc9268bcef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb59e858d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f5fe710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc928871320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcbb01c66a0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc930a32b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc9271c4fd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc928871898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb3f602a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9271c4198>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f602438>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc9268bc470>, <tensorflow.python.keras.layers.core.Activation object at 0x7fcb3f5fe278>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fcb3e1c3748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc930a69b00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc926fbc4e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fc926fe0320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcb3f5fea58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc92687e7b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fc92687e470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fcb58da8b3 ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 22,327,585
# Trainable params: 13,742,977
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 17s 136ms/step - loss: 0.5694 - acc: 0.7976 - val_loss: 0.4000 - val_acc: 0.8325
#
# Epoch 00001: val_loss did not improve from 0.34906
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4545 - acc: 0.7906 - val_loss: 0.3764 - val_acc: 0.8525
#
# Epoch 00002: val_loss did not improve from 0.34906
# Epoch 3/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4055 - acc: 0.8205 - val_loss: 0.4126 - val_acc: 0.8313
#
# Epoch 00003: val_loss did not improve from 0.34906
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4328 - acc: 0.8137 - val_loss: 0.4040 - val_acc: 0.8238
#
# Epoch 00004: val_loss did not improve from 0.34906
# Epoch 5/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3973 - acc: 0.8288 - val_loss: 0.3466 - val_acc: 0.8625
#
# Epoch 00005: val_loss improved from 0.34906 to 0.34657, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3732 - acc: 0.8351 - val_loss: 0.3187 - val_acc: 0.8687
#
# Epoch 00006: val_loss improved from 0.34657 to 0.31869, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3673 - acc: 0.8448 - val_loss: 0.3000 - val_acc: 0.8763
#
# Epoch 00007: val_loss improved from 0.31869 to 0.30005, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3389 - acc: 0.8511 - val_loss: 0.2847 - val_acc: 0.8938
#
# Epoch 00008: val_loss improved from 0.30005 to 0.28469, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3179 - acc: 0.8738 - val_loss: 0.2706 - val_acc: 0.8938
#
# Epoch 00009: val_loss improved from 0.28469 to 0.27065, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3498 - acc: 0.8380 - val_loss: 0.3106 - val_acc: 0.8637
#
# Epoch 00010: val_loss did not improve from 0.27065
# Epoch 11/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3162 - acc: 0.8599 - val_loss: 0.2706 - val_acc: 0.8825
#
# Epoch 00011: val_loss improved from 0.27065 to 0.27065, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3235 - acc: 0.8546 - val_loss: 0.2795 - val_acc: 0.8863
#
# Epoch 00012: val_loss did not improve from 0.27065
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3267 - acc: 0.8686 - val_loss: 0.2775 - val_acc: 0.8687
#
# Epoch 00013: val_loss did not improve from 0.27065
# Epoch 14/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3052 - acc: 0.8639 - val_loss: 0.2542 - val_acc: 0.8838
#
# Epoch 00014: val_loss improved from 0.27065 to 0.25424, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3290 - acc: 0.8594 - val_loss: 0.3350 - val_acc: 0.8712
#
# Epoch 00015: val_loss did not improve from 0.25424
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3272 - acc: 0.8583 - val_loss: 0.2513 - val_acc: 0.8938
#
# Epoch 00016: val_loss improved from 0.25424 to 0.25127, saving model to checkpoint.h5
# Epoch 17/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3095 - acc: 0.8635 - val_loss: 0.2697 - val_acc: 0.8888
#
# Epoch 00017: val_loss did not improve from 0.25127
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3215 - acc: 0.8690 - val_loss: 0.2855 - val_acc: 0.8825
#
# Epoch 00018: val_loss did not improve from 0.25127
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3341 - acc: 0.8566 - val_loss: 0.3100 - val_acc: 0.8775
#
# Epoch 00019: val_loss did not improve from 0.25127
# Epoch 20/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2760 - acc: 0.8914 - val_loss: 0.2439 - val_acc: 0.9075
#
# Epoch 00020: val_loss improved from 0.25127 to 0.24387, saving model to checkpoint.h5
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2948 - acc: 0.8777 - val_loss: 0.2511 - val_acc: 0.8900
#
# Epoch 00021: val_loss did not improve from 0.24387
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3005 - acc: 0.8781 - val_loss: 0.2990 - val_acc: 0.8712
#
# Epoch 00022: val_loss did not improve from 0.24387
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2648 - acc: 0.8976 - val_loss: 0.3564 - val_acc: 0.8200
#
# Epoch 00023: val_loss did not improve from 0.24387
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2920 - acc: 0.8744 - val_loss: 0.2718 - val_acc: 0.8913
#
# Epoch 00024: val_loss did not improve from 0.24387
# Epoch 25/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3093 - acc: 0.8706 - val_loss: 0.2768 - val_acc: 0.8888
#
# Epoch 00025: val_loss did not improve from 0.24387
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2975 - acc: 0.8796 - val_loss: 0.2910 - val_acc: 0.8737
#
# Epoch 00026: val_loss did not improve from 0.24387
# Epoch 27/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2702 - acc: 0.8892 - val_loss: 0.2490 - val_acc: 0.8850
#
# Epoch 00027: val_loss did not improve from 0.24387
# Epoch 28/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2838 - acc: 0.8719 - val_loss: 0.2878 - val_acc: 0.8825
#
# Epoch 00028: val_loss did not improve from 0.24387
# Epoch 29/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3047 - acc: 0.8721 - val_loss: 0.2572 - val_acc: 0.8913
#
# Epoch 00029: val_loss did not improve from 0.24387
# Epoch 30/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2717 - acc: 0.8893 - val_loss: 0.2404 - val_acc: 0.9013
#
# Epoch 00030: val_loss improved from 0.24387 to 0.24042, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2661 - acc: 0.8829 - val_loss: 0.2590 - val_acc: 0.8838
#
# Epoch 00031: val_loss did not improve from 0.24042
# Epoch 32/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2675 - acc: 0.8875 - val_loss: 0.3057 - val_acc: 0.8712
#
# Epoch 00032: val_loss did not improve from 0.24042
# Epoch 33/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2672 - acc: 0.8909 - val_loss: 0.2832 - val_acc: 0.8775
#
# Epoch 00033: val_loss did not improve from 0.24042
# Epoch 34/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2736 - acc: 0.8858 - val_loss: 0.2911 - val_acc: 0.8712
#
# Epoch 00034: val_loss did not improve from 0.24042
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3025 - acc: 0.8689 - val_loss: 0.2583 - val_acc: 0.8963
#
# Epoch 00035: val_loss did not improve from 0.24042
# Epoch 36/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2461 - acc: 0.8973 - val_loss: 0.2713 - val_acc: 0.8825
#
# Epoch 00036: val_loss did not improve from 0.24042
# Epoch 37/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2654 - acc: 0.8896 - val_loss: 0.3562 - val_acc: 0.8388
#
# Epoch 00037: val_loss did not improve from 0.24042
# Epoch 38/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2671 - acc: 0.8902 - val_loss: 0.3528 - val_acc: 0.8200
#
# Epoch 00038: val_loss did not improve from 0.24042
# Epoch 39/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2969 - acc: 0.8772 - val_loss: 0.2615 - val_acc: 0.8913
#
# Epoch 00039: val_loss did not improve from 0.24042
# Epoch 40/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2810 - acc: 0.8838 - val_loss: 0.2825 - val_acc: 0.8850
#
# Epoch 00040: val_loss did not improve from 0.24042
# Epoch 41/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2766 - acc: 0.8859 - val_loss: 0.2458 - val_acc: 0.8938
#
# Epoch 00041: val_loss did not improve from 0.24042
# Epoch 42/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2799 - acc: 0.8826 - val_loss: 0.2827 - val_acc: 0.8675
#
# Epoch 00042: val_loss did not improve from 0.24042
# Epoch 43/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2779 - acc: 0.8835 - val_loss: 0.2426 - val_acc: 0.8950
#
# Epoch 00043: val_loss did not improve from 0.24042
# Epoch 44/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2588 - acc: 0.8820 - val_loss: 0.2713 - val_acc: 0.8813
#
# Epoch 00044: val_loss did not improve from 0.24042
# Epoch 45/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2636 - acc: 0.8868 - val_loss: 0.2475 - val_acc: 0.9062
#
# Epoch 00045: val_loss did not improve from 0.24042
# Epoch 46/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2530 - acc: 0.8930 - val_loss: 0.2503 - val_acc: 0.8938
#
# Epoch 00046: val_loss did not improve from 0.24042
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2502 - acc: 0.8954 - val_loss: 0.2993 - val_acc: 0.8687
#
# Epoch 00047: val_loss did not improve from 0.24042
# Epoch 48/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2650 - acc: 0.8924 - val_loss: 0.2515 - val_acc: 0.9050
#
# Epoch 00048: val_loss did not improve from 0.24042
# Epoch 49/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2948 - acc: 0.8791 - val_loss: 0.2290 - val_acc: 0.8975
#
# Epoch 00049: val_loss improved from 0.24042 to 0.22903, saving model to checkpoint.h5
# Epoch 50/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2623 - acc: 0.8953 - val_loss: 0.2650 - val_acc: 0.8888
#
# Epoch 00050: val_loss did not improve from 0.22903
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.2821 - acc: 0.8687
#
# ---------------------------------
# Accuracy: 86.87 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.86      0.88       179
#          1.0       0.85      0.89      0.87       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_globalAvgPool_dense_256x1_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-6f56e0441ad0> in <module>()
#       1 #free RAM
# ----> 2 del model
#       3 del conv_base
#       4 del history
#       5 get_ipython().system("rm 'checkpoint.h5'")
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, 3x [ DropOut(0.5 + Dense (256)]

# %% [markdown]
# ##Flatten, Non Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 4,850,689
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 23s 132ms/step - loss: 0.6889 - acc: 0.5410 - val_loss: 0.6063 - val_acc: 0.7837
#
# Epoch 00001: val_loss improved from inf to 0.60633, saving model to checkpoint_2.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6529 - acc: 0.6276 - val_loss: 0.5349 - val_acc: 0.7663
#
# Epoch 00002: val_loss improved from 0.60633 to 0.53495, saving model to checkpoint_2.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.6049 - acc: 0.6912 - val_loss: 0.4486 - val_acc: 0.8200
#
# Epoch 00003: val_loss improved from 0.53495 to 0.44857, saving model to checkpoint_2.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5696 - acc: 0.7145 - val_loss: 0.4159 - val_acc: 0.8338
#
# Epoch 00004: val_loss improved from 0.44857 to 0.41586, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5524 - acc: 0.7532 - val_loss: 0.3903 - val_acc: 0.8325
#
# Epoch 00005: val_loss improved from 0.41586 to 0.39029, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5334 - acc: 0.7438 - val_loss: 0.3746 - val_acc: 0.8425
#
# Epoch 00006: val_loss improved from 0.39029 to 0.37460, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5118 - acc: 0.7436 - val_loss: 0.3772 - val_acc: 0.8350
#
# Epoch 00007: val_loss did not improve from 0.37460
# Epoch 8/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5062 - acc: 0.7693 - val_loss: 0.3519 - val_acc: 0.8475
#
# Epoch 00008: val_loss improved from 0.37460 to 0.35193, saving model to checkpoint_2.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5036 - acc: 0.7662 - val_loss: 0.3393 - val_acc: 0.8575
#
# Epoch 00009: val_loss improved from 0.35193 to 0.33933, saving model to checkpoint_2.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5000 - acc: 0.7603 - val_loss: 0.3336 - val_acc: 0.8525
#
# Epoch 00010: val_loss improved from 0.33933 to 0.33365, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4775 - acc: 0.7785 - val_loss: 0.3365 - val_acc: 0.8525
#
# Epoch 00011: val_loss did not improve from 0.33365
# Epoch 12/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4587 - acc: 0.8011 - val_loss: 0.3274 - val_acc: 0.8537
#
# Epoch 00012: val_loss improved from 0.33365 to 0.32737, saving model to checkpoint_2.h5
# Epoch 13/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4717 - acc: 0.7826 - val_loss: 0.3212 - val_acc: 0.8625
#
# Epoch 00013: val_loss improved from 0.32737 to 0.32117, saving model to checkpoint_2.h5
# Epoch 14/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4646 - acc: 0.7867 - val_loss: 0.3203 - val_acc: 0.8587
#
# Epoch 00014: val_loss improved from 0.32117 to 0.32031, saving model to checkpoint_2.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4486 - acc: 0.7980 - val_loss: 0.3236 - val_acc: 0.8637
#
# Epoch 00015: val_loss did not improve from 0.32031
# Epoch 16/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4861 - acc: 0.7698 - val_loss: 0.3207 - val_acc: 0.8550
#
# Epoch 00016: val_loss did not improve from 0.32031
# Epoch 17/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4265 - acc: 0.8042 - val_loss: 0.3252 - val_acc: 0.8600
#
# Epoch 00017: val_loss did not improve from 0.32031
# Epoch 18/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4912 - acc: 0.7747 - val_loss: 0.3311 - val_acc: 0.8575
#
# Epoch 00018: val_loss did not improve from 0.32031
# Epoch 19/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4526 - acc: 0.7985 - val_loss: 0.3255 - val_acc: 0.8612
#
# Epoch 00019: val_loss did not improve from 0.32031
# Epoch 20/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4574 - acc: 0.7967 - val_loss: 0.3261 - val_acc: 0.8587
#
# Epoch 00020: val_loss did not improve from 0.32031
# Epoch 21/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4697 - acc: 0.7863 - val_loss: 0.3215 - val_acc: 0.8587
#
# Epoch 00021: val_loss did not improve from 0.32031
# Epoch 22/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4432 - acc: 0.7959 - val_loss: 0.3199 - val_acc: 0.8612
#
# Epoch 00022: val_loss improved from 0.32031 to 0.31986, saving model to checkpoint_2.h5
# Epoch 23/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4413 - acc: 0.7990 - val_loss: 0.3141 - val_acc: 0.8712
#
# Epoch 00023: val_loss improved from 0.31986 to 0.31413, saving model to checkpoint_2.h5
# Epoch 24/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4574 - acc: 0.7885 - val_loss: 0.3144 - val_acc: 0.8675
#
# Epoch 00024: val_loss did not improve from 0.31413
# Epoch 25/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4537 - acc: 0.7898 - val_loss: 0.3252 - val_acc: 0.8700
#
# Epoch 00025: val_loss did not improve from 0.31413
# Epoch 26/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4508 - acc: 0.7946 - val_loss: 0.3150 - val_acc: 0.8650
#
# Epoch 00026: val_loss did not improve from 0.31413
# Epoch 27/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4346 - acc: 0.8034 - val_loss: 0.3111 - val_acc: 0.8662
#
# Epoch 00027: val_loss improved from 0.31413 to 0.31114, saving model to checkpoint_2.h5
# Epoch 28/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4475 - acc: 0.7886 - val_loss: 0.3046 - val_acc: 0.8725
#
# Epoch 00028: val_loss improved from 0.31114 to 0.30457, saving model to checkpoint_2.h5
# Epoch 29/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4371 - acc: 0.8121 - val_loss: 0.3128 - val_acc: 0.8612
#
# Epoch 00029: val_loss did not improve from 0.30457
# Epoch 30/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4177 - acc: 0.8118 - val_loss: 0.3075 - val_acc: 0.8662
#
# Epoch 00030: val_loss did not improve from 0.30457
# Epoch 31/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4439 - acc: 0.8015 - val_loss: 0.3058 - val_acc: 0.8725
#
# Epoch 00031: val_loss did not improve from 0.30457
# Epoch 32/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4509 - acc: 0.7956 - val_loss: 0.3053 - val_acc: 0.8775
#
# Epoch 00032: val_loss did not improve from 0.30457
# Epoch 33/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4039 - acc: 0.8207 - val_loss: 0.3021 - val_acc: 0.8775
#
# Epoch 00033: val_loss improved from 0.30457 to 0.30206, saving model to checkpoint_2.h5
# Epoch 34/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4210 - acc: 0.7900 - val_loss: 0.3089 - val_acc: 0.8687
#
# Epoch 00034: val_loss did not improve from 0.30206
# Epoch 35/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4378 - acc: 0.7985 - val_loss: 0.3089 - val_acc: 0.8712
#
# Epoch 00035: val_loss did not improve from 0.30206
# Epoch 36/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4035 - acc: 0.8158 - val_loss: 0.3098 - val_acc: 0.8737
#
# Epoch 00036: val_loss did not improve from 0.30206
# Epoch 37/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4424 - acc: 0.7997 - val_loss: 0.3101 - val_acc: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.30206
# Epoch 38/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4298 - acc: 0.8034 - val_loss: 0.3098 - val_acc: 0.8650
#
# Epoch 00038: val_loss did not improve from 0.30206
# Epoch 39/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4091 - acc: 0.8216 - val_loss: 0.3035 - val_acc: 0.8637
#
# Epoch 00039: val_loss did not improve from 0.30206
# Epoch 40/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4466 - acc: 0.7960 - val_loss: 0.3152 - val_acc: 0.8687
#
# Epoch 00040: val_loss did not improve from 0.30206
# Epoch 41/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4366 - acc: 0.8065 - val_loss: 0.3183 - val_acc: 0.8662
#
# Epoch 00041: val_loss did not improve from 0.30206
# Epoch 42/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4438 - acc: 0.8134 - val_loss: 0.3214 - val_acc: 0.8700
#
# Epoch 00042: val_loss did not improve from 0.30206
# Epoch 43/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4567 - acc: 0.8027 - val_loss: 0.3142 - val_acc: 0.8775
#
# Epoch 00043: val_loss did not improve from 0.30206
# Epoch 44/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4128 - acc: 0.8126 - val_loss: 0.3123 - val_acc: 0.8737
#
# Epoch 00044: val_loss did not improve from 0.30206
# Epoch 45/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4271 - acc: 0.8041 - val_loss: 0.3161 - val_acc: 0.8650
#
# Epoch 00045: val_loss did not improve from 0.30206
# Epoch 46/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3994 - acc: 0.8149 - val_loss: 0.3128 - val_acc: 0.8700
#
# Epoch 00046: val_loss did not improve from 0.30206
# Epoch 47/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4285 - acc: 0.8060 - val_loss: 0.3137 - val_acc: 0.8737
#
# Epoch 00047: val_loss did not improve from 0.30206
# Epoch 48/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4239 - acc: 0.8092 - val_loss: 0.3096 - val_acc: 0.8750
#
# Epoch 00048: val_loss did not improve from 0.30206
# Epoch 49/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4276 - acc: 0.7944 - val_loss: 0.3211 - val_acc: 0.8737
#
# Epoch 00049: val_loss did not improve from 0.30206
# Epoch 50/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3941 - acc: 0.8384 - val_loss: 0.3113 - val_acc: 0.8662
#
# Epoch 00050: val_loss did not improve from 0.30206

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3752 - acc: 0.8313
#
# ---------------------------------
# Accuracy: 83.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       179
#          1.0       0.81      0.83      0.82       157
#
#     accuracy                           0.83       336
#    macro avg       0.83      0.83      0.83       336
# weighted avg       0.83      0.83      0.83       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')

#unfreeze last convolutional block
conv_base.trainable = True


for layer in conv_base.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 4,850,689
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 129ms/step - loss: 0.9642 - acc: 0.7270 - val_loss: 0.5226 - val_acc: 0.7925
#
# Epoch 00001: val_loss improved from inf to 0.52259, saving model to checkpoint_2.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6317 - acc: 0.6987 - val_loss: 0.4344 - val_acc: 0.8125
#
# Epoch 00002: val_loss improved from 0.52259 to 0.43441, saving model to checkpoint_2.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5765 - acc: 0.7367 - val_loss: 0.3832 - val_acc: 0.8375
#
# Epoch 00003: val_loss improved from 0.43441 to 0.38323, saving model to checkpoint_2.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5687 - acc: 0.7428 - val_loss: 0.3521 - val_acc: 0.8438
#
# Epoch 00004: val_loss improved from 0.38323 to 0.35209, saving model to checkpoint_2.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5215 - acc: 0.7546 - val_loss: 0.3736 - val_acc: 0.8500
#
# Epoch 00005: val_loss did not improve from 0.35209
# Epoch 6/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5075 - acc: 0.7560 - val_loss: 0.3869 - val_acc: 0.8475
#
# Epoch 00006: val_loss did not improve from 0.35209
# Epoch 7/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5081 - acc: 0.7560 - val_loss: 0.3452 - val_acc: 0.8625
#
# Epoch 00007: val_loss improved from 0.35209 to 0.34516, saving model to checkpoint_2.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5141 - acc: 0.7490 - val_loss: 0.4003 - val_acc: 0.8238
#
# Epoch 00008: val_loss did not improve from 0.34516
# Epoch 9/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5224 - acc: 0.7579 - val_loss: 0.3385 - val_acc: 0.8475
#
# Epoch 00009: val_loss improved from 0.34516 to 0.33849, saving model to checkpoint_2.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4810 - acc: 0.7871 - val_loss: 0.3383 - val_acc: 0.8625
#
# Epoch 00010: val_loss improved from 0.33849 to 0.33834, saving model to checkpoint_2.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4699 - acc: 0.7742 - val_loss: 0.3793 - val_acc: 0.8662
#
# Epoch 00011: val_loss did not improve from 0.33834
# Epoch 12/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4558 - acc: 0.7740 - val_loss: 0.3786 - val_acc: 0.8512
#
# Epoch 00012: val_loss did not improve from 0.33834
# Epoch 13/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4843 - acc: 0.7760 - val_loss: 0.3767 - val_acc: 0.8537
#
# Epoch 00013: val_loss did not improve from 0.33834
# Epoch 14/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4943 - acc: 0.7498 - val_loss: 0.3703 - val_acc: 0.8537
#
# Epoch 00014: val_loss did not improve from 0.33834
# Epoch 15/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4878 - acc: 0.7796 - val_loss: 0.3561 - val_acc: 0.8475
#
# Epoch 00015: val_loss did not improve from 0.33834
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f56d6e4df60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56d6eb2080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d6ed8320>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56d677e0b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56dfdebef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56dfdf7978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56dfdd3668>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56d6e5a978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56dfdf0cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56dfdf4cc0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f56dfdf4160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56dfdf03c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56dfdfd5f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56dfdd8c88>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de74f748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56dfdd8828>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de758128>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f56de75c710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de777a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de77c630>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de77cc88>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de767748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de76c320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de767320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de782c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de75d710>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de786c18>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f56de71a860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de75cb00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de76cd30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de78d5c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de7234a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de7587b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de773860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de70e1d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de725128>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de75d0f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de76c6a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de70ef60>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de725f60>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f56de71a128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de72c2b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de70eba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de732f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de71ab38>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de73a4a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de7588d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de73a82 ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 26,619,041
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 20s 150ms/step - loss: 0.6578 - acc: 0.7755 - val_loss: 0.5563 - val_acc: 0.7513
#
# Epoch 00001: val_loss did not improve from 0.33834
# Epoch 2/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.4304 - acc: 0.8234 - val_loss: 0.3824 - val_acc: 0.8375
#
# Epoch 00002: val_loss did not improve from 0.33834
# Epoch 3/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4162 - acc: 0.8085 - val_loss: 0.4054 - val_acc: 0.8750
#
# Epoch 00003: val_loss did not improve from 0.33834
# Epoch 4/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3746 - acc: 0.8402 - val_loss: 0.3713 - val_acc: 0.8263
#
# Epoch 00004: val_loss did not improve from 0.33834
# Epoch 5/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4186 - acc: 0.8287 - val_loss: 0.2729 - val_acc: 0.9025
#
# Epoch 00005: val_loss improved from 0.33834 to 0.27291, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3637 - acc: 0.8430 - val_loss: 0.2568 - val_acc: 0.9137
#
# Epoch 00006: val_loss improved from 0.27291 to 0.25680, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2974 - acc: 0.8731 - val_loss: 0.2253 - val_acc: 0.9150
#
# Epoch 00007: val_loss improved from 0.25680 to 0.22527, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3194 - acc: 0.8751 - val_loss: 0.3293 - val_acc: 0.8562
#
# Epoch 00008: val_loss did not improve from 0.22527
# Epoch 9/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3019 - acc: 0.8873 - val_loss: 0.3977 - val_acc: 0.8275
#
# Epoch 00009: val_loss did not improve from 0.22527
# Epoch 10/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3287 - acc: 0.8690 - val_loss: 0.3720 - val_acc: 0.8000
#
# Epoch 00010: val_loss did not improve from 0.22527
# Epoch 11/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2857 - acc: 0.8867 - val_loss: 0.2638 - val_acc: 0.8875
#
# Epoch 00011: val_loss did not improve from 0.22527
# Epoch 12/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.3542 - acc: 0.8804 - val_loss: 0.3302 - val_acc: 0.8313
#
# Epoch 00012: val_loss did not improve from 0.22527
# Epoch 13/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2732 - acc: 0.8988 - val_loss: 0.3011 - val_acc: 0.8900
#
# Epoch 00013: val_loss did not improve from 0.22527
# Epoch 14/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2718 - acc: 0.9018 - val_loss: 0.3348 - val_acc: 0.8662
#
# Epoch 00014: val_loss did not improve from 0.22527
# Epoch 15/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2204 - acc: 0.9238 - val_loss: 0.4156 - val_acc: 0.8313
#
# Epoch 00015: val_loss did not improve from 0.22527
# Epoch 16/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2801 - acc: 0.8893 - val_loss: 0.2435 - val_acc: 0.9137
#
# Epoch 00016: val_loss did not improve from 0.22527
# Epoch 17/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2578 - acc: 0.8939 - val_loss: 0.2512 - val_acc: 0.9112
#
# Epoch 00017: val_loss did not improve from 0.22527
# Epoch 18/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2685 - acc: 0.8928 - val_loss: 0.3915 - val_acc: 0.8625
#
# Epoch 00018: val_loss did not improve from 0.22527
# Epoch 19/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2592 - acc: 0.9002 - val_loss: 0.3170 - val_acc: 0.8662
#
# Epoch 00019: val_loss did not improve from 0.22527
# Epoch 20/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2443 - acc: 0.9125 - val_loss: 0.2853 - val_acc: 0.8800
#
# Epoch 00020: val_loss did not improve from 0.22527
# Epoch 21/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2168 - acc: 0.9286 - val_loss: 0.2658 - val_acc: 0.9050
#
# Epoch 00021: val_loss did not improve from 0.22527
# Epoch 22/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2396 - acc: 0.9088 - val_loss: 0.2537 - val_acc: 0.9013
#
# Epoch 00022: val_loss did not improve from 0.22527
# Epoch 23/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2406 - acc: 0.9222 - val_loss: 0.3046 - val_acc: 0.8737
#
# Epoch 00023: val_loss did not improve from 0.22527
# Epoch 24/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2321 - acc: 0.9065 - val_loss: 0.3168 - val_acc: 0.8662
#
# Epoch 00024: val_loss did not improve from 0.22527
# Epoch 25/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2104 - acc: 0.9169 - val_loss: 0.3320 - val_acc: 0.8700
#
# Epoch 00025: val_loss did not improve from 0.22527
# Epoch 26/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2182 - acc: 0.9093 - val_loss: 0.2637 - val_acc: 0.8938
#
# Epoch 00026: val_loss did not improve from 0.22527
# Epoch 27/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2134 - acc: 0.9043 - val_loss: 0.2551 - val_acc: 0.9050
#
# Epoch 00027: val_loss did not improve from 0.22527
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2825 - acc: 0.8781
#
# ---------------------------------
# Accuracy: 87.81 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.86      0.88       179
#          1.0       0.85      0.89      0.87       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True

for layer in conv_base.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 656,385
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 129ms/step - loss: 0.7216 - acc: 0.6608 - val_loss: 0.5709 - val_acc: 0.7638
#
# Epoch 00001: val_loss improved from inf to 0.57086, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6027 - acc: 0.6887 - val_loss: 0.4552 - val_acc: 0.8225
#
# Epoch 00002: val_loss improved from 0.57086 to 0.45516, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5785 - acc: 0.7362 - val_loss: 0.4176 - val_acc: 0.8238
#
# Epoch 00003: val_loss improved from 0.45516 to 0.41761, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5738 - acc: 0.7238 - val_loss: 0.4179 - val_acc: 0.8363
#
# Epoch 00004: val_loss did not improve from 0.41761
# Epoch 5/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5267 - acc: 0.7464 - val_loss: 0.3897 - val_acc: 0.8400
#
# Epoch 00005: val_loss improved from 0.41761 to 0.38968, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5258 - acc: 0.7538 - val_loss: 0.3773 - val_acc: 0.8438
#
# Epoch 00006: val_loss improved from 0.38968 to 0.37729, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5223 - acc: 0.7508 - val_loss: 0.3927 - val_acc: 0.8388
#
# Epoch 00007: val_loss did not improve from 0.37729
# Epoch 8/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5238 - acc: 0.7443 - val_loss: 0.3978 - val_acc: 0.8363
#
# Epoch 00008: val_loss did not improve from 0.37729
# Epoch 9/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5237 - acc: 0.7440 - val_loss: 0.3710 - val_acc: 0.8438
#
# Epoch 00009: val_loss improved from 0.37729 to 0.37095, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.5011 - acc: 0.7530 - val_loss: 0.3779 - val_acc: 0.8475
#
# Epoch 00010: val_loss did not improve from 0.37095
# Epoch 11/15
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4961 - acc: 0.7742 - val_loss: 0.3914 - val_acc: 0.8487
#
# Epoch 00011: val_loss did not improve from 0.37095
# Epoch 12/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4996 - acc: 0.7643 - val_loss: 0.3694 - val_acc: 0.8413
#
# Epoch 00012: val_loss improved from 0.37095 to 0.36938, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4878 - acc: 0.7680 - val_loss: 0.3829 - val_acc: 0.8512
#
# Epoch 00013: val_loss did not improve from 0.36938
# Epoch 14/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5159 - acc: 0.7716 - val_loss: 0.3698 - val_acc: 0.8487
#
# Epoch 00014: val_loss did not improve from 0.36938
# Epoch 15/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4615 - acc: 0.7962 - val_loss: 0.3889 - val_acc: 0.8500
#
# Epoch 00015: val_loss did not improve from 0.36938
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f54accf9470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de590c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56de3ef780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac7ef240>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54acd5a550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acd57ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54acc6b828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac85bef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac92c4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac92c0f0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f54aca7a160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac99e4a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54aca56cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac9b2780>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de4f86d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acc155c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54addeb7b8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f54acace080>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac92c828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac7bca20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54aca03048>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac92cb70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54acc6b668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54aca7a828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54accf65c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac860d30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac7fdba8>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f56de43ff98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54aca7ae10>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac9b22b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54accf6b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac7fd048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acbd9240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac850470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54accf66d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac7fdf28>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac8e4128>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54acda1be0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac9efd30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54acd7b320>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f56de3e7898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac9b2e10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac747dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54acd89dd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54accf6c50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54acc48b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acc48a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac752a2 ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 22,424,737
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 19s 146ms/step - loss: 0.6841 - acc: 0.7773 - val_loss: 0.4971 - val_acc: 0.7688
#
# Epoch 00001: val_loss did not improve from 0.36938
# Epoch 2/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.3984 - acc: 0.8234 - val_loss: 0.4260 - val_acc: 0.8288
#
# Epoch 00002: val_loss did not improve from 0.36938
# Epoch 3/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3758 - acc: 0.8264 - val_loss: 0.2790 - val_acc: 0.8913
#
# Epoch 00003: val_loss improved from 0.36938 to 0.27900, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3590 - acc: 0.8498 - val_loss: 0.2942 - val_acc: 0.9050
#
# Epoch 00004: val_loss did not improve from 0.27900
# Epoch 5/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3374 - acc: 0.8722 - val_loss: 0.3054 - val_acc: 0.9075
#
# Epoch 00005: val_loss did not improve from 0.27900
# Epoch 6/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3142 - acc: 0.8716 - val_loss: 0.3032 - val_acc: 0.8963
#
# Epoch 00006: val_loss did not improve from 0.27900
# Epoch 7/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3076 - acc: 0.8547 - val_loss: 0.2972 - val_acc: 0.8950
#
# Epoch 00007: val_loss did not improve from 0.27900
# Epoch 8/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3329 - acc: 0.8756 - val_loss: 0.2730 - val_acc: 0.9100
#
# Epoch 00008: val_loss improved from 0.27900 to 0.27296, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2942 - acc: 0.8798 - val_loss: 0.2628 - val_acc: 0.9062
#
# Epoch 00009: val_loss improved from 0.27296 to 0.26283, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2622 - acc: 0.8967 - val_loss: 0.2777 - val_acc: 0.9050
#
# Epoch 00010: val_loss did not improve from 0.26283
# Epoch 11/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2998 - acc: 0.8703 - val_loss: 0.2829 - val_acc: 0.9000
#
# Epoch 00011: val_loss did not improve from 0.26283
# Epoch 12/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2624 - acc: 0.9009 - val_loss: 0.2773 - val_acc: 0.9038
#
# Epoch 00012: val_loss did not improve from 0.26283
# Epoch 13/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2753 - acc: 0.8929 - val_loss: 0.2367 - val_acc: 0.9225
#
# Epoch 00013: val_loss improved from 0.26283 to 0.23675, saving model to checkpoint.h5
# Epoch 14/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2270 - acc: 0.9098 - val_loss: 0.2478 - val_acc: 0.9025
#
# Epoch 00014: val_loss did not improve from 0.23675
# Epoch 15/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2181 - acc: 0.9061 - val_loss: 0.2864 - val_acc: 0.8950
#
# Epoch 00015: val_loss did not improve from 0.23675
# Epoch 16/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2551 - acc: 0.8964 - val_loss: 0.3567 - val_acc: 0.8775
#
# Epoch 00016: val_loss did not improve from 0.23675
# Epoch 17/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2162 - acc: 0.9098 - val_loss: 0.2665 - val_acc: 0.9100
#
# Epoch 00017: val_loss did not improve from 0.23675
# Epoch 18/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2269 - acc: 0.9156 - val_loss: 0.2587 - val_acc: 0.8975
#
# Epoch 00018: val_loss did not improve from 0.23675
# Epoch 19/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2356 - acc: 0.9157 - val_loss: 0.2696 - val_acc: 0.9087
#
# Epoch 00019: val_loss did not improve from 0.23675
# Epoch 20/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2130 - acc: 0.9131 - val_loss: 0.2207 - val_acc: 0.9150
#
# Epoch 00020: val_loss improved from 0.23675 to 0.22068, saving model to checkpoint.h5
# Epoch 21/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1895 - acc: 0.9300 - val_loss: 0.2972 - val_acc: 0.8662
#
# Epoch 00021: val_loss did not improve from 0.22068
# Epoch 22/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2095 - acc: 0.9271 - val_loss: 0.3510 - val_acc: 0.8650
#
# Epoch 00022: val_loss did not improve from 0.22068
# Epoch 23/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2122 - acc: 0.9081 - val_loss: 0.2289 - val_acc: 0.9175
#
# Epoch 00023: val_loss did not improve from 0.22068
# Epoch 24/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.2028 - acc: 0.9237 - val_loss: 0.2786 - val_acc: 0.8863
#
# Epoch 00024: val_loss did not improve from 0.22068
# Epoch 25/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2197 - acc: 0.9158 - val_loss: 0.3484 - val_acc: 0.8413
#
# Epoch 00025: val_loss did not improve from 0.22068
# Epoch 26/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1547 - acc: 0.9392 - val_loss: 0.2663 - val_acc: 0.8950
#
# Epoch 00026: val_loss did not improve from 0.22068
# Epoch 27/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1834 - acc: 0.9328 - val_loss: 0.3631 - val_acc: 0.8150
#
# Epoch 00027: val_loss did not improve from 0.22068
# Epoch 28/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1661 - acc: 0.9406 - val_loss: 0.2229 - val_acc: 0.9187
#
# Epoch 00028: val_loss did not improve from 0.22068
# Epoch 29/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1963 - acc: 0.9276 - val_loss: 0.2417 - val_acc: 0.9050
#
# Epoch 00029: val_loss did not improve from 0.22068
# Epoch 30/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1854 - acc: 0.9397 - val_loss: 0.2423 - val_acc: 0.9038
#
# Epoch 00030: val_loss did not improve from 0.22068
# Epoch 31/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2095 - acc: 0.9103 - val_loss: 0.2218 - val_acc: 0.9225
#
# Epoch 00031: val_loss did not improve from 0.22068
# Epoch 32/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.1816 - acc: 0.9290 - val_loss: 0.2924 - val_acc: 0.8938
#
# Epoch 00032: val_loss did not improve from 0.22068
# Epoch 33/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1950 - acc: 0.9259 - val_loss: 0.2206 - val_acc: 0.9125
#
# Epoch 00033: val_loss improved from 0.22068 to 0.22063, saving model to checkpoint.h5
# Epoch 34/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1883 - acc: 0.9195 - val_loss: 0.2137 - val_acc: 0.9125
#
# Epoch 00034: val_loss improved from 0.22063 to 0.21372, saving model to checkpoint.h5
# Epoch 35/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1551 - acc: 0.9321 - val_loss: 0.2924 - val_acc: 0.8737
#
# Epoch 00035: val_loss did not improve from 0.21372
# Epoch 36/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1693 - acc: 0.9340 - val_loss: 0.2194 - val_acc: 0.9162
#
# Epoch 00036: val_loss did not improve from 0.21372
# Epoch 37/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1843 - acc: 0.9449 - val_loss: 0.2500 - val_acc: 0.9137
#
# Epoch 00037: val_loss did not improve from 0.21372
# Epoch 38/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1775 - acc: 0.9276 - val_loss: 0.2637 - val_acc: 0.9013
#
# Epoch 00038: val_loss did not improve from 0.21372
# Epoch 39/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1603 - acc: 0.9372 - val_loss: 0.2470 - val_acc: 0.9050
#
# Epoch 00039: val_loss did not improve from 0.21372
# Epoch 40/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1666 - acc: 0.9391 - val_loss: 0.3495 - val_acc: 0.8475
#
# Epoch 00040: val_loss did not improve from 0.21372
# Epoch 41/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1744 - acc: 0.9431 - val_loss: 0.2249 - val_acc: 0.9200
#
# Epoch 00041: val_loss did not improve from 0.21372
# Epoch 42/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1309 - acc: 0.9503 - val_loss: 0.2148 - val_acc: 0.9325
#
# Epoch 00042: val_loss did not improve from 0.21372
# Epoch 43/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1728 - acc: 0.9303 - val_loss: 0.3331 - val_acc: 0.8712
#
# Epoch 00043: val_loss did not improve from 0.21372
# Epoch 44/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1494 - acc: 0.9411 - val_loss: 0.2661 - val_acc: 0.9100
#
# Epoch 00044: val_loss did not improve from 0.21372
# Epoch 45/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1635 - acc: 0.9439 - val_loss: 0.2328 - val_acc: 0.9162
#
# Epoch 00045: val_loss did not improve from 0.21372
# Epoch 46/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1671 - acc: 0.9345 - val_loss: 0.2857 - val_acc: 0.8900
#
# Epoch 00046: val_loss did not improve from 0.21372
# Epoch 47/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1826 - acc: 0.9276 - val_loss: 0.2184 - val_acc: 0.9300
#
# Epoch 00047: val_loss did not improve from 0.21372
# Epoch 48/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1582 - acc: 0.9337 - val_loss: 0.2155 - val_acc: 0.9162
#
# Epoch 00048: val_loss did not improve from 0.21372
# Epoch 49/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1635 - acc: 0.9347 - val_loss: 0.2911 - val_acc: 0.8750
#
# Epoch 00049: val_loss did not improve from 0.21372
# Epoch 50/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1609 - acc: 0.9374 - val_loss: 0.2721 - val_acc: 0.8950
#
# Epoch 00050: val_loss did not improve from 0.21372
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2494 - acc: 0.9000
#
# ---------------------------------
# Accuracy: 90.00 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90       179
#          1.0       0.89      0.89      0.89       157
#
#     accuracy                           0.90       336
#    macro avg       0.90      0.90      0.90       336
# weighted avg       0.90      0.90      0.90       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_globalAvgPool_dense_256x3_all_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'
# Out:
# rm: cannot remove 'checkpoint_2.h5': No such file or directory

# %% [markdown]
# ## Flatten, Last Block Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last Inception module
for layer in conv_base.layers[:280]:
   layer.trainable = False
for layer in conv_base.layers[280:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 4,850,689
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 135ms/step - loss: 0.8679 - acc: 0.6825 - val_loss: 0.5121 - val_acc: 0.7800
#
# Epoch 00001: val_loss improved from inf to 0.51214, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6276 - acc: 0.7180 - val_loss: 0.4695 - val_acc: 0.7912
#
# Epoch 00002: val_loss improved from 0.51214 to 0.46946, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5527 - acc: 0.7370 - val_loss: 0.4092 - val_acc: 0.8150
#
# Epoch 00003: val_loss improved from 0.46946 to 0.40917, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5447 - acc: 0.7577 - val_loss: 0.4027 - val_acc: 0.8313
#
# Epoch 00004: val_loss improved from 0.40917 to 0.40270, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5582 - acc: 0.7528 - val_loss: 0.3943 - val_acc: 0.8325
#
# Epoch 00005: val_loss improved from 0.40270 to 0.39432, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4975 - acc: 0.7629 - val_loss: 0.3876 - val_acc: 0.8163
#
# Epoch 00006: val_loss improved from 0.39432 to 0.38760, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5061 - acc: 0.7576 - val_loss: 0.3936 - val_acc: 0.8175
#
# Epoch 00007: val_loss did not improve from 0.38760
# Epoch 8/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4948 - acc: 0.7823 - val_loss: 0.3917 - val_acc: 0.8350
#
# Epoch 00008: val_loss did not improve from 0.38760
# Epoch 9/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4632 - acc: 0.7856 - val_loss: 0.3915 - val_acc: 0.8425
#
# Epoch 00009: val_loss did not improve from 0.38760
# Epoch 10/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4883 - acc: 0.7706 - val_loss: 0.3596 - val_acc: 0.8462
#
# Epoch 00010: val_loss improved from 0.38760 to 0.35959, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4890 - acc: 0.7741 - val_loss: 0.3862 - val_acc: 0.8450
#
# Epoch 00011: val_loss did not improve from 0.35959
# Epoch 12/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4877 - acc: 0.7858 - val_loss: 0.3705 - val_acc: 0.8500
#
# Epoch 00012: val_loss did not improve from 0.35959
# Epoch 13/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4781 - acc: 0.7880 - val_loss: 0.3731 - val_acc: 0.8450
#
# Epoch 00013: val_loss did not improve from 0.35959
# Epoch 14/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5004 - acc: 0.7782 - val_loss: 0.3900 - val_acc: 0.8438
#
# Epoch 00014: val_loss did not improve from 0.35959
# Epoch 15/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4444 - acc: 0.7905 - val_loss: 0.3619 - val_acc: 0.8425
#
# Epoch 00015: val_loss did not improve from 0.35959
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f56c5787fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac44a978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7c30ac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ade65ac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7d05128>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54adf187f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ade41c50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac44a3c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56c568e908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56d633c748>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f56c565b860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7d05710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d612bfd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7a630f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac6582b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56c568ec50>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de0ab438>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f56c426f470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7e1be10>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d611f7b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56c4279c50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c56971d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56d611ff60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7c0c320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54adf10160>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de07c828>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56d60b2198>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f56de0a8390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c5697198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7c0ce80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c4279160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de07c9e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acc7a940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54adf102e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d63370b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d64edac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54adf10898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56c4279710>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7e17a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56c5480f98>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f54ac455898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56d611fe80>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56c436a860>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54adf4b828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7e306d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56d634bd30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d650d438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56c437c9e ...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 10,924,225
# Non-trainable params: 15,729,248
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 135ms/step - loss: 0.5515 - acc: 0.8023 - val_loss: 0.4347 - val_acc: 0.7925
#
# Epoch 00001: val_loss did not improve from 0.35959
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4831 - acc: 0.7775 - val_loss: 0.3578 - val_acc: 0.8512
#
# Epoch 00002: val_loss improved from 0.35959 to 0.35780, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4923 - acc: 0.7967 - val_loss: 0.3768 - val_acc: 0.8550
#
# Epoch 00003: val_loss did not improve from 0.35780
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4442 - acc: 0.7836 - val_loss: 0.3266 - val_acc: 0.8587
#
# Epoch 00004: val_loss improved from 0.35780 to 0.32659, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4114 - acc: 0.8192 - val_loss: 0.3234 - val_acc: 0.8550
#
# Epoch 00005: val_loss improved from 0.32659 to 0.32338, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4175 - acc: 0.8145 - val_loss: 0.3576 - val_acc: 0.8562
#
# Epoch 00006: val_loss did not improve from 0.32338
# Epoch 7/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4282 - acc: 0.8127 - val_loss: 0.3313 - val_acc: 0.8600
#
# Epoch 00007: val_loss did not improve from 0.32338
# Epoch 8/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4119 - acc: 0.8250 - val_loss: 0.3439 - val_acc: 0.8587
#
# Epoch 00008: val_loss did not improve from 0.32338
# Epoch 9/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3719 - acc: 0.8539 - val_loss: 0.3706 - val_acc: 0.8537
#
# Epoch 00009: val_loss did not improve from 0.32338
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4183 - acc: 0.8113 - val_loss: 0.3644 - val_acc: 0.8500
#
# Epoch 00010: val_loss did not improve from 0.32338
# Epoch 11/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4255 - acc: 0.8097 - val_loss: 0.3695 - val_acc: 0.8388
#
# Epoch 00011: val_loss did not improve from 0.32338
# Epoch 12/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4086 - acc: 0.8185 - val_loss: 0.3709 - val_acc: 0.8625
#
# Epoch 00012: val_loss did not improve from 0.32338
# Epoch 13/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3516 - acc: 0.8526 - val_loss: 0.3648 - val_acc: 0.8587
#
# Epoch 00013: val_loss did not improve from 0.32338
# Epoch 14/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3674 - acc: 0.8469 - val_loss: 0.3800 - val_acc: 0.8462
#
# Epoch 00014: val_loss did not improve from 0.32338
# Epoch 15/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3797 - acc: 0.8274 - val_loss: 0.3879 - val_acc: 0.8500
#
# Epoch 00015: val_loss did not improve from 0.32338
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4046 - acc: 0.8107 - val_loss: 0.3768 - val_acc: 0.8338
#
# Epoch 00016: val_loss did not improve from 0.32338
# Epoch 17/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3940 - acc: 0.8355 - val_loss: 0.3552 - val_acc: 0.8562
#
# Epoch 00017: val_loss did not improve from 0.32338
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3916 - acc: 0.8259 - val_loss: 0.3800 - val_acc: 0.8600
#
# Epoch 00018: val_loss did not improve from 0.32338
# Epoch 19/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3741 - acc: 0.8372 - val_loss: 0.3524 - val_acc: 0.8712
#
# Epoch 00019: val_loss did not improve from 0.32338
# Epoch 20/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3420 - acc: 0.8492 - val_loss: 0.3658 - val_acc: 0.8462
#
# Epoch 00020: val_loss did not improve from 0.32338
# Epoch 21/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3722 - acc: 0.8424 - val_loss: 0.3413 - val_acc: 0.8650
#
# Epoch 00021: val_loss did not improve from 0.32338
# Epoch 22/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3625 - acc: 0.8400 - val_loss: 0.3322 - val_acc: 0.8750
#
# Epoch 00022: val_loss did not improve from 0.32338
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3314 - acc: 0.8555 - val_loss: 0.3397 - val_acc: 0.8687
#
# Epoch 00023: val_loss did not improve from 0.32338
# Epoch 24/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3613 - acc: 0.8362 - val_loss: 0.3706 - val_acc: 0.8313
#
# Epoch 00024: val_loss did not improve from 0.32338
# Epoch 25/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3466 - acc: 0.8496 - val_loss: 0.3610 - val_acc: 0.8725
#
# Epoch 00025: val_loss did not improve from 0.32338
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3558 - acc: 0.8406
#
# ---------------------------------
# Accuracy: 84.06 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       179
#          1.0       0.81      0.83      0.82       157
#
#     accuracy                           0.83       336
#    macro avg       0.83      0.83      0.83       336
# weighted avg       0.83      0.83      0.83       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x3_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 2 Inception modules	
for layer in conv_base.layers[:249]:
   layer.trainable = False
for layer in conv_base.layers[249:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 4,850,689
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 22s 135ms/step - loss: 0.9252 - acc: 0.6038 - val_loss: 0.5001 - val_acc: 0.8087
#
# Epoch 00001: val_loss improved from inf to 0.50005, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6120 - acc: 0.7158 - val_loss: 0.4658 - val_acc: 0.7937
#
# Epoch 00002: val_loss improved from 0.50005 to 0.46577, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5481 - acc: 0.7428 - val_loss: 0.4467 - val_acc: 0.8125
#
# Epoch 00003: val_loss improved from 0.46577 to 0.44666, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5288 - acc: 0.7354 - val_loss: 0.4318 - val_acc: 0.8263
#
# Epoch 00004: val_loss improved from 0.44666 to 0.43175, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.4941 - acc: 0.7748 - val_loss: 0.4025 - val_acc: 0.8263
#
# Epoch 00005: val_loss improved from 0.43175 to 0.40250, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.5008 - acc: 0.7614 - val_loss: 0.4171 - val_acc: 0.8275
#
# Epoch 00006: val_loss did not improve from 0.40250
# Epoch 7/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5104 - acc: 0.7615 - val_loss: 0.4038 - val_acc: 0.8263
#
# Epoch 00007: val_loss did not improve from 0.40250
# Epoch 8/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4890 - acc: 0.7747 - val_loss: 0.4050 - val_acc: 0.8175
#
# Epoch 00008: val_loss did not improve from 0.40250
# Epoch 9/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4922 - acc: 0.7749 - val_loss: 0.3884 - val_acc: 0.8250
#
# Epoch 00009: val_loss improved from 0.40250 to 0.38843, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4856 - acc: 0.7688 - val_loss: 0.3789 - val_acc: 0.8375
#
# Epoch 00010: val_loss improved from 0.38843 to 0.37887, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4811 - acc: 0.7832 - val_loss: 0.3978 - val_acc: 0.8325
#
# Epoch 00011: val_loss did not improve from 0.37887
# Epoch 12/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4771 - acc: 0.7839 - val_loss: 0.4066 - val_acc: 0.8375
#
# Epoch 00012: val_loss did not improve from 0.37887
# Epoch 13/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4671 - acc: 0.7906 - val_loss: 0.3906 - val_acc: 0.8363
#
# Epoch 00013: val_loss did not improve from 0.37887
# Epoch 14/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4576 - acc: 0.7908 - val_loss: 0.3925 - val_acc: 0.8263
#
# Epoch 00014: val_loss did not improve from 0.37887
# Epoch 15/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4479 - acc: 0.7978 - val_loss: 0.4132 - val_acc: 0.8338
#
# Epoch 00015: val_loss did not improve from 0.37887
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f21b8ae79b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f21b8ae7dd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f21b8a8a3c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21b8a8aba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e68f278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e68fe48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e61ee48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e6257f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e62a400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e632940>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f211e625f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e63a828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e63d358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e63d588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e645860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e64d470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e645a58>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f211e651cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5f1048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e608f98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e610f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5e9860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e608048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5e7470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e59e518>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5e9a58>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5a6390>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f211e5b2f98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5dc6d8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5f1d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5a6cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5b2a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5e0358>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5fb9e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e59e278>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5adc18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5e0588>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e6009e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5ad978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5b9940>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f211e5c1fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e600470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5e76d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5f1c18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e55e438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e5dcd30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e5d4c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e6510f ...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 15,965,569
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 127ms/step - loss: 0.6569 - acc: 0.7778 - val_loss: 0.4549 - val_acc: 0.7850
#
# Epoch 00001: val_loss did not improve from 0.37887
# Epoch 2/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4860 - acc: 0.7719 - val_loss: 0.4736 - val_acc: 0.7950
#
# Epoch 00002: val_loss did not improve from 0.37887
# Epoch 3/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4460 - acc: 0.7952 - val_loss: 0.4005 - val_acc: 0.8462
#
# Epoch 00003: val_loss did not improve from 0.37887
# Epoch 4/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.4191 - acc: 0.8124 - val_loss: 0.4115 - val_acc: 0.8163
#
# Epoch 00004: val_loss did not improve from 0.37887
# Epoch 5/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4508 - acc: 0.7920 - val_loss: 0.3378 - val_acc: 0.8562
#
# Epoch 00005: val_loss improved from 0.37887 to 0.33784, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4478 - acc: 0.8009 - val_loss: 0.3449 - val_acc: 0.8562
#
# Epoch 00006: val_loss did not improve from 0.33784
# Epoch 7/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4233 - acc: 0.8118 - val_loss: 0.3384 - val_acc: 0.8612
#
# Epoch 00007: val_loss did not improve from 0.33784
# Epoch 8/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3787 - acc: 0.8279 - val_loss: 0.3604 - val_acc: 0.8650
#
# Epoch 00008: val_loss did not improve from 0.33784
# Epoch 9/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4200 - acc: 0.8074 - val_loss: 0.3588 - val_acc: 0.8525
#
# Epoch 00009: val_loss did not improve from 0.33784
# Epoch 10/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3637 - acc: 0.8566 - val_loss: 0.4769 - val_acc: 0.7650
#
# Epoch 00010: val_loss did not improve from 0.33784
# Epoch 11/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3611 - acc: 0.8482 - val_loss: 0.4583 - val_acc: 0.7525
#
# Epoch 00011: val_loss did not improve from 0.33784
# Epoch 12/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3481 - acc: 0.8571 - val_loss: 0.3230 - val_acc: 0.8763
#
# Epoch 00012: val_loss improved from 0.33784 to 0.32296, saving model to checkpoint.h5
# Epoch 13/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4036 - acc: 0.8360 - val_loss: 0.3364 - val_acc: 0.8500
#
# Epoch 00013: val_loss did not improve from 0.32296
# Epoch 14/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3641 - acc: 0.8509 - val_loss: 0.3278 - val_acc: 0.8575
#
# Epoch 00014: val_loss did not improve from 0.32296
# Epoch 15/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3752 - acc: 0.8545 - val_loss: 0.3499 - val_acc: 0.8562
#
# Epoch 00015: val_loss did not improve from 0.32296
# Epoch 16/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3788 - acc: 0.8233 - val_loss: 0.3461 - val_acc: 0.8512
#
# Epoch 00016: val_loss did not improve from 0.32296
# Epoch 17/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3614 - acc: 0.8537 - val_loss: 0.3921 - val_acc: 0.7912
#
# Epoch 00017: val_loss did not improve from 0.32296
# Epoch 18/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3557 - acc: 0.8516 - val_loss: 0.3637 - val_acc: 0.8350
#
# Epoch 00018: val_loss did not improve from 0.32296
# Epoch 19/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3492 - acc: 0.8536 - val_loss: 0.3582 - val_acc: 0.8550
#
# Epoch 00019: val_loss did not improve from 0.32296
# Epoch 20/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3793 - acc: 0.8389 - val_loss: 0.3316 - val_acc: 0.8750
#
# Epoch 00020: val_loss did not improve from 0.32296
# Epoch 21/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3456 - acc: 0.8417 - val_loss: 0.3518 - val_acc: 0.8700
#
# Epoch 00021: val_loss did not improve from 0.32296
# Epoch 22/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3452 - acc: 0.8453 - val_loss: 0.3103 - val_acc: 0.8825
#
# Epoch 00022: val_loss improved from 0.32296 to 0.31026, saving model to checkpoint.h5
# Epoch 23/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3428 - acc: 0.8583 - val_loss: 0.3297 - val_acc: 0.8600
#
# Epoch 00023: val_loss did not improve from 0.31026
# Epoch 24/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3530 - acc: 0.8527 - val_loss: 0.3613 - val_acc: 0.8250
#
# Epoch 00024: val_loss did not improve from 0.31026
# Epoch 25/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3487 - acc: 0.8587 - val_loss: 0.3336 - val_acc: 0.8650
#
# Epoch 00025: val_loss did not improve from 0.31026
# Epoch 26/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3506 - acc: 0.8463 - val_loss: 0.3447 - val_acc: 0.8875
#
# Epoch 00026: val_loss did not improve from 0.31026
# Epoch 27/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3552 - acc: 0.8414 - val_loss: 0.3070 - val_acc: 0.8913
#
# Epoch 00027: val_loss improved from 0.31026 to 0.30705, saving model to checkpoint.h5
# Epoch 28/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3262 - acc: 0.8593 - val_loss: 0.3567 - val_acc: 0.8775
#
# Epoch 00028: val_loss did not improve from 0.30705
# Epoch 29/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3209 - acc: 0.8523 - val_loss: 0.3249 - val_acc: 0.8700
#
# Epoch 00029: val_loss did not improve from 0.30705
# Epoch 30/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2912 - acc: 0.8719 - val_loss: 0.3230 - val_acc: 0.8850
#
# Epoch 00030: val_loss did not improve from 0.30705
# Epoch 31/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2939 - acc: 0.8865 - val_loss: 0.3091 - val_acc: 0.8763
#
# Epoch 00031: val_loss did not improve from 0.30705
# Epoch 32/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2869 - acc: 0.8775 - val_loss: 0.4817 - val_acc: 0.7513
#
# Epoch 00032: val_loss did not improve from 0.30705
# Epoch 33/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3813 - acc: 0.8558 - val_loss: 0.3279 - val_acc: 0.8800
#
# Epoch 00033: val_loss did not improve from 0.30705
# Epoch 34/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2924 - acc: 0.8852 - val_loss: 0.3483 - val_acc: 0.8775
#
# Epoch 00034: val_loss did not improve from 0.30705
# Epoch 35/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3156 - acc: 0.8752 - val_loss: 0.3622 - val_acc: 0.8888
#
# Epoch 00035: val_loss did not improve from 0.30705
# Epoch 36/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3208 - acc: 0.8516 - val_loss: 0.3540 - val_acc: 0.8775
#
# Epoch 00036: val_loss did not improve from 0.30705
# Epoch 37/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.2987 - acc: 0.8832 - val_loss: 0.3718 - val_acc: 0.8788
#
# Epoch 00037: val_loss did not improve from 0.30705
# Epoch 38/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3183 - acc: 0.8653 - val_loss: 0.3949 - val_acc: 0.8788
#
# Epoch 00038: val_loss did not improve from 0.30705
# Epoch 39/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2955 - acc: 0.8718 - val_loss: 0.3304 - val_acc: 0.8888
#
# Epoch 00039: val_loss did not improve from 0.30705
# Epoch 40/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3213 - acc: 0.8551 - val_loss: 0.3504 - val_acc: 0.8788
#
# Epoch 00040: val_loss did not improve from 0.30705
# Epoch 41/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3149 - acc: 0.8709 - val_loss: 0.4065 - val_acc: 0.8363
#
# Epoch 00041: val_loss did not improve from 0.30705
# Epoch 42/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3174 - acc: 0.8714 - val_loss: 0.4479 - val_acc: 0.7663
#
# Epoch 00042: val_loss did not improve from 0.30705
# Epoch 43/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3268 - acc: 0.8560 - val_loss: 0.3732 - val_acc: 0.8838
#
# Epoch 00043: val_loss did not improve from 0.30705
# Epoch 44/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.2920 - acc: 0.8681 - val_loss: 0.3373 - val_acc: 0.8825
#
# Epoch 00044: val_loss did not improve from 0.30705
# Epoch 45/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3310 - acc: 0.8815 - val_loss: 0.3781 - val_acc: 0.8725
#
# Epoch 00045: val_loss did not improve from 0.30705
# Epoch 46/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3078 - acc: 0.8811 - val_loss: 0.4373 - val_acc: 0.7912
#
# Epoch 00046: val_loss did not improve from 0.30705
# Epoch 47/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3135 - acc: 0.8655 - val_loss: 0.4032 - val_acc: 0.8275
#
# Epoch 00047: val_loss did not improve from 0.30705
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3314 - acc: 0.8594
#
# ---------------------------------
# Accuracy: 85.94 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.87      0.87       179
#          1.0       0.85      0.85      0.85       157
#
#     accuracy                           0.86       336
#    macro avg       0.86      0.86      0.86       336
# weighted avg       0.86      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x3_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 2 Inception modules	
for layer in conv_base.layers[:249]:
   layer.trainable = False
for layer in conv_base.layers[249:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 656,385
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 130ms/step - loss: 0.7108 - acc: 0.6487 - val_loss: 0.5680 - val_acc: 0.7225
#
# Epoch 00001: val_loss improved from inf to 0.56803, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.6206 - acc: 0.6915 - val_loss: 0.5243 - val_acc: 0.7425
#
# Epoch 00002: val_loss improved from 0.56803 to 0.52426, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5813 - acc: 0.7097 - val_loss: 0.4597 - val_acc: 0.7950
#
# Epoch 00003: val_loss improved from 0.52426 to 0.45966, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5160 - acc: 0.7474 - val_loss: 0.4543 - val_acc: 0.8050
#
# Epoch 00004: val_loss improved from 0.45966 to 0.45431, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5252 - acc: 0.7464 - val_loss: 0.4312 - val_acc: 0.8050
#
# Epoch 00005: val_loss improved from 0.45431 to 0.43123, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.5274 - acc: 0.7509 - val_loss: 0.4350 - val_acc: 0.8125
#
# Epoch 00006: val_loss did not improve from 0.43123
# Epoch 7/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4893 - acc: 0.7692 - val_loss: 0.4294 - val_acc: 0.8025
#
# Epoch 00007: val_loss improved from 0.43123 to 0.42944, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.4928 - acc: 0.7686 - val_loss: 0.4296 - val_acc: 0.8100
#
# Epoch 00008: val_loss did not improve from 0.42944
# Epoch 9/15
# 93/93 [==============================] - 10s 113ms/step - loss: 0.5064 - acc: 0.7469 - val_loss: 0.4257 - val_acc: 0.7925
#
# Epoch 00009: val_loss improved from 0.42944 to 0.42573, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5139 - acc: 0.7719 - val_loss: 0.4380 - val_acc: 0.8075
#
# Epoch 00010: val_loss did not improve from 0.42573
# Epoch 11/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4852 - acc: 0.7669 - val_loss: 0.4307 - val_acc: 0.8012
#
# Epoch 00011: val_loss did not improve from 0.42573
# Epoch 12/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5017 - acc: 0.7733 - val_loss: 0.4158 - val_acc: 0.8100
#
# Epoch 00012: val_loss improved from 0.42573 to 0.41585, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5337 - acc: 0.7373 - val_loss: 0.4218 - val_acc: 0.8125
#
# Epoch 00013: val_loss did not improve from 0.41585
# Epoch 14/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.4710 - acc: 0.7750 - val_loss: 0.4238 - val_acc: 0.8213
#
# Epoch 00014: val_loss did not improve from 0.41585
# Epoch 15/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5029 - acc: 0.7711 - val_loss: 0.4000 - val_acc: 0.8125
#
# Epoch 00015: val_loss improved from 0.41585 to 0.39996, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f54ac4ec2b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de47b4e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b60d9278>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7c43e80>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de47b828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54acd26048>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56de6c87b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54adf6c438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54adf7da90>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7af4390>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f54b7af45c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de47b7b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac42a668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7cefc18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de1a20f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d653df98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac40b198>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f56de462a58>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de699320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54adf8bc18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b62f1438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c54ab470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac4175f8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7ae5c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7af57f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56d6efe588>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54acd01c50>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f54b7c5a518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c54af2b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7cefda0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54b7af5588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f54ac405438>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7c43f60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac536908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7af5cc0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f56d6efe438>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54ac536470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b62f1cf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56dfdced30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f56c41afb70>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f54b630aac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de462780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac8d07f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f54b7e0d2b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56c41afcc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f56de68e6d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54b7d81f98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f54ac8ed20 ...
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 11,771,265
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 133ms/step - loss: 0.5416 - acc: 0.7760 - val_loss: 0.4894 - val_acc: 0.8050
#
# Epoch 00001: val_loss did not improve from 0.39996
# Epoch 2/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4861 - acc: 0.7663 - val_loss: 0.3944 - val_acc: 0.8250
#
# Epoch 00002: val_loss improved from 0.39996 to 0.39438, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4738 - acc: 0.7725 - val_loss: 0.3657 - val_acc: 0.8388
#
# Epoch 00003: val_loss improved from 0.39438 to 0.36571, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4256 - acc: 0.8061 - val_loss: 0.3610 - val_acc: 0.8450
#
# Epoch 00004: val_loss improved from 0.36571 to 0.36102, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4252 - acc: 0.8265 - val_loss: 0.5888 - val_acc: 0.7650
#
# Epoch 00005: val_loss did not improve from 0.36102
# Epoch 6/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3743 - acc: 0.8389 - val_loss: 0.3637 - val_acc: 0.8462
#
# Epoch 00006: val_loss did not improve from 0.36102
# Epoch 7/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3841 - acc: 0.8348 - val_loss: 0.3575 - val_acc: 0.8525
#
# Epoch 00007: val_loss improved from 0.36102 to 0.35748, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3587 - acc: 0.8408 - val_loss: 0.3433 - val_acc: 0.8587
#
# Epoch 00008: val_loss improved from 0.35748 to 0.34328, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3820 - acc: 0.8338 - val_loss: 0.3151 - val_acc: 0.8612
#
# Epoch 00009: val_loss improved from 0.34328 to 0.31505, saving model to checkpoint.h5
# Epoch 10/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3925 - acc: 0.8377 - val_loss: 0.5987 - val_acc: 0.7400
#
# Epoch 00010: val_loss did not improve from 0.31505
# Epoch 11/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3880 - acc: 0.8389 - val_loss: 0.3252 - val_acc: 0.8425
#
# Epoch 00011: val_loss did not improve from 0.31505
# Epoch 12/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3571 - acc: 0.8416 - val_loss: 0.3267 - val_acc: 0.8512
#
# Epoch 00012: val_loss did not improve from 0.31505
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3936 - acc: 0.8420 - val_loss: 0.2909 - val_acc: 0.8875
#
# Epoch 00013: val_loss improved from 0.31505 to 0.29092, saving model to checkpoint.h5
# Epoch 14/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3243 - acc: 0.8559 - val_loss: 0.3090 - val_acc: 0.8700
#
# Epoch 00014: val_loss did not improve from 0.29092
# Epoch 15/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3374 - acc: 0.8660 - val_loss: 0.3299 - val_acc: 0.8687
#
# Epoch 00015: val_loss did not improve from 0.29092
# Epoch 16/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3385 - acc: 0.8491 - val_loss: 0.3784 - val_acc: 0.8737
#
# Epoch 00016: val_loss did not improve from 0.29092
# Epoch 17/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3559 - acc: 0.8573 - val_loss: 0.3269 - val_acc: 0.8838
#
# Epoch 00017: val_loss did not improve from 0.29092
# Epoch 18/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3248 - acc: 0.8613 - val_loss: 0.3513 - val_acc: 0.8562
#
# Epoch 00018: val_loss did not improve from 0.29092
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3372 - acc: 0.8544 - val_loss: 0.2995 - val_acc: 0.8675
#
# Epoch 00019: val_loss did not improve from 0.29092
# Epoch 20/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3214 - acc: 0.8528 - val_loss: 0.3782 - val_acc: 0.8125
#
# Epoch 00020: val_loss did not improve from 0.29092
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3445 - acc: 0.8671 - val_loss: 0.3110 - val_acc: 0.8838
#
# Epoch 00021: val_loss did not improve from 0.29092
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3310 - acc: 0.8557 - val_loss: 0.3934 - val_acc: 0.8363
#
# Epoch 00022: val_loss did not improve from 0.29092
# Epoch 23/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3231 - acc: 0.8634 - val_loss: 0.3010 - val_acc: 0.8737
#
# Epoch 00023: val_loss did not improve from 0.29092
# Epoch 24/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3285 - acc: 0.8833 - val_loss: 0.2878 - val_acc: 0.8900
#
# Epoch 00024: val_loss improved from 0.29092 to 0.28778, saving model to checkpoint.h5
# Epoch 25/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3202 - acc: 0.8720 - val_loss: 0.2956 - val_acc: 0.8913
#
# Epoch 00025: val_loss did not improve from 0.28778
# Epoch 26/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3146 - acc: 0.8608 - val_loss: 0.3656 - val_acc: 0.8263
#
# Epoch 00026: val_loss did not improve from 0.28778
# Epoch 27/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3076 - acc: 0.8704 - val_loss: 0.3157 - val_acc: 0.8725
#
# Epoch 00027: val_loss did not improve from 0.28778
# Epoch 28/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2963 - acc: 0.8800 - val_loss: 0.2908 - val_acc: 0.8938
#
# Epoch 00028: val_loss did not improve from 0.28778
# Epoch 29/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2999 - acc: 0.8663 - val_loss: 0.3427 - val_acc: 0.8400
#
# Epoch 00029: val_loss did not improve from 0.28778
# Epoch 30/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3030 - acc: 0.8793 - val_loss: 0.2972 - val_acc: 0.8700
#
# Epoch 00030: val_loss did not improve from 0.28778
# Epoch 31/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3079 - acc: 0.8813 - val_loss: 0.3163 - val_acc: 0.8850
#
# Epoch 00031: val_loss did not improve from 0.28778
# Epoch 32/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2993 - acc: 0.8703 - val_loss: 0.4006 - val_acc: 0.8138
#
# Epoch 00032: val_loss did not improve from 0.28778
# Epoch 33/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3080 - acc: 0.8745 - val_loss: 0.3043 - val_acc: 0.8900
#
# Epoch 00033: val_loss did not improve from 0.28778
# Epoch 34/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3019 - acc: 0.8703 - val_loss: 0.3507 - val_acc: 0.8512
#
# Epoch 00034: val_loss did not improve from 0.28778
# Epoch 35/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2936 - acc: 0.8605 - val_loss: 0.2882 - val_acc: 0.8838
#
# Epoch 00035: val_loss did not improve from 0.28778
# Epoch 36/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3103 - acc: 0.8761 - val_loss: 0.2959 - val_acc: 0.8763
#
# Epoch 00036: val_loss did not improve from 0.28778
# Epoch 37/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3112 - acc: 0.8676 - val_loss: 0.3807 - val_acc: 0.8288
#
# Epoch 00037: val_loss did not improve from 0.28778
# Epoch 38/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2943 - acc: 0.8736 - val_loss: 0.2900 - val_acc: 0.8938
#
# Epoch 00038: val_loss did not improve from 0.28778
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3035 - acc: 0.8656 - val_loss: 0.2830 - val_acc: 0.8863
#
# Epoch 00039: val_loss improved from 0.28778 to 0.28302, saving model to checkpoint.h5
# Epoch 40/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2878 - acc: 0.8789 - val_loss: 0.3226 - val_acc: 0.8913
#
# Epoch 00040: val_loss did not improve from 0.28302
# Epoch 41/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3005 - acc: 0.8735 - val_loss: 0.3402 - val_acc: 0.8712
#
# Epoch 00041: val_loss did not improve from 0.28302
# Epoch 42/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2832 - acc: 0.8733 - val_loss: 0.3149 - val_acc: 0.8650
#
# Epoch 00042: val_loss did not improve from 0.28302
# Epoch 43/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2703 - acc: 0.8973 - val_loss: 0.3134 - val_acc: 0.8888
#
# Epoch 00043: val_loss did not improve from 0.28302
# Epoch 44/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2899 - acc: 0.8725 - val_loss: 0.3001 - val_acc: 0.8900
#
# Epoch 00044: val_loss did not improve from 0.28302
# Epoch 45/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2790 - acc: 0.8774 - val_loss: 0.3218 - val_acc: 0.8575
#
# Epoch 00045: val_loss did not improve from 0.28302
# Epoch 46/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3160 - acc: 0.8575 - val_loss: 0.2910 - val_acc: 0.8938
#
# Epoch 00046: val_loss did not improve from 0.28302
# Epoch 47/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3041 - acc: 0.8838 - val_loss: 0.2965 - val_acc: 0.8725
#
# Epoch 00047: val_loss did not improve from 0.28302
# Epoch 48/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3020 - acc: 0.8711 - val_loss: 0.2985 - val_acc: 0.8775
#
# Epoch 00048: val_loss did not improve from 0.28302
# Epoch 49/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2988 - acc: 0.8777 - val_loss: 0.2803 - val_acc: 0.8888
#
# Epoch 00049: val_loss improved from 0.28302 to 0.28029, saving model to checkpoint.h5
# Epoch 50/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2964 - acc: 0.8729 - val_loss: 0.2921 - val_acc: 0.8850
#
# Epoch 00050: val_loss did not improve from 0.28029
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3215 - acc: 0.8687
#
# ---------------------------------
# Accuracy: 86.87 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.88      0.88       179
#          1.0       0.86      0.85      0.86       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_globalAvgPool_dense_256x3_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True	 

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 4,850,689
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 125ms/step - loss: 0.8558 - acc: 0.6900 - val_loss: 0.5172 - val_acc: 0.7550
#
# Epoch 00001: val_loss improved from inf to 0.51720, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.7131 - acc: 0.6967 - val_loss: 0.4782 - val_acc: 0.7788
#
# Epoch 00002: val_loss improved from 0.51720 to 0.47821, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.5445 - acc: 0.7542 - val_loss: 0.4310 - val_acc: 0.8112
#
# Epoch 00003: val_loss improved from 0.47821 to 0.43101, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.5426 - acc: 0.7469 - val_loss: 0.4148 - val_acc: 0.8200
#
# Epoch 00004: val_loss improved from 0.43101 to 0.41481, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4847 - acc: 0.7862 - val_loss: 0.4283 - val_acc: 0.8037
#
# Epoch 00005: val_loss did not improve from 0.41481
# Epoch 6/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4863 - acc: 0.7721 - val_loss: 0.3998 - val_acc: 0.8313
#
# Epoch 00006: val_loss improved from 0.41481 to 0.39983, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4892 - acc: 0.7719 - val_loss: 0.3882 - val_acc: 0.8300
#
# Epoch 00007: val_loss improved from 0.39983 to 0.38817, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4764 - acc: 0.7820 - val_loss: 0.3878 - val_acc: 0.8363
#
# Epoch 00008: val_loss improved from 0.38817 to 0.38785, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4989 - acc: 0.7682 - val_loss: 0.3855 - val_acc: 0.8413
#
# Epoch 00009: val_loss improved from 0.38785 to 0.38551, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4411 - acc: 0.8020 - val_loss: 0.3814 - val_acc: 0.8425
#
# Epoch 00010: val_loss improved from 0.38551 to 0.38140, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4521 - acc: 0.7992 - val_loss: 0.3725 - val_acc: 0.8450
#
# Epoch 00011: val_loss improved from 0.38140 to 0.37250, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4707 - acc: 0.8003 - val_loss: 0.4003 - val_acc: 0.8363
#
# Epoch 00012: val_loss did not improve from 0.37250
# Epoch 13/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4722 - acc: 0.7864 - val_loss: 0.3831 - val_acc: 0.8388
#
# Epoch 00013: val_loss did not improve from 0.37250
# Epoch 14/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4494 - acc: 0.7853 - val_loss: 0.3775 - val_acc: 0.8425
#
# Epoch 00014: val_loss did not improve from 0.37250
# Epoch 15/15
# 93/93 [==============================] - 11s 113ms/step - loss: 0.4714 - acc: 0.7945 - val_loss: 0.3803 - val_acc: 0.8400
#
# Epoch 00015: val_loss did not improve from 0.37250
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f218ea09898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e574208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e282cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eecb101d0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef7a1c630>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eecb3eef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eedb93278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec856780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec5c8c50>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec580128>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f1eec9c1b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eeca0fc88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eecabf438>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec91d978>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e339b70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec8fc780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec6b8668>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f1eec6b8198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecb36668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec8e8b70>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec79f748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eeca0fd68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec6d8198>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eecb16588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eeca73c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec60c1d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec60c780>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f1eedba8048>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecb42c18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecb0da90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecb60b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eeca73470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec801898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec884358>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec742978>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec6b8b38>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec6d82b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec79f828>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec79e470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec60ccc0>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f211e266438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec5dbeb8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec433fd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec4582b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec60c0f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec8c1518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec8c17f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec43d71 ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,653,473
# Trainable params: 18,068,865
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 129ms/step - loss: 0.6146 - acc: 0.7632 - val_loss: 0.4618 - val_acc: 0.7688
#
# Epoch 00001: val_loss did not improve from 0.37250
# Epoch 2/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4914 - acc: 0.7809 - val_loss: 0.4790 - val_acc: 0.7688
#
# Epoch 00002: val_loss did not improve from 0.37250
# Epoch 3/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4318 - acc: 0.7996 - val_loss: 0.4089 - val_acc: 0.8112
#
# Epoch 00003: val_loss did not improve from 0.37250
# Epoch 4/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4634 - acc: 0.7994 - val_loss: 0.5799 - val_acc: 0.7588
#
# Epoch 00004: val_loss did not improve from 0.37250
# Epoch 5/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4089 - acc: 0.8155 - val_loss: 0.4084 - val_acc: 0.8112
#
# Epoch 00005: val_loss did not improve from 0.37250
# Epoch 6/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3624 - acc: 0.8501 - val_loss: 0.7306 - val_acc: 0.7575
#
# Epoch 00006: val_loss did not improve from 0.37250
# Epoch 7/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4070 - acc: 0.8265 - val_loss: 0.4275 - val_acc: 0.8275
#
# Epoch 00007: val_loss did not improve from 0.37250
# Epoch 8/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4330 - acc: 0.8297 - val_loss: 0.3335 - val_acc: 0.8475
#
# Epoch 00008: val_loss improved from 0.37250 to 0.33354, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3753 - acc: 0.8632 - val_loss: 0.3508 - val_acc: 0.8487
#
# Epoch 00009: val_loss did not improve from 0.33354
# Epoch 10/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3377 - acc: 0.8551 - val_loss: 0.4149 - val_acc: 0.8525
#
# Epoch 00010: val_loss did not improve from 0.33354
# Epoch 11/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3521 - acc: 0.8602 - val_loss: 0.3541 - val_acc: 0.8662
#
# Epoch 00011: val_loss did not improve from 0.33354
# Epoch 12/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3338 - acc: 0.8510 - val_loss: 0.3687 - val_acc: 0.8575
#
# Epoch 00012: val_loss did not improve from 0.33354
# Epoch 13/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3401 - acc: 0.8516 - val_loss: 0.3421 - val_acc: 0.8500
#
# Epoch 00013: val_loss did not improve from 0.33354
# Epoch 14/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3309 - acc: 0.8663 - val_loss: 0.3408 - val_acc: 0.8637
#
# Epoch 00014: val_loss did not improve from 0.33354
# Epoch 15/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3866 - acc: 0.8392 - val_loss: 0.3354 - val_acc: 0.8500
#
# Epoch 00015: val_loss did not improve from 0.33354
# Epoch 16/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3345 - acc: 0.8624 - val_loss: 0.3632 - val_acc: 0.8600
#
# Epoch 00016: val_loss did not improve from 0.33354
# Epoch 17/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3305 - acc: 0.8668 - val_loss: 0.3392 - val_acc: 0.8637
#
# Epoch 00017: val_loss did not improve from 0.33354
# Epoch 18/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3253 - acc: 0.8709 - val_loss: 0.3524 - val_acc: 0.8625
#
# Epoch 00018: val_loss did not improve from 0.33354
# Epoch 19/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3191 - acc: 0.8703 - val_loss: 0.3431 - val_acc: 0.8737
#
# Epoch 00019: val_loss did not improve from 0.33354
# Epoch 20/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3119 - acc: 0.8714 - val_loss: 0.4033 - val_acc: 0.8150
#
# Epoch 00020: val_loss did not improve from 0.33354
# Epoch 21/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3022 - acc: 0.8730 - val_loss: 0.3307 - val_acc: 0.8712
#
# Epoch 00021: val_loss improved from 0.33354 to 0.33065, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3222 - acc: 0.8767 - val_loss: 0.3046 - val_acc: 0.8750
#
# Epoch 00022: val_loss improved from 0.33065 to 0.30461, saving model to checkpoint.h5
# Epoch 23/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3290 - acc: 0.8725 - val_loss: 0.3111 - val_acc: 0.8662
#
# Epoch 00023: val_loss did not improve from 0.30461
# Epoch 24/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3339 - acc: 0.8760 - val_loss: 0.3956 - val_acc: 0.8125
#
# Epoch 00024: val_loss did not improve from 0.30461
# Epoch 25/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3062 - acc: 0.8766 - val_loss: 0.3520 - val_acc: 0.8712
#
# Epoch 00025: val_loss did not improve from 0.30461
# Epoch 26/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3119 - acc: 0.8726 - val_loss: 0.3476 - val_acc: 0.8825
#
# Epoch 00026: val_loss did not improve from 0.30461
# Epoch 27/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2942 - acc: 0.8823 - val_loss: 0.3363 - val_acc: 0.8763
#
# Epoch 00027: val_loss did not improve from 0.30461
# Epoch 28/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2888 - acc: 0.8686 - val_loss: 0.3133 - val_acc: 0.8637
#
# Epoch 00028: val_loss did not improve from 0.30461
# Epoch 29/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3048 - acc: 0.8743 - val_loss: 0.3213 - val_acc: 0.8662
#
# Epoch 00029: val_loss did not improve from 0.30461
# Epoch 30/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3253 - acc: 0.8723 - val_loss: 0.3495 - val_acc: 0.8525
#
# Epoch 00030: val_loss did not improve from 0.30461
# Epoch 31/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3258 - acc: 0.8645 - val_loss: 0.3282 - val_acc: 0.8763
#
# Epoch 00031: val_loss did not improve from 0.30461
# Epoch 32/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2745 - acc: 0.8864 - val_loss: 0.3529 - val_acc: 0.8675
#
# Epoch 00032: val_loss did not improve from 0.30461
# Epoch 33/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2830 - acc: 0.8777 - val_loss: 0.3427 - val_acc: 0.8763
#
# Epoch 00033: val_loss did not improve from 0.30461
# Epoch 34/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3089 - acc: 0.8795 - val_loss: 0.3411 - val_acc: 0.8863
#
# Epoch 00034: val_loss did not improve from 0.30461
# Epoch 35/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3010 - acc: 0.8776 - val_loss: 0.3620 - val_acc: 0.8400
#
# Epoch 00035: val_loss did not improve from 0.30461
# Epoch 36/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2786 - acc: 0.8773 - val_loss: 0.3736 - val_acc: 0.8325
#
# Epoch 00036: val_loss did not improve from 0.30461
# Epoch 37/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.3054 - acc: 0.8800 - val_loss: 0.3443 - val_acc: 0.8475
#
# Epoch 00037: val_loss did not improve from 0.30461
# Epoch 38/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2858 - acc: 0.8805 - val_loss: 0.3527 - val_acc: 0.8550
#
# Epoch 00038: val_loss did not improve from 0.30461
# Epoch 39/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2354 - acc: 0.9138 - val_loss: 0.3303 - val_acc: 0.8650
#
# Epoch 00039: val_loss did not improve from 0.30461
# Epoch 40/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3221 - acc: 0.8570 - val_loss: 0.3070 - val_acc: 0.8650
#
# Epoch 00040: val_loss did not improve from 0.30461
# Epoch 41/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3021 - acc: 0.8695 - val_loss: 0.3149 - val_acc: 0.8825
#
# Epoch 00041: val_loss did not improve from 0.30461
# Epoch 42/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2804 - acc: 0.8901 - val_loss: 0.3318 - val_acc: 0.8700
#
# Epoch 00042: val_loss did not improve from 0.30461
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3184 - acc: 0.8906
#
# ---------------------------------
# Accuracy: 89.06 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89       179
#          1.0       0.86      0.89      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x3_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True	

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 656,385
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 122ms/step - loss: 0.7182 - acc: 0.6787 - val_loss: 0.5953 - val_acc: 0.6313
#
# Epoch 00001: val_loss improved from inf to 0.59529, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6174 - acc: 0.6728 - val_loss: 0.5365 - val_acc: 0.7237
#
# Epoch 00002: val_loss improved from 0.59529 to 0.53645, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6282 - acc: 0.7328 - val_loss: 0.5367 - val_acc: 0.6975
#
# Epoch 00003: val_loss did not improve from 0.53645
# Epoch 4/15
# 93/93 [==============================] - 10s 113ms/step - loss: 0.5511 - acc: 0.7308 - val_loss: 0.4744 - val_acc: 0.7775
#
# Epoch 00004: val_loss improved from 0.53645 to 0.47441, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5105 - acc: 0.7400 - val_loss: 0.4424 - val_acc: 0.7987
#
# Epoch 00005: val_loss improved from 0.47441 to 0.44238, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5401 - acc: 0.7519 - val_loss: 0.4305 - val_acc: 0.8037
#
# Epoch 00006: val_loss improved from 0.44238 to 0.43054, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4936 - acc: 0.7562 - val_loss: 0.4447 - val_acc: 0.7987
#
# Epoch 00007: val_loss did not improve from 0.43054
# Epoch 8/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5231 - acc: 0.7431 - val_loss: 0.4495 - val_acc: 0.8025
#
# Epoch 00008: val_loss did not improve from 0.43054
# Epoch 9/15
# 93/93 [==============================] - 10s 109ms/step - loss: 0.5240 - acc: 0.7347 - val_loss: 0.4301 - val_acc: 0.8062
#
# Epoch 00009: val_loss improved from 0.43054 to 0.43012, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5107 - acc: 0.7459 - val_loss: 0.4426 - val_acc: 0.8163
#
# Epoch 00010: val_loss did not improve from 0.43012
# Epoch 11/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5150 - acc: 0.7588 - val_loss: 0.4376 - val_acc: 0.8125
#
# Epoch 00011: val_loss did not improve from 0.43012
# Epoch 12/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5041 - acc: 0.7795 - val_loss: 0.4292 - val_acc: 0.8025
#
# Epoch 00012: val_loss improved from 0.43012 to 0.42916, saving model to checkpoint.h5
# Epoch 13/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5087 - acc: 0.7620 - val_loss: 0.4160 - val_acc: 0.8125
#
# Epoch 00013: val_loss improved from 0.42916 to 0.41597, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4779 - acc: 0.7614 - val_loss: 0.4187 - val_acc: 0.8238
#
# Epoch 00014: val_loss did not improve from 0.41597
# Epoch 15/15
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5128 - acc: 0.7536 - val_loss: 0.4048 - val_acc: 0.8213
#
# Epoch 00015: val_loss improved from 0.41597 to 0.40479, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f1ef7db36a0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f63ed048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f2106853908>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef7cd95c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f60b7fd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f607dd68>, <tensorflow.python.keras.layers.core.Activation object at 0x7f2106beef60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e329a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7a94ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e5b2b00>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f211e5b25f8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f63ed4a8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eedbfbe10>, <tensorflow.python.keras.layers.core.Activation object at 0x7f20f7797748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eebcf1358>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f607d668>, <tensorflow.python.keras.layers.core.Activation object at 0x7f21071e6cc0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f21071e6240>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f2106ae02b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f6552748>, <tensorflow.python.keras.layers.core.Activation object at 0x7f2106bbedd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f64baa20>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef7df12e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7cd9a90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7cc47f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f2106bc5898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f20f60a4f60>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f20f65979e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f6571c88>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f6489198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f60a4ba8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f6552908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f64895f8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7d942e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7cc4908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f6552198>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef7d94a90>, <tensorflow.python.keras.layers.core.Activation object at 0x7f20f60a4898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f20f648c6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef7df1940>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f20f6057208>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef621ce80>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef79435c0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef7960dd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f6540fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f65400f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f6540470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f62835f ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,459,169
# Trainable params: 13,874,561
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 128ms/step - loss: 0.5761 - acc: 0.7664 - val_loss: 0.4162 - val_acc: 0.8325
#
# Epoch 00001: val_loss did not improve from 0.40479
# Epoch 2/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4779 - acc: 0.7708 - val_loss: 0.3278 - val_acc: 0.8725
#
# Epoch 00002: val_loss improved from 0.40479 to 0.32780, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4662 - acc: 0.7790 - val_loss: 0.3586 - val_acc: 0.8438
#
# Epoch 00003: val_loss did not improve from 0.32780
# Epoch 4/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4178 - acc: 0.8240 - val_loss: 0.4022 - val_acc: 0.8250
#
# Epoch 00004: val_loss did not improve from 0.32780
# Epoch 5/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4041 - acc: 0.8166 - val_loss: 0.3057 - val_acc: 0.8813
#
# Epoch 00005: val_loss improved from 0.32780 to 0.30569, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3572 - acc: 0.8445 - val_loss: 0.3466 - val_acc: 0.8725
#
# Epoch 00006: val_loss did not improve from 0.30569
# Epoch 7/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4027 - acc: 0.8088 - val_loss: 0.4501 - val_acc: 0.8263
#
# Epoch 00007: val_loss did not improve from 0.30569
# Epoch 8/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3908 - acc: 0.8287 - val_loss: 0.2943 - val_acc: 0.8913
#
# Epoch 00008: val_loss improved from 0.30569 to 0.29433, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3545 - acc: 0.8455 - val_loss: 0.3395 - val_acc: 0.8512
#
# Epoch 00009: val_loss did not improve from 0.29433
# Epoch 10/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3595 - acc: 0.8532 - val_loss: 0.3516 - val_acc: 0.8512
#
# Epoch 00010: val_loss did not improve from 0.29433
# Epoch 11/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3284 - acc: 0.8485 - val_loss: 0.2708 - val_acc: 0.8913
#
# Epoch 00011: val_loss improved from 0.29433 to 0.27080, saving model to checkpoint.h5
# Epoch 12/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3610 - acc: 0.8476 - val_loss: 0.3345 - val_acc: 0.8600
#
# Epoch 00012: val_loss did not improve from 0.27080
# Epoch 13/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3155 - acc: 0.8646 - val_loss: 0.2730 - val_acc: 0.8925
#
# Epoch 00013: val_loss did not improve from 0.27080
# Epoch 14/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3524 - acc: 0.8501 - val_loss: 0.2688 - val_acc: 0.8900
#
# Epoch 00014: val_loss improved from 0.27080 to 0.26877, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3490 - acc: 0.8452 - val_loss: 0.2764 - val_acc: 0.8825
#
# Epoch 00015: val_loss did not improve from 0.26877
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3274 - acc: 0.8785 - val_loss: 0.2979 - val_acc: 0.8838
#
# Epoch 00016: val_loss did not improve from 0.26877
# Epoch 17/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3458 - acc: 0.8485 - val_loss: 0.2574 - val_acc: 0.9013
#
# Epoch 00017: val_loss improved from 0.26877 to 0.25740, saving model to checkpoint.h5
# Epoch 18/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3609 - acc: 0.8541 - val_loss: 0.2830 - val_acc: 0.8975
#
# Epoch 00018: val_loss did not improve from 0.25740
# Epoch 19/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2959 - acc: 0.8765 - val_loss: 0.2876 - val_acc: 0.8712
#
# Epoch 00019: val_loss did not improve from 0.25740
# Epoch 20/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3627 - acc: 0.8486 - val_loss: 0.3031 - val_acc: 0.8775
#
# Epoch 00020: val_loss did not improve from 0.25740
# Epoch 21/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3235 - acc: 0.8570 - val_loss: 0.2560 - val_acc: 0.8938
#
# Epoch 00021: val_loss improved from 0.25740 to 0.25603, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2929 - acc: 0.8691 - val_loss: 0.2657 - val_acc: 0.8950
#
# Epoch 00022: val_loss did not improve from 0.25603
# Epoch 23/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3199 - acc: 0.8664 - val_loss: 0.2612 - val_acc: 0.9013
#
# Epoch 00023: val_loss did not improve from 0.25603
# Epoch 24/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3332 - acc: 0.8717 - val_loss: 0.2996 - val_acc: 0.8712
#
# Epoch 00024: val_loss did not improve from 0.25603
# Epoch 25/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3041 - acc: 0.8718 - val_loss: 0.2867 - val_acc: 0.9013
#
# Epoch 00025: val_loss did not improve from 0.25603
# Epoch 26/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3244 - acc: 0.8688 - val_loss: 0.2832 - val_acc: 0.8900
#
# Epoch 00026: val_loss did not improve from 0.25603
# Epoch 27/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3305 - acc: 0.8672 - val_loss: 0.3076 - val_acc: 0.8725
#
# Epoch 00027: val_loss did not improve from 0.25603
# Epoch 28/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.3545 - acc: 0.8524 - val_loss: 0.2970 - val_acc: 0.8800
#
# Epoch 00028: val_loss did not improve from 0.25603
# Epoch 29/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2974 - acc: 0.8762 - val_loss: 0.2759 - val_acc: 0.9000
#
# Epoch 00029: val_loss did not improve from 0.25603
# Epoch 30/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3058 - acc: 0.8875 - val_loss: 0.2763 - val_acc: 0.8938
#
# Epoch 00030: val_loss did not improve from 0.25603
# Epoch 31/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2902 - acc: 0.8812 - val_loss: 0.2764 - val_acc: 0.9050
#
# Epoch 00031: val_loss did not improve from 0.25603
# Epoch 32/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3091 - acc: 0.8794 - val_loss: 0.3391 - val_acc: 0.8438
#
# Epoch 00032: val_loss did not improve from 0.25603
# Epoch 33/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3128 - acc: 0.8635 - val_loss: 0.3158 - val_acc: 0.8838
#
# Epoch 00033: val_loss did not improve from 0.25603
# Epoch 34/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2516 - acc: 0.9005 - val_loss: 0.3042 - val_acc: 0.8750
#
# Epoch 00034: val_loss did not improve from 0.25603
# Epoch 35/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2878 - acc: 0.8854 - val_loss: 0.2555 - val_acc: 0.9025
#
# Epoch 00035: val_loss improved from 0.25603 to 0.25555, saving model to checkpoint.h5
# Epoch 36/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3077 - acc: 0.8625 - val_loss: 0.2563 - val_acc: 0.9013
#
# Epoch 00036: val_loss did not improve from 0.25555
# Epoch 37/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.3223 - acc: 0.8636 - val_loss: 0.3187 - val_acc: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.25555
# Epoch 38/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2949 - acc: 0.8870 - val_loss: 0.2576 - val_acc: 0.9025
#
# Epoch 00038: val_loss did not improve from 0.25555
# Epoch 39/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2474 - acc: 0.8995 - val_loss: 0.2671 - val_acc: 0.8963
#
# Epoch 00039: val_loss did not improve from 0.25555
# Epoch 40/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2961 - acc: 0.8782 - val_loss: 0.2813 - val_acc: 0.9025
#
# Epoch 00040: val_loss did not improve from 0.25555
# Epoch 41/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2947 - acc: 0.8845 - val_loss: 0.2660 - val_acc: 0.9062
#
# Epoch 00041: val_loss did not improve from 0.25555
# Epoch 42/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2490 - acc: 0.9065 - val_loss: 0.3034 - val_acc: 0.9000
#
# Epoch 00042: val_loss did not improve from 0.25555
# Epoch 43/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2592 - acc: 0.8956 - val_loss: 0.2707 - val_acc: 0.8900
#
# Epoch 00043: val_loss did not improve from 0.25555
# Epoch 44/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3035 - acc: 0.8735 - val_loss: 0.3076 - val_acc: 0.8800
#
# Epoch 00044: val_loss did not improve from 0.25555
# Epoch 45/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2722 - acc: 0.8896 - val_loss: 0.2990 - val_acc: 0.8763
#
# Epoch 00045: val_loss did not improve from 0.25555
# Epoch 46/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2340 - acc: 0.9189 - val_loss: 0.2815 - val_acc: 0.8963
#
# Epoch 00046: val_loss did not improve from 0.25555
# Epoch 47/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2667 - acc: 0.8842 - val_loss: 0.3162 - val_acc: 0.8763
#
# Epoch 00047: val_loss did not improve from 0.25555
# Epoch 48/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2595 - acc: 0.8955 - val_loss: 0.2869 - val_acc: 0.8888
#
# Epoch 00048: val_loss did not improve from 0.25555
# Epoch 49/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.2778 - acc: 0.8844 - val_loss: 0.3232 - val_acc: 0.8512
#
# Epoch 00049: val_loss did not improve from 0.25555
# Epoch 50/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.2706 - acc: 0.8824 - val_loss: 0.2698 - val_acc: 0.8988
#
# Epoch 00050: val_loss did not improve from 0.25555
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3068 - acc: 0.8719
#
# ---------------------------------
# Accuracy: 87.19 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.85      0.87       179
#          1.0       0.84      0.89      0.86       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_globalAvgPool_dense_256x3_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# # Architecture : Flatten/GlobalAveragePooling, 5x [ DropOut(0.5 + Dense (256)]

# %% [markdown]
# ##Flatten, Non Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-4), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=50,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 4,982,273
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 15s 122ms/step - loss: 0.7225 - acc: 0.6267 - val_loss: 0.6758 - val_acc: 0.5550
#
# Epoch 00001: val_loss improved from inf to 0.67581, saving model to checkpoint_2.h5
# Epoch 2/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6972 - acc: 0.5304 - val_loss: 0.6789 - val_acc: 0.6787
#
# Epoch 00002: val_loss did not improve from 0.67581
# Epoch 3/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.6973 - acc: 0.5384 - val_loss: 0.6658 - val_acc: 0.7200
#
# Epoch 00003: val_loss improved from 0.67581 to 0.66580, saving model to checkpoint_2.h5
# Epoch 4/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6817 - acc: 0.5661 - val_loss: 0.6580 - val_acc: 0.7400
#
# Epoch 00004: val_loss improved from 0.66580 to 0.65797, saving model to checkpoint_2.h5
# Epoch 5/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6833 - acc: 0.5594 - val_loss: 0.6429 - val_acc: 0.7325
#
# Epoch 00005: val_loss improved from 0.65797 to 0.64294, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6560 - acc: 0.5766 - val_loss: 0.6156 - val_acc: 0.7500
#
# Epoch 00006: val_loss improved from 0.64294 to 0.61556, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.6417 - acc: 0.6054 - val_loss: 0.5870 - val_acc: 0.7875
#
# Epoch 00007: val_loss improved from 0.61556 to 0.58700, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.6265 - acc: 0.6495 - val_loss: 0.5481 - val_acc: 0.8037
#
# Epoch 00008: val_loss improved from 0.58700 to 0.54811, saving model to checkpoint_2.h5
# Epoch 9/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5969 - acc: 0.6760 - val_loss: 0.5077 - val_acc: 0.8100
#
# Epoch 00009: val_loss improved from 0.54811 to 0.50768, saving model to checkpoint_2.h5
# Epoch 10/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5861 - acc: 0.7051 - val_loss: 0.4829 - val_acc: 0.8188
#
# Epoch 00010: val_loss improved from 0.50768 to 0.48294, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5373 - acc: 0.7339 - val_loss: 0.4482 - val_acc: 0.8288
#
# Epoch 00011: val_loss improved from 0.48294 to 0.44820, saving model to checkpoint_2.h5
# Epoch 12/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5530 - acc: 0.7323 - val_loss: 0.4496 - val_acc: 0.7900
#
# Epoch 00012: val_loss did not improve from 0.44820
# Epoch 13/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5623 - acc: 0.7242 - val_loss: 0.4290 - val_acc: 0.8213
#
# Epoch 00013: val_loss improved from 0.44820 to 0.42898, saving model to checkpoint_2.h5
# Epoch 14/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4869 - acc: 0.7774 - val_loss: 0.4177 - val_acc: 0.8288
#
# Epoch 00014: val_loss improved from 0.42898 to 0.41773, saving model to checkpoint_2.h5
# Epoch 15/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.5258 - acc: 0.7519 - val_loss: 0.4134 - val_acc: 0.8225
#
# Epoch 00015: val_loss improved from 0.41773 to 0.41340, saving model to checkpoint_2.h5
# Epoch 16/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.5483 - acc: 0.7576 - val_loss: 0.4140 - val_acc: 0.8138
#
# Epoch 00016: val_loss did not improve from 0.41340
# Epoch 17/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4804 - acc: 0.7944 - val_loss: 0.3998 - val_acc: 0.8300
#
# Epoch 00017: val_loss improved from 0.41340 to 0.39976, saving model to checkpoint_2.h5
# Epoch 18/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5160 - acc: 0.7652 - val_loss: 0.3972 - val_acc: 0.8275
#
# Epoch 00018: val_loss improved from 0.39976 to 0.39723, saving model to checkpoint_2.h5
# Epoch 19/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4664 - acc: 0.8108 - val_loss: 0.3886 - val_acc: 0.8250
#
# Epoch 00019: val_loss improved from 0.39723 to 0.38859, saving model to checkpoint_2.h5
# Epoch 20/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4831 - acc: 0.7776 - val_loss: 0.3818 - val_acc: 0.8325
#
# Epoch 00020: val_loss improved from 0.38859 to 0.38181, saving model to checkpoint_2.h5
# Epoch 21/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5033 - acc: 0.7617 - val_loss: 0.3885 - val_acc: 0.8350
#
# Epoch 00021: val_loss did not improve from 0.38181
# Epoch 22/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4508 - acc: 0.7969 - val_loss: 0.3730 - val_acc: 0.8413
#
# Epoch 00022: val_loss improved from 0.38181 to 0.37298, saving model to checkpoint_2.h5
# Epoch 23/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4868 - acc: 0.7918 - val_loss: 0.3769 - val_acc: 0.8300
#
# Epoch 00023: val_loss did not improve from 0.37298
# Epoch 24/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4647 - acc: 0.8092 - val_loss: 0.3775 - val_acc: 0.8325
#
# Epoch 00024: val_loss did not improve from 0.37298
# Epoch 25/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4579 - acc: 0.7975 - val_loss: 0.3779 - val_acc: 0.8250
#
# Epoch 00025: val_loss did not improve from 0.37298
# Epoch 26/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4586 - acc: 0.7864 - val_loss: 0.3666 - val_acc: 0.8438
#
# Epoch 00026: val_loss improved from 0.37298 to 0.36658, saving model to checkpoint_2.h5
# Epoch 27/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4600 - acc: 0.7939 - val_loss: 0.3720 - val_acc: 0.8425
#
# Epoch 00027: val_loss did not improve from 0.36658
# Epoch 28/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4480 - acc: 0.7995 - val_loss: 0.3745 - val_acc: 0.8325
#
# Epoch 00028: val_loss did not improve from 0.36658
# Epoch 29/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4554 - acc: 0.8004 - val_loss: 0.3847 - val_acc: 0.8238
#
# Epoch 00029: val_loss did not improve from 0.36658
# Epoch 30/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4269 - acc: 0.8137 - val_loss: 0.3732 - val_acc: 0.8363
#
# Epoch 00030: val_loss did not improve from 0.36658
# Epoch 31/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4293 - acc: 0.8187 - val_loss: 0.3715 - val_acc: 0.8363
#
# Epoch 00031: val_loss did not improve from 0.36658
# Epoch 32/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4619 - acc: 0.7843 - val_loss: 0.3736 - val_acc: 0.8375
#
# Epoch 00032: val_loss did not improve from 0.36658
# Epoch 33/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4491 - acc: 0.7902 - val_loss: 0.3776 - val_acc: 0.8250
#
# Epoch 00033: val_loss did not improve from 0.36658
# Epoch 34/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4786 - acc: 0.7961 - val_loss: 0.3720 - val_acc: 0.8350
#
# Epoch 00034: val_loss did not improve from 0.36658
# Epoch 35/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4383 - acc: 0.8085 - val_loss: 0.3770 - val_acc: 0.8350
#
# Epoch 00035: val_loss did not improve from 0.36658
# Epoch 36/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.4437 - acc: 0.8181 - val_loss: 0.3696 - val_acc: 0.8338
#
# Epoch 00036: val_loss did not improve from 0.36658
# Epoch 37/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4300 - acc: 0.8124 - val_loss: 0.3738 - val_acc: 0.8363
#
# Epoch 00037: val_loss did not improve from 0.36658
# Epoch 38/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4386 - acc: 0.8030 - val_loss: 0.3956 - val_acc: 0.8238
#
# Epoch 00038: val_loss did not improve from 0.36658
# Epoch 39/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4343 - acc: 0.8086 - val_loss: 0.3689 - val_acc: 0.8413
#
# Epoch 00039: val_loss did not improve from 0.36658
# Epoch 40/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4690 - acc: 0.7959 - val_loss: 0.3785 - val_acc: 0.8313
#
# Epoch 00040: val_loss did not improve from 0.36658
# Epoch 41/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4496 - acc: 0.7875 - val_loss: 0.3788 - val_acc: 0.8313
#
# Epoch 00041: val_loss did not improve from 0.36658
# Epoch 42/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4741 - acc: 0.7819 - val_loss: 0.3950 - val_acc: 0.8275
#
# Epoch 00042: val_loss did not improve from 0.36658
# Epoch 43/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4582 - acc: 0.7956 - val_loss: 0.3853 - val_acc: 0.8300
#
# Epoch 00043: val_loss did not improve from 0.36658
# Epoch 44/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4072 - acc: 0.8177 - val_loss: 0.3929 - val_acc: 0.8225
#
# Epoch 00044: val_loss did not improve from 0.36658
# Epoch 45/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4321 - acc: 0.8185 - val_loss: 0.3643 - val_acc: 0.8438
#
# Epoch 00045: val_loss improved from 0.36658 to 0.36428, saving model to checkpoint_2.h5
# Epoch 46/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.4273 - acc: 0.7977 - val_loss: 0.3836 - val_acc: 0.8238
#
# Epoch 00046: val_loss did not improve from 0.36428
# Epoch 47/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.3985 - acc: 0.8248 - val_loss: 0.3566 - val_acc: 0.8388
#
# Epoch 00047: val_loss improved from 0.36428 to 0.35655, saving model to checkpoint_2.h5
# Epoch 48/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.4198 - acc: 0.8093 - val_loss: 0.3743 - val_acc: 0.8450
#
# Epoch 00048: val_loss did not improve from 0.35655
# Epoch 49/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.4381 - acc: 0.8025 - val_loss: 0.3654 - val_acc: 0.8338
#
# Epoch 00049: val_loss did not improve from 0.35655
# Epoch 50/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4442 - acc: 0.8079 - val_loss: 0.3678 - val_acc: 0.8388
#
# Epoch 00050: val_loss did not improve from 0.35655

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3610 - acc: 0.8375
#
# ---------------------------------
# Accuracy: 83.75 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       179
#          1.0       0.81      0.83      0.82       157
#
#     accuracy                           0.83       336
#    macro avg       0.83      0.83      0.83       336
# weighted avg       0.83      0.83      0.83       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## Flatten, all trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint_2.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint_2.h5')

#unfreeze last convolutional block
conv_base.trainable = True

for layer in conv_base.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint_2.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 18432)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 4,982,273
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 126ms/step - loss: 0.9839 - acc: 0.6105 - val_loss: 0.6527 - val_acc: 0.5875
#
# Epoch 00001: val_loss improved from inf to 0.65269, saving model to checkpoint_2.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.7155 - acc: 0.5726 - val_loss: 0.6212 - val_acc: 0.7912
#
# Epoch 00002: val_loss improved from 0.65269 to 0.62116, saving model to checkpoint_2.h5
# Epoch 3/15
# 93/93 [==============================] - 10s 113ms/step - loss: 0.6554 - acc: 0.6047 - val_loss: 0.5423 - val_acc: 0.7850
#
# Epoch 00003: val_loss improved from 0.62116 to 0.54233, saving model to checkpoint_2.h5
# Epoch 4/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.6063 - acc: 0.6832 - val_loss: 0.4889 - val_acc: 0.8163
#
# Epoch 00004: val_loss improved from 0.54233 to 0.48891, saving model to checkpoint_2.h5
# Epoch 5/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.5757 - acc: 0.7275 - val_loss: 0.5406 - val_acc: 0.7200
#
# Epoch 00005: val_loss did not improve from 0.48891
# Epoch 6/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5733 - acc: 0.7149 - val_loss: 0.4098 - val_acc: 0.8475
#
# Epoch 00006: val_loss improved from 0.48891 to 0.40982, saving model to checkpoint_2.h5
# Epoch 7/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5274 - acc: 0.7345 - val_loss: 0.4380 - val_acc: 0.8250
#
# Epoch 00007: val_loss did not improve from 0.40982
# Epoch 8/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5343 - acc: 0.7424 - val_loss: 0.4689 - val_acc: 0.8150
#
# Epoch 00008: val_loss did not improve from 0.40982
# Epoch 9/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5118 - acc: 0.7628 - val_loss: 0.4475 - val_acc: 0.8125
#
# Epoch 00009: val_loss did not improve from 0.40982
# Epoch 10/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5337 - acc: 0.7593 - val_loss: 0.4343 - val_acc: 0.8250
#
# Epoch 00010: val_loss did not improve from 0.40982
# Epoch 11/15
# 93/93 [==============================] - 10s 112ms/step - loss: 0.5051 - acc: 0.7571 - val_loss: 0.3852 - val_acc: 0.8438
#
# Epoch 00011: val_loss improved from 0.40982 to 0.38521, saving model to checkpoint_2.h5
# Epoch 12/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5168 - acc: 0.7505 - val_loss: 0.4242 - val_acc: 0.8363
#
# Epoch 00012: val_loss did not improve from 0.38521
# Epoch 13/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.5099 - acc: 0.7657 - val_loss: 0.4348 - val_acc: 0.8188
#
# Epoch 00013: val_loss did not improve from 0.38521
# Epoch 14/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4781 - acc: 0.7865 - val_loss: 0.4207 - val_acc: 0.8350
#
# Epoch 00014: val_loss did not improve from 0.38521
# Epoch 15/15
# 93/93 [==============================] - 10s 111ms/step - loss: 0.4990 - acc: 0.7695 - val_loss: 0.4471 - val_acc: 0.8425
#
# Epoch 00015: val_loss did not improve from 0.38521
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f1ef623e320>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef62a4390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1ef7e52320>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eebdda898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eedcdc0b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec5f0e48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec473e48>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecabbba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f648c400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f20f648cf98>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f1eebdfe9b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f2107337a20>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f2106f2aba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e29a400>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eeb973198>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f2106c3a978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef62704e0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f2107343860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f20f64d4ef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f2106c41940>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e366be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eecb3d0f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef607c710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f20f651b3c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eedcf18d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1ef6721748>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e2a90b8>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f211e37a668>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f2106e72cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f2106f2a198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1ef7cf0518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f211e2a9c88>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eedcd6908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec60f668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eedcf1320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f211e2a9e48>, <tensorflow.python.keras.layers.core.Activation object at 0x7f2107d42e80>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e366eb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f211e37a9e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec534f98>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f2107296710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec51fc18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec51fba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f1eec47cb00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec534748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f1eec521470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f1eec5214e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f210730504 ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 18432)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 26,750,625
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 19s 142ms/step - loss: 0.6359 - acc: 0.7760 - val_loss: 0.3835 - val_acc: 0.8388
#
# Epoch 00001: val_loss improved from 0.38521 to 0.38349, saving model to checkpoint_2.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4910 - acc: 0.7826 - val_loss: 0.4707 - val_acc: 0.8288
#
# Epoch 00002: val_loss did not improve from 0.38349
# Epoch 3/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4368 - acc: 0.8095 - val_loss: 0.5290 - val_acc: 0.7962
#
# Epoch 00003: val_loss did not improve from 0.38349
# Epoch 4/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4439 - acc: 0.8282 - val_loss: 0.4237 - val_acc: 0.8512
#
# Epoch 00004: val_loss did not improve from 0.38349
# Epoch 5/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4117 - acc: 0.8226 - val_loss: 0.3756 - val_acc: 0.8838
#
# Epoch 00005: val_loss improved from 0.38349 to 0.37560, saving model to checkpoint_2.h5
# Epoch 6/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3990 - acc: 0.8360 - val_loss: 0.3411 - val_acc: 0.8963
#
# Epoch 00006: val_loss improved from 0.37560 to 0.34114, saving model to checkpoint_2.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4163 - acc: 0.8411 - val_loss: 0.3205 - val_acc: 0.9013
#
# Epoch 00007: val_loss improved from 0.34114 to 0.32051, saving model to checkpoint_2.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3532 - acc: 0.8674 - val_loss: 0.3389 - val_acc: 0.8950
#
# Epoch 00008: val_loss did not improve from 0.32051
# Epoch 9/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3781 - acc: 0.8566 - val_loss: 0.3355 - val_acc: 0.8988
#
# Epoch 00009: val_loss did not improve from 0.32051
# Epoch 10/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.3394 - acc: 0.8697 - val_loss: 0.3106 - val_acc: 0.9187
#
# Epoch 00010: val_loss improved from 0.32051 to 0.31058, saving model to checkpoint_2.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3266 - acc: 0.8741 - val_loss: 0.3594 - val_acc: 0.9062
#
# Epoch 00011: val_loss did not improve from 0.31058
# Epoch 12/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3528 - acc: 0.8576 - val_loss: 0.4576 - val_acc: 0.8788
#
# Epoch 00012: val_loss did not improve from 0.31058
# Epoch 13/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3323 - acc: 0.8642 - val_loss: 0.3922 - val_acc: 0.9137
#
# Epoch 00013: val_loss did not improve from 0.31058
# Epoch 14/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3332 - acc: 0.8790 - val_loss: 0.4209 - val_acc: 0.8975
#
# Epoch 00014: val_loss did not improve from 0.31058
# Epoch 15/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2876 - acc: 0.8795 - val_loss: 0.4406 - val_acc: 0.8763
#
# Epoch 00015: val_loss did not improve from 0.31058
# Epoch 16/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3134 - acc: 0.8849 - val_loss: 0.4180 - val_acc: 0.8675
#
# Epoch 00016: val_loss did not improve from 0.31058
# Epoch 17/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2842 - acc: 0.8902 - val_loss: 0.3351 - val_acc: 0.9225
#
# Epoch 00017: val_loss did not improve from 0.31058
# Epoch 18/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2914 - acc: 0.8870 - val_loss: 0.3775 - val_acc: 0.9262
#
# Epoch 00018: val_loss did not improve from 0.31058
# Epoch 19/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2466 - acc: 0.9129 - val_loss: 0.4109 - val_acc: 0.8788
#
# Epoch 00019: val_loss did not improve from 0.31058
# Epoch 20/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2552 - acc: 0.9091 - val_loss: 0.3867 - val_acc: 0.8988
#
# Epoch 00020: val_loss did not improve from 0.31058
# Epoch 21/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2606 - acc: 0.8922 - val_loss: 0.4471 - val_acc: 0.8350
#
# Epoch 00021: val_loss did not improve from 0.31058
# Epoch 22/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2704 - acc: 0.8977 - val_loss: 0.4447 - val_acc: 0.8975
#
# Epoch 00022: val_loss did not improve from 0.31058
# Epoch 23/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2705 - acc: 0.9009 - val_loss: 0.4216 - val_acc: 0.8800
#
# Epoch 00023: val_loss did not improve from 0.31058
# Epoch 24/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2493 - acc: 0.9027 - val_loss: 0.3748 - val_acc: 0.8925
#
# Epoch 00024: val_loss did not improve from 0.31058
# Epoch 25/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2497 - acc: 0.9022 - val_loss: 0.4042 - val_acc: 0.8888
#
# Epoch 00025: val_loss did not improve from 0.31058
# Epoch 26/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2423 - acc: 0.9029 - val_loss: 0.4599 - val_acc: 0.8500
#
# Epoch 00026: val_loss did not improve from 0.31058
# Epoch 27/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2249 - acc: 0.9191 - val_loss: 0.3909 - val_acc: 0.8650
#
# Epoch 00027: val_loss did not improve from 0.31058
# Epoch 28/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2857 - acc: 0.8893 - val_loss: 0.3832 - val_acc: 0.9150
#
# Epoch 00028: val_loss did not improve from 0.31058
# Epoch 29/50
# 93/93 [==============================] - 12s 129ms/step - loss: 0.2426 - acc: 0.9042 - val_loss: 0.3641 - val_acc: 0.9212
#
# Epoch 00029: val_loss did not improve from 0.31058
# Epoch 30/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.2195 - acc: 0.9226 - val_loss: 0.3945 - val_acc: 0.9262
#
# Epoch 00030: val_loss did not improve from 0.31058
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3461 - acc: 0.8813
#
# ---------------------------------
# Accuracy: 88.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.85      0.88       179
#          1.0       0.84      0.91      0.87       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.88      0.88       336
# weighted avg       0.88      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'

# %% [markdown]
# ## GlobalAveragePooling, all Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()
train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)

test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze last convolutional block
conv_base.trainable = True


for layer in conv_base.layers:
  layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-3
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 787,969
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 132ms/step - loss: 0.7247 - acc: 0.6340 - val_loss: 0.6572 - val_acc: 0.6587
#
# Epoch 00001: val_loss improved from inf to 0.65725, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.6715 - acc: 0.5766 - val_loss: 0.6090 - val_acc: 0.7462
#
# Epoch 00002: val_loss improved from 0.65725 to 0.60901, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6525 - acc: 0.6208 - val_loss: 0.5297 - val_acc: 0.7812
#
# Epoch 00003: val_loss improved from 0.60901 to 0.52970, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5733 - acc: 0.7193 - val_loss: 0.4941 - val_acc: 0.7812
#
# Epoch 00004: val_loss improved from 0.52970 to 0.49408, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5831 - acc: 0.7221 - val_loss: 0.4511 - val_acc: 0.8125
#
# Epoch 00005: val_loss improved from 0.49408 to 0.45110, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5636 - acc: 0.7262 - val_loss: 0.4390 - val_acc: 0.8238
#
# Epoch 00006: val_loss improved from 0.45110 to 0.43904, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5451 - acc: 0.7247 - val_loss: 0.4505 - val_acc: 0.8112
#
# Epoch 00007: val_loss did not improve from 0.43904
# Epoch 8/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5203 - acc: 0.7608 - val_loss: 0.4318 - val_acc: 0.8200
#
# Epoch 00008: val_loss improved from 0.43904 to 0.43179, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5328 - acc: 0.7601 - val_loss: 0.4178 - val_acc: 0.8188
#
# Epoch 00009: val_loss improved from 0.43179 to 0.41782, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5552 - acc: 0.7399 - val_loss: 0.4377 - val_acc: 0.7937
#
# Epoch 00010: val_loss did not improve from 0.41782
# Epoch 11/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5386 - acc: 0.7657 - val_loss: 0.4105 - val_acc: 0.8300
#
# Epoch 00011: val_loss improved from 0.41782 to 0.41048, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4791 - acc: 0.7680 - val_loss: 0.4374 - val_acc: 0.8213
#
# Epoch 00012: val_loss did not improve from 0.41048
# Epoch 13/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4950 - acc: 0.7636 - val_loss: 0.4151 - val_acc: 0.8250
#
# Epoch 00013: val_loss did not improve from 0.41048
# Epoch 14/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5045 - acc: 0.7668 - val_loss: 0.4423 - val_acc: 0.8213
#
# Epoch 00014: val_loss did not improve from 0.41048
# Epoch 15/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5072 - acc: 0.7540 - val_loss: 0.4246 - val_acc: 0.8350
#
# Epoch 00015: val_loss did not improve from 0.41048
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6c640622b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c64062390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a40eb22b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36f252e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c64062ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c7466a128>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cc8abe0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c7463a6d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36f93dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a35d00cf8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6c6cd4ac18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c64062c50>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36fe9470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6df60278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a40de01d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a3731f0f0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53495fd0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6c53495b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a35cc4400>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a372b68d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6de6b908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a362549e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6ddec7f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36f53630>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c06cd30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a35cf8a20>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c06c748>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f6a36fcdda0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36fd3278>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6ddeca90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a364e05f8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a372b6ef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c7463ad30>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c5327f588>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6428d080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a35cf84e0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c5327f6d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6de6b978>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36fcd1d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36fa3fd0>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f6a40ea3358>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36241f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c641b4f98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36ecf7b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36fa3a20>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36f939e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36f93eb8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c641afb7 ...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 22,556,321
# Non-trainable params: 34,432
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 20s 150ms/step - loss: 0.6706 - acc: 0.7657 - val_loss: 0.6329 - val_acc: 0.5788
#
# Epoch 00001: val_loss did not improve from 0.41048
# Epoch 2/50
# 93/93 [==============================] - 13s 137ms/step - loss: 0.4531 - acc: 0.8120 - val_loss: 0.4501 - val_acc: 0.7763
#
# Epoch 00002: val_loss did not improve from 0.41048
# Epoch 3/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.4128 - acc: 0.8210 - val_loss: 0.5369 - val_acc: 0.7375
#
# Epoch 00003: val_loss did not improve from 0.41048
# Epoch 4/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.3796 - acc: 0.8363 - val_loss: 0.3791 - val_acc: 0.8537
#
# Epoch 00004: val_loss improved from 0.41048 to 0.37905, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.3609 - acc: 0.8538 - val_loss: 0.2983 - val_acc: 0.8875
#
# Epoch 00005: val_loss improved from 0.37905 to 0.29834, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.3047 - acc: 0.8733 - val_loss: 0.3272 - val_acc: 0.8450
#
# Epoch 00006: val_loss did not improve from 0.29834
# Epoch 7/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.3406 - acc: 0.8449 - val_loss: 0.2575 - val_acc: 0.9013
#
# Epoch 00007: val_loss improved from 0.29834 to 0.25750, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.3487 - acc: 0.8572 - val_loss: 0.2784 - val_acc: 0.8913
#
# Epoch 00008: val_loss did not improve from 0.25750
# Epoch 9/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2798 - acc: 0.8926 - val_loss: 0.3952 - val_acc: 0.8438
#
# Epoch 00009: val_loss did not improve from 0.25750
# Epoch 10/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.2703 - acc: 0.8945 - val_loss: 0.2699 - val_acc: 0.9112
#
# Epoch 00010: val_loss did not improve from 0.25750
# Epoch 11/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2855 - acc: 0.8796 - val_loss: 0.3905 - val_acc: 0.8338
#
# Epoch 00011: val_loss did not improve from 0.25750
# Epoch 12/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2596 - acc: 0.9051 - val_loss: 0.2703 - val_acc: 0.8913
#
# Epoch 00012: val_loss did not improve from 0.25750
# Epoch 13/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2493 - acc: 0.9082 - val_loss: 0.2776 - val_acc: 0.8975
#
# Epoch 00013: val_loss did not improve from 0.25750
# Epoch 14/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2650 - acc: 0.8875 - val_loss: 0.2530 - val_acc: 0.9087
#
# Epoch 00014: val_loss improved from 0.25750 to 0.25297, saving model to checkpoint.h5
# Epoch 15/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2605 - acc: 0.8934 - val_loss: 0.2610 - val_acc: 0.9038
#
# Epoch 00015: val_loss did not improve from 0.25297
# Epoch 16/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2575 - acc: 0.9116 - val_loss: 0.2811 - val_acc: 0.8913
#
# Epoch 00016: val_loss did not improve from 0.25297
# Epoch 17/50
# 93/93 [==============================] - 13s 136ms/step - loss: 0.2680 - acc: 0.9039 - val_loss: 0.2857 - val_acc: 0.9087
#
# Epoch 00017: val_loss did not improve from 0.25297
# Epoch 18/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2149 - acc: 0.9059 - val_loss: 0.2487 - val_acc: 0.9100
#
# Epoch 00018: val_loss improved from 0.25297 to 0.24868, saving model to checkpoint.h5
# Epoch 19/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2359 - acc: 0.8963 - val_loss: 0.2510 - val_acc: 0.9137
#
# Epoch 00019: val_loss did not improve from 0.24868
# Epoch 20/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2463 - acc: 0.9091 - val_loss: 0.3126 - val_acc: 0.8550
#
# Epoch 00020: val_loss did not improve from 0.24868
# Epoch 21/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2515 - acc: 0.9061 - val_loss: 0.2818 - val_acc: 0.8525
#
# Epoch 00021: val_loss did not improve from 0.24868
# Epoch 22/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1997 - acc: 0.9202 - val_loss: 0.2361 - val_acc: 0.9062
#
# Epoch 00022: val_loss improved from 0.24868 to 0.23608, saving model to checkpoint.h5
# Epoch 23/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2115 - acc: 0.9139 - val_loss: 0.3068 - val_acc: 0.8763
#
# Epoch 00023: val_loss did not improve from 0.23608
# Epoch 24/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1964 - acc: 0.9123 - val_loss: 0.2486 - val_acc: 0.9038
#
# Epoch 00024: val_loss did not improve from 0.23608
# Epoch 25/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2373 - acc: 0.9189 - val_loss: 0.2342 - val_acc: 0.9050
#
# Epoch 00025: val_loss improved from 0.23608 to 0.23419, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2069 - acc: 0.9282 - val_loss: 0.3047 - val_acc: 0.8813
#
# Epoch 00026: val_loss did not improve from 0.23419
# Epoch 27/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2630 - acc: 0.8962 - val_loss: 0.3188 - val_acc: 0.8950
#
# Epoch 00027: val_loss did not improve from 0.23419
# Epoch 28/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1973 - acc: 0.9284 - val_loss: 0.2709 - val_acc: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.23419
# Epoch 29/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.1940 - acc: 0.9326 - val_loss: 0.2315 - val_acc: 0.8975
#
# Epoch 00029: val_loss improved from 0.23419 to 0.23146, saving model to checkpoint.h5
# Epoch 30/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1533 - acc: 0.9400 - val_loss: 0.2232 - val_acc: 0.9100
#
# Epoch 00030: val_loss improved from 0.23146 to 0.22319, saving model to checkpoint.h5
# Epoch 31/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1959 - acc: 0.9306 - val_loss: 0.2569 - val_acc: 0.9125
#
# Epoch 00031: val_loss did not improve from 0.22319
# Epoch 32/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2110 - acc: 0.9150 - val_loss: 0.2311 - val_acc: 0.9137
#
# Epoch 00032: val_loss did not improve from 0.22319
# Epoch 33/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.2047 - acc: 0.9218 - val_loss: 0.2300 - val_acc: 0.9150
#
# Epoch 00033: val_loss did not improve from 0.22319
# Epoch 34/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.2338 - acc: 0.9219 - val_loss: 0.2621 - val_acc: 0.9187
#
# Epoch 00034: val_loss did not improve from 0.22319
# Epoch 35/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.2617 - acc: 0.9062 - val_loss: 0.2327 - val_acc: 0.9212
#
# Epoch 00035: val_loss did not improve from 0.22319
# Epoch 36/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1959 - acc: 0.9302 - val_loss: 0.3165 - val_acc: 0.8712
#
# Epoch 00036: val_loss did not improve from 0.22319
# Epoch 37/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2025 - acc: 0.9192 - val_loss: 0.3015 - val_acc: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.22319
# Epoch 38/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1962 - acc: 0.9253 - val_loss: 0.2765 - val_acc: 0.8825
#
# Epoch 00038: val_loss did not improve from 0.22319
# Epoch 39/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1620 - acc: 0.9360 - val_loss: 0.2369 - val_acc: 0.9175
#
# Epoch 00039: val_loss did not improve from 0.22319
# Epoch 40/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1574 - acc: 0.9431 - val_loss: 0.2766 - val_acc: 0.8900
#
# Epoch 00040: val_loss did not improve from 0.22319
# Epoch 41/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1851 - acc: 0.9345 - val_loss: 0.2767 - val_acc: 0.8875
#
# Epoch 00041: val_loss did not improve from 0.22319
# Epoch 42/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1826 - acc: 0.9324 - val_loss: 0.2299 - val_acc: 0.9112
#
# Epoch 00042: val_loss did not improve from 0.22319
# Epoch 43/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.1657 - acc: 0.9378 - val_loss: 0.2606 - val_acc: 0.9025
#
# Epoch 00043: val_loss did not improve from 0.22319
# Epoch 44/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1880 - acc: 0.9272 - val_loss: 0.3858 - val_acc: 0.8062
#
# Epoch 00044: val_loss did not improve from 0.22319
# Epoch 45/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1564 - acc: 0.9472 - val_loss: 0.2943 - val_acc: 0.8900
#
# Epoch 00045: val_loss did not improve from 0.22319
# Epoch 46/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.2306 - acc: 0.9157 - val_loss: 0.2434 - val_acc: 0.9175
#
# Epoch 00046: val_loss did not improve from 0.22319
# Epoch 47/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1817 - acc: 0.9328 - val_loss: 0.2420 - val_acc: 0.9287
#
# Epoch 00047: val_loss did not improve from 0.22319
# Epoch 48/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.1734 - acc: 0.9380 - val_loss: 0.2850 - val_acc: 0.8888
#
# Epoch 00048: val_loss did not improve from 0.22319
# Epoch 49/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1635 - acc: 0.9246 - val_loss: 0.2576 - val_acc: 0.9025
#
# Epoch 00049: val_loss did not improve from 0.22319
# Epoch 50/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.1816 - acc: 0.9304 - val_loss: 0.2766 - val_acc: 0.8763
#
# Epoch 00050: val_loss did not improve from 0.22319
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2302 - acc: 0.8813
#
# ---------------------------------
# Accuracy: 88.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.87      0.89       179
#          1.0       0.86      0.90      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.89      0.88       336
# weighted avg       0.89      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_gAVG_dense_256x5_all_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint_2.h5'
# Out:
# rm: cannot remove 'checkpoint_2.h5': No such file or directory

# %% [markdown]
# ## Flatten, Last Block Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last Inception module
for layer in conv_base.layers[:280]:
   layer.trainable = False
for layer in conv_base.layers[280:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 18432)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 4,982,273
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 16s 132ms/step - loss: 0.9683 - acc: 0.6358 - val_loss: 0.6499 - val_acc: 0.6800
#
# Epoch 00001: val_loss improved from inf to 0.64988, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.7537 - acc: 0.5598 - val_loss: 0.6482 - val_acc: 0.6938
#
# Epoch 00002: val_loss improved from 0.64988 to 0.64824, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6549 - acc: 0.6287 - val_loss: 0.5398 - val_acc: 0.7688
#
# Epoch 00003: val_loss improved from 0.64824 to 0.53982, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5958 - acc: 0.7012 - val_loss: 0.4517 - val_acc: 0.7950
#
# Epoch 00004: val_loss improved from 0.53982 to 0.45173, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5668 - acc: 0.7231 - val_loss: 0.4431 - val_acc: 0.7937
#
# Epoch 00005: val_loss improved from 0.45173 to 0.44309, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5854 - acc: 0.7093 - val_loss: 0.4167 - val_acc: 0.8100
#
# Epoch 00006: val_loss improved from 0.44309 to 0.41666, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5216 - acc: 0.7523 - val_loss: 0.4227 - val_acc: 0.8250
#
# Epoch 00007: val_loss did not improve from 0.41666
# Epoch 8/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5240 - acc: 0.7389 - val_loss: 0.4111 - val_acc: 0.8175
#
# Epoch 00008: val_loss improved from 0.41666 to 0.41111, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5102 - acc: 0.7566 - val_loss: 0.3868 - val_acc: 0.8313
#
# Epoch 00009: val_loss improved from 0.41111 to 0.38675, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4989 - acc: 0.7624 - val_loss: 0.4057 - val_acc: 0.8288
#
# Epoch 00010: val_loss did not improve from 0.38675
# Epoch 11/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.5684 - acc: 0.7449 - val_loss: 0.4113 - val_acc: 0.8363
#
# Epoch 00011: val_loss did not improve from 0.38675
# Epoch 12/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4785 - acc: 0.7684 - val_loss: 0.4539 - val_acc: 0.8087
#
# Epoch 00012: val_loss did not improve from 0.38675
# Epoch 13/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5143 - acc: 0.7474 - val_loss: 0.3674 - val_acc: 0.8500
#
# Epoch 00013: val_loss improved from 0.38675 to 0.36743, saving model to checkpoint.h5
# Epoch 14/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4691 - acc: 0.7849 - val_loss: 0.3688 - val_acc: 0.8562
#
# Epoch 00014: val_loss did not improve from 0.36743
# Epoch 15/15
# 93/93 [==============================] - 11s 118ms/step - loss: 0.4801 - acc: 0.7669 - val_loss: 0.3774 - val_acc: 0.8462
#
# Epoch 00015: val_loss did not improve from 0.36743
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6a35d00358>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a35d00630>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6ca373c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c29fd68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6ca37f60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a35d00c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a385d12e8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36d46240>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c2b16a0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53543320>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a36cc5f28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a35d00860>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a35d1d400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c64189828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6df72828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c53314da0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c641893c8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a35d1d0f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a40bd4940>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6cc57b00>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c241b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6c2b1748>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6c2417f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a35d358d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c6507b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cc57fd0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cc57f28>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f6c642c7cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a35d16be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a35d16080>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c642c7b70>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c642c7ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c53332208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a385d1780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c642c7630>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6ce58b7160>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c535c1780>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c650080>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53332dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a385d1eb8>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f6c6ca18c18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a384b2da0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c641d68>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6dfa0940>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a384b2f28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a3634ccf8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a35d1d0b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a3634c6a ...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 18432)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               4718848
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 11,055,809
# Non-trainable params: 15,729,248
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 16s 135ms/step - loss: 0.5234 - acc: 0.8100 - val_loss: 0.3451 - val_acc: 0.8438
#
# Epoch 00001: val_loss improved from 0.36743 to 0.34515, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4429 - acc: 0.7999 - val_loss: 0.3761 - val_acc: 0.8363
#
# Epoch 00002: val_loss did not improve from 0.34515
# Epoch 3/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4675 - acc: 0.8002 - val_loss: 0.3936 - val_acc: 0.8400
#
# Epoch 00003: val_loss did not improve from 0.34515
# Epoch 4/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4671 - acc: 0.7767 - val_loss: 0.3615 - val_acc: 0.8363
#
# Epoch 00004: val_loss did not improve from 0.34515
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4934 - acc: 0.7784 - val_loss: 0.3776 - val_acc: 0.8675
#
# Epoch 00005: val_loss did not improve from 0.34515
# Epoch 6/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4201 - acc: 0.8179 - val_loss: 0.3635 - val_acc: 0.8475
#
# Epoch 00006: val_loss did not improve from 0.34515
# Epoch 7/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4573 - acc: 0.8069 - val_loss: 0.4110 - val_acc: 0.8450
#
# Epoch 00007: val_loss did not improve from 0.34515
# Epoch 8/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4513 - acc: 0.7893 - val_loss: 0.4115 - val_acc: 0.8413
#
# Epoch 00008: val_loss did not improve from 0.34515
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4340 - acc: 0.8045 - val_loss: 0.4606 - val_acc: 0.7862
#
# Epoch 00009: val_loss did not improve from 0.34515
# Epoch 10/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4107 - acc: 0.8293 - val_loss: 0.3898 - val_acc: 0.8475
#
# Epoch 00010: val_loss did not improve from 0.34515
# Epoch 11/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3795 - acc: 0.8274 - val_loss: 0.4299 - val_acc: 0.8462
#
# Epoch 00011: val_loss did not improve from 0.34515
# Epoch 12/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4443 - acc: 0.7996 - val_loss: 0.4123 - val_acc: 0.8475
#
# Epoch 00012: val_loss did not improve from 0.34515
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4050 - acc: 0.8197 - val_loss: 0.4284 - val_acc: 0.8425
#
# Epoch 00013: val_loss did not improve from 0.34515
# Epoch 14/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4257 - acc: 0.8376 - val_loss: 0.3955 - val_acc: 0.8612
#
# Epoch 00014: val_loss did not improve from 0.34515
# Epoch 15/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4154 - acc: 0.8255 - val_loss: 0.4248 - val_acc: 0.8200
#
# Epoch 00015: val_loss did not improve from 0.34515
# Epoch 16/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3941 - acc: 0.8367 - val_loss: 0.4065 - val_acc: 0.8637
#
# Epoch 00016: val_loss did not improve from 0.34515
# Epoch 17/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4068 - acc: 0.8345 - val_loss: 0.4063 - val_acc: 0.8487
#
# Epoch 00017: val_loss did not improve from 0.34515
# Epoch 18/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.4123 - acc: 0.8239 - val_loss: 0.3990 - val_acc: 0.8737
#
# Epoch 00018: val_loss did not improve from 0.34515
# Epoch 19/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3861 - acc: 0.8393 - val_loss: 0.4074 - val_acc: 0.8575
#
# Epoch 00019: val_loss did not improve from 0.34515
# Epoch 20/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3750 - acc: 0.8366 - val_loss: 0.4216 - val_acc: 0.8462
#
# Epoch 00020: val_loss did not improve from 0.34515
# Epoch 21/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3716 - acc: 0.8370 - val_loss: 0.3930 - val_acc: 0.8612
#
# Epoch 00021: val_loss did not improve from 0.34515
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 25ms/step - loss: 0.3660 - acc: 0.8313
#
# ---------------------------------
# Accuracy: 83.13 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.81      0.84       179
#          1.0       0.80      0.85      0.82       157
#
#     accuracy                           0.83       336
#    macro avg       0.83      0.83      0.83       336
# weighted avg       0.83      0.83      0.83       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x5_last_block_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 2 Inception modules	
for layer in conv_base.layers[:249]:
   layer.trainable = False
for layer in conv_base.layers[249:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 4,982,273
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 19s 148ms/step - loss: 0.9471 - acc: 0.6612 - val_loss: 0.6787 - val_acc: 0.5175
#
# Epoch 00001: val_loss improved from inf to 0.67869, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 12s 131ms/step - loss: 0.7353 - acc: 0.5512 - val_loss: 0.6218 - val_acc: 0.8025
#
# Epoch 00002: val_loss improved from 0.67869 to 0.62178, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.6530 - acc: 0.6392 - val_loss: 0.5658 - val_acc: 0.8012
#
# Epoch 00003: val_loss improved from 0.62178 to 0.56582, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.5945 - acc: 0.6990 - val_loss: 0.5036 - val_acc: 0.7900
#
# Epoch 00004: val_loss improved from 0.56582 to 0.50361, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.5347 - acc: 0.7616 - val_loss: 0.4649 - val_acc: 0.7987
#
# Epoch 00005: val_loss improved from 0.50361 to 0.46488, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 12s 130ms/step - loss: 0.5281 - acc: 0.7558 - val_loss: 0.4494 - val_acc: 0.8138
#
# Epoch 00006: val_loss improved from 0.46488 to 0.44940, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4981 - acc: 0.7742 - val_loss: 0.4504 - val_acc: 0.8238
#
# Epoch 00007: val_loss did not improve from 0.44940
# Epoch 8/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4939 - acc: 0.7577 - val_loss: 0.4052 - val_acc: 0.8338
#
# Epoch 00008: val_loss improved from 0.44940 to 0.40518, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 12s 131ms/step - loss: 0.5178 - acc: 0.7583 - val_loss: 0.4267 - val_acc: 0.8188
#
# Epoch 00009: val_loss did not improve from 0.40518
# Epoch 10/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4769 - acc: 0.7868 - val_loss: 0.4723 - val_acc: 0.7875
#
# Epoch 00010: val_loss did not improve from 0.40518
# Epoch 11/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.5336 - acc: 0.7515 - val_loss: 0.4180 - val_acc: 0.8350
#
# Epoch 00011: val_loss did not improve from 0.40518
# Epoch 12/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4957 - acc: 0.7591 - val_loss: 0.4393 - val_acc: 0.8062
#
# Epoch 00012: val_loss did not improve from 0.40518
# Epoch 13/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.5228 - acc: 0.7557 - val_loss: 0.4186 - val_acc: 0.8288
#
# Epoch 00013: val_loss did not improve from 0.40518
# Epoch 14/15
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4861 - acc: 0.7917 - val_loss: 0.4571 - val_acc: 0.8050
#
# Epoch 00014: val_loss did not improve from 0.40518
# Epoch 15/15
# 93/93 [==============================] - 12s 128ms/step - loss: 0.4973 - acc: 0.7668 - val_loss: 0.4563 - val_acc: 0.8288
#
# Epoch 00015: val_loss did not improve from 0.40518
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f55f001cf28>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55f001cb38>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f582218ef98>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55eff96ef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f58221859e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efca8c88>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efb7fac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efbc22e8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efe96278>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efc52550>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55eff96470>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55eff96320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efaf81d0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efbf7198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f5822247b38>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efab16d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efcd8dd8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f55effedb38>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efc520b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efeca748>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efc09f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efef43c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efde8898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efca2748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efdfccf8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efecab70>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55eff1c3c8>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f55f00222b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efd323c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efbf7908>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efee9b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55eff1cb00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efd1c3c8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efbd1828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efdfca90>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efcbee80>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efb77ef0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55eff1c5f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55f0022390>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55efba4438>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f582217b5c0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efdfcb00>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55efdfc278>, <tensorflow.python.keras.layers.core.Activation object at 0x7f55ef392710>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efba4a90>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f55efdfcf98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55ef381748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f55f930e08 ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 16,097,153
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 19s 151ms/step - loss: 0.6660 - acc: 0.7697 - val_loss: 0.4781 - val_acc: 0.7575
#
# Epoch 00001: val_loss did not improve from 0.40518
# Epoch 2/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.5319 - acc: 0.7471 - val_loss: 0.4857 - val_acc: 0.7425
#
# Epoch 00002: val_loss did not improve from 0.40518
# Epoch 3/50
# 93/93 [==============================] - 13s 135ms/step - loss: 0.4944 - acc: 0.7698 - val_loss: 0.4812 - val_acc: 0.7950
#
# Epoch 00003: val_loss did not improve from 0.40518
# Epoch 4/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.4527 - acc: 0.7960 - val_loss: 0.4304 - val_acc: 0.8050
#
# Epoch 00004: val_loss did not improve from 0.40518
# Epoch 5/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.4977 - acc: 0.7693 - val_loss: 0.4955 - val_acc: 0.7437
#
# Epoch 00005: val_loss did not improve from 0.40518
# Epoch 6/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.4501 - acc: 0.8023 - val_loss: 0.3681 - val_acc: 0.8612
#
# Epoch 00006: val_loss improved from 0.40518 to 0.36807, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4324 - acc: 0.8155 - val_loss: 0.3877 - val_acc: 0.8338
#
# Epoch 00007: val_loss did not improve from 0.36807
# Epoch 8/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.4342 - acc: 0.8186 - val_loss: 0.4374 - val_acc: 0.7850
#
# Epoch 00008: val_loss did not improve from 0.36807
# Epoch 9/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4228 - acc: 0.8208 - val_loss: 0.4012 - val_acc: 0.8238
#
# Epoch 00009: val_loss did not improve from 0.36807
# Epoch 10/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.4056 - acc: 0.8324 - val_loss: 0.4033 - val_acc: 0.8487
#
# Epoch 00010: val_loss did not improve from 0.36807
# Epoch 11/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.4070 - acc: 0.8305 - val_loss: 0.4080 - val_acc: 0.8338
#
# Epoch 00011: val_loss did not improve from 0.36807
# Epoch 12/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3968 - acc: 0.8438 - val_loss: 0.4847 - val_acc: 0.7650
#
# Epoch 00012: val_loss did not improve from 0.36807
# Epoch 13/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4008 - acc: 0.8392 - val_loss: 0.3966 - val_acc: 0.8562
#
# Epoch 00013: val_loss did not improve from 0.36807
# Epoch 14/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.4312 - acc: 0.8284 - val_loss: 0.4183 - val_acc: 0.8537
#
# Epoch 00014: val_loss did not improve from 0.36807
# Epoch 15/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3883 - acc: 0.8533 - val_loss: 0.4592 - val_acc: 0.8000
#
# Epoch 00015: val_loss did not improve from 0.36807
# Epoch 16/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.4133 - acc: 0.8325 - val_loss: 0.4271 - val_acc: 0.8612
#
# Epoch 00016: val_loss did not improve from 0.36807
# Epoch 17/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3525 - acc: 0.8557 - val_loss: 0.4167 - val_acc: 0.8313
#
# Epoch 00017: val_loss did not improve from 0.36807
# Epoch 18/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3683 - acc: 0.8621 - val_loss: 0.5350 - val_acc: 0.8125
#
# Epoch 00018: val_loss did not improve from 0.36807
# Epoch 19/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3873 - acc: 0.8327 - val_loss: 0.4253 - val_acc: 0.8163
#
# Epoch 00019: val_loss did not improve from 0.36807
# Epoch 20/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3930 - acc: 0.8352 - val_loss: 0.4995 - val_acc: 0.7387
#
# Epoch 00020: val_loss did not improve from 0.36807
# Epoch 21/50
# 93/93 [==============================] - 12s 134ms/step - loss: 0.3666 - acc: 0.8542 - val_loss: 0.3850 - val_acc: 0.8700
#
# Epoch 00021: val_loss did not improve from 0.36807
# Epoch 22/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3670 - acc: 0.8444 - val_loss: 0.4391 - val_acc: 0.8413
#
# Epoch 00022: val_loss did not improve from 0.36807
# Epoch 23/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3826 - acc: 0.8420 - val_loss: 0.3662 - val_acc: 0.8662
#
# Epoch 00023: val_loss improved from 0.36807 to 0.36620, saving model to checkpoint.h5
# Epoch 24/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3736 - acc: 0.8418 - val_loss: 0.5416 - val_acc: 0.7675
#
# Epoch 00024: val_loss did not improve from 0.36620
# Epoch 25/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.4024 - acc: 0.8387 - val_loss: 0.3792 - val_acc: 0.8525
#
# Epoch 00025: val_loss did not improve from 0.36620
# Epoch 26/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.4037 - acc: 0.8321 - val_loss: 0.4394 - val_acc: 0.8413
#
# Epoch 00026: val_loss did not improve from 0.36620
# Epoch 27/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3512 - acc: 0.8514 - val_loss: 0.4547 - val_acc: 0.8575
#
# Epoch 00027: val_loss did not improve from 0.36620
# Epoch 28/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3800 - acc: 0.8572 - val_loss: 0.4424 - val_acc: 0.8238
#
# Epoch 00028: val_loss did not improve from 0.36620
# Epoch 29/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3255 - acc: 0.8473 - val_loss: 0.5357 - val_acc: 0.7487
#
# Epoch 00029: val_loss did not improve from 0.36620
# Epoch 30/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3158 - acc: 0.8702 - val_loss: 0.4493 - val_acc: 0.8462
#
# Epoch 00030: val_loss did not improve from 0.36620
# Epoch 31/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3594 - acc: 0.8576 - val_loss: 0.4459 - val_acc: 0.8213
#
# Epoch 00031: val_loss did not improve from 0.36620
# Epoch 32/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3445 - acc: 0.8578 - val_loss: 0.3772 - val_acc: 0.8625
#
# Epoch 00032: val_loss did not improve from 0.36620
# Epoch 33/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3502 - acc: 0.8410 - val_loss: 0.4974 - val_acc: 0.7738
#
# Epoch 00033: val_loss did not improve from 0.36620
# Epoch 34/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3317 - acc: 0.8703 - val_loss: 0.3866 - val_acc: 0.8550
#
# Epoch 00034: val_loss did not improve from 0.36620
# Epoch 35/50
# 93/93 [==============================] - 12s 133ms/step - loss: 0.3332 - acc: 0.8638 - val_loss: 0.4117 - val_acc: 0.8512
#
# Epoch 00035: val_loss did not improve from 0.36620
# Epoch 36/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3528 - acc: 0.8400 - val_loss: 0.4975 - val_acc: 0.7763
#
# Epoch 00036: val_loss did not improve from 0.36620
# Epoch 37/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3406 - acc: 0.8626 - val_loss: 0.5437 - val_acc: 0.6513
#
# Epoch 00037: val_loss did not improve from 0.36620
# Epoch 38/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3217 - acc: 0.8625 - val_loss: 0.4225 - val_acc: 0.8625
#
# Epoch 00038: val_loss did not improve from 0.36620
# Epoch 39/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3256 - acc: 0.8718 - val_loss: 0.4344 - val_acc: 0.8450
#
# Epoch 00039: val_loss did not improve from 0.36620
# Epoch 40/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3321 - acc: 0.8559 - val_loss: 0.4570 - val_acc: 0.7650
#
# Epoch 00040: val_loss did not improve from 0.36620
# Epoch 41/50
# 93/93 [==============================] - 12s 132ms/step - loss: 0.3080 - acc: 0.8727 - val_loss: 0.4449 - val_acc: 0.8213
#
# Epoch 00041: val_loss did not improve from 0.36620
# Epoch 42/50
# 93/93 [==============================] - 12s 130ms/step - loss: 0.3436 - acc: 0.8418 - val_loss: 0.5747 - val_acc: 0.7487
#
# Epoch 00042: val_loss did not improve from 0.36620
# Epoch 43/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.3463 - acc: 0.8509 - val_loss: 0.4854 - val_acc: 0.7513
#
# Epoch 00043: val_loss did not improve from 0.36620
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3727 - acc: 0.8594
#
# ---------------------------------
# Accuracy: 85.94 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.83      0.86       179
#          1.0       0.82      0.89      0.85       157
#
#     accuracy                           0.86       336
#    macro avg       0.86      0.86      0.86       336
# weighted avg       0.86      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x5_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 2 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 2 Inception modules	
for layer in conv_base.layers[:249]:
   layer.trainable = False
for layer in conv_base.layers[249:]:
   layer.trainable = True

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 787,969
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 17s 133ms/step - loss: 0.7555 - acc: 0.6351 - val_loss: 0.6934 - val_acc: 0.4812
#
# Epoch 00001: val_loss improved from inf to 0.69342, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.6883 - acc: 0.5783 - val_loss: 0.6179 - val_acc: 0.7325
#
# Epoch 00002: val_loss improved from 0.69342 to 0.61788, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.6530 - acc: 0.6365 - val_loss: 0.5419 - val_acc: 0.7987
#
# Epoch 00003: val_loss improved from 0.61788 to 0.54188, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.6052 - acc: 0.6681 - val_loss: 0.5165 - val_acc: 0.7738
#
# Epoch 00004: val_loss improved from 0.54188 to 0.51651, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5855 - acc: 0.6910 - val_loss: 0.4724 - val_acc: 0.8050
#
# Epoch 00005: val_loss improved from 0.51651 to 0.47240, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5284 - acc: 0.7384 - val_loss: 0.4889 - val_acc: 0.8163
#
# Epoch 00006: val_loss did not improve from 0.47240
# Epoch 7/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5522 - acc: 0.7364 - val_loss: 0.4334 - val_acc: 0.8087
#
# Epoch 00007: val_loss improved from 0.47240 to 0.43339, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5214 - acc: 0.7419 - val_loss: 0.4597 - val_acc: 0.8175
#
# Epoch 00008: val_loss did not improve from 0.43339
# Epoch 9/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5272 - acc: 0.7476 - val_loss: 0.4196 - val_acc: 0.8225
#
# Epoch 00009: val_loss improved from 0.43339 to 0.41957, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5020 - acc: 0.7617 - val_loss: 0.4281 - val_acc: 0.8250
#
# Epoch 00010: val_loss did not improve from 0.41957
# Epoch 11/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5259 - acc: 0.7490 - val_loss: 0.4279 - val_acc: 0.8213
#
# Epoch 00011: val_loss did not improve from 0.41957
# Epoch 12/15
# 93/93 [==============================] - 11s 119ms/step - loss: 0.5223 - acc: 0.7525 - val_loss: 0.4506 - val_acc: 0.8188
#
# Epoch 00012: val_loss did not improve from 0.41957
# Epoch 13/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5316 - acc: 0.7479 - val_loss: 0.4347 - val_acc: 0.8213
#
# Epoch 00013: val_loss did not improve from 0.41957
# Epoch 14/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5025 - acc: 0.7642 - val_loss: 0.4524 - val_acc: 0.8300
#
# Epoch 00014: val_loss did not improve from 0.41957
# Epoch 15/15
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5083 - acc: 0.7772 - val_loss: 0.4125 - val_acc: 0.8338
#
# Epoch 00015: val_loss improved from 0.41957 to 0.41254, saving model to checkpoint.h5
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fbbf58e79b0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe062e9668>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe063c1d30>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebde1828>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec120320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbf58a26d8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebde1358>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec120a58>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebf317b8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbed1d6e80>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fbbebdc6390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec10fba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebe70ac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbed1d6b00>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbe06551470>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbec0e3a90>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbed1e68d0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fbbebce0588>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec127f28>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebbb63c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebc66518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec198ac8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebd1c390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebde16d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebdf9da0>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebd6b550>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebbb65c0>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fbbebc9a128>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebfce7b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebeb40b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebdf90f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebbb64e0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebd2fef0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebd6bfd0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebdf9dd8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebbb6dd8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebcf75f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebc66828>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbebf0d518>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbec138320>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fbe06383160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbed1d6908>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbe9a30c898>, <tensorflow.python.keras.layers.core.Activation object at 0x7fbbeba6f7f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbec138f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fbbebf92710>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbebf92080>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fbbeba78da ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 11,902,849
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 17s 138ms/step - loss: 0.5839 - acc: 0.7785 - val_loss: 0.3951 - val_acc: 0.8350
#
# Epoch 00001: val_loss improved from 0.41254 to 0.39510, saving model to checkpoint.h5
# Epoch 2/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4868 - acc: 0.7826 - val_loss: 0.6231 - val_acc: 0.6687
#
# Epoch 00002: val_loss did not improve from 0.39510
# Epoch 3/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4599 - acc: 0.7769 - val_loss: 0.3652 - val_acc: 0.8200
#
# Epoch 00003: val_loss improved from 0.39510 to 0.36524, saving model to checkpoint.h5
# Epoch 4/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.4480 - acc: 0.7939 - val_loss: 0.4458 - val_acc: 0.7138
#
# Epoch 00004: val_loss did not improve from 0.36524
# Epoch 5/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4378 - acc: 0.7946 - val_loss: 0.4992 - val_acc: 0.7713
#
# Epoch 00005: val_loss did not improve from 0.36524
# Epoch 6/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4061 - acc: 0.8345 - val_loss: 0.3642 - val_acc: 0.8525
#
# Epoch 00006: val_loss improved from 0.36524 to 0.36416, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4238 - acc: 0.8177 - val_loss: 0.3480 - val_acc: 0.8575
#
# Epoch 00007: val_loss improved from 0.36416 to 0.34796, saving model to checkpoint.h5
# Epoch 8/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3834 - acc: 0.8226 - val_loss: 0.4159 - val_acc: 0.8125
#
# Epoch 00008: val_loss did not improve from 0.34796
# Epoch 9/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.4117 - acc: 0.8250 - val_loss: 0.4000 - val_acc: 0.8275
#
# Epoch 00009: val_loss did not improve from 0.34796
# Epoch 10/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3815 - acc: 0.8311 - val_loss: 0.3073 - val_acc: 0.8913
#
# Epoch 00010: val_loss improved from 0.34796 to 0.30734, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3838 - acc: 0.8273 - val_loss: 0.3675 - val_acc: 0.8788
#
# Epoch 00011: val_loss did not improve from 0.30734
# Epoch 12/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3934 - acc: 0.8361 - val_loss: 0.3972 - val_acc: 0.8363
#
# Epoch 00012: val_loss did not improve from 0.30734
# Epoch 13/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.3511 - acc: 0.8542 - val_loss: 0.3231 - val_acc: 0.8850
#
# Epoch 00013: val_loss did not improve from 0.30734
# Epoch 14/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3786 - acc: 0.8442 - val_loss: 0.3243 - val_acc: 0.8650
#
# Epoch 00014: val_loss did not improve from 0.30734
# Epoch 15/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3295 - acc: 0.8698 - val_loss: 0.4413 - val_acc: 0.8188
#
# Epoch 00015: val_loss did not improve from 0.30734
# Epoch 16/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3711 - acc: 0.8593 - val_loss: 0.5278 - val_acc: 0.7850
#
# Epoch 00016: val_loss did not improve from 0.30734
# Epoch 17/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3757 - acc: 0.8346 - val_loss: 0.3787 - val_acc: 0.8850
#
# Epoch 00017: val_loss did not improve from 0.30734
# Epoch 18/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3789 - acc: 0.8458 - val_loss: 0.4105 - val_acc: 0.8325
#
# Epoch 00018: val_loss did not improve from 0.30734
# Epoch 19/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3379 - acc: 0.8565 - val_loss: 0.3785 - val_acc: 0.8438
#
# Epoch 00019: val_loss did not improve from 0.30734
# Epoch 20/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3484 - acc: 0.8574 - val_loss: 0.3284 - val_acc: 0.8662
#
# Epoch 00020: val_loss did not improve from 0.30734
# Epoch 21/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3223 - acc: 0.8695 - val_loss: 0.3005 - val_acc: 0.8888
#
# Epoch 00021: val_loss improved from 0.30734 to 0.30046, saving model to checkpoint.h5
# Epoch 22/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3333 - acc: 0.8755 - val_loss: 0.3125 - val_acc: 0.8763
#
# Epoch 00022: val_loss did not improve from 0.30046
# Epoch 23/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3681 - acc: 0.8350 - val_loss: 0.3860 - val_acc: 0.8363
#
# Epoch 00023: val_loss did not improve from 0.30046
# Epoch 24/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3601 - acc: 0.8565 - val_loss: 0.3214 - val_acc: 0.8775
#
# Epoch 00024: val_loss did not improve from 0.30046
# Epoch 25/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3399 - acc: 0.8612 - val_loss: 0.3290 - val_acc: 0.8925
#
# Epoch 00025: val_loss did not improve from 0.30046
# Epoch 26/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3187 - acc: 0.8636 - val_loss: 0.3130 - val_acc: 0.8850
#
# Epoch 00026: val_loss did not improve from 0.30046
# Epoch 27/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3229 - acc: 0.8651 - val_loss: 0.3787 - val_acc: 0.8363
#
# Epoch 00027: val_loss did not improve from 0.30046
# Epoch 28/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3413 - acc: 0.8592 - val_loss: 0.3945 - val_acc: 0.8700
#
# Epoch 00028: val_loss did not improve from 0.30046
# Epoch 29/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3394 - acc: 0.8683 - val_loss: 0.3571 - val_acc: 0.8700
#
# Epoch 00029: val_loss did not improve from 0.30046
# Epoch 30/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3579 - acc: 0.8380 - val_loss: 0.3407 - val_acc: 0.8775
#
# Epoch 00030: val_loss did not improve from 0.30046
# Epoch 31/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3150 - acc: 0.8692 - val_loss: 0.3269 - val_acc: 0.8925
#
# Epoch 00031: val_loss did not improve from 0.30046
# Epoch 32/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3112 - acc: 0.8686 - val_loss: 0.3416 - val_acc: 0.8888
#
# Epoch 00032: val_loss did not improve from 0.30046
# Epoch 33/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3308 - acc: 0.8521 - val_loss: 0.3195 - val_acc: 0.8975
#
# Epoch 00033: val_loss did not improve from 0.30046
# Epoch 34/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.3024 - acc: 0.8772 - val_loss: 0.3473 - val_acc: 0.8662
#
# Epoch 00034: val_loss did not improve from 0.30046
# Epoch 35/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3123 - acc: 0.8692 - val_loss: 0.3774 - val_acc: 0.8900
#
# Epoch 00035: val_loss did not improve from 0.30046
# Epoch 36/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3419 - acc: 0.8459 - val_loss: 0.3286 - val_acc: 0.8825
#
# Epoch 00036: val_loss did not improve from 0.30046
# Epoch 37/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3693 - acc: 0.8507 - val_loss: 0.3629 - val_acc: 0.8913
#
# Epoch 00037: val_loss did not improve from 0.30046
# Epoch 38/50
# 93/93 [==============================] - 12s 125ms/step - loss: 0.3306 - acc: 0.8738 - val_loss: 0.4399 - val_acc: 0.8300
#
# Epoch 00038: val_loss did not improve from 0.30046
# Epoch 39/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3014 - acc: 0.8747 - val_loss: 0.3761 - val_acc: 0.8737
#
# Epoch 00039: val_loss did not improve from 0.30046
# Epoch 40/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.3003 - acc: 0.8786 - val_loss: 0.3451 - val_acc: 0.8938
#
# Epoch 00040: val_loss did not improve from 0.30046
# Epoch 41/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.3071 - acc: 0.8569 - val_loss: 0.4169 - val_acc: 0.8263
#
# Epoch 00041: val_loss did not improve from 0.30046
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 26ms/step - loss: 0.3435 - acc: 0.8719
#
# ---------------------------------
# Accuracy: 87.19 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.85      0.88       179
#          1.0       0.84      0.89      0.87       157
#
#     accuracy                           0.87       336
#    macro avg       0.87      0.87      0.87       336
# weighted avg       0.87      0.87      0.87       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception__globalAvgPool_dense_256x5_last_2_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## Flatten, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True	

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 4,982,273
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 129ms/step - loss: 1.0253 - acc: 0.6022 - val_loss: 0.6673 - val_acc: 0.5938
#
# Epoch 00001: val_loss improved from inf to 0.66733, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.7499 - acc: 0.5364 - val_loss: 0.6195 - val_acc: 0.7163
#
# Epoch 00002: val_loss improved from 0.66733 to 0.61954, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6593 - acc: 0.6178 - val_loss: 0.5871 - val_acc: 0.8025
#
# Epoch 00003: val_loss improved from 0.61954 to 0.58707, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6327 - acc: 0.6938 - val_loss: 0.5000 - val_acc: 0.8188
#
# Epoch 00004: val_loss improved from 0.58707 to 0.50000, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5552 - acc: 0.7278 - val_loss: 0.4988 - val_acc: 0.8325
#
# Epoch 00005: val_loss improved from 0.50000 to 0.49879, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5869 - acc: 0.7278 - val_loss: 0.4569 - val_acc: 0.8213
#
# Epoch 00006: val_loss improved from 0.49879 to 0.45694, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5283 - acc: 0.7356 - val_loss: 0.4358 - val_acc: 0.8238
#
# Epoch 00007: val_loss improved from 0.45694 to 0.43580, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5150 - acc: 0.7474 - val_loss: 0.4102 - val_acc: 0.8375
#
# Epoch 00008: val_loss improved from 0.43580 to 0.41018, saving model to checkpoint.h5
# Epoch 9/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5608 - acc: 0.7316 - val_loss: 0.3886 - val_acc: 0.8350
#
# Epoch 00009: val_loss improved from 0.41018 to 0.38860, saving model to checkpoint.h5
# Epoch 10/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5272 - acc: 0.7520 - val_loss: 0.4025 - val_acc: 0.8587
#
# Epoch 00010: val_loss did not improve from 0.38860
# Epoch 11/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4970 - acc: 0.7640 - val_loss: 0.3866 - val_acc: 0.8338
#
# Epoch 00011: val_loss improved from 0.38860 to 0.38659, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5252 - acc: 0.7673 - val_loss: 0.4354 - val_acc: 0.8388
#
# Epoch 00012: val_loss did not improve from 0.38659
# Epoch 13/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5097 - acc: 0.7614 - val_loss: 0.3902 - val_acc: 0.8525
#
# Epoch 00013: val_loss did not improve from 0.38659
# Epoch 14/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.4596 - acc: 0.7977 - val_loss: 0.3933 - val_acc: 0.8525
#
# Epoch 00014: val_loss did not improve from 0.38659
# Epoch 15/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.4995 - acc: 0.7703 - val_loss: 0.4290 - val_acc: 0.8600
#
# Epoch 00015: val_loss did not improve from 0.38659
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6a3703aef0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a37328f60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c74366cc0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36e42cf8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c7435c828>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c743f4940>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a370bdf98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a373b3898>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a373e8be0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36efc5f8>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a373e8d68>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a373286d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36fe7ba8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a373280f0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c7441eb70>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36e9cd68>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a370dcb70>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6a370dc898>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a373e86d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36ead5f8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36f33048>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a371e7438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a373fc780>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36f780f0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a3704a470>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36f33860>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36e8a7f0>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f6a36f2d860>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a37328fd0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a373c24a8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a3704af98>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36e8a0b8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a373c2518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a40bb9048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a3704ada0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36eadeb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36e8d400>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36fc5e10>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a372f9eb8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36e30b00>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f6c7434c438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a371e76a0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6ce5306898>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a36d25198>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36e30160>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a36fe75c0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36fe7208>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a36d033c ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 18432)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 26,785,057
# Trainable params: 18,200,449
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 17s 132ms/step - loss: 0.6193 - acc: 0.7809 - val_loss: 0.4803 - val_acc: 0.7862
#
# Epoch 00001: val_loss did not improve from 0.38659
# Epoch 2/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.5503 - acc: 0.7335 - val_loss: 0.4597 - val_acc: 0.8037
#
# Epoch 00002: val_loss did not improve from 0.38659
# Epoch 3/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4946 - acc: 0.7736 - val_loss: 0.4374 - val_acc: 0.8138
#
# Epoch 00003: val_loss did not improve from 0.38659
# Epoch 4/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4809 - acc: 0.7687 - val_loss: 0.3862 - val_acc: 0.8338
#
# Epoch 00004: val_loss improved from 0.38659 to 0.38623, saving model to checkpoint.h5
# Epoch 5/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4258 - acc: 0.8215 - val_loss: 0.4613 - val_acc: 0.7862
#
# Epoch 00005: val_loss did not improve from 0.38623
# Epoch 6/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4568 - acc: 0.7899 - val_loss: 0.4063 - val_acc: 0.8487
#
# Epoch 00006: val_loss did not improve from 0.38623
# Epoch 7/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4497 - acc: 0.7823 - val_loss: 0.5152 - val_acc: 0.8487
#
# Epoch 00007: val_loss did not improve from 0.38623
# Epoch 8/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4398 - acc: 0.7966 - val_loss: 0.4229 - val_acc: 0.8075
#
# Epoch 00008: val_loss did not improve from 0.38623
# Epoch 9/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4185 - acc: 0.8123 - val_loss: 0.4432 - val_acc: 0.7875
#
# Epoch 00009: val_loss did not improve from 0.38623
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4067 - acc: 0.8217 - val_loss: 0.3823 - val_acc: 0.8600
#
# Epoch 00010: val_loss improved from 0.38623 to 0.38233, saving model to checkpoint.h5
# Epoch 11/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4011 - acc: 0.8215 - val_loss: 0.3961 - val_acc: 0.8138
#
# Epoch 00011: val_loss did not improve from 0.38233
# Epoch 12/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4518 - acc: 0.8239 - val_loss: 0.4762 - val_acc: 0.8012
#
# Epoch 00012: val_loss did not improve from 0.38233
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3691 - acc: 0.8327 - val_loss: 0.4450 - val_acc: 0.7962
#
# Epoch 00013: val_loss did not improve from 0.38233
# Epoch 14/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4014 - acc: 0.8263 - val_loss: 0.4451 - val_acc: 0.8413
#
# Epoch 00014: val_loss did not improve from 0.38233
# Epoch 15/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3624 - acc: 0.8522 - val_loss: 0.3727 - val_acc: 0.8413
#
# Epoch 00015: val_loss improved from 0.38233 to 0.37265, saving model to checkpoint.h5
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4009 - acc: 0.8232 - val_loss: 0.3862 - val_acc: 0.8462
#
# Epoch 00016: val_loss did not improve from 0.37265
# Epoch 17/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3718 - acc: 0.8472 - val_loss: 0.3834 - val_acc: 0.8587
#
# Epoch 00017: val_loss did not improve from 0.37265
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3638 - acc: 0.8486 - val_loss: 0.4148 - val_acc: 0.8562
#
# Epoch 00018: val_loss did not improve from 0.37265
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4037 - acc: 0.8249 - val_loss: 0.4052 - val_acc: 0.8325
#
# Epoch 00019: val_loss did not improve from 0.37265
# Epoch 20/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3923 - acc: 0.8263 - val_loss: 0.3967 - val_acc: 0.8188
#
# Epoch 00020: val_loss did not improve from 0.37265
# Epoch 21/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3386 - acc: 0.8506 - val_loss: 0.4376 - val_acc: 0.8425
#
# Epoch 00021: val_loss did not improve from 0.37265
# Epoch 22/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3865 - acc: 0.8370 - val_loss: 0.4071 - val_acc: 0.8400
#
# Epoch 00022: val_loss did not improve from 0.37265
# Epoch 23/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3855 - acc: 0.8685 - val_loss: 0.4020 - val_acc: 0.8213
#
# Epoch 00023: val_loss did not improve from 0.37265
# Epoch 24/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3580 - acc: 0.8439 - val_loss: 0.4109 - val_acc: 0.8300
#
# Epoch 00024: val_loss did not improve from 0.37265
# Epoch 25/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3257 - acc: 0.8574 - val_loss: 0.2890 - val_acc: 0.8900
#
# Epoch 00025: val_loss improved from 0.37265 to 0.28896, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3171 - acc: 0.8752 - val_loss: 0.4321 - val_acc: 0.8350
#
# Epoch 00026: val_loss did not improve from 0.28896
# Epoch 27/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3350 - acc: 0.8720 - val_loss: 0.3324 - val_acc: 0.8925
#
# Epoch 00027: val_loss did not improve from 0.28896
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3255 - acc: 0.8645 - val_loss: 0.3999 - val_acc: 0.8438
#
# Epoch 00028: val_loss did not improve from 0.28896
# Epoch 29/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3329 - acc: 0.8653 - val_loss: 0.4620 - val_acc: 0.7887
#
# Epoch 00029: val_loss did not improve from 0.28896
# Epoch 30/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3466 - acc: 0.8610 - val_loss: 0.3783 - val_acc: 0.8537
#
# Epoch 00030: val_loss did not improve from 0.28896
# Epoch 31/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3221 - acc: 0.8638 - val_loss: 0.4918 - val_acc: 0.7550
#
# Epoch 00031: val_loss did not improve from 0.28896
# Epoch 32/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2936 - acc: 0.8813 - val_loss: 0.4986 - val_acc: 0.7563
#
# Epoch 00032: val_loss did not improve from 0.28896
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3764 - acc: 0.8316 - val_loss: 0.3649 - val_acc: 0.8863
#
# Epoch 00033: val_loss did not improve from 0.28896
# Epoch 34/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3341 - acc: 0.8698 - val_loss: 0.4734 - val_acc: 0.8087
#
# Epoch 00034: val_loss did not improve from 0.28896
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3467 - acc: 0.8580 - val_loss: 0.4870 - val_acc: 0.8163
#
# Epoch 00035: val_loss did not improve from 0.28896
# Epoch 36/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3631 - acc: 0.8580 - val_loss: 0.3962 - val_acc: 0.8687
#
# Epoch 00036: val_loss did not improve from 0.28896
# Epoch 37/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3204 - acc: 0.8735 - val_loss: 0.3797 - val_acc: 0.8800
#
# Epoch 00037: val_loss did not improve from 0.28896
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3216 - acc: 0.8668 - val_loss: 0.3632 - val_acc: 0.8650
#
# Epoch 00038: val_loss did not improve from 0.28896
# Epoch 39/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3378 - acc: 0.8538 - val_loss: 0.3920 - val_acc: 0.8662
#
# Epoch 00039: val_loss did not improve from 0.28896
# Epoch 40/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3202 - acc: 0.8526 - val_loss: 0.3901 - val_acc: 0.8850
#
# Epoch 00040: val_loss did not improve from 0.28896
# Epoch 41/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.2976 - acc: 0.8888 - val_loss: 0.4837 - val_acc: 0.7763
#
# Epoch 00041: val_loss did not improve from 0.28896
# Epoch 42/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3222 - acc: 0.8730 - val_loss: 0.3616 - val_acc: 0.8800
#
# Epoch 00042: val_loss did not improve from 0.28896
# Epoch 43/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3170 - acc: 0.8804 - val_loss: 0.4089 - val_acc: 0.8250
#
# Epoch 00043: val_loss did not improve from 0.28896
# Epoch 44/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.3273 - acc: 0.8692 - val_loss: 0.4044 - val_acc: 0.8763
#
# Epoch 00044: val_loss did not improve from 0.28896
# Epoch 45/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3067 - acc: 0.8789 - val_loss: 0.4262 - val_acc: 0.8313
#
# Epoch 00045: val_loss did not improve from 0.28896
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.3214 - acc: 0.8562
#
# ---------------------------------
# Accuracy: 85.62 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.87       179
#          1.0       0.87      0.83      0.85       157
#
#     accuracy                           0.86       336
#    macro avg       0.86      0.86      0.86       336
# weighted avg       0.86      0.86      0.86       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_flatten_dense_256x5_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'

# %% [markdown]
# ## GlobalAveragePooling, Last 3 Blocks Trainable

# %%
from keras.applications import InceptionV3

conv_base = InceptionV3(weights='imagenet',
                        include_top=False,
                        input_shape=(150, 150, 3))
#conv_base.summary()

# %%
train_images, train_labels, test_images, test_labels = load_training()

train_images_split, valid_images_split, train_labels_split, valid_labels_split, train_datagen, valid_datagen, test_datagen = init_data(base_NN="InceptionV3", GCN=False, augmentation=True)


test_images = remove_baseline(test_images)
test_labels = remove_baseline(test_labels)
test_labels = labels_mapping(test_labels)
test_images, test_labels = shuffle_dataset(test_images, test_labels)
test_images = test_images.reshape(test_images.shape + (1,))

#expand test images from grayscale to RGB 
if test_images.shape[3] == 1:
  test_images = np.repeat(test_images, 3, axis = 3)

print()
print(train_images_split.shape)
print(test_images.shape)
# Out:
# (1873, 150, 150, 1)
# (803, 150, 150, 1)
# (1873,)
# (803,)
# Done
#
# (1873, 150, 150, 3)
# (336, 150, 150, 3)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='checkpoint.h5',
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True,
    verbose = 1)

#add custom fully-connected network on top of the already-trained base network 
model = models.Sequential()
model.add(conv_base)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

#freeze convolutional base 
conv_base.trainable = False
model.summary()

model.compile(loss="binary_crossentropy",
            optimizer=optimizers.Adam(lr=1e-3), # lr = 0.0001
            metrics=METRICS) 

#train fully-connected added part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=15,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])

model.load_weights('checkpoint.h5')

#unfreeze convolutional base 
conv_base.trainable = True
#unfreeze last 3 Inception modules
for layer in conv_base.layers[:218]:
   layer.trainable = False
for layer in conv_base.layers[218:]:
   layer.trainable = True	

print(conv_base.layers)

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),  #lr=1e-4
              metrics=METRICS)


#jointly train both the unfreezed layers and the fully-connected part 
history = model.fit(train_datagen.flow(train_images_split,
                                       train_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    steps_per_epoch=len(train_images_split) // BATCH_SIZE, 
                    epochs=EPOCHS,
                    validation_data=valid_datagen.flow(valid_images_split,
                                       valid_labels_split,
                                       batch_size=BATCH_SIZE,
                                       shuffle=True),
                    validation_steps=len(valid_labels_split) // BATCH_SIZE,
                    callbacks=[es, model_checkpoint_callback, GarbageCollectorCallback()])
print('done')
model.load_weights('checkpoint.h5')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 787,969
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/15
# 93/93 [==============================] - 15s 129ms/step - loss: 0.7252 - acc: 0.6358 - val_loss: 0.6535 - val_acc: 0.6975
#
# Epoch 00001: val_loss improved from inf to 0.65347, saving model to checkpoint.h5
# Epoch 2/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6833 - acc: 0.5758 - val_loss: 0.6042 - val_acc: 0.7500
#
# Epoch 00002: val_loss improved from 0.65347 to 0.60422, saving model to checkpoint.h5
# Epoch 3/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.6409 - acc: 0.6508 - val_loss: 0.5345 - val_acc: 0.7550
#
# Epoch 00003: val_loss improved from 0.60422 to 0.53455, saving model to checkpoint.h5
# Epoch 4/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.6296 - acc: 0.6474 - val_loss: 0.5061 - val_acc: 0.7900
#
# Epoch 00004: val_loss improved from 0.53455 to 0.50609, saving model to checkpoint.h5
# Epoch 5/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5760 - acc: 0.7032 - val_loss: 0.4540 - val_acc: 0.7975
#
# Epoch 00005: val_loss improved from 0.50609 to 0.45399, saving model to checkpoint.h5
# Epoch 6/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5651 - acc: 0.7220 - val_loss: 0.4483 - val_acc: 0.8175
#
# Epoch 00006: val_loss improved from 0.45399 to 0.44834, saving model to checkpoint.h5
# Epoch 7/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5538 - acc: 0.7231 - val_loss: 0.4481 - val_acc: 0.8112
#
# Epoch 00007: val_loss improved from 0.44834 to 0.44810, saving model to checkpoint.h5
# Epoch 8/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5154 - acc: 0.7478 - val_loss: 0.4485 - val_acc: 0.8012
#
# Epoch 00008: val_loss did not improve from 0.44810
# Epoch 9/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5107 - acc: 0.7609 - val_loss: 0.4676 - val_acc: 0.7987
#
# Epoch 00009: val_loss did not improve from 0.44810
# Epoch 10/15
# 93/93 [==============================] - 11s 115ms/step - loss: 0.5013 - acc: 0.7642 - val_loss: 0.4369 - val_acc: 0.8275
#
# Epoch 00010: val_loss improved from 0.44810 to 0.43695, saving model to checkpoint.h5
# Epoch 11/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5203 - acc: 0.7690 - val_loss: 0.4010 - val_acc: 0.8175
#
# Epoch 00011: val_loss improved from 0.43695 to 0.40105, saving model to checkpoint.h5
# Epoch 12/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.5195 - acc: 0.7600 - val_loss: 0.4465 - val_acc: 0.8075
#
# Epoch 00012: val_loss did not improve from 0.40105
# Epoch 13/15
# 93/93 [==============================] - 11s 114ms/step - loss: 0.5266 - acc: 0.7492 - val_loss: 0.4045 - val_acc: 0.8263
#
# Epoch 00013: val_loss did not improve from 0.40105
# Epoch 14/15
# 93/93 [==============================] - 11s 116ms/step - loss: 0.5167 - acc: 0.7519 - val_loss: 0.4154 - val_acc: 0.8163
#
# Epoch 00014: val_loss did not improve from 0.40105
# Epoch 15/15
# 93/93 [==============================] - 11s 117ms/step - loss: 0.4852 - acc: 0.7782 - val_loss: 0.4146 - val_acc: 0.8200
#
# Epoch 00015: val_loss did not improve from 0.40105
# [<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f6a364e5f60>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c64094ba8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6a3644bd30>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cab5438>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6cbe96d8>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6cc2a3c8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6de383c8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6cb6c9b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6cbf49e8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53423be0>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6c64224da0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6c18f320>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c83e358>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cc3c7b8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a365411d0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6cb65b38>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c8b0400>, <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f6c6c8b0be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a41fe4048>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6ca9cd68>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cc01518>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c5344fdd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c534e1550>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6cccd518>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6de44438>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53456ac8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c4a9940>, <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7f6c6cab5550>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6cc09d30>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6cc3cc18>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6a41ff0dd8>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6c4a92b0>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6423ff98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c8a2c18>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6de44748>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c534719b0>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6a3861bc88>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c53471c18>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6c6dc4a8>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c6cb78e48>, <tensorflow.python.keras.layers.merge.Concatenate object at 0x7f6a36496cc0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c534e1f98>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c64261940>, <tensorflow.python.keras.layers.core.Activation object at 0x7f6c640a2be0>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c640a2390>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f6c6cd73390>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c6c6e1f60>, <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f6c641fd86 ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 3, 3, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               524544
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 22,590,753
# Trainable params: 14,006,145
# Non-trainable params: 8,584,608
# _________________________________________________________________
# Epoch 1/50
# 93/93 [==============================] - 17s 135ms/step - loss: 0.6701 - acc: 0.7454 - val_loss: 0.6912 - val_acc: 0.6538
#
# Epoch 00001: val_loss did not improve from 0.40105
# Epoch 2/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.5137 - acc: 0.7506 - val_loss: 0.3963 - val_acc: 0.8300
#
# Epoch 00002: val_loss improved from 0.40105 to 0.39629, saving model to checkpoint.h5
# Epoch 3/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.4640 - acc: 0.7912 - val_loss: 0.4273 - val_acc: 0.8138
#
# Epoch 00003: val_loss did not improve from 0.39629
# Epoch 4/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4126 - acc: 0.8181 - val_loss: 0.4295 - val_acc: 0.7925
#
# Epoch 00004: val_loss did not improve from 0.39629
# Epoch 5/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.4504 - acc: 0.8117 - val_loss: 0.3762 - val_acc: 0.8313
#
# Epoch 00005: val_loss improved from 0.39629 to 0.37616, saving model to checkpoint.h5
# Epoch 6/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.4166 - acc: 0.8045 - val_loss: 0.3754 - val_acc: 0.8188
#
# Epoch 00006: val_loss improved from 0.37616 to 0.37536, saving model to checkpoint.h5
# Epoch 7/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.4295 - acc: 0.8153 - val_loss: 0.4867 - val_acc: 0.7875
#
# Epoch 00007: val_loss did not improve from 0.37536
# Epoch 8/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3945 - acc: 0.8368 - val_loss: 0.3090 - val_acc: 0.8850
#
# Epoch 00008: val_loss improved from 0.37536 to 0.30902, saving model to checkpoint.h5
# Epoch 9/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3346 - acc: 0.8732 - val_loss: 0.3784 - val_acc: 0.8487
#
# Epoch 00009: val_loss did not improve from 0.30902
# Epoch 10/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3919 - acc: 0.8283 - val_loss: 0.3559 - val_acc: 0.8637
#
# Epoch 00010: val_loss did not improve from 0.30902
# Epoch 11/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3588 - acc: 0.8405 - val_loss: 0.3119 - val_acc: 0.8725
#
# Epoch 00011: val_loss did not improve from 0.30902
# Epoch 12/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3478 - acc: 0.8616 - val_loss: 0.3149 - val_acc: 0.8687
#
# Epoch 00012: val_loss did not improve from 0.30902
# Epoch 13/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3503 - acc: 0.8431 - val_loss: 0.3316 - val_acc: 0.8687
#
# Epoch 00013: val_loss did not improve from 0.30902
# Epoch 14/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3545 - acc: 0.8581 - val_loss: 0.3219 - val_acc: 0.8687
#
# Epoch 00014: val_loss did not improve from 0.30902
# Epoch 15/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.3512 - acc: 0.8502 - val_loss: 0.3456 - val_acc: 0.8625
#
# Epoch 00015: val_loss did not improve from 0.30902
# Epoch 16/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3191 - acc: 0.8781 - val_loss: 0.3243 - val_acc: 0.8750
#
# Epoch 00016: val_loss did not improve from 0.30902
# Epoch 17/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3427 - acc: 0.8644 - val_loss: 0.3514 - val_acc: 0.8662
#
# Epoch 00017: val_loss did not improve from 0.30902
# Epoch 18/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3402 - acc: 0.8777 - val_loss: 0.3332 - val_acc: 0.8675
#
# Epoch 00018: val_loss did not improve from 0.30902
# Epoch 19/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3367 - acc: 0.8590 - val_loss: 0.4852 - val_acc: 0.7937
#
# Epoch 00019: val_loss did not improve from 0.30902
# Epoch 20/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3324 - acc: 0.8605 - val_loss: 0.3270 - val_acc: 0.8612
#
# Epoch 00020: val_loss did not improve from 0.30902
# Epoch 21/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3095 - acc: 0.8730 - val_loss: 0.3321 - val_acc: 0.8750
#
# Epoch 00021: val_loss did not improve from 0.30902
# Epoch 22/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3083 - acc: 0.8615 - val_loss: 0.3425 - val_acc: 0.8550
#
# Epoch 00022: val_loss did not improve from 0.30902
# Epoch 23/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3127 - acc: 0.8706 - val_loss: 0.3217 - val_acc: 0.8537
#
# Epoch 00023: val_loss did not improve from 0.30902
# Epoch 24/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3282 - acc: 0.8564 - val_loss: 0.3884 - val_acc: 0.8350
#
# Epoch 00024: val_loss did not improve from 0.30902
# Epoch 25/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3099 - acc: 0.8807 - val_loss: 0.2963 - val_acc: 0.8888
#
# Epoch 00025: val_loss improved from 0.30902 to 0.29631, saving model to checkpoint.h5
# Epoch 26/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3006 - acc: 0.8602 - val_loss: 0.3153 - val_acc: 0.8562
#
# Epoch 00026: val_loss did not improve from 0.29631
# Epoch 27/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2986 - acc: 0.8674 - val_loss: 0.2914 - val_acc: 0.8825
#
# Epoch 00027: val_loss improved from 0.29631 to 0.29143, saving model to checkpoint.h5
# Epoch 28/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3245 - acc: 0.8691 - val_loss: 0.3233 - val_acc: 0.8600
#
# Epoch 00028: val_loss did not improve from 0.29143
# Epoch 29/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2616 - acc: 0.8881 - val_loss: 0.3426 - val_acc: 0.8637
#
# Epoch 00029: val_loss did not improve from 0.29143
# Epoch 30/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2934 - acc: 0.8795 - val_loss: 0.4271 - val_acc: 0.8150
#
# Epoch 00030: val_loss did not improve from 0.29143
# Epoch 31/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3107 - acc: 0.8696 - val_loss: 0.3589 - val_acc: 0.8500
#
# Epoch 00031: val_loss did not improve from 0.29143
# Epoch 32/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2595 - acc: 0.8974 - val_loss: 0.3057 - val_acc: 0.8737
#
# Epoch 00032: val_loss did not improve from 0.29143
# Epoch 33/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.2803 - acc: 0.8853 - val_loss: 0.3454 - val_acc: 0.8687
#
# Epoch 00033: val_loss did not improve from 0.29143
# Epoch 34/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3088 - acc: 0.8649 - val_loss: 0.3298 - val_acc: 0.8900
#
# Epoch 00034: val_loss did not improve from 0.29143
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2985 - acc: 0.8738 - val_loss: 0.3444 - val_acc: 0.8737
#
# Epoch 00035: val_loss did not improve from 0.29143
# Epoch 36/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2944 - acc: 0.8770 - val_loss: 0.4567 - val_acc: 0.7725
#
# Epoch 00036: val_loss did not improve from 0.29143
# Epoch 37/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2914 - acc: 0.8704 - val_loss: 0.3174 - val_acc: 0.8712
#
# Epoch 00037: val_loss did not improve from 0.29143
# Epoch 38/50
# 93/93 [==============================] - 11s 120ms/step - loss: 0.3050 - acc: 0.8752 - val_loss: 0.3060 - val_acc: 0.8925
#
# Epoch 00038: val_loss did not improve from 0.29143
# Epoch 39/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.2787 - acc: 0.8863 - val_loss: 0.3702 - val_acc: 0.8888
#
# Epoch 00039: val_loss did not improve from 0.29143
# Epoch 40/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3008 - acc: 0.8764 - val_loss: 0.3527 - val_acc: 0.8637
#
# Epoch 00040: val_loss did not improve from 0.29143
# Epoch 41/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2914 - acc: 0.8640 - val_loss: 0.3999 - val_acc: 0.8200
#
# Epoch 00041: val_loss did not improve from 0.29143
# Epoch 42/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.2945 - acc: 0.8787 - val_loss: 0.3091 - val_acc: 0.8750
#
# Epoch 00042: val_loss did not improve from 0.29143
# Epoch 43/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.3112 - acc: 0.8749 - val_loss: 0.3415 - val_acc: 0.8587
#
# Epoch 00043: val_loss did not improve from 0.29143
# Epoch 44/50
# 93/93 [==============================] - 12s 124ms/step - loss: 0.2891 - acc: 0.8729 - val_loss: 0.3044 - val_acc: 0.8975
#
# Epoch 00044: val_loss did not improve from 0.29143
# Epoch 45/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2888 - acc: 0.8807 - val_loss: 0.3740 - val_acc: 0.8775
#
# Epoch 00045: val_loss did not improve from 0.29143
# Epoch 46/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.2732 - acc: 0.8975 - val_loss: 0.3581 - val_acc: 0.8763
#
# Epoch 00046: val_loss did not improve from 0.29143
# Epoch 47/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.3032 - acc: 0.8879 - val_loss: 0.3224 - val_acc: 0.8863
#
# Epoch 00047: val_loss did not improve from 0.29143
# done

# %%
plt_a = plot_acc(history)
#save & show plot
#plt_a.savefig(os.path.join(PLOTS_PATH, 'model_0_a.png'))
plt_a.show()

plt_b = plot_loss(history)
#save & show plot
#plt_b.savefig(os.path.join(PLOTS_PATH, 'model_0_b.png'))
plt_b.show()

# %%
test_loss, test_accuracy = model.evaluate(test_datagen.flow(test_images,
                                                            test_labels,
                                                            batch_size=BATCH_SIZE,
                                                            shuffle=False),
                                            steps=len(test_images) // BATCH_SIZE,
                                            callbacks=[GarbageCollectorCallback()]
)

print("\n---------------------------------")
print("Accuracy:", "%0.2f" % (test_accuracy*100), "%")
#print("Precision:", "%0.2f" % (test_precision*100), "%")
#print("Recall:", "%0.2f" % (test_recall*100), "%")
#print("AUC:", "%0.2f" % test_auc)
print("---------------------------------\n")

#print confusion matrix
classes = ["Masses", "Calcification"]
plt_0 = plot_confusion_matrix(model,
                      classes,
                      test_images,
                      test_labels,
                      title='Confusion matrix',
                      cmap=plt.cm.Blues)  

#save plot
#plt_0.savefig(os.path.join(PLOTS_PATH, 'model_0_CM.png'))
# Out:
# 16/16 [==============================] - 0s 24ms/step - loss: 0.2936 - acc: 0.8875
#
# ---------------------------------
# Accuracy: 88.75 %
# ---------------------------------
#
# Confusion Matrix
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.85      0.89       179
#          1.0       0.85      0.92      0.88       157
#
#     accuracy                           0.88       336
#    macro avg       0.88      0.89      0.88       336
# weighted avg       0.89      0.88      0.88       336

# %%
#ROC-AUC 
auc_1, plt_1 = plot_AUC(model, test_images, test_labels)
AUC_values.append(auc_1)

#save & show plot
#plt_1.savefig(os.path.join(PLOTS_PATH, 'model_1_AUC.png'))
plt_1.show()

# %%
models.save_model(model, os.path.join(MODEL_PATH, 'Inception_globalAvgPool_dense_256x5_last_3_blocks_trainable.h5'))

# %%
#free RAM 
del model
del conv_base
del history
# !rm 'checkpoint.h5'
